# %% [markdown]
# # Imports & Notes to Improve Workflow

# %%
# Setup matplotlib to plot inline (within the notebook)
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns;
import pandas as pd
import numpy as np
from datetime import datetime
# Libraries to aid in web scraping
import requests
import json
import re #regex
from bs4 import BeautifulSoup
import requests
import threading
from threading import Thread
#Notes for efficienccy:
#shift + tab when cursor is in arguments to bring up its documentation
#ex: pd.DataFrame(Shift+tab here)
#recall: Json == Dictionary
#to know functions of pandas:
#dir(pd)

# %% [markdown]
# # Reading The Data

# %%
# using pandas and read_csv()
acquis = pd.read_csv("datasets/startups/acquisitions.csv")
additions = pd.read_csv("datasets/startups/additions.csv")
companies = pd.read_csv("datasets/startups/companies.csv")
invests = pd.read_csv("datasets/startups/investments.csv")
rounds = pd.read_csv("datasets/startups/rounds.csv")
dfAll = [acquis, additions, companies, invests, rounds]

# %%
#shapes (rows x cols) of each dataset
for ele in dfAll:
    print(ele.shape)
# Out:
# (18969, 18)
# (2213, 4)
# (66368, 14)
# (168647, 18)
# (114949, 12)

# %% [markdown]
# # Samples of the datasets

# %%
acquis.sample(5).transpose()
# Out:
#                                              11988  \
# company_permalink       /organization/one-main-com
# company_name                          One Main.com
# company_category_list                  Curated Web
# company_country_code                           NaN
# company_state_code                             NaN
# company_region                                 NaN
# company_city                                   NaN
# acquirer_permalink         /organization/earthlink
# acquirer_name                            EarthLink
# acquirer_category_list        Curated Web|Software
# acquirer_country_code                          USA
# acquirer_state_code                             GA
# acquirer_region                            Atlanta
# acquirer_city                              Atlanta
# acquired_at                               9/1/2000
# acquired_month                             2000-09
# price_amount                           305000000.0
# price_currency_code                            USD
#
#                                                   18635  \
# company_permalink                   /organization/wonpy
# company_name                                      Wonpy
# company_category_list                          Startups
# company_country_code                                NaN
# company_state_code                                  NaN
# company_region                                      NaN
# company_city                                        NaN
# acquirer_permalink          /organization/cofounderslab
# acquirer_name                             CoFoundersLab
# acquirer_category_list  Curated Web|Internet|Networking
# acquirer_country_code                               USA
# acquirer_state_code                                  MD
# acquirer_region                        Washington, D.C.
# acquirer_city                                 Rockville
# acquired_at                                   1/30/2014
# acquired_month                                  2014-01
# price_amount                                        NaN
# price_currency_code                                 USD
#
#                                                                     2800   \
# company_permalink                                     /organization/c-sam
# company_name                                                        C-sam
# company_category_list   Marketplaces|Mobile Payments|Point of Sale|Sec...
# company_country_code                                                  USA
# company_state_code                                                     IL
# company_region                                                    Chicago
# company_city                                                      Chicago
# acquirer_permalink                               /organization/mastercard
# acquirer_name                                                  MasterCard
# acquirer_category_list  Business Services|Cloud Data Services|Informat...
# acquirer_country_code                                                 USA
# acquirer_state_code                                                    NY
# acquirer_region                                             New York City
# acquirer_city                                                    Purchase
# acquired_at                                                     2/24/2014
# acquired_month                                                    2014-02
# price_amount                                                          NaN
# price_currency_code                                                   USD
#
#                                                                     2210   \
# company_permalink            /organization/bioserve-biotechnologies-india
# company_name                             BioServe Biotechnologies (India)
# company_category_list                    Biotechnology|Health Diagnostics
# company_country_code                                                  IND
# company_state_code                                                      2
# company_region                                                  Hyderabad
# company_city                                                    Hyderabad
# acquirer_permalink                          /organization/cancer-genetics
# acquirer_name                                             Cancer Genetics
# acquirer_category_list  Biotechnology|Health and Wellness|Health Diagn...
# acquirer_country_code                                                 USA
# acquirer_state_code                                                    NJ
# acquirer_region                                                    Newark
# acquirer_city                                                  Rutherford
# acquired_at                                                     8/18/2014
# acquired_month                                                    2014-08
# price_amount                                                    1900000.0
# price_currency_code                                                   USD
#
#                                                         15813
# company_permalink       /organization/starband-communications
# company_name                          StarBand Communications
# company_category_list    Internet|Services|Telecommunications
# company_country_code                                      NaN
# company_state_code                                        NaN
# company_region                                            NaN
# company_city                                              NaN
# acquirer_permalink                     /organization/spacenet
# acquirer_name                                        Spacenet
# acquirer_category_list                            Web Hosting
# acquirer_country_code                                     USA
# acquirer_state_code                                        VA
# acquirer_region                              Washington, D.C.
# acquirer_city                                          Mclean
# acquired_at                                          3/1/2005
# acquired_month                                        2005-03
# price_amount                                              NaN
# price_currency_code                                       USD

# %%
additions.sample(5).transpose()
# Out:
#                       2173           1574      779                 1138  \
# content    Rounds: venture  Rounds: grant  Profiles  Profiles: Products
# month_str          2012-09        2010-03   2010-12             2014-11
# year_str              2012           2010      2010                2014
# value                  251             11      4542                1378
#
#               489
# content       IPOs
# month_str  1995-06
# year_str      1995
# value           14

# %%
companies.sample(5).transpose()
# Out:
#                                            1192                  42567  \
# permalink          /organization/acuitas-medical  /organization/paxvax
# name                             Acuitas Medical                PaxVax
# homepage_url       http://www.acuitasmedical.com     http://paxvax.com
# category_list                        Health Care         Biotechnology
# funding_total_usd                        1067275             129606472
# status                                 operating             operating
# country_code                                 GBR                   USA
# state_code                                    C9                    CA
# region                               GBR - Other           SF Bay Area
# city                                       Wales            Menlo Park
# funding_rounds                                 2                     7
# founded_at                                   NaN              1/1/2007
# first_funding_at                       7/22/2010             11/9/2009
# last_funding_at                        6/22/2011             7/28/2014
#
#                                  54001                               40317  \
# permalink          /organization/spool        /organization/ocp-collective
# name                             Spool                      OCP Collective
# homepage_url       http://getspool.com                                 NaN
# category_list                 Software  Medical|Service Providers|Services
# funding_total_usd              1000000                             6368603
# status                        acquired                           operating
# country_code                       USA                                 USA
# state_code                          CA                                  NY
# region                     SF Bay Area                       New York City
# city                     San Francisco                            New York
# funding_rounds                       1                                   5
# founded_at                         NaN                            1/1/2011
# first_funding_at              1/4/2012                           12/2/2011
# last_funding_at               1/4/2012                            6/1/2015
#
#                                                                43589
# permalink                                /organization/pigmata-media
# name                                                   Pigmata Media
# homepage_url                                  http://www.pigmata.com
# category_list      Interface Design|Internet Marketing|Software|W...
# funding_total_usd                                               5000
# status                                                        closed
# country_code                                                     PHL
# state_code                                                        D9
# region                                                        Manila
# city                                                          Makati
# funding_rounds                                                     1
# founded_at                                                 10/8/2007
# first_funding_at                                            1/1/2008
# last_funding_at                                             1/1/2008

# %%
invests.sample(5).transpose()
# Out:
#                                                                   72575   \
# company_permalink                         /organization/invoke-solutions
# company_name                                            Invoke Solutions
# company_category_list                                        Curated Web
# company_country_code                                                 USA
# company_state_code                                                    MA
# company_region                                                    Boston
# company_city                                                     Waltham
# investor_permalink                             /organization/bev-capital
# investor_name                                                BEV Capital
# investor_country_code                                                USA
# investor_state_code                                                   CT
# investor_region                                                 Hartford
# investor_city                                                   Stamford
# funding_round_permalink  /funding-round/b1da55486ca857ff36d2818cd7a831d2
# funding_round_type                                               venture
# funding_round_code                                                   NaN
# funded_at                                                      3/11/2008
# raised_amount_usd                                              7000000.0
#
#                                                                   37634   \
# company_permalink                                    /organization/cubie
# company_name                                                        Pal+
# company_category_list                                             Mobile
# company_country_code                                                 TWN
# company_state_code                                                     3
# company_region                                                    Taiwan
# company_city                                                      Taipei
# investor_permalink                         /organization/biglobe-capital
# investor_name                                            BIGLOBE Capital
# investor_country_code                                                JPN
# investor_state_code                                                   40
# investor_region                                                    Tokyo
# investor_city                                                      Tokyo
# funding_round_permalink  /funding-round/416e0fa6991c1e58c253ea99db4a1a58
# funding_round_type                                                  seed
# funding_round_code                                                   NaN
# funded_at                                                      11/2/2012
# raised_amount_usd                                              1100000.0
#
#                                                                     147607  \
# company_permalink                                     /organization/thrill
# company_name                                                        Thrill
# company_category_list    Curated Web|Emerging Markets|Mobile|Online Dat...
# company_country_code                                                   SGP
# company_state_code                                                     NaN
# company_region                                                   Singapore
# company_city                                                     Singapore
# investor_permalink                 /organization/social-discovery-ventures
# investor_name                                                   SDVentures
# investor_country_code                                                  USA
# investor_state_code                                                     NY
# investor_region                                              New York City
# investor_city                                                     New York
# funding_round_permalink    /funding-round/6a5045c8c073cda63f77cb5ffaed0c0c
# funding_round_type                                        convertible_note
# funding_round_code                                                     NaN
# funded_at                                                        5/22/2015
# raised_amount_usd                                                      NaN
#
#                                                                   44357   \
# company_permalink                           /organization/e-security-inc
# company_name                                                  e-Security
# company_category_list                                           Software
# company_country_code                                                 USA
# company_state_code                                                    FL
# company_region                                     Florida's Space Coast
# company_city                                                   Rockledge
# investor_permalink                         /organization/updata-partners
# investor_name                                            Updata Partners
# investor_country_code                                                USA
# investor_state_code                                                   DC
# investor_region                                         Washington, D.C.
# investor_city                                                 Washington
# funding_round_permalink  /funding-round/ee482125f7731845033ec7f7b346c820
# funding_round_type                                               venture
# funding_round_code                                                   NaN
# funded_at                                                      1/16/2001
# raised_amount_usd                                             13000000.0
#
#                                                                     147665
# company_permalink                                 /organization/thrivehive
# company_name                                                    ThriveHive
# company_category_list    Advertising|Email Marketing|Internet Marketing...
# company_country_code                                                   USA
# company_state_code                                                      MA
# company_region                                                      Boston
# company_city                                                     Cambridge
# investor_permalink                                   /person/mitch-roberts
# investor_name                                                Mitch Roberts
# investor_country_code                                                  NaN
# investor_state_code                                                    NaN
# investor_region                                                        NaN
# investor_city                                                          NaN
# funding_round_permalink    /funding-round/f216d52feec56e1d2231540232f934fe
# funding_round_type                                                    seed
# funding_round_code                                                     NaN
# funded_at                                                         7/9/2013
# raised_amount_usd                                                1500000.0

# %%
rounds.sample(5).transpose()
# Out:
#                                                                    85796  \
# company_permalink                  /organization/sankalpa-yoga-community
# company_name                                     Sankalpa Yoga Community
# company_category_list                                     Sporting Goods
# company_country_code                                                 USA
# company_state_code                                                    CA
# company_region                                               Los Angeles
# company_city                                                Santa Monica
# funding_round_permalink  /funding-round/52e8a5ba4e2895de5e21696708500f83
# funding_round_type                                                  seed
# funding_round_code                                                   NaN
# funded_at                                                     11/15/2014
# raised_amount_usd                                                    NaN
#
#                                                                    3490   \
# company_permalink                                 /organization/agilence
# company_name                                                    Agilence
# company_category_list     Enterprise Software|Retail Technology|Security
# company_country_code                                                 USA
# company_state_code                                                    NJ
# company_region                                                NJ - Other
# company_city                                                Mount Laurel
# funding_round_permalink  /funding-round/95c175ae5ca4495a43468d9a03407604
# funding_round_type                                               venture
# funding_round_code                                                     C
# funded_at                                                      5/11/2012
# raised_amount_usd                                              4227468.0
#
#                                                                    46136  \
# company_permalink                                   /organization/idubba
# company_name                                                      Chaska
# company_category_list                                              Games
# company_country_code                                                 IND
# company_state_code                                                    36
# company_region                                                 New Delhi
# company_city                                                       Noida
# funding_round_permalink  /funding-round/6ab0adf613afca2ecf234ddc8470a207
# funding_round_type                                                  seed
# funding_round_code                                                   NaN
# funded_at                                                       5/1/2015
# raised_amount_usd                                               200000.0
#
#                                                                    10799  \
# company_permalink                  /organization/bear-state-technologies
# company_name                                     Bear State Technologies
# company_category_list                                            Medical
# company_country_code                                                 USA
# company_state_code                                                    AR
# company_region                                               Little Rock
# company_city                                                 Little Rock
# funding_round_permalink  /funding-round/5b94500226593f077e01ab3d4dc8c4e7
# funding_round_type                                   equity_crowdfunding
# funding_round_code                                                   NaN
# funded_at                                                     12/11/2014
# raised_amount_usd                                                    NaN
#
#                                                                    297
# company_permalink                                     /organization/2can
# company_name                                                        2can
# company_category_list                                Credit Cards|Mobile
# company_country_code                                                 RUS
# company_state_code                                                    48
# company_region                                                    Moscow
# company_city                                                      Moscow
# funding_round_permalink  /funding-round/428bbe0a69f0568d8b064a31b6faff65
# funding_round_type                                               venture
# funding_round_code                                                   NaN
# funded_at                                                     11/18/2015
# raised_amount_usd                                              1300000.0

# %% [markdown]
# # Seeing the columns in the datasets

# %%
def datasetsCols(dfList, datasetNames, pad=""):
    """
    Takes dataframes and returns a dataframe (df) with each column having a df's
    column names. The "pad" is to make sure all lists of columns have 
    the same length padded out with "pad"
    Example
    pad = "XX", datasetNames = ["cars", "planes"]
    dfList = [carsDF, planesDF]
    returned data frame:
            cars            planes
    0       numOfWheels     numOfWings
    1       manufacturer    manufacturer
    2       make            XX
    """
    cols = []
    maxArrayLen = 0
    for i, df in enumerate(dfList):
        cols.append(df.columns.tolist())
        maxArrayLen = max(maxArrayLen, len(cols[i]))
    
    dictCsvs = {}
    for i, df in enumerate(dfList):
        cols[i] += [pad] * (maxArrayLen - len(cols[i])) #padding the lists to make them have equal lengths 
        dictCsvs.update({datasetNames[i] : cols[i]})

    return pd.DataFrame(dictCsvs)

# %%
lstCsvNames = ["acquisitions", "additions", "companies", "investments", "rounds"]

dfAllCols = datasetsCols(dfAll, lstCsvNames)
dfAllCols
# Out:
#               acquisitions  additions          companies  \
# 0        company_permalink    content          permalink
# 1             company_name  month_str               name
# 2    company_category_list   year_str       homepage_url
# 3     company_country_code      value      category_list
# 4       company_state_code             funding_total_usd
# 5           company_region                        status
# 6             company_city                  country_code
# 7       acquirer_permalink                    state_code
# 8            acquirer_name                        region
# 9   acquirer_category_list                          city
# 10   acquirer_country_code                funding_rounds
# 11     acquirer_state_code                    founded_at
# 12         acquirer_region              first_funding_at
# 13           acquirer_city               last_funding_at
# 14             acquired_at
# 15          acquired_month
# 16            price_amount
# 17     price_currency_code
#
#                 investments                   rounds
# 0         company_permalink        company_permalink
# 1              company_name             company_name
# 2     company_category_list    company_category_list
# 3      company_country_code     company_country_code
# 4        company_state_code       company_state_code
# 5            company_region           company_region
# 6              company_city             company_city
# 7        investor_permalink  funding_round_permalink
# 8             investor_name       funding_round_type
# 9     investor_country_code       funding_round_code
# 10      investor_state_code                funded_at
# 11          investor_region        raised_amount_usd
# 12            investor_city
# 13  funding_round_permalink
# 14       funding_round_type
# 15       funding_round_code
# 16                funded_at
# 17        raised_amount_usd

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# First, lets change the columns in the `companies` dataset <br>
# to be the similar to all other datasets: <br>
# (we're doing this in case we merge the datasets together, we want them to have the same column names)

# %%
companies.rename(columns = {'permalink' : 'company_permalink', 
                            'name' : 'company_name',
                            'category_list' : 'company_category_list',
                            'country_code' : 'company_country_code',
                            'state_code' : 'company_state_code',
                            'region' : 'company_region',
                            'city' : 'company_city'}, inplace = True)

# %%
dfAll[2] = companies
dfAllCols = datasetsCols(dfAll, lstCsvNames)
dfAllCols
# Out:
#               acquisitions  additions              companies  \
# 0        company_permalink    content      company_permalink
# 1             company_name  month_str           company_name
# 2    company_category_list   year_str           homepage_url
# 3     company_country_code      value  company_category_list
# 4       company_state_code                 funding_total_usd
# 5           company_region                            status
# 6             company_city              company_country_code
# 7       acquirer_permalink                company_state_code
# 8            acquirer_name                    company_region
# 9   acquirer_category_list                      company_city
# 10   acquirer_country_code                    funding_rounds
# 11     acquirer_state_code                        founded_at
# 12         acquirer_region                  first_funding_at
# 13           acquirer_city                   last_funding_at
# 14             acquired_at
# 15          acquired_month
# 16            price_amount
# 17     price_currency_code
#
#                 investments                   rounds
# 0         company_permalink        company_permalink
# 1              company_name             company_name
# 2     company_category_list    company_category_list
# 3      company_country_code     company_country_code
# 4        company_state_code       company_state_code
# 5            company_region           company_region
# 6              company_city             company_city
# 7        investor_permalink  funding_round_permalink
# 8             investor_name       funding_round_type
# 9     investor_country_code       funding_round_code
# 10      investor_state_code                funded_at
# 11          investor_region        raised_amount_usd
# 12            investor_city
# 13  funding_round_permalink
# 14       funding_round_type
# 15       funding_round_code
# 16                funded_at
# 17        raised_amount_usd

# %% [markdown]
# Let's start by analyzing `additions` dataset, as it has unusual format of columns

# %% [markdown]
# ## Removing "additions" Dataset

# %%
additions.sample(5)
# Out:
#                      content month_str  year_str  value
# 949         Profiles: People   2007-10      2007    287
# 1580           Rounds: grant   2010-09      2010     14
# 421                     IPOs   1989-09      1989      1
# 1821  Rounds: private_equity   2013-12      2013     37
# 1059      Profiles: Products   2008-04      2008    195

# %%
additions["content"].unique()
# Out:
# array(['Acquisitions', 'IPOs', 'Profiles', 'Profiles: Organizations',
#        'Profiles: People', 'Profiles: Products', 'Rounds',
#        'Rounds: angel', 'Rounds: convertible_note',
#        'Rounds: debt_financing', 'Rounds: equity_crowdfunding',
#        'Rounds: grant', 'Rounds: non_equity_assistance',
#        'Rounds: post_ipo_debt', 'Rounds: post_ipo_equity',
#        'Rounds: private_equity', 'Rounds: product_crowdfunding',
#        'Rounds: secondary_market', 'Rounds: seed', 'Rounds: undisclosed',
#        'Rounds: venture'], dtype=object)

# %%
dfAllCols
# Out:
#               acquisitions  additions              companies  \
# 0        company_permalink    content      company_permalink
# 1             company_name  month_str           company_name
# 2    company_category_list   year_str           homepage_url
# 3     company_country_code      value  company_category_list
# 4       company_state_code                 funding_total_usd
# 5           company_region                            status
# 6             company_city              company_country_code
# 7       acquirer_permalink                company_state_code
# 8            acquirer_name                    company_region
# 9   acquirer_category_list                      company_city
# 10   acquirer_country_code                    funding_rounds
# 11     acquirer_state_code                        founded_at
# 12         acquirer_region                  first_funding_at
# 13           acquirer_city                   last_funding_at
# 14             acquired_at
# 15          acquired_month
# 16            price_amount
# 17     price_currency_code
#
#                 investments                   rounds
# 0         company_permalink        company_permalink
# 1              company_name             company_name
# 2     company_category_list    company_category_list
# 3      company_country_code     company_country_code
# 4        company_state_code       company_state_code
# 5            company_region           company_region
# 6              company_city             company_city
# 7        investor_permalink  funding_round_permalink
# 8             investor_name       funding_round_type
# 9     investor_country_code       funding_round_code
# 10      investor_state_code                funded_at
# 11          investor_region        raised_amount_usd
# 12            investor_city
# 13  funding_round_permalink
# 14       funding_round_type
# 15       funding_round_code
# 16                funded_at
# 17        raised_amount_usd

# %%
additions.shape
# Out:
# (2213, 4)

# %%
companies.shape, rounds.shape
# Out:
# ((66368, 14), (114949, 12))

# %% [markdown]
# So apparently there are no columns that could be used to join with the other datasets. <br>
# Furthermore, the "value" column is too vague to be useful. <br>
# Therefore, the "additions" dataset will be discarded.

# %%
dfAll.pop(1)
lstCsvNames.pop(1)
len(dfAll), lstCsvNames
# Out:
# (4, ['acquisitions', 'companies', 'investments', 'rounds'])

# %% [markdown]
# ## `rounds` Dataset

# %%
dfAllCols.iloc[:, -2:]
# Out:
#                 investments                   rounds
# 0         company_permalink        company_permalink
# 1              company_name             company_name
# 2     company_category_list    company_category_list
# 3      company_country_code     company_country_code
# 4        company_state_code       company_state_code
# 5            company_region           company_region
# 6              company_city             company_city
# 7        investor_permalink  funding_round_permalink
# 8             investor_name       funding_round_type
# 9     investor_country_code       funding_round_code
# 10      investor_state_code                funded_at
# 11          investor_region        raised_amount_usd
# 12            investor_city
# 13  funding_round_permalink
# 14       funding_round_type
# 15       funding_round_code
# 16                funded_at
# 17        raised_amount_usd

# %%
invests.shape, rounds.shape
# Out:
# ((168647, 18), (114949, 12))

# %%
invests.head()
# Out:
#                   company_permalink        company_name company_category_list  \
# 0             /organization/0-6-com             0-6.com           Curated Web
# 1    /organization/004-technologies    004 Technologies              Software
# 2  /organization/01games-technology  01Games Technology                 Games
# 3              /organization/0xdata              H2O.ai             Analytics
# 4              /organization/0xdata              H2O.ai             Analytics
#
#   company_country_code company_state_code         company_region  \
# 0                  CHN                 22                Beijing
# 1                  USA                 IL  Springfield, Illinois
# 2                  HKG                NaN              Hong Kong
# 3                  USA                 CA            SF Bay Area
# 4                  USA                 CA            SF Bay Area
#
#     company_city                    investor_permalink  \
# 0        Beijing     /organization/dt-capital-partners
# 1      Champaign       /organization/venturecapital-de
# 2      Hong Kong     /organization/cyberport-hong-kong
# 3  Mountain View             /organization/capital-one
# 4  Mountain View  /organization/nexus-venture-partners
#
#             investor_name investor_country_code investor_state_code  \
# 0     DT Capital Partners                   CHN                  23
# 1   VCDE Venture Partners                   DEU                   5
# 2     Cyberport Hong Kong                   HKG                 NaN
# 3             Capital One                   USA                  VA
# 4  Nexus Venture Partners                   USA                  CA
#
#     investor_region investor_city  \
# 0          Shanghai      Shanghai
# 1         Frankfurt     Frankfurt
# 2         Hong Kong     Hong Kong
# 3  Washington, D.C.        Mclean
# 4       SF Bay Area    Menlo Park
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 1  /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830            venture
# 2  /funding-round/7d53696f2b4f607a2f2a8cbb83d01839        undisclosed
# 3  /funding-round/3bb2ee4a2d89251a10aaa735b1180e44            venture
# 4  /funding-round/383a9bd2c04f7038bb543ccef5ba3eae               seed
#
#   funding_round_code  funded_at  raised_amount_usd
# 0                  A  3/19/2008          2000000.0
# 1                NaN  7/24/2014                NaN
# 2                NaN   7/1/2014            41250.0
# 3                  B  11/9/2015         20000000.0
# 4                NaN  5/22/2013          3000000.0

# %%
rounds.head()
# Out:
#                      company_permalink            company_name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2               /organization/-qounter                :Qounter
# 3  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 4                /organization/0-6-com                 0-6.com
#
#                                company_category_list company_country_code  \
# 0                                              Media                  IND
# 1  Application Platforms|Real Time|Social Network...                  USA
# 2  Application Platforms|Real Time|Social Network...                  USA
# 3                                  Apps|Games|Mobile                  NaN
# 4                                        Curated Web                  CHN
#
#   company_state_code company_region   company_city  \
# 0                 16         Mumbai         Mumbai
# 1                 DE     DE - Other  Delaware City
# 2                 DE     DE - Other  Delaware City
# 3                NaN            NaN            NaN
# 4                 22        Beijing        Beijing
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B    1/5/2015         10000000.0
# 1                  A  10/14/2014                NaN
# 2                NaN    3/1/2014           700000.0
# 3                  B   1/30/2014          3406878.0
# 4                  A   3/19/2008          2000000.0

# %%
len(invests["company_name"].unique()), len(rounds["company_name"].unique())
# Out:
# (44579, 66103)

# %% [markdown]
# Since there are companies in `rounds` dataset that are not in `investments` dataset, <br>
# therefore we should keep `rounds` dataset for further analysis.

# %% [markdown]
# # Data Cleaning (Cont.)

# %% [markdown]
# ## Checking All Missing Values

# %%
def datasetsNulls(dfList, datasetNames, nullCol="nulls_", pad=""):
    """
    Use this when you want to display a column of column names,
    then a column of the null values, and repeat that for each dataset.
    Returns a dataframe
    """
    cols = []
    nulls = []
    maxArrayLen = 0
    for i, df in enumerate(dfList):
        cols.append(df.columns.tolist())
        nulls.append(df.isnull().sum().tolist())
        maxArrayLen = max(maxArrayLen, len(cols[i]))
    
    dictCsvs = {}
    for i, df in enumerate(dfList):
        cols[i] += [pad] * (maxArrayLen - len(cols[i])) #padding the lists to make them have equal lengths 
        nulls[i] += [None] *  (maxArrayLen - len(nulls[i]))
        dictCsvs[datasetNames[i]] = cols[i]
        dictCsvs[nullCol + str(i+1)] = nulls[i]
    
    return pd.DataFrame(dictCsvs)

# %%
dfAllNulls = datasetsNulls(dfAll, lstCsvNames)
dfAllNulls
# Out:
#               acquisitions  nulls_1              companies  nulls_2  \
# 0        company_permalink        0      company_permalink      0.0
# 1             company_name        1           company_name      1.0
# 2    company_category_list     4984           homepage_url   5058.0
# 3     company_country_code     4669  company_category_list   3148.0
# 4       company_state_code     4949      funding_total_usd      0.0
# 5           company_region     4911                 status      0.0
# 6             company_city     4911   company_country_code   6958.0
# 7       acquirer_permalink        1     company_state_code   8547.0
# 8            acquirer_name        1         company_region   8030.0
# 9   acquirer_category_list     2389           company_city   8028.0
# 10   acquirer_country_code     1171         funding_rounds      0.0
# 11     acquirer_state_code     1436             founded_at  15221.0
# 12         acquirer_region     1360       first_funding_at     24.0
# 13           acquirer_city     1360        last_funding_at      0.0
# 14             acquired_at       13                             NaN
# 15          acquired_month       15                             NaN
# 16            price_amount    13957                             NaN
# 17     price_currency_code        7                             NaN
#
#                 investments  nulls_3                   rounds  nulls_4
# 0         company_permalink        0        company_permalink      0.0
# 1              company_name        1             company_name      1.0
# 2     company_category_list     3632    company_category_list   3410.0
# 3      company_country_code    10521     company_country_code   8678.0
# 4        company_state_code    13431       company_state_code  10946.0
# 5            company_region    12485           company_region  10167.0
# 6              company_city    12483             company_city  10164.0
# 7        investor_permalink       12  funding_round_permalink      0.0
# 8             investor_name       12       funding_round_type      0.0
# 9     investor_country_code    30939       funding_round_code  83809.0
# 10      investor_state_code    44739                funded_at      0.0
# 11          investor_region    43217        raised_amount_usd  19990.0
# 12            investor_city    32164                               NaN
# 13  funding_round_permalink        0                               NaN
# 14       funding_round_type        0                               NaN
# 15       funding_round_code    87585                               NaN
# 16                funded_at        0                               NaN
# 17        raised_amount_usd    21619                               NaN

# %% [markdown]
# ### `dropna()` for columns with few missing values

# %% [markdown]
# Notice that there is one row that doesn't contain a company name, <br>
# so let's validate that it is the same company across all datasets, <br>
# so we can remove it:

# %%
datasetsCols(dfAll, lstCsvNames)
# Out:
#               acquisitions              companies              investments  \
# 0        company_permalink      company_permalink        company_permalink
# 1             company_name           company_name             company_name
# 2    company_category_list           homepage_url    company_category_list
# 3     company_country_code  company_category_list     company_country_code
# 4       company_state_code      funding_total_usd       company_state_code
# 5           company_region                 status           company_region
# 6             company_city   company_country_code             company_city
# 7       acquirer_permalink     company_state_code       investor_permalink
# 8            acquirer_name         company_region            investor_name
# 9   acquirer_category_list           company_city    investor_country_code
# 10   acquirer_country_code         funding_rounds      investor_state_code
# 11     acquirer_state_code             founded_at          investor_region
# 12         acquirer_region       first_funding_at            investor_city
# 13           acquirer_city        last_funding_at  funding_round_permalink
# 14             acquired_at                              funding_round_type
# 15          acquired_month                              funding_round_code
# 16            price_amount                                       funded_at
# 17     price_currency_code                               raised_amount_usd
#
#                      rounds
# 0         company_permalink
# 1              company_name
# 2     company_category_list
# 3      company_country_code
# 4        company_state_code
# 5            company_region
# 6              company_city
# 7   funding_round_permalink
# 8        funding_round_type
# 9        funding_round_code
# 10                funded_at
# 11        raised_amount_usd
# 12
# 13
# 14
# 15
# 16
# 17

# %%
#company_permalink of each row that doesn't have a company name:
for df in dfAll:
    print(df[df['company_name'].isnull()]['company_permalink'].values)
# Out:
# ['mendatio"']
# ['/organization/tell-it-in']
# ['/organization/tell-it-in']
# ['/organization/tell-it-in']

# %% [markdown]
# So apparently, the `acquisitions` dataset has a different permalink that has no company name, <br>
# So we could remove these two companies, as the total number of companies are big enough to get the insight that we want.

# %% [markdown]
# `dfAllNulls` dataframe also shows that there are missing values for `acquirer_name` and `investor_name` <br>
# which can't be imputed, so we'll also remove them.

# %% [markdown]
# Finally, we'll remove the missing values for columns that have less than 100 `NaN`, <br>
# as they're small in comparison to their respective datasets:

# %%
# This syntax won't work, as it turns out, df[0] is a copy of a dataframe (eg: a copy of acquisitions, so they don't share the same reference)
#for df in dfAll:
#    nulls = df.isnull().sum()
#    cols = nulls[(nulls <= 100) & (nulls != 0)].index.tolist()
#    df.dropna(subset=cols, inplace=True)
#dfAllNulls = datasetsNulls(dfAll, lstCsvNames)
#dfAllNulls

# %%
nulls = acquis.isnull().sum()
cols = nulls[(nulls <= 100) & (nulls != 0)].index.tolist()
acquis.dropna(subset=cols, inplace=True)

nulls = companies.isnull().sum()
cols = nulls[(nulls <= 100) & (nulls != 0)].index.tolist()
companies.dropna(subset=cols, inplace=True)

nulls = invests.isnull().sum()
cols = nulls[(nulls <= 100) & (nulls != 0)].index.tolist()
invests.dropna(subset=cols, inplace=True)

nulls = rounds.isnull().sum()
cols = nulls[(nulls <= 100) & (nulls != 0)].index.tolist()
rounds.dropna(subset=cols, inplace=True)

# %%
dfAll = [acquis, companies, invests, rounds]
lstCsvNames = ["acquisitions", "companies", "investments", "rounds"]
dfAllNulls = datasetsNulls(dfAll, lstCsvNames)
dfAllNulls
# Out:
#               acquisitions  nulls_1              companies  nulls_2  \
# 0        company_permalink        0      company_permalink      0.0
# 1             company_name        0           company_name      0.0
# 2    company_category_list     4977           homepage_url   5058.0
# 3     company_country_code     4661  company_category_list   3147.0
# 4       company_state_code     4940      funding_total_usd      0.0
# 5           company_region     4902                 status      0.0
# 6             company_city     4902   company_country_code   6956.0
# 7       acquirer_permalink        0     company_state_code   8545.0
# 8            acquirer_name        0         company_region   8028.0
# 9   acquirer_category_list     2387           company_city   8026.0
# 10   acquirer_country_code     1168         funding_rounds      0.0
# 11     acquirer_state_code     1432             founded_at  15218.0
# 12         acquirer_region     1356       first_funding_at      0.0
# 13           acquirer_city     1356        last_funding_at      0.0
# 14             acquired_at        0                             NaN
# 15          acquired_month        0                             NaN
# 16            price_amount    13941                             NaN
# 17     price_currency_code        0                             NaN
#
#                 investments  nulls_3                   rounds  nulls_4
# 0         company_permalink        0        company_permalink      0.0
# 1              company_name        0             company_name      0.0
# 2     company_category_list     3632    company_category_list   3410.0
# 3      company_country_code    10521     company_country_code   8678.0
# 4        company_state_code    13431       company_state_code  10946.0
# 5            company_region    12485           company_region  10167.0
# 6              company_city    12483             company_city  10164.0
# 7        investor_permalink        0  funding_round_permalink      0.0
# 8             investor_name        0       funding_round_type      0.0
# 9     investor_country_code    30927       funding_round_code  83808.0
# 10      investor_state_code    44727                funded_at      0.0
# 11          investor_region    43205        raised_amount_usd  19990.0
# 12            investor_city    32152                               NaN
# 13  funding_round_permalink        0                               NaN
# 14       funding_round_type        0                               NaN
# 15       funding_round_code    87576                               NaN
# 16                funded_at        0                               NaN
# 17        raised_amount_usd    21619                               NaN

# %% [markdown]
# ## Converting & Imputing Dates

# %% [markdown]
# We are currently interested in 'founded_at', 'first_funding_at' and 'last_funding_at' columns. <br>
# Before doing operations on dates, they need to be converted first from 'Object' to 'DateTime'.

# %%
companies['founded_at'] =pd.to_datetime(companies['founded_at'], errors = 'coerce')
companies['first_funding_at'] =pd.to_datetime(companies['first_funding_at'], errors = 'coerce') 
#^^ 3 rows will not be converted succesfully and will become "NaN" (shown later)
companies['last_funding_at'] =pd.to_datetime(companies['last_funding_at'], errors = 'coerce')
companies.dtypes
# Out:
# company_permalink                object
# company_name                     object
# homepage_url                     object
# company_category_list            object
# funding_total_usd                object
# status                           object
# company_country_code             object
# company_state_code               object
# company_region                   object
# company_city                     object
# funding_rounds                    int64
# founded_at               datetime64[ns]
# first_funding_at         datetime64[ns]
# last_funding_at          datetime64[ns]
# dtype: object

# %% [markdown]
# After converting, we need to impute the missing values on the dates of when those companies where founded at. <br>
# So, this will be done by first creating a new column that calculates how long it took to get the first funding. <br>
# This will be done by subtracting the date of the founding from the date of the first funding. <br> Note that we will find some values in negative which indicate that some companies took funding before establishing it.

# %%
companies['time_before_first_fund'] = companies['first_funding_at'] - companies['founded_at']
companies['time_before_first_fund']
# Out:
# 0             NaT
# 1       -187 days
# 2             NaT
# 3        443 days
# 4       1665 days
#            ...
# 66363         NaT
# 66364   -194 days
# 66365   1308 days
# 66366    365 days
# 66367         NaT
# Name: time_before_first_fund, Length: 66343, dtype: timedelta64[ns]

# %% [markdown]
# Now we need to calculate the mean of the time before the first funding and impute the missing values with this average. Notice that the average is 1370 days which is around 3.7 years which means there must be some outliers that messed up the average.

# %%
companies['time_before_first_fund'].mean()
# Out:
# Timedelta('1370 days 03:49:18.015610624')

# %% [markdown]
# Therefore, we will need to visualize those outliers and maybe if they are causing inaccuracy in the data, we can drop them.

# %%
plt.scatter(companies['first_funding_at'], companies['founded_at'], s = 20, alpha = 0.5)
plt.xlabel('first_funding_at')
plt.ylabel('founded_at');

# %% [markdown]
# We Noticed that there are some outliers than can be removed from the dataset <br>
# so we will create a temporary dataframe that will contain the outliers so we can drop them later on. <br>The first outliers that we want to deduct are the ones at the left of the center.

# %%
from datetime import datetime
tempdf = companies.copy()
tempdf = tempdf[
    (tempdf.first_funding_at <= datetime.strptime("01/01/1983", "%d/%m/%Y")) 
    & 
    (tempdf.founded_at <= datetime.strptime("01/01/2000", "%d/%m/%Y"))
]
dropseries = tempdf.copy()
dropseries
# Out:
#                         company_permalink          company_name  \
# 744                /organization/abo-data              ABO Data
# 3728                  /organization/apple                 Apple
# 8786   /organization/buena-park-locksmith  Buena Park Locksmith
# 26908                  /organization/ikro                  Ikro
# 28378             /organization/intercomp             Intercomp
# 36251              /organization/mitrol-2                Mitrol
#
#                               homepage_url  \
# 744                      http://PLATONE.IO
# 3728                  http://www.apple.com
# 8786   http://www.BuenaParkLocksmithCA.com
# 26908              http://www.ikro.com.br/
# 28378                                  NaN
# 36251                                  NaN
#
#                                    company_category_list funding_total_usd  \
# 744                                  Enterprise Software           1000000
# 3728   Computers|Consumer Electronics|Electronics|Har...            250000
# 8786                                    Local Businesses                 -
# 26908            Automotive|Heavy Industry|Manufacturing            724000
# 28378                                                NaN            549000
# 36251                                                NaN           9000000
#
#           status company_country_code company_state_code company_region  \
# 744    operating                  USA                 TX     TX - Other
# 3728         ipo                  USA                 CA    SF Bay Area
# 8786   operating                  USA                 CA        Anaheim
# 26908     closed                  BRA                 23    BRA - Other
# 28378     closed                  NaN                NaN            NaN
# 36251     closed                  NaN                NaN            NaN
#
#       company_city  funding_rounds founded_at first_funding_at  \
# 744          Italy               1 1979-01-01       1979-01-01
# 3728     Cupertino               1 1976-04-01       1977-05-15
# 8786    Buena Park               1 1974-11-20       1973-04-15
# 26908       Canoas               1 1947-01-01       1982-06-01
# 28378          NaN               1 1968-01-01       1971-01-01
# 36251          NaN               1 1971-01-01       1980-01-01
#
#       last_funding_at time_before_first_fund
# 744        1979-01-01                 0 days
# 3728       1977-05-15               409 days
# 8786       1973-04-15              -584 days
# 26908      1982-06-01             12935 days
# 28378      1971-01-01              1096 days
# 36251      1980-01-01              3287 days

# %% [markdown]
# Plotting the outliers on a separate graph:

# %%
plt.scatter(tempdf['first_funding_at'], tempdf['founded_at'], s = 20)
plt.xlabel('first_funding_at')
plt.ylabel('founded_at')
# Out:
# Text(0, 0.5, 'founded_at')

# %% [markdown]
# Now we will determine the outliers that are the bottom of the center from the original graph.

# %%
tempdf = companies.copy()
tempdf = tempdf[(tempdf.first_funding_at < datetime.strptime("01/01/2005", "%d/%m/%Y"))& (tempdf.founded_at <= datetime.strptime("01/01/1900", "%d/%m/%Y"))]
tempdf
# Out:
#                                        company_permalink  \
# 4563   /organization/asia-pacific-marine-container-lines
# 4748                               /organization/athenix
# 8240                       /organization/boylan-bottling
# 12370                /organization/coleman-natural-foods
# 13513  /organization/counterpane-internet-security-in...
# 20690                      /organization/fkk-corporation
# 47744               /organization/remington-arms-company
# 49957               /organization/scottish-newcastle-plc
#
#                               company_name                     homepage_url  \
# 4563   Asia Pacific Marine Container Lines     http://AsiaPacificMarine.com
# 4748                               Athenix       http://www.athenixcorp.com
# 8240                       Boylan Bottling  https://www.boylanbottling.com/
# 12370                Coleman Natural Foods   http://www.colemannatural.com/
# 13513        Counterpane Internet Security       http://www.counterpane.com
# 20690                      FKK Corporation   http://www.fkk-corporation.com
# 47744               Remington Arms Company        http://www.remington.com/
# 49957             Scottish & Newcastle PLC                              NaN
#
#                                    company_category_list funding_total_usd  \
# 4563   Logistics Company|Shipping|Shipping Broker Ind...                 -
# 4748                                       Biotechnology          43500000
# 8240                                                 NaN                 -
# 12370                                        Hospitality           9000000
# 13513       Risk Management|Sales and Marketing|Security          20000000
# 20690                                Hardware + Software                 -
# 47744              Manufacturing|Outdoors|Sporting Goods          30000000
# 49957                                            Brewing           4200000
#
#           status company_country_code company_state_code company_region  \
# 4563      closed                  CAN                 BC      Vancouver
# 4748    acquired                  USA                 NC        Raleigh
# 8240      closed                  USA                 NY  New York City
# 12370  operating                  USA                 NC      Asheville
# 13513   acquired                  USA                 CA    SF Bay Area
# 20690  operating                  JPN                 22          Kyoto
# 47744  operating                  USA                 NC     Greensboro
# 49957  operating                  GBR                 U8      Edinburgh
#
#         company_city  funding_rounds founded_at first_funding_at  \
# 4563       Vancouver               1 1870-01-05       1998-09-01
# 4748         Raleigh               4 1863-01-01       2001-09-10
# 8240        New York               1 1891-01-01       2003-09-10
# 12370  Mountain Home               1 1875-01-01       2003-08-20
# 13513      Cupertino               1 1888-01-01       2003-01-14
# 20690      Kyoto-shi               1 1854-02-01       1995-01-01
# 47744        Madison               1 1816-01-01       2003-01-10
# 49957      Edinburgh               1 1749-01-01       2003-10-10
#
#       last_funding_at time_before_first_fund
# 4563       1998-09-01             46990 days
# 4748       2008-07-23             50656 days
# 8240       2003-09-10             41159 days
# 12370      2003-08-20             46982 days
# 13513      2003-01-14             42016 days
# 20690      1995-01-01             51468 days
# 47744      2003-01-10             68310 days
# 49957      2003-10-10             93053 days

# %% [markdown]
# Plotting the outliers on a separate graph:

# %%
plt.scatter(tempdf['first_funding_at'], tempdf['founded_at'], s = 20)
plt.xlabel('first_funding_at')
plt.ylabel('founded_at')
# Out:
# Text(0, 0.5, 'founded_at')

# %% [markdown]
# Now we will concatenate the newly discovered outliers to the ones from before

# %%
dropseries = pd.concat([dropseries, tempdf])
dropseries
# Out:
#                                        company_permalink  \
# 744                               /organization/abo-data
# 3728                                 /organization/apple
# 8786                  /organization/buena-park-locksmith
# 26908                                 /organization/ikro
# 28378                            /organization/intercomp
# 36251                             /organization/mitrol-2
# 4563   /organization/asia-pacific-marine-container-lines
# 4748                               /organization/athenix
# 8240                       /organization/boylan-bottling
# 12370                /organization/coleman-natural-foods
# 13513  /organization/counterpane-internet-security-in...
# 20690                      /organization/fkk-corporation
# 47744               /organization/remington-arms-company
# 49957               /organization/scottish-newcastle-plc
#
#                               company_name  \
# 744                               ABO Data
# 3728                                 Apple
# 8786                  Buena Park Locksmith
# 26908                                 Ikro
# 28378                            Intercomp
# 36251                               Mitrol
# 4563   Asia Pacific Marine Container Lines
# 4748                               Athenix
# 8240                       Boylan Bottling
# 12370                Coleman Natural Foods
# 13513        Counterpane Internet Security
# 20690                      FKK Corporation
# 47744               Remington Arms Company
# 49957             Scottish & Newcastle PLC
#
#                               homepage_url  \
# 744                      http://PLATONE.IO
# 3728                  http://www.apple.com
# 8786   http://www.BuenaParkLocksmithCA.com
# 26908              http://www.ikro.com.br/
# 28378                                  NaN
# 36251                                  NaN
# 4563          http://AsiaPacificMarine.com
# 4748            http://www.athenixcorp.com
# 8240       https://www.boylanbottling.com/
# 12370       http://www.colemannatural.com/
# 13513           http://www.counterpane.com
# 20690       http://www.fkk-corporation.com
# 47744            http://www.remington.com/
# 49957                                  NaN
#
#                                    company_category_list funding_total_usd  \
# 744                                  Enterprise Software           1000000
# 3728   Computers|Consumer Electronics|Electronics|Har...            250000
# 8786                                    Local Businesses                 -
# 26908            Automotive|Heavy Industry|Manufacturing            724000
# 28378                                                NaN            549000
# 36251                                                NaN           9000000
# 4563   Logistics Company|Shipping|Shipping Broker Ind...                 -
# 4748                                       Biotechnology          43500000
# 8240                                                 NaN                 -
# 12370                                        Hospitality           9000000
# 13513       Risk Management|Sales and Marketing|Security          20000000
# 20690                                Hardware + Software                 -
# 47744              Manufacturing|Outdoors|Sporting Goods          30000000
# 49957                                            Brewing           4200000
#
#           status company_country_code company_state_code company_region  \
# 744    operating                  USA                 TX     TX - Other
# 3728         ipo                  USA                 CA    SF Bay Area
# 8786   operating                  USA                 CA        Anaheim
# 26908     closed                  BRA                 23    BRA - Other
# 28378     closed                  NaN                NaN            NaN
# 36251     closed                  NaN                NaN            NaN
# 4563      closed                  CAN                 BC      Vancouver
# 4748    acquired                  USA                 NC        Raleigh
# 8240      closed                  USA                 NY  New York City
# 12370  operating                  USA                 NC      Asheville
# 13513   acquired                  USA                 CA    SF Bay Area
# 20690  operating                  JPN                 22          Kyoto
# 47744  operating                  USA                 NC     Greensboro
# 49957  operating                  GBR                 U8      Edinburgh
#
#         company_city  funding_rounds founded_at first_funding_at  \
# 744            Italy               1 1979-01-01       1979-01-01
# 3728       Cupertino               1 1976-04-01       1977-05-15
# 8786      Buena Park               1 1974-11-20       1973-04-15
# 26908         Canoas               1 1947-01-01       1982-06-01
# 28378            NaN               1 1968-01-01       1971-01-01
# 36251            NaN               1 1971-01-01       1980-01-01
# 4563       Vancouver               1 1870-01-05       1998-09-01
# 4748         Raleigh               4 1863-01-01       2001-09-10
# 8240        New York               1 1891-01-01       2003-09-10
# 12370  Mountain Home               1 1875-01-01       2003-08-20
# 13513      Cupertino               1 1888-01-01       2003-01-14
# 20690      Kyoto-shi               1 1854-02-01       1995-01-01
# 47744        Madison               1 1816-01-01       2003-01-10
# 49957      Edinburgh               1 1749-01-01       2003-10-10
#
#       last_funding_at time_before_first_fund
# 744        1979-01-01                 0 days
# 3728       1977-05-15               409 days
# 8786       1973-04-15              -584 days
# 26908      1982-06-01             12935 days
# 28378      1971-01-01              1096 days
# 36251      1980-01-01              3287 days
# 4563       1998-09-01             46990 days
# 4748       2008-07-23             50656 days
# 8240       2003-09-10             41159 days
# 12370      2003-08-20             46982 days
# 13513      2003-01-14             42016 days
# 20690      1995-01-01             51468 days
# 47744      2003-01-10             68310 days
# 49957      2003-10-10             93053 days

# %% [markdown]
# Finally, we will deduct the outliers that are the top right corner

# %%
tempdf = companies.copy()
tempdf = tempdf[(tempdf.first_funding_at > datetime.strptime("01/01/2010", "%d/%m/%Y"))& (tempdf.founded_at >= datetime.strptime("01/01/2030", "%d/%m/%Y"))]
tempdf
# Out:
#                 company_permalink  company_name             homepage_url  \
# 16681  /organization/dugoutfc-ltd  DugoutFC Ltd  http://www.dugoutfc.com
# 32736      /organization/livamp-2        LIVAMP    http://www.livamp.com
# 53396         /organization/soply         Soply       https://soply.com/
#
#                                 company_category_list funding_total_usd  \
# 16681                                  Fantasy Sports            100000
# 32736                       Entertainment|Music|Video            300000
# 53396  Creative Industries|Digital Media|Marketplaces            150000
#
#           status company_country_code company_state_code company_region  \
# 16681  operating                  NaN                NaN            NaN
# 32736     closed                  NaN                NaN            NaN
# 53396  operating                  GBR                 H9         London
#
#       company_city  funding_rounds founded_at first_funding_at  \
# 16681          NaN               1 2105-02-17       2015-01-01
# 32736          NaN               1 2041-09-21       2015-08-31
# 53396       London               1 2104-01-01       2013-07-01
#
#       last_funding_at time_before_first_fund
# 16681      2015-01-01            -32919 days
# 32736      2015-08-31             -9518 days
# 53396      2013-07-01            -33055 days

# %% [markdown]
# Visualizing the outliers:

# %%
from datetime import date
plt.scatter(tempdf['first_funding_at'], tempdf['founded_at'].dt.year, s = 40, marker='x', color='r') # 's' == marker size
plt.xlabel('first_funding_at')
plt.ylabel('founded_at')
plt.xticks(['2013-07-01', '2015-01-01', '2015-08-31'])
plt.yticks(range(2010, 2110, 10));
plt.axhline(date.today().year, color='b', linestyle='--')
plt.figtext(x=.92, y=.21, s='current date')
# Out:
# Text(0.92, 0.21, 'current date')

# %% [markdown]
# Concatinating the outliers on the rest:

# %%
dropseries = pd.concat([dropseries, tempdf])
dropseries
# Out:
#                                        company_permalink  \
# 744                               /organization/abo-data
# 3728                                 /organization/apple
# 8786                  /organization/buena-park-locksmith
# 26908                                 /organization/ikro
# 28378                            /organization/intercomp
# 36251                             /organization/mitrol-2
# 4563   /organization/asia-pacific-marine-container-lines
# 4748                               /organization/athenix
# 8240                       /organization/boylan-bottling
# 12370                /organization/coleman-natural-foods
# 13513  /organization/counterpane-internet-security-in...
# 20690                      /organization/fkk-corporation
# 47744               /organization/remington-arms-company
# 49957               /organization/scottish-newcastle-plc
# 16681                         /organization/dugoutfc-ltd
# 32736                             /organization/livamp-2
# 53396                                /organization/soply
#
#                               company_name  \
# 744                               ABO Data
# 3728                                 Apple
# 8786                  Buena Park Locksmith
# 26908                                 Ikro
# 28378                            Intercomp
# 36251                               Mitrol
# 4563   Asia Pacific Marine Container Lines
# 4748                               Athenix
# 8240                       Boylan Bottling
# 12370                Coleman Natural Foods
# 13513        Counterpane Internet Security
# 20690                      FKK Corporation
# 47744               Remington Arms Company
# 49957             Scottish & Newcastle PLC
# 16681                         DugoutFC Ltd
# 32736                               LIVAMP
# 53396                                Soply
#
#                               homepage_url  \
# 744                      http://PLATONE.IO
# 3728                  http://www.apple.com
# 8786   http://www.BuenaParkLocksmithCA.com
# 26908              http://www.ikro.com.br/
# 28378                                  NaN
# 36251                                  NaN
# 4563          http://AsiaPacificMarine.com
# 4748            http://www.athenixcorp.com
# 8240       https://www.boylanbottling.com/
# 12370       http://www.colemannatural.com/
# 13513           http://www.counterpane.com
# 20690       http://www.fkk-corporation.com
# 47744            http://www.remington.com/
# 49957                                  NaN
# 16681              http://www.dugoutfc.com
# 32736                http://www.livamp.com
# 53396                   https://soply.com/
#
#                                    company_category_list funding_total_usd  \
# 744                                  Enterprise Software           1000000
# 3728   Computers|Consumer Electronics|Electronics|Har...            250000
# 8786                                    Local Businesses                 -
# 26908            Automotive|Heavy Industry|Manufacturing            724000
# 28378                                                NaN            549000
# 36251                                                NaN           9000000
# 4563   Logistics Company|Shipping|Shipping Broker Ind...                 -
# 4748                                       Biotechnology          43500000
# 8240                                                 NaN                 -
# 12370                                        Hospitality           9000000
# 13513       Risk Management|Sales and Marketing|Security          20000000
# 20690                                Hardware + Software                 -
# 47744              Manufacturing|Outdoors|Sporting Goods          30000000
# 49957                                            Brewing           4200000
# 16681                                     Fantasy Sports            100000
# 32736                          Entertainment|Music|Video            300000
# 53396     Creative Industries|Digital Media|Marketplaces            150000
#
#           status company_country_code company_state_code company_region  \
# 744    operating                  USA                 TX     TX - Other
# 3728         ipo                  USA                 CA    SF Bay Area
# 8786   operating                  USA                 CA        Anaheim
# 26908     closed                  BRA                 23    BRA - Other
# 28378     closed                  NaN                NaN            NaN
# 36251     closed                  NaN                NaN            NaN
# 4563      closed                  CAN                 BC      Vancouver
# 4748    acquired                  USA                 NC        Raleigh
# 8240      closed                  USA                 NY  New York City
# 12370  operating                  USA                 NC      Asheville
# 13513   acquired                  USA                 CA    SF Bay Area
# 20690  operating                  JPN                 22          Kyoto
# 47744  operating                  USA                 NC     Greensboro
# 49957  operating                  GBR                 U8      Edinburgh
# 16681  operating                  NaN                NaN            NaN
# 32736     closed                  NaN                NaN            NaN
# 53396  operating                  GBR                 H9         London
#
#         company_city  funding_rounds founded_at first_funding_at  \
# 744            Italy               1 1979-01-01       1979-01-01
# 3728       Cupertino               1 1976-04-01       1977-05-15
# 8786      Buena Park               1 1974-11-20       1973-04-15
# 26908         Canoas               1 1947-01-01       1982-06-01
# 28378            NaN               1 1968-01-01       1971-01-01
# 36251            NaN               1 1971-01-01       1980-01-01
# 4563       Vancouver               1 1870-01-05       1998-09-01
# 4748         Raleigh               4 1863-01-01       2001-09-10
# 8240        New York               1 1891-01-01       2003-09-10
# 12370  Mountain Home               1 1875-01-01       2003-08-20
# 13513      Cupertino               1 1888-01-01       2003-01-14
# 20690      Kyoto-shi               1 1854-02-01       1995-01-01
# 47744        Madison               1 1816-01-01       2003-01-10
# 49957      Edinburgh               1 1749-01-01       2003-10-10
# 16681            NaN               1 2105-02-17       2015-01-01
# 32736            NaN               1 2041-09-21       2015-08-31
# 53396         London               1 2104-01-01       2013-07-01
#
#       last_funding_at time_before_first_fund
# 744        1979-01-01                 0 days
# 3728       1977-05-15               409 days
# 8786       1973-04-15              -584 days
# 26908      1982-06-01             12935 days
# 28378      1971-01-01              1096 days
# 36251      1980-01-01              3287 days
# 4563       1998-09-01             46990 days
# 4748       2008-07-23             50656 days
# 8240       2003-09-10             41159 days
# 12370      2003-08-20             46982 days
# 13513      2003-01-14             42016 days
# 20690      1995-01-01             51468 days
# 47744      2003-01-10             68310 days
# 49957      2003-10-10             93053 days
# 16681      2015-01-01            -32919 days
# 32736      2015-08-31             -9518 days
# 53396      2013-07-01            -33055 days

# %% [markdown]
# Now, we can drop all of the outliers that have been detected.

# %%
list = dropseries.index
companies = companies.drop(list)
#companies['time_before_first_fund'].sort_values(ascending=False)

# %% [markdown]
# Plotting the graph once more after cleaning:

# %%
plt.scatter(companies['first_funding_at'], companies['founded_at'], s = 20, alpha=0.5)
plt.xlabel('first_funding_at')
plt.ylabel('founded_at')
# Out:
# Text(0, 0.5, 'founded_at')

# %% [markdown]
# Now, we can calculate the mean. Notice that there were not much of a difference but deducting the outliers helped keeping the data realistic because some dates were 2090, 2100, etc. which is unrealistic.

# %%
companies['time_before_first_fund'].mean()
# Out:
# Timedelta('1363 days 03:13:16.759422320')

# %% [markdown]
# Filling the missing values with the new mean:

# %%
companies['time_before_first_fund'].fillna(companies['time_before_first_fund'].mean(), inplace = True)
companies['time_before_first_fund']
# Out:
# 0       1363 days 03:13:16.759422320
# 1                -187 days +00:00:00
# 2       1363 days 03:13:16.759422320
# 3                  443 days 00:00:00
# 4                 1665 days 00:00:00
#                     ...
# 66363   1363 days 03:13:16.759422320
# 66364            -194 days +00:00:00
# 66365             1308 days 00:00:00
# 66366              365 days 00:00:00
# 66367   1363 days 03:13:16.759422320
# Name: time_before_first_fund, Length: 66326, dtype: timedelta64[ns]

# %% [markdown]
# After calculating the mean and filling the nulls with it, now we can impute the missing dates in the 'founded_at' column by subtracting the time before first funding from the first funding date.

# %%
companies['founded_at'].fillna(companies['first_funding_at'] - companies['time_before_first_fund'], inplace = True)
companies['founded_at']
# Out:
# 0       2011-04-12 20:46:43.240577680
# 1       2014-09-04 00:00:00.000000000
# 2       2010-05-07 20:46:43.240577680
# 3       2007-01-01 00:00:00.000000000
# 4       2010-01-01 00:00:00.000000000
#                      ...
# 66363   2008-07-07 20:46:43.240577680
# 66364   2012-05-13 00:00:00.000000000
# 66365   2011-01-01 00:00:00.000000000
# 66366   2014-01-01 00:00:00.000000000
# 66367   2010-01-06 20:46:43.240577680
# Name: founded_at, Length: 66326, dtype: datetime64[ns]

# %% [markdown]
# Converting 'aquired_at' of the acquisitons dataset from Object to date:

# %%
acquis['acquired_at'] =pd.to_datetime(acquis['acquired_at'], errors = 'coerce')
acquis.dtypes
# Out:
# company_permalink                 object
# company_name                      object
# company_category_list             object
# company_country_code              object
# company_state_code                object
# company_region                    object
# company_city                      object
# acquirer_permalink                object
# acquirer_name                     object
# acquirer_category_list            object
# acquirer_country_code             object
# acquirer_state_code               object
# acquirer_region                   object
# acquirer_city                     object
# acquired_at               datetime64[ns]
# acquired_month                    object
# price_amount                     float64
# price_currency_code               object
# dtype: object

# %% [markdown]
# Converting 'funded_at' of the investments dataset from Object to date:

# %%
invests['funded_at'] =pd.to_datetime(invests['funded_at'], errors = 'coerce')
invests.dtypes
# Out:
# company_permalink                  object
# company_name                       object
# company_category_list              object
# company_country_code               object
# company_state_code                 object
# company_region                     object
# company_city                       object
# investor_permalink                 object
# investor_name                      object
# investor_country_code              object
# investor_state_code                object
# investor_region                    object
# investor_city                      object
# funding_round_permalink            object
# funding_round_type                 object
# funding_round_code                 object
# funded_at                  datetime64[ns]
# raised_amount_usd                 float64
# dtype: object

# %% [markdown]
# Converting 'funded_at' of the rounds dataset from Object to date:

# %%
rounds['funded_at'] =pd.to_datetime(rounds['funded_at'], errors = 'coerce')
rounds.dtypes
# Out:
# company_permalink                  object
# company_name                       object
# company_category_list              object
# company_country_code               object
# company_state_code                 object
# company_region                     object
# company_city                       object
# funding_round_permalink            object
# funding_round_type                 object
# funding_round_code                 object
# funded_at                  datetime64[ns]
# raised_amount_usd                 float64
# dtype: object

# %% [markdown]
# ## Imputing Categories

# %% [markdown]
# Regarding the category list in the five datasets, since we don't have any indicator on deducing the null values in this column, we will fill the nulls with "missing". With samples, it's provided that the same rows (companies) that their category is missing in one dataset, are the same rows in the others so even merging the datasets will not be helpful.

# %%
companies['company_category_list'].fillna('missing', inplace=True)
acquis['company_category_list'].fillna('missing', inplace=True)
acquis['acquirer_category_list'].fillna('missing', inplace=True)
invests['company_category_list'].fillna('missing', inplace=True)
rounds['company_category_list'].fillna('missing', inplace=True)

# %% [markdown]
# ## Imputing Raised Amount

# %% [markdown]
# There are alot of missing data in the raised amount column in the data set. One strategy that could be taken is to calculate the mean of all the funds of a certain company and impute its nulls with the average of total fund it has recieved before. First we calculate the mean of the total funding of each company then add it in a new row, then compare each row if the raised amount column is null, then fill it with the average of the company otherwise leave it as it is.

# %%
total = invests.groupby(['company_name'])['raised_amount_usd'].transform(np.mean) #side note below
total = pd.DataFrame(total) #could be omitted, as we can assign the column 'total_raised' to a series, not just a dataframe
invests['total_raised'] = total
invests['raised_amount_usd'] = np.where((invests['raised_amount_usd'].isnull()), invests['total_raised'], invests['raised_amount_usd'])
#                                                      if this ^ is true        then impute with this ^    else impute with this ^
invests['raised_amount_usd'].fillna(invests['raised_amount_usd'].mean(), inplace = True)
invests
# Out:
#                                         company_permalink  \
# 0                                   /organization/0-6-com
# 1                          /organization/004-technologies
# 2                        /organization/01games-technology
# 3                                    /organization/0xdata
# 4                                    /organization/0xdata
# ...                                                   ...
# 168642                          /organization/zzzzapp-com
# 168643                                /organization/Áeron
# 168644                                /organization/Áeron
# 168645                              /organization/Ôasys-2
# 168646  /organization/İnovatiff-reklam-ve-tanıtım-hizm...
#
#                                       company_name  \
# 0                                          0-6.com
# 1                                 004 Technologies
# 2                               01Games Technology
# 3                                           H2O.ai
# 4                                           H2O.ai
# ...                                            ...
# 168642                       Zzzzapp Wireless ltd.
# 168643                                       ÁERON
# 168644                                       ÁERON
# 168645                                       Ôasys
# 168646  İnovatiff Reklam ve Tanıtım Hizmetleri Tic
#
#                                     company_category_list  \
# 0                                             Curated Web
# 1                                                Software
# 2                                                   Games
# 3                                               Analytics
# 4                                               Analytics
# ...                                                   ...
# 168642        Advertising|Mobile|Web Development|Wireless
# 168643                                            missing
# 168644                                            missing
# 168645  Consumer Electronics|Internet of Things|Teleco...
# 168646                 Consumer Goods|E-Commerce|Internet
#
#        company_country_code company_state_code         company_region  \
# 0                       CHN                 22                Beijing
# 1                       USA                 IL  Springfield, Illinois
# 2                       HKG                NaN              Hong Kong
# 3                       USA                 CA            SF Bay Area
# 4                       USA                 CA            SF Bay Area
# ...                     ...                ...                    ...
# 168642                  HRV                 15                  Split
# 168643                  NaN                NaN                    NaN
# 168644                  NaN                NaN                    NaN
# 168645                  USA                 CA            SF Bay Area
# 168646                  NaN                NaN                    NaN
#
#          company_city                               investor_permalink  \
# 0             Beijing                /organization/dt-capital-partners
# 1           Champaign                  /organization/venturecapital-de
# 2           Hong Kong                /organization/cyberport-hong-kong
# 3       Mountain View                        /organization/capital-one
# 4       Mountain View             /organization/nexus-venture-partners
# ...               ...                                              ...
# 168642          Split                             /organization/eleven
# 168643            NaN                    /organization/day-one-capital
# 168644            NaN  /organization/sz-chenyi-capital-fund-management
# 168645  San Francisco                    /organization/startupbootcamp
# 168646            NaN                           /person/serkan-erdoğan
#
#                             investor_name investor_country_code  \
# 0                     DT Capital Partners                   CHN
# 1                   VCDE Venture Partners                   DEU
# 2                     Cyberport Hong Kong                   HKG
# 3                             Capital One                   USA
# 4                  Nexus Venture Partners                   USA
# ...                                   ...                   ...
# 168642                             Eleven                   BGR
# 168643    Day One Capital Fund Management                   HUN
# 168644  Széchenyi Capital Fund Management                   NaN
# 168645                    Startupbootcamp                   GBR
# 168646                     Serkan Erdoğan                   NaN
#
#        investor_state_code   investor_region investor_city  \
# 0                       23          Shanghai      Shanghai
# 1                        5         Frankfurt     Frankfurt
# 2                      NaN         Hong Kong     Hong Kong
# 3                       VA  Washington, D.C.        Mclean
# 4                       CA       SF Bay Area    Menlo Park
# ...                    ...               ...           ...
# 168642                  42             Sofia         Sofia
# 168643                   5          Budapest      Budapest
# 168644                 NaN               NaN           NaN
# 168645                  H9            London        London
# 168646                 NaN               NaN           NaN
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 1       /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830            venture
# 2       /funding-round/7d53696f2b4f607a2f2a8cbb83d01839        undisclosed
# 3       /funding-round/3bb2ee4a2d89251a10aaa735b1180e44            venture
# 4       /funding-round/383a9bd2c04f7038bb543ccef5ba3eae               seed
# ...                                                 ...                ...
# 168642  /funding-round/ff1aa06ed5da186c84f101549035d4ae               seed
# 168643  /funding-round/59f4dce44723b794f21ded3daed6e4fe            venture
# 168644  /funding-round/59f4dce44723b794f21ded3daed6e4fe            venture
# 168645  /funding-round/35f09d0794651719b02bbfd859ba9ff5               seed
# 168646  /funding-round/af942869878d2cd788ef5189b435ebc4              grant
#
#        funding_round_code  funded_at  raised_amount_usd  total_raised
# 0                       A 2008-03-19       2.000000e+06  2.000000e+06
# 1                     NaN 2014-07-24       1.493930e+07           NaN
# 2                     NaN 2014-07-01       4.125000e+04  4.125000e+04
# 3                       B 2015-11-09       2.000000e+07  1.010714e+07
# 4                     NaN 2013-05-22       3.000000e+06  1.010714e+07
# ...                   ...        ...                ...           ...
# 168642                NaN 2013-05-01       3.284200e+04  3.576800e+04
# 168643                  A 2014-08-01       1.493930e+07           NaN
# 168644                  A 2014-08-01       1.493930e+07           NaN
# 168645                NaN 2015-01-01       1.819200e+04  1.819200e+04
# 168646                NaN 2013-10-01       1.485100e+04  1.485100e+04
#
# [168634 rows x 19 columns]

# %% [markdown]
# ### Side note: difference between `.mean()` and `.transform(np.mean)`
# ([source](https://stackoverflow.com/questions/40957932/transform-vs-aggregate-in-pandas))

# %% [markdown]
# <img src='Phase 1/meanVsTransform1.png' width=500>

# %% [markdown]
# <img src='Phase 1/meanVsTransform2.png' width=300>

# %% [markdown]
# <img src='Phase 1/meanVsTransform33.png' width=600>

# %% [markdown]
# And we want to broadcast values and have it with original index (0 to len(invests)), <br>
# as this will assign `invests['total_raised'] = total` based on the index values <br>
# Example:

# %% [markdown]
# <img src='Phase 1/colEqualSeries1.png' width=400>

# %% [markdown]
# <img src='Phase 1/colEqualSeries2.png' width=400>

# %% [markdown]
# <img src='Phase 1/colEqualSeries3.png' width=200>

# %% [markdown]
# ## Cleaning & Imputing Geographical Locations

# %% [markdown]
# ### Removing `company_state_code` and `company_region`

# %% [markdown]
# We don't need `company_state_code` in our analysis, <br>
# As country code and city are sufficient to know <br>
# an approximation of the geographical location of the company. <br>
# Therefore, let's remove it:

# %%
companies[['company_country_code', 'company_state_code', 'company_city']].head(10)
# Out:
#   company_country_code company_state_code   company_city
# 0                  IND                 16         Mumbai
# 1                  USA                 DE  Delaware City
# 2                  NaN                NaN            NaN
# 3                  CHN                 22        Beijing
# 4                  USA                 IL      Champaign
# 5                  HKG                NaN      Hong Kong
# 6                  CAN                 BC      Vancouver
# 7                  USA                 CA  Mountain View
# 8                  USA                 CA  San Francisco
# 9                  CHL                 12     Las Condes

# %%
companies.drop('company_state_code', axis=1, inplace=True)

# %% [markdown]
# `company_region` is also redundent, as it is usually the same as `company_city`.<br>
# Let's validate this:

# %%
# Note: same logic applies for the permalinks
acquis.dropna(subset=['acquirer_permalink', 'acquirer_name'], inplace=True)
invests.dropna(subset=['investor_permalink', 'investor_name'], inplace=True)

# %% [markdown]
# Also, we'll remove the missing values for columns that have less than 100 `NaN`, <br>
# as they're small in comparison to their respective datasets:

# %%
companies[companies.company_region == companies.company_city][['company_region', 'company_city']]
# Out:
#       company_region company_city
# 0             Mumbai       Mumbai
# 3            Beijing      Beijing
# 5          Hong Kong    Hong Kong
# 6          Vancouver    Vancouver
# 11           Orlando      Orlando
# ...              ...          ...
# 66354           Bath         Bath
# 66360      Milwaukee    Milwaukee
# 66362         London       London
# 66363        Beijing      Beijing
# 66364          Split        Split
#
# [25356 rows x 2 columns]

# %% [markdown]
# Let's see the mean of similarity between the strings using builtin library `difflib.SequenceMatcher`:

# %%
from difflib import SequenceMatcher
similarities = []
rgs = companies.company_region.values.tolist()
cts = companies.company_city.values.tolist()
for i in range(min(len(rgs), len(cts))):
    if not (rgs[i] != rgs[i] or cts[i] != cts[i]): # If either of the elements is NaN, then don't find the similarity
        similarities.append(SequenceMatcher(None, rgs[i], cts[i]).ratio()) # Gets the similarity between each two strings
avgSim = sum(similarities) / len(similarities)
avgSim
# Out:
# 0.6175397944380312

# %% [markdown]
# However, `SequenceMatcher` only finds the longest contiguous matching subsequence, <br>
# and all other characters will drastically decrease the similarity, which isn't very accurate, <br>
# Therefore, let's try to see how many times a string is a substring of another:

# %%
subsCount = 0
for i in range(min(len(rgs), len(cts))):
    if not (rgs[i] != rgs[i] or cts[i] != cts[i]):
        subsCount += (rgs[i] in cts[i] or cts[i] in rgs[i])
subsCount
# Out:
# 29878

# %% [markdown]
# So to summarize: almost half of the companies have the same data for `region` and `city` (25360) <br>
# There are around 5000 companies that have the same semantic meaning between the data <br>
# (e.g: 'New York City' is the same as 'NYC, New York City') <br>
# Therefore, `company_region` can be removed without losing any possible future insights:

# %%
companies.drop('company_region', axis=1, inplace=True)

acquis.drop('company_region', axis=1, inplace=True)
acquis.drop('acquirer_region', axis=1, inplace=True)

invests.drop('company_region', axis=1, inplace=True)
invests.drop('investor_region', axis=1, inplace=True)

rounds.drop('company_region', axis=1, inplace=True)

# %% [markdown]
# ### Imputing `company_country_code` and `company_city`

# %% [markdown]
# #### Failed attempt using [Crunchbase](https://www.crunchbase.com):
# 1. check the company's permalink
# 2. find HTML that contains the headquarters location (country and city)
# 3. scrape country and convert it to country code using `pycountry.countries`
# 4. scrape city and impute it in `company_city`

# %% [markdown]
# Step 1: appending "https://www.crunchbase.com" to each permalink <br>
# to be able to access the company's webpage on crunchbase. <br>
# However, since the new permalink will be much longer (thus slower for accessing as a dataset's primary index) <br>
# we'll create a function that appends the string as a prefix and that will be accessed throughout the notebook

# %% [markdown]
# Step 2: Finding location of country and city on the webpage:
# let's check company [004](https://www.crunchbase.com/organization/004)'s webpage for example: <Br>
# <img src="Phase 1/countryAndCityInCrunchbase.png" width=400 height=300 />

# %% [markdown]
# By inspecting the HTML, we notice 4 instances of the class <br>
# `component--field-formatter field-type-identifier-multi` (in a `span` element),<br>and the data that we want
# is always the first instance: <br>
# <img src="Phase 1/countryAndCityLocationInHTML.png" width=700 height=500 />

# %% [markdown]
# Step 3: scrape that info using `requests` and `bs4` libraries: <br>
# (Note, we're using `threading.Thread` here to increase performance by scraping in multithreads)

# %% [markdown]
# However, this is a deadend, as crunchbase is powered by [distill network](https://www.google.com/search?q=distil+network&sxsrf=APq-WBt2mubTHz1xGfmKgpzlWtHah5qAaA%3A1648578960023&ei=kFFDYsx646qVB_nKh7gK&ved=0ahUKEwjMgq-a--v2AhVjVeUKHXnlAacQ4dUDCA4&uact=5&oq=distil+network&gs_lcp=Cgdnd3Mtd2l6EAMyBggAEAcQHjIGCAAQBxAeMgYIABAHEB4yBggAEAcQHjIGCAAQBxAeMgYIABAHEB4yBggAEAcQHjIGCAAQBxAeMgYIABAHEB4yBggAEAcQHjoHCCMQsAMQJzoHCAAQRxCwA0oECEEYAEoECEYYAFCyCliyCmCLD2gBcAF4AIABowGIAaMBkgEDMC4xmAEAoAEByAEKwAEB&sclient=gws-wiz#:~:text=distil%20networks%20uses%20machine%20learning%20to%20identify%20and%20mitigate%20potential%20bad%20bots%2C%20fingerprinting%20them%20so%20that%20they%20can%20still%20be%20tracked%20if%20they%20reconnect%20from%20a%20different%20ip%20address) <br>
# So when we tried to scrap from it, the following html was always displayed: <br><br>
# <img src="Phase 1/crunchbaseAccessDenied.png">

# %% [markdown]
# ### Failed attempt using [linkedin](https://www.linkedin.com/in/ashrafharess/)

# %% [markdown]
# It failed because after a while, linkedin detects that you are a bot: <br><br>
# <img src='Phase 1/linkedinSecurityCheck.png' width=500 height=300>

# %% [markdown]
# However, the steps are displayed below to show how this was initially done using multithreads:

# %% [markdown]
# Step 1: Login into linkedin using `selenium.webdriver`:

# %%
from selenium import webdriver
import time
import warnings
import chromedriver_autoinstaller as chr
chr.install() #automatically install chromedriver compatible with the chorme broswer currently on your O.S.
warnings.filterwarnings('ignore') # to suppress warnings about internal code deprecations
options=webdriver.ChromeOptions()
options.add_argument('--incognito')
options.add_argument('--headless')
driver=webdriver.Chrome(options=options)
driver.get('https://www.linkedin.com/uas/login')

username = driver.find_element_by_id('username')
username.send_keys('xxfarah600xx@gmail.com')
password = driver.find_element_by_id('password')
password.send_keys('#0LinkedIn0#')
log_in_button = driver.find_element_by_class_name('from__button--floating')
log_in_button.click()

# %% [markdown]
# Step 2: Visualize the html of the data you need to scrape: <br><br>
# <img src='Phase 1/linkedinAboutLocations.png' width=800 height=500>

# %%
driver.get('https://www.linkedin.com/company/absolvent/about/')
time.sleep(3) # sleeping to render javascript code before parsing to BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
locCard = soup.find('div', 'org-location-card pv2')
locCard.text
# Out:
# '\n\n      Primary\n    \n \n     Warsaw,   PL\n  \n\n\n        Get directions\n      \n\n        Get directions to  Warsaw,   PL\n      \n\n\n\n\n'

# %%
import re
re.findall(r'Primary[\n\s]+(\w+)', locCard.text)
# Out:
# ['Warsaw']

# %% [markdown]
# Step 3: Visualize another part of the html in case step 3 doesn't work: <br><br>
# <img src='Phase 1/linkedinAboutHeadquarters.png' width=700 height=500>

# %%
driver.get('https://www.linkedin.com/company/association-for-computing-machinery/about/')
time.sleep(3) # sleeping to render javascript code before parsing to BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
dl = soup.find('div', 'mb6').find('dl')
dl
# Out:
# <dl class="overflow-hidden">
# <dt class="mb1 text-heading-small">
#           Website
#         </dt>
# <dd class="mb4 text-body-small t-black--light">
# <a class="link-without-visited-state ember-view" href="https://www.acm.org/" id="ember61" rel="noopener noreferrer" tabindex="0" target="_blank">
# <span class="link-without-visited-state" dir="ltr">
#               https://www.acm.org/
#             </span>
# </a>
# </dd>
# <dt class="mb1 text-heading-small">
#           Phone
#         </dt>
# <dd class="mb4 text-body-small t-black--light">
# <a class="link-without-visited-state ember-view" href="tel:+1 (212) 626-0500" id="ember62" rel="noopener noreferrer" tabindex="0" target="_blank">
# <span aria-hidden="true" class="link-without-visited-state" dir="ltr">
#               +1 (212) 626-0500
#             </span>
# <span class="visually-hidden">
#               Phone number is +1 (212) 626-0500
#             </span>
# </a>
# </dd>
# <dt class="mb1 text-heading-small">
#             Industry
#           </dt>
# <dd class="mb4 text-body-small t-black--light">
#             Book and Periodical Publishing
#           </dd>
# <dt class="mb1 text-heading-small">
#           Company size
#         </dt>
# <dd class="text-body-small t-black--light mb1">
#             51-200 employees
#         </dd>
# <dd class="text-body-small t-black--light mb4">
#             1,178 on LinkedIn
#             <span class="artdeco-hoverable-trigger artdeco-hoverable-trigger--content-placed-bottom artdeco-hoverable-trigger--is-hoverable ember-view" id="ember63" tabindex="-1">
# <button aria-controls="artdeco-hoverable-artdeco-gen-42" aria-describedby="artdeco-hoverable-artdeco-gen-42" aria-label="More info" class="org-about-company-module__employees-count-tooltip-trigger artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view" id="ember64" type="button"> <li-icon aria-hidden="true" class="artdeco-button__icon" size="small" type="notify-pebble-icon"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M12 2H4a2 2 0 00-2 2v8a2 2 0 002 2h8a2 2 0 002-2V4a2 2 0 00-2-2zm-3 8v2H7.5A1.5 1.5 0 016 10.5a1.56 1.56 0 01.1-.5l1.08-3h2.13l-1.09 3zm0-3.75A1.25 1.25 0 1110.25 5 1.25 1.25 0 019 6.25z"></path>
# </svg></li-icon>
# <span class="artdeco-button__text">
#     Includes members with current employer listed as ACM, Association for Computing Machinery, including part-time roles.
# </span></button>
# <div class="ember-view" id="artdeco-gen-42"><div class="ember-view" id="ember66"></div></div>
# </span>
# </dd>
# <dt class="mb1 text-heading-small">
#             Headquarters
#           </dt>
# <dd class="mb4 text-body-small t-black--light">
#             New York, NY
#           </dd>
# <!-- -->
# <dt class="mb1 text-heading-small">
#           Founded
#         </dt>
# <dd class="mb4 text-body-small t-black--light">
#           1947
#         </dd>
# <dt class="mb1 text-heading-small">
#           Specialties
#         </dt>
# <dd class="mb4 text-body-small t-black--light" dir="ltr">
#           Computing
#         </dd>
# </dl>

# %%
dl = soup.find('div', 'mb6').find('dl')
nms = []
for tag in dl:
    txt = tag.text
    nms.append(txt)
nms
# Out:
# ['\n',
#  '\n          Website\n        ',
#  '\n',
#  '\n\n\n              https://www.acm.org/\n            \n\n',
#  '\n',
#  '\n          Phone\n        ',
#  '\n',
#  '\n\n\n              +1 (212) 626-0500\n            \n\n              Phone number is +1 (212) 626-0500\n            \n\n',
#  '\n',
#  '\n            Industry\n          ',
#  '\n',
#  '\n            Book and Periodical Publishing\n          ',
#  '\n',
#  '\n          Company size\n        ',
#  '\n',
#  '\n            51-200 employees\n        ',
#  '\n',
#  '\n            1,178 on LinkedIn\n            \n \n\n\n\n    Includes members with current employer listed as ACM, Association for Computing Machinery, including part-time roles.\n\n\n\n',
#  '\n',
#  '\n            Headquarters\n          ',
#  '\n',
#  '\n            New York, NY\n          ',
#  '\n',
#  '',
#  '\n',
#  '\n          Founded\n        ',
#  '\n',
#  '\n          1947\n        ',
#  '\n',
#  '\n          Specialties\n        ',
#  '\n',
#  '\n          Computing\n        ',
#  '\n']

# %%
# getting the values in key-value pairs, then we will extract the country from key "Headquarters"
dl = soup.find('div', 'mb6').find('dl')
keys = []
values = []
for tag in dl.find_all('dt'):
    txt = tag.text.strip()
    if (txt != ''):
        keys.append(txt)
for tag in dl.find_all('dd'):
    txt = tag.text.strip()
    if (txt != ''):
        values.append(txt)

# %%
keys, values
# Out:
# (['Website',
#   'Phone',
#   'Industry',
#   'Company size',
#   'Headquarters',
#   'Founded',
#   'Specialties'],
#  ['https://www.acm.org/',
#   '+1 (212) 626-0500\n            \n\n              Phone number is +1 (212) 626-0500',
#   'Book and Periodical Publishing',
#   '51-200 employees',
#   '1,178 on LinkedIn\n            \n \n\n\n\n    Includes members with current employer listed as ACM, Association for Computing Machinery, including part-time roles.',
#   'New York, NY',
#   '1947',
#   'Computing'])

# %%
values = [txt for txt in values if "Includes" not in txt] # a message which contains the word "Includes" sometime appears and is not needed, thus we don't include it
values
# Out:
# ['https://www.acm.org/',
#  '+1 (212) 626-0500\n            \n\n              Phone number is +1 (212) 626-0500',
#  'Book and Periodical Publishing',
#  '51-200 employees',
#  'New York, NY',
#  '1947',
#  'Computing']

# %%
# putting the key-value pairs in a dictionary
linkedinDict = dict(zip(keys, values))
linkedinDict
# Out:
# {'Website': 'https://www.acm.org/',
#  'Phone': '+1 (212) 626-0500\n            \n\n              Phone number is +1 (212) 626-0500',
#  'Industry': 'Book and Periodical Publishing',
#  'Company size': '51-200 employees',
#  'Headquarters': 'New York, NY',
#  'Founded': '1947',
#  'Specialties': 'Computing'}

# %%
linkedinDict["Headquarters"]
# Out:
# 'New York, NY'

# %% [markdown]
# Step 4: getting the country code of the companies and their corresponding indices and putting them in a list of tuples:

# %%
import threading # using multithreads to speed things up a little
lock = threading.Lock()
import pycountry
from geopy.geocoders import Nominatim # using this library to convert cities to countries
import time
import re

geolocator = Nominatim(user_agent="ashraf196280@bue.edu.eg")

idxToNan = []
def fetchCountry(idx, link):
    try:
        lock.acquire()
        driver.get(link) # same driver used from step 1
        time.sleep(2)
        soup = BeautifulSoup(driver.page_source, "html.parser")
        lock.release()
        dl = soup.find('div', 'mb6').find('dl')
        keys = []
        values = []
        for tag in dl.find_all('dt'):
            txt = tag.text.strip()
            if (txt != ''):
                keys.append(txt)
        for tag in dl.find_all('dd'):
            txt = tag.text.strip()
            if (txt != ''):
                values.append(txt)
        values = [txt for txt in values if "Includes" not in txt]
        linkedinDict = dict(zip(keys, values))
        if ('Headquarters' in linkedinDict):
            city = linkedinDict["Headquarters"]
            city = city.split(',')[0] # eg: "Cupertino, California" will be ["Cupertino", "California"], so "Cupertino" will be returned
        else:
            locCard = soup.find('div', 'org-location-card pv2')
            city = re.findall(r'Primary[\n\s]+(\w+)', locCard.text)[0]
        lock.acquire()
        location = geolocator.geocode(city, language="en")
        lock.release()
        if location is None:
            raise
    except:
        lock.acquire()
        idxToNan.append((idx, "missing")) # means that this website is not found on linkedin, so declare it as missing
        lock.release()
        return
    
    country = location.address.split(', ')[-1]
    try:
        alpha3Code = pycountry.countries.get(name=country).alpha_3
    except:
        alpha3Code = country[0:3].upper() #if not found in pycountry, assume that it is the first 3 letters of the country name
    lock.acquire()
    idxToNan.append((idx, alpha3Code))
    lock.release()

# %%
from threading import Thread
def imputeFromLinks(df, colToSuffixIntoURL, colToImpute, start, end, linkPrefix = ""):
    links = df[df[colToImpute].isnull()][[colToSuffixIntoURL]].squeeze()[start:end] # "squeeze()" converts df to series
    threads = []
    for tup in links.iteritems(): # tup[0] --> index, tup[1] --> url (i.e. link)
        th = Thread(target=fetchCountry, args=(tup[0], linkPrefix + tup[1].replace(" ", "") + '/about')) #making sure company name doesn't have spaces when suffixed into the url
        threads.append(th)
        th.start()
    for th in threads:
        th.join() # to wait until all multithreads finish to properly display the dataframe

# %%
# single threaded version (just in case multithreads gets blocked by linkedin)
from threading import Thread
def imputeFromLinksSingleThreads(df, colToSuffixIntoURL, colToImpute, linkPrefix = ""):
    links = df[df[colToImpute].isnull()][[colToSuffixIntoURL]].squeeze() # "squeeze()" converts df to series
    for tup in links.iteritems(): # tup[0] --> index, tup[1] --> url (i.e. link)
        fetchCountry(tup[0], linkPrefix + tup[1].replace(" ", "") + '/about') #making sure company name doesn't have spaces when suffixed into the url

# %%
links = companies[companies['company_country_code'].isnull()][['company_name']].squeeze()
len(links)
# Out:
# 6952

# %%
#imputeFromLinks(companies, "company_name", "company_country_code", "https://www.linkedin.com/company/", 0, 10)

# %%
#idxToNan

# %%
# this was to save the output to a csv file in case the pc shut off after the above cell executed
#dfLinkedin = pd.DataFrame(idxToNan, columns=['index', 'company_country_code'])
#dfLinkedin.set_index('index')
#dfLinkedin.to_csv('Phase 1/countryCodesLinkedIn.csv', index=False)

# %% [markdown]
# #### Successful attempt using TLDs of `homepage_url`

# %% [markdown]
# Let's check the top level domain (TLD) of each link using regex and see if we can use that <br>
# to impute the country code:

# %%
# As you can see, there are only approximately 1500 rows that don't contain neither country_code nor homepage_url
hUrls = companies[companies['company_country_code'].isnull()][['homepage_url']].squeeze()
hUrls.dropna(inplace=True)
len(hUrls), len(companies[companies['company_country_code'].isnull()])
# Out:
# (5548, 6952)

# %%
hUrls.head(3)
# Out:
# 2         http://oneofthem.jp
# 21    http://www.1000chi.com/
# 35    http://beansaround.com/
# Name: homepage_url, dtype: object

# %%
hUrls.str.findall(r'(\.[^.]*)$').head(3) # use '\.([^.]*)$' if you don't want the '.', but we do, so leave it
# Out:
# 2       [.jp]
# 21    [.com/]
# 35    [.com/]
# Name: homepage_url, dtype: object

# %%
hUrls = hUrls.str.findall(r'(\.[^.]*)$').apply(lambda x : ''.join(x).split('/')[0]) # apply() will convert the list of strings to a string and remove '/' at the end of the string
hUrls
# Out:
# 2         .jp
# 21       .com
# 35       .com
# 39       .com
# 45       .com
#          ...
# 66317    .com
# 66325     .co
# 66333    .com
# 66365     .hu
# 66367    .com
# Name: homepage_url, Length: 5548, dtype: object

# %%
unwantedVals = hUrls.str.contains(pat='^$|com') # "^$" means empty string, "|" means "or"
hUrls = hUrls[~unwantedVals] # "~" is equivalent to "unwantedVals == False"
hUrls
# Out:
# 2           .jp
# 54          .br
# 79       .media
# 126         .hk
# 159         .me
#           ...
# 66220       .cz
# 66230       .my
# 66270      .php
# 66325       .co
# 66365       .hu
# Name: homepage_url, Length: 1541, dtype: object

# %% [markdown]
# Create a dictionary where key = TLD, value = country <br>
# e.g --> '.jp' : 'Japan'

# %%
#csv obtained from https://gist.github.com/derlin/421d2bb55018a1538271227ff6b1299d#file-country-codes-tlds-csv
tldsToCountries = pd.read_csv('Phase 1/country-codes-tlds.csv')
tldsToCountries.drop_duplicates(subset='tld', keep='first', inplace=True)
tldsToCountries['tld'] = tldsToCountries['tld'].apply(lambda x: x.replace(' ', ''))
tldsToCountries.to_csv(r'Phase 1/newCountryCodesTlds.csv', index = None, header=True)
tldsToCountries = tldsToCountries.set_index('tld').squeeze()
tldsToCountries = tldsToCountries.to_dict()
tldsToCountries['.jp']
# Out:
# 'Japan'

# %% [markdown]
# Use that dictionary to convert TLDs to their respective countries:

# %%
hCompanyLocs = hUrls.copy()
hCompanyLocs = hCompanyLocs.apply(lambda x : tldsToCountries[x] if (x in tldsToCountries) else 'none')
hCompanyLocs = hCompanyLocs[hCompanyLocs != 'none']
hCompanyLocs
# Out:
# 2                           Japan
# 54                         Brazil
# 126                     Hong Kong
# 159                    Montenegro
# 281                   Switzerland
#                    ...
# 66184              Réunion Island
# 66220    Czechia (Czech Republic)
# 66230                    Malaysia
# 66325                    Colombia
# 66365                     Hungary
# Name: homepage_url, Length: 1213, dtype: object

# %%
# 1213 countries could be imputed
len(hCompanyLocs)
# Out:
# 1213

# %% [markdown]
# Convert those countries to country codes:

# %%
import pycountry
def toAlphaCode3(country):
    countryInfo = pycountry.countries.get(name=country)
    if (countryInfo is None):
        return "none"
    return countryInfo.alpha_3

hCompanyLocs = hCompanyLocs.apply(lambda x : toAlphaCode3(x))
hCompanyLocs = hCompanyLocs[hCompanyLocs != 'none']
hCompanyLocs
# Out:
# 2        JPN
# 54       BRA
# 126      HKG
# 159      MNE
# 281      CHE
#         ...
# 65745    SVK
# 66120    POL
# 66230    MYS
# 66325    COL
# 66365    HUN
# Name: homepage_url, Length: 900, dtype: object

# %%
# only 900 countries have country codes present, so impute those only
# the following is just to illustrate the for loop in the next cell:
hCompanyLocs.index[0], hCompanyLocs.iloc[0]
# Out:
# (2, 'JPN')

# %% [markdown]
# impute into `country_codes` of `companies` dataset

# %%
for i in range(len(hCompanyLocs)):
    idx = hCompanyLocs.index[i]
    code = hCompanyLocs.iloc[i]
    companies.at[idx, 'company_country_code'] = code

# %% [markdown]
# #### Imputing rest of cities and country codes

# %% [markdown]
# After the failed attempt to scrape the country and then get the country code of each company we will impute the values with "missing" for now.

# %%
companies['company_country_code'].fillna("missing", inplace=True)
companies['company_city'].fillna("missing", inplace=True)

acquis['company_country_code'].fillna("missing", inplace=True)
acquis['company_state_code'].fillna("missing", inplace=True)
acquis['company_city'].fillna("missing")
acquis['acquirer_country_code'].fillna("missing", inplace=True)
acquis['acquirer_state_code'].fillna("missing", inplace=True)
acquis['acquirer_city'].fillna("missing", inplace=True)

invests['company_country_code'].fillna("missing", inplace=True)
invests['company_state_code'].fillna("missing", inplace=True)
invests['company_city'].fillna("missing", inplace=True)
invests['investor_city'].fillna("missing", inplace=True)
invests['investor_country_code'].fillna("missing", inplace=True)
invests['investor_state_code'].fillna("missing", inplace=True)

rounds['company_country_code'].fillna("missing", inplace=True)

# %% [markdown]
# ## Removing duplicates in `acquistions` dataset

# %%
# To show that there really are duplicates in acquisitions dataset
acquis[acquis.duplicated(keep = False) == True] #False : Mark all duplicates as True
# Out:
#                      company_permalink       company_name  \
# 1856     /organization/backcountry-com    Backcountry.com
# 1857     /organization/backcountry-com    Backcountry.com
# 1932   /organization/bartlett-holdings  Bartlett Holdings
# 1933   /organization/bartlett-holdings  Bartlett Holdings
# 1934   /organization/bartlett-holdings  Bartlett Holdings
# ...                                ...                ...
# 17643        /organization/unveillance        Unveillance
# 17644        /organization/unveillance        Unveillance
# 17645        /organization/unveillance        Unveillance
# 18387         /organization/webmethods         webMethods
# 18388         /organization/webmethods         webMethods
#
#                          company_category_list company_country_code  \
# 1856                                E-Commerce                  USA
# 1857                                E-Commerce                  USA
# 1932                                   missing                  USA
# 1933                                   missing                  USA
# 1934                                   missing                  USA
# ...                                        ...                  ...
# 17643                               Technology                  USA
# 17644                               Technology                  USA
# 17645                               Technology                  USA
# 18387  B2B|Enterprise Software|Web Development              missing
# 18388  B2B|Enterprise Software|Web Development              missing
#
#       company_state_code      company_city  \
# 1856                  UT         Park City
# 1857                  UT         Park City
# 1932                  MA  Plymouth Meeting
# 1933                  MA  Plymouth Meeting
# 1934                  MA  Plymouth Meeting
# ...                  ...               ...
# 17643                 DE        Wilmington
# 17644                 DE        Wilmington
# 17645                 DE        Wilmington
# 18387            missing               NaN
# 18388            missing               NaN
#
#                         acquirer_permalink          acquirer_name  \
# 1856   /organization/tsg-consumer-partners  TSG Consumer Partners
# 1857   /organization/tsg-consumer-partners  TSG Consumer Partners
# 1932        /organization/harvest-partners       Harvest Partners
# 1933        /organization/harvest-partners       Harvest Partners
# 1934        /organization/harvest-partners       Harvest Partners
# ...                                    ...                    ...
# 17643               /organization/mandiant               Mandiant
# 17644               /organization/mandiant               Mandiant
# 17645               /organization/mandiant               Mandiant
# 18387            /organization/software-ag            Software AG
# 18388            /organization/software-ag            Software AG
#
#                                   acquirer_category_list  \
# 1856                                             missing
# 1857                                             missing
# 1932                                             missing
# 1933                                             missing
# 1934                                             missing
# ...                                                  ...
# 17643                                           Security
# 17644                                           Security
# 17645                                           Security
# 18387  Big Data|Enterprises|Enterprise Software|Software
# 18388  Big Data|Enterprises|Enterprise Software|Software
#
#       acquirer_country_code acquirer_state_code  acquirer_city acquired_at  \
# 1856                    USA                  CA  San Francisco  2015-07-01
# 1857                    USA                  CA  San Francisco  2015-07-01
# 1932                    USA                  NY       New York  2010-12-01
# 1933                    USA                  NY       New York  2010-12-01
# 1934                    USA                  NY       New York  2010-12-01
# ...                     ...                 ...            ...         ...
# 17643                   USA                  VA     Alexandria  2012-09-10
# 17644                   USA                  VA     Alexandria  2012-09-10
# 17645                   USA                  VA     Alexandria  2012-09-10
# 18387                   DEU                   5      Darmstadt  2007-04-01
# 18388                   DEU                   5      Darmstadt  2007-04-01
#
#       acquired_month  price_amount price_currency_code
# 1856         2015-07           NaN                 USD
# 1857         2015-07           NaN                 USD
# 1932         2010-12           NaN                 USD
# 1933         2010-12           NaN                 USD
# 1934         2010-12           NaN                 USD
# ...              ...           ...                 ...
# 17643        2012-09           NaN                 USD
# 17644        2012-09           NaN                 USD
# 17645        2012-09           NaN                 USD
# 18387        2007-04   500000000.0                 USD
# 18388        2007-04   500000000.0                 USD
#
# [71 rows x 16 columns]

# %%
acquis.drop_duplicates()
acquis
# Out:
#                                        company_permalink  \
# 0                                   /organization/003-ru
# 1                          /organization/0958572-b-c-ltd
# 2                     /organization/1-800-communications
# 3                           /organization/1-800-contacts
# 4      /organization/1-844-446-4460-pogo-customer-ser...
# ...                                                  ...
# 18963                          /organization/zynk-mobile
# 18964                               /organization/zyrion
# 18965                               /organization/zystor
# 18966                          /organization/zytex-group
# 18967                   /organization/’compass-solutions
#
#                                             company_name  \
# 0                                                 003.RU
# 1                                      0958572 B.C. Ltd.
# 2                                   1-800 Communications
# 3                                         1-800 Contacts
# 4      Games Support +1-800-311-5934 Pogo Games techn...
# ...                                                  ...
# 18963                                        Zynk Mobile
# 18964                                         Zyrion Inc
# 18965                                             Zystor
# 18966                                        Zytex group
# 18967                                N’compass Solutions
#
#                            company_category_list company_country_code  \
# 0      Consumer Electronics|Electronics|Internet                  RUS
# 1                                        missing              missing
# 2                                        missing                  USA
# 3                          Consumer Goods|Retail                  USA
# 4                                        missing              missing
# ...                                          ...                  ...
# 18963                                    missing              missing
# 18964                        Networking|Software                  USA
# 18965                              Biotechnology                  USA
# 18966                              Manufacturing                  IND
# 18967                     Information Technology                  USA
#
#       company_state_code company_city  \
# 0                     48       Moscow
# 1                missing          NaN
# 2                     NY   Hicksville
# 3                     UT       Draper
# 4                missing          NaN
# ...                  ...          ...
# 18963            missing          NaN
# 18964                 CA    Sunnyvale
# 18965                 WI    Milwaukee
# 18966                 16       Mumbai
# 18967                 MN  Maple Grove
#
#                                       acquirer_permalink  \
# 0                             /organization/media-saturn
# 1      /organization/atlas-intellectual-property-mana...
# 2                           /organization/carsdirect-com
# 3                    /organization/thomas-h-lee-partners
# 4      /organization/pogo-customer-service-number-1-8...
# ...                                                  ...
# 18963                               /organization/zenvia
# 18964                               /organization/kaseya
# 18965              /organization/biomarin-pharmaceutical
# 18966                          /organization/brenntag-ag
# 18967                /organization/alphapoint-technology
#
#                                            acquirer_name  \
# 0                                           Media Saturn
# 1             ATLAS Intellectual Property Management Co.
# 2                                         CarsDirect.com
# 3                                 Thomas H. Lee Partners
# 4      Games Support +1-800-311-5934 Pogo Games techn...
# ...                                                  ...
# 18963                                             Zenvia
# 18964                                             Kaseya
# 18965                            BioMarin Pharmaceutical
# 18966                                        Brenntag AG
# 18967                              AlphaPoint Technology
#
#                                   acquirer_category_list  \
# 0          Enterprise Software|Media|Sales and Marketing
# 1              Finance|FinTech|Mobile|Telecommunications
# 2                                             E-Commerce
# 3      Business Development|Impact Investing|Investme...
# 4                                                missing
# ...                                                  ...
# 18963                                             Mobile
# 18964  Data Centers|Data Security|Flash Storage|Homel...
# 18965                                    Pharmaceuticals
# 18966                   Chemicals|Manufacturing|Services
# 18967  Data Center Infrastructure|Intellectual Asset ...
#
#       acquirer_country_code acquirer_state_code        acquirer_city  \
# 0                       ESP                  56            Barcelona
# 1                       USA                  WA              Seattle
# 2                       USA                  CA           El Segundo
# 3                       USA                  MA               Boston
# 4                       USA                  NY           Mamaroneck
# ...                     ...                 ...                  ...
# 18963                   BRA                  23         Porto Alegre
# 18964               missing             missing              missing
# 18965                   USA                  CA           San Rafael
# 18966                   DEU                   7  Mülheim An Der Ruhr
# 18967                   USA                  FL             Sarasota
#
#       acquired_at acquired_month  price_amount price_currency_code
# 0      2012-07-23        2012-07           NaN                 USD
# 1      2012-02-02        2012-02     9000000.0                 USD
# 2      2005-06-12        2005-06           NaN                 USD
# 3      2014-01-07        2014-01           NaN                 USD
# 4      2001-02-02        2001-02           NaN                 USD
# ...           ...            ...           ...                 ...
# 18963  2013-03-01        2013-03           NaN                 USD
# 18964  2013-06-25        2013-06           NaN                 USD
# 18965  2010-08-18        2010-08   115000000.0                 USD
# 18966  2013-09-25        2013-09    14000000.0                 USD
# 18967  2014-12-25        2014-12     4800000.0                 USD
#
# [18950 rows x 16 columns]

# %% [markdown]
# ## Checking and Converting `dtypes`

# %%
def datasetsDtypes(dfList, datasetNames, dtypesCol="dtypes_", pad=""):
    cols = []
    nulls = []
    maxArrayLen = 0
    for i, df in enumerate(dfList):
        cols.append(df.columns.tolist())
        nulls.append(df.dtypes.tolist())
        maxArrayLen = max(maxArrayLen, len(cols[i]))
    
    dictCsvs = {}
    for i, df in enumerate(dfList):
        cols[i] += [pad] * (maxArrayLen - len(cols[i])) #padding the lists to make them have equal lengths 
        nulls[i] += [None] *  (maxArrayLen - len(nulls[i]))
        dictCsvs[datasetNames[i]] = cols[i]
        dictCsvs[dtypesCol + str(i+1)] = nulls[i]
    
    return pd.DataFrame(dictCsvs)

# %%
datasetsDtypes(dfAll, lstCsvNames)
# Out:
#               acquisitions        dtypes_1               companies  \
# 0        company_permalink          object       company_permalink
# 1             company_name          object            company_name
# 2    company_category_list          object            homepage_url
# 3     company_country_code          object   company_category_list
# 4       company_state_code          object       funding_total_usd
# 5             company_city          object                  status
# 6       acquirer_permalink          object    company_country_code
# 7            acquirer_name          object      company_state_code
# 8   acquirer_category_list          object          company_region
# 9    acquirer_country_code          object            company_city
# 10     acquirer_state_code          object          funding_rounds
# 11           acquirer_city          object              founded_at
# 12             acquired_at  datetime64[ns]        first_funding_at
# 13          acquired_month          object         last_funding_at
# 14            price_amount         float64  time_before_first_fund
# 15     price_currency_code          object
# 16                                    None
#
#            dtypes_2              investments        dtypes_3  \
# 0            object        company_permalink          object
# 1            object             company_name          object
# 2            object    company_category_list          object
# 3            object     company_country_code          object
# 4            object       company_state_code          object
# 5            object             company_city          object
# 6            object       investor_permalink          object
# 7            object            investor_name          object
# 8            object    investor_country_code          object
# 9            object      investor_state_code          object
# 10            int64            investor_city          object
# 11   datetime64[ns]  funding_round_permalink          object
# 12   datetime64[ns]       funding_round_type          object
# 13   datetime64[ns]       funding_round_code          object
# 14  timedelta64[ns]                funded_at  datetime64[ns]
# 15             None        raised_amount_usd         float64
# 16             None             total_raised         float64
#
#                      rounds        dtypes_4
# 0         company_permalink          object
# 1              company_name          object
# 2     company_category_list          object
# 3      company_country_code          object
# 4        company_state_code          object
# 5              company_city          object
# 6   funding_round_permalink          object
# 7        funding_round_type          object
# 8        funding_round_code          object
# 9                 funded_at  datetime64[ns]
# 10        raised_amount_usd         float64
# 11                                     None
# 12                                     None
# 13                                     None
# 14                                     None
# 15                                     None
# 16                                     None

# %% [markdown]
# From the above dataframe, convert `funding_total_usd` <br>
# in `companies` datset into float and then fill it and <br>
# `raised_amount_usd` in `rounds` dataset to  nulls with zeros

# %%
companies['funding_total_usd'] = pd.to_numeric(companies['funding_total_usd'],errors = 'coerce') #converted to int
companies['funding_total_usd'].fillna(0, inplace = True) #removed NaNs
companies['funding_total_usd'] = companies['funding_total_usd'].astype(float, errors = 'raise') #converted to float

# %%
rounds['raised_amount_usd'].fillna(0, inplace = True)

# %%
dfAll = [acquis, companies, invests, rounds] # Reassigning dfAll as sometimes the updates done in a dataframe don't reflect in the list
lstCsvNames = ["acquisitions", "companies", "investments", "rounds"]
datasetsDtypes(dfAll, lstCsvNames)
# Out:
#               acquisitions        dtypes_1               companies  \
# 0        company_permalink          object       company_permalink
# 1             company_name          object            company_name
# 2    company_category_list          object            homepage_url
# 3     company_country_code          object   company_category_list
# 4       company_state_code          object       funding_total_usd
# 5             company_city          object                  status
# 6       acquirer_permalink          object    company_country_code
# 7            acquirer_name          object            company_city
# 8   acquirer_category_list          object          funding_rounds
# 9    acquirer_country_code          object              founded_at
# 10     acquirer_state_code          object        first_funding_at
# 11           acquirer_city          object         last_funding_at
# 12             acquired_at  datetime64[ns]  time_before_first_fund
# 13          acquired_month          object
# 14            price_amount         float64
# 15     price_currency_code          object
# 16                                    None
#
#            dtypes_2              investments        dtypes_3  \
# 0            object        company_permalink          object
# 1            object             company_name          object
# 2            object    company_category_list          object
# 3            object     company_country_code          object
# 4           float64       company_state_code          object
# 5            object             company_city          object
# 6            object       investor_permalink          object
# 7            object            investor_name          object
# 8             int64    investor_country_code          object
# 9    datetime64[ns]      investor_state_code          object
# 10   datetime64[ns]            investor_city          object
# 11   datetime64[ns]  funding_round_permalink          object
# 12  timedelta64[ns]       funding_round_type          object
# 13             None       funding_round_code          object
# 14             None                funded_at  datetime64[ns]
# 15             None        raised_amount_usd         float64
# 16             None             total_raised         float64
#
#                      rounds        dtypes_4
# 0         company_permalink          object
# 1              company_name          object
# 2     company_category_list          object
# 3      company_country_code          object
# 4        company_state_code          object
# 5              company_city          object
# 6   funding_round_permalink          object
# 7        funding_round_type          object
# 8        funding_round_code          object
# 9                 funded_at  datetime64[ns]
# 10        raised_amount_usd         float64
# 11                                     None
# 12                                     None
# 13                                     None
# 14                                     None
# 15                                     None
# 16                                     None

# %% [markdown]
# ## Checking Nulls

# %% [markdown]
# Now that we imputed all missing data, we will check and see that there are no more null values in any data set. Notice that the other nulls are in columns that are dropped already in the dataframes.

# %%
dfAll = [acquis, companies, invests, rounds] # Reassigning dfAll as sometimes the updates done in a dataframe don't reflect in the list
lstCsvNames = ["acquisitions", "companies", "investments", "rounds"]
dfAllNulls = datasetsNulls(dfAll, lstCsvNames)
dfAllNulls
# Out:
#               acquisitions  nulls_1               companies  nulls_2  \
# 0        company_permalink      0.0       company_permalink      0.0
# 1             company_name      0.0            company_name      0.0
# 2    company_category_list      0.0            homepage_url   5055.0
# 3     company_country_code      0.0   company_category_list      0.0
# 4       company_state_code      0.0       funding_total_usd      0.0
# 5             company_city   4902.0                  status      0.0
# 6       acquirer_permalink      0.0    company_country_code      0.0
# 7            acquirer_name      0.0            company_city      0.0
# 8   acquirer_category_list      0.0          funding_rounds      0.0
# 9    acquirer_country_code      0.0              founded_at      1.0
# 10     acquirer_state_code      0.0        first_funding_at      3.0
# 11           acquirer_city      0.0         last_funding_at      0.0
# 12             acquired_at      0.0  time_before_first_fund      0.0
# 13          acquired_month      0.0                              NaN
# 14            price_amount  13941.0                              NaN
# 15     price_currency_code      0.0                              NaN
# 16                              NaN                              NaN
#
#                 investments  nulls_3                   rounds  nulls_4
# 0         company_permalink        0        company_permalink      0.0
# 1              company_name        0             company_name      0.0
# 2     company_category_list        0    company_category_list      0.0
# 3      company_country_code        0     company_country_code      0.0
# 4        company_state_code        0       company_state_code  10946.0
# 5              company_city        0             company_city  10164.0
# 6        investor_permalink        0  funding_round_permalink      0.0
# 7             investor_name        0       funding_round_type      0.0
# 8     investor_country_code        0       funding_round_code  83808.0
# 9       investor_state_code        0                funded_at      0.0
# 10            investor_city        0        raised_amount_usd      0.0
# 11  funding_round_permalink        0                               NaN
# 12       funding_round_type        0                               NaN
# 13       funding_round_code    87576                               NaN
# 14                funded_at        0                               NaN
# 15        raised_amount_usd        0                               NaN
# 16             total_raised    14384                               NaN

# %%
# Note that "founded_at" and "first_funding_at" has new NaNs, as the conversion to datetime wasn't successful in 3 rows
# so let's remove them
companies.dropna(subset=['founded_at'], inplace=True)
companies.dropna(subset=['first_funding_at'], inplace=True)

# %%
companies.reset_index(inplace = True)
companies.drop(['index'], axis = 1, inplace = True)

# %%
companies.dropna(subset = ['homepage_url'], inplace = True)
companies.isnull().sum()
# Out:
# company_permalink         0
# company_name              0
# homepage_url              0
# company_category_list     0
# funding_total_usd         0
# status                    0
# company_country_code      0
# company_city              0
# funding_rounds            0
# founded_at                0
# first_funding_at          0
# last_funding_at           0
# time_before_first_fund    0
# dtype: int64

# %%
dfAll = [acquis, companies, invests, rounds] # Reassigning dfAll as sometimes the updates done in a dataframe don't reflect in the list
lstCsvNames = ["acquisitions", "companies", "investments", "rounds"]
dfAllNulls = datasetsNulls(dfAll, lstCsvNames)
dfAllNulls
# Out:
#               acquisitions  nulls_1               companies  nulls_2  \
# 0        company_permalink      0.0       company_permalink      0.0
# 1             company_name      0.0            company_name      0.0
# 2    company_category_list      0.0            homepage_url      0.0
# 3     company_country_code      0.0   company_category_list      0.0
# 4       company_state_code      0.0       funding_total_usd      0.0
# 5             company_city   4902.0                  status      0.0
# 6       acquirer_permalink      0.0    company_country_code      0.0
# 7            acquirer_name      0.0            company_city      0.0
# 8   acquirer_category_list      0.0          funding_rounds      0.0
# 9    acquirer_country_code      0.0              founded_at      0.0
# 10     acquirer_state_code      0.0        first_funding_at      0.0
# 11           acquirer_city      0.0         last_funding_at      0.0
# 12             acquired_at      0.0  time_before_first_fund      0.0
# 13          acquired_month      0.0                              NaN
# 14            price_amount  13941.0                              NaN
# 15     price_currency_code      0.0                              NaN
# 16                              NaN                              NaN
#
#                 investments  nulls_3                   rounds  nulls_4
# 0         company_permalink        0        company_permalink      0.0
# 1              company_name        0             company_name      0.0
# 2     company_category_list        0    company_category_list      0.0
# 3      company_country_code        0     company_country_code      0.0
# 4        company_state_code        0       company_state_code  10946.0
# 5              company_city        0             company_city  10164.0
# 6        investor_permalink        0  funding_round_permalink      0.0
# 7             investor_name        0       funding_round_type      0.0
# 8     investor_country_code        0       funding_round_code  83808.0
# 9       investor_state_code        0                funded_at      0.0
# 10            investor_city        0        raised_amount_usd      0.0
# 11  funding_round_permalink        0                               NaN
# 12       funding_round_type        0                               NaN
# 13       funding_round_code    87576                               NaN
# 14                funded_at        0                               NaN
# 15        raised_amount_usd        0                               NaN
# 16             total_raised    14384                               NaN

# %% [markdown]
# # Saving Cleaned Datasets

# %%
#prefix = 'datasets/startupsCleaned/'
#suffix = 'Cleaned.csv'
#acquis.to_csv(prefix+'acquisitions'+suffix, index=False)
#companies.to_csv(prefix+'companies'+suffix, index=False)
#invests.to_csv(prefix+'investments'+suffix, index=False)
#rounds.to_csv(prefix+'rounds'+suffix, index=False)

# %% [markdown]
# # Answering Questions From The Given Datasets

# %% [markdown]
# ## Question 1 (Ashraf & Farah)

# %% [markdown]
# -	Can the factors that affect a start-up’s growth be determined?
#     -	For this: We are initially interested in <br> `raised_amount_usd`, `status`, `time_before_first_fund`, and `funding_rounds`

# %% [markdown]
# This question can be measured with two approches:
# - Divide the companies into categories based on their status (either closed, operating or acquired) then look at the average of funding each category receives, then determine the correlation between the closed companies and their failure due to the low funds.
# - the second approch is finding the time it took for a company to receive its first funding regardless of how big or small this funding is. Funding after the company's establishment is assumed to be important on its success, so we'll try to verify this assumption.

# %% [markdown]
# First, we will join the two datasets to answer our question which are companies and rounds

# %%
companies.sort_values(by=['company_name'], inplace=True)
rounds.sort_values(by=['company_name'],inplace=True)
comp_rounds = companies.join(rounds.set_index('company_name'), on='company_name', lsuffix='_left', rsuffix='_right')
comp_rounds.columns
# Out:
# Index(['company_permalink_left', 'company_name', 'homepage_url',
#        'company_category_list_left', 'funding_total_usd', 'status',
#        'company_country_code_left', 'company_city_left', 'funding_rounds',
#        'founded_at', 'first_funding_at', 'last_funding_at',
#        'time_before_first_fund', 'company_permalink_right',
#        'company_category_list_right', 'company_country_code_right',
#        'company_state_code', 'company_city_right', 'funding_round_permalink',
#        'funding_round_type', 'funding_round_code', 'funded_at',
#        'raised_amount_usd'],
#       dtype='object')

# %% [markdown]
# We will slice our new joined dataset into three categories based on the company's status:

# %%
operatingcomp_rounds = comp_rounds[comp_rounds['status'] == 'operating']
operatingcomp_rounds = operatingcomp_rounds[['company_name', 'funding_rounds', 'raised_amount_usd', 'funded_at']]
operatingcomp_rounds
# Out:
#                  company_name  funding_rounds  raised_amount_usd  funded_at
# 24834                #HASHOFF               2           455000.0 2014-12-08
# 24834                #HASHOFF               2           500000.0 2015-08-11
# 0                       #fame               1         10000000.0 2015-01-05
# 59865      &TV Communications               2          1000000.0 2010-06-04
# 59865      &TV Communications               2          3000000.0 2010-09-23
# ...                       ...             ...                ...        ...
# 31273  İş kutusu video ajansı               1           100000.0 2014-03-13
# 18338                 Еnso.fm               1            27838.0 2015-07-01
# 51421                 ​Shwrüm               1            50000.0 2013-01-01
# 63581                 ​WestEd               1          3000000.0 2014-07-22
# 10952           吃神马 ChiShenMa               1                0.0 2014-02-28
#
# [86286 rows x 4 columns]

# %%
acquiredcomp_rounds = comp_rounds[comp_rounds['status'] == 'acquired']
acquiredcomp_rounds = acquiredcomp_rounds[['company_name', 'funding_rounds', 'raised_amount_usd', 'funded_at']]
acquiredcomp_rounds
# Out:
#        company_name  funding_rounds  raised_amount_usd  funded_at
# 63168      #waywire               1          1750000.0 2012-06-30
# 47298         (RED)               1             2323.0 2000-03-05
# 54410     //Staq.io               1                0.0 2012-10-01
# 15     1 Mainstream               1          5000000.0 2015-03-17
# 20     1000 Markets               1           500000.0 2009-05-15
# ...             ...             ...                ...        ...
# 66232        zulily               4          6000000.0 2010-08-04
# 66232        zulily               4         85000000.0 2012-11-15
# 66264         zurvu               1          1200000.0 2014-03-20
# 66271        zuuka!               2                0.0 2011-01-24
# 66271        zuuka!               2                0.0 2012-06-11
#
# [11113 rows x 4 columns]

# %%
closedcomp_rounds = comp_rounds[comp_rounds['status'] == 'closed']
closedcomp_rounds = closedcomp_rounds[['company_name', 'funding_rounds', 'raised_amount_usd', 'funded_at']]
closedcomp_rounds
# Out:
#                company_name  funding_rounds  raised_amount_usd  funded_at
# 8378   #BratPackStyle, LLC.               1                0.0 2015-06-01
# 11986         .Club Domains               1          7000000.0 2013-05-31
# 21439         .FOX Networks               1          4912393.0 2007-01-16
# 12508           .comDominio               1                0.0 2004-02-12
# 34             10BestThings               1            50000.0 2009-04-01
# ...                     ...             ...                ...        ...
# 65107                yes.no               1          1000000.0 2015-05-01
# 65246                 yoone               1           197597.0 2010-11-03
# 65248                yoonew               2          2000000.0 2005-08-01
# 65248                yoonew               2          2000000.0 2007-01-01
# 66014     zipcodemailer.com               1            15000.0 2008-09-10
#
# [7972 rows x 4 columns]

# %% [markdown]
# Now we group the operating, acquired, and closed companies by their name and see how much total of fundings across the rounds each company earned. We will see that some of the closed companies did not receive any fundings and this has to be one of the highlighted reasons to their failure.

# %%
operatingtotal = pd.DataFrame(operatingcomp_rounds.groupby(['company_name'])['raised_amount_usd'].sum())
operatingtotal
# Out:
#                         raised_amount_usd
# company_name
# #HASHOFF                         955000.0
# #fame                          10000000.0
# &TV Communications              4000000.0
# 'Rock' Your Paper                 60385.0
# ( caravelo (                    1089811.0
# ...                                   ...
# İş kutusu video ajansı           100000.0
# Еnso.fm                           27838.0
# ​Shwrüm                           50000.0
# ​WestEd                         3000000.0
# 吃神马 ChiShenMa                         0.0
#
# [49007 rows x 1 columns]

# %%
acquiredtotal = pd.DataFrame(acquiredcomp_rounds.groupby(['company_name'])['raised_amount_usd'].sum())
acquiredtotal
# Out:
#               raised_amount_usd
# company_name
# #waywire              1750000.0
# (RED)                    2323.0
# //Staq.io                   0.0
# 1 Mainstream          5000000.0
# 1000 Markets           500000.0
# ...                         ...
# youcalc               3840000.0
# zoidu                   48600.0
# zulily              138600000.0
# zurvu                 1200000.0
# zuuka!                      0.0
#
# [5084 rows x 1 columns]

# %%
closedtotal = pd.DataFrame(closedcomp_rounds.groupby(['company_name'])['raised_amount_usd'].sum())
closedtotal
# Out:
#                       raised_amount_usd
# company_name
# #BratPackStyle, LLC.                0.0
# .Club Domains                 7000000.0
# .FOX Networks                 4912393.0
# .comDominio                         0.0
# 10BestThings                    50000.0
# ...                                 ...
# xkoto                        11035000.0
# yes.no                        1000000.0
# yoone                          197597.0
# yoonew                        4000000.0
# zipcodemailer.com               15000.0
#
# [5512 rows x 1 columns]

# %% [markdown]
#  Comparing the raised amount to the operating companies to the closed companies seem to be higher on average. Now let's calculate the average of the whole raised amount to see how much on average does a company need for operation.

# %%
d = {'status': ['operating', 'acquired', 'closed'], 
'mean': [
    operatingtotal['raised_amount_usd'].mean(),
     acquiredtotal['raised_amount_usd'].mean(), 
     closedtotal['raised_amount_usd'].mean()]}
statuses = pd.DataFrame(d)
statuses
# Out:
#       status          mean
# 0  operating  1.131934e+07
# 1   acquired  2.432912e+07
# 2     closed  8.301936e+06

# %%
plt.bar(statuses['status'], statuses['mean']);

# %% [markdown]
# Initally, it seems that the closed companies have the lowest fundings. However, it is important to realize that the data is not distributed equally:

# %%
numOfCompanies = []
labels = ['operating', 'closed', 'acquired']
numOfCompanies.append(len(comp_rounds[comp_rounds['status'] == 'operating']))
numOfCompanies.append(len(comp_rounds[comp_rounds['status'] == 'closed']))
numOfCompanies.append(len(comp_rounds[comp_rounds['status'] == 'acquired']))
numOfCompanies
plt.pie(numOfCompanies, labels=labels, autopct='%1.0f%%');

# %% [markdown]
# And since the difference between the fundings of operating companies to the closed ones is only 3 million USD, therefore one can deduce that the closed companies relatively had a lot of fundings, yet they weren't able to continue operating and closed.

# %% [markdown]
# (side note: the acquired companies received much more which makes sense since the acquired companies mostly received those fundings either with debt until they got acquired.)

# %% [markdown]
# In Conclusion, **not getting enough funding is not a critical factor on the company's chance of success**. This means that the companies shouldn't be demotivated if they recieved low fundings.

# %% [markdown]
# Regarding the second approach, we will look now at the closed companies that recieved more than one funding round:

# %% [markdown]
# Now we will look at the time before the first funding were the fundings for the closed companies. We will ignore the negative signs and consider its absolute values as it might have one date came before the other or it might have been subtracted by 0 in case it received more than one funding on the same day. To solve the negatives problem we will perform the absolute function.

# %%
comp_rounds = companies.set_index('company_name')
comp_rounds['time_before_first_fund'] = comp_rounds['time_before_first_fund'].abs()
comp_rounds = comp_rounds.sort_values('time_before_first_fund', ascending=False)

# %%
operatingcomp_rounds = comp_rounds[comp_rounds['status'] == 'operating']['time_before_first_fund'][0:5]
operatingcomp_rounds
# Out:
# company_name
# Rutgers University            91028 days
# University of New Brunswick   83774 days
# University of Pittsburgh      83569 days
# Georgetown University         82220 days
# University of Michigan        71912 days
# Name: time_before_first_fund, dtype: timedelta64[ns]

# %%
# getting the days as int instead of timedelta64[ns]
operatingDaysGap = []
for i in range(5):
    operatingDaysGap.append(operatingcomp_rounds[i].days)  
operatingDaysGap
# Out:
# [91028, 83774, 83569, 82220, 71912]

# %%
closedcomp_rounds = comp_rounds[comp_rounds['status'] == 'closed']['time_before_first_fund'][0:5]
closedcomp_rounds
# Out:
# company_name
# The National Urban League   38653 days
# Selectron                   19540 days
# Signicast                   18060 days
# Impact Products             17409 days
# Il Bisonte                  16603 days
# Name: time_before_first_fund, dtype: timedelta64[ns]

# %%
# getting the days as int instead of timedelta64[ns]
closedDaysGap = []
for i in range(5):
    closedDaysGap.append(closedcomp_rounds[i].days)  
closedDaysGap
# Out:
# [38653, 19540, 18060, 17409, 16603]

# %%
compLabels = ['Group A','Group B','Group C','Group D', 'Group E']
X_axis = np.arange(len(compLabels)) # equivalent to array([0, 1, 2, 3, 4])
plt.bar(X_axis - 0.2, operatingDaysGap, 0.4, label = 'Operating') # width of each bar is 0.4
plt.bar(X_axis + 0.2, closedDaysGap, 0.4, label = 'Closed')
plt.xlabel('groups of operating and closed companies')
plt.ylabel('days before first funding')
plt.legend()
plt.xticks(X_axis, compLabels);

# %% [markdown]
# From the plot shown above, it seems the operating companies had bigger gaps between funding and establishment. <br>
# so one can safely assume that the time between the company's foundtion and the first funding isn't an effective factor.

# %% [markdown]
# In conclusion, time taken to get the first funding can be considered a **non-critical factor in affecting the success of the company**. <br>
# It means that the company doesn't heavily rely on that first funding to remain operating.

# %% [markdown]
# ## Question 2 (Ashraf & Farah)

# %% [markdown]
# Regarding the Second Question:  <br>
# - 	Which regions (countries) are most probable to have the most failed startups?
#     -	For this: We are initially interested in <br> `country_code`, `status`, and `investor_name`

# %% [markdown]
# First we need to join the companies dataset with the investments dataset

# %%
companies.sort_values(by=['company_name'], inplace=True)
invests.sort_values(by=['company_name'],inplace=True) #for eye-candy purposes
comp_invests = companies.join(invests.set_index('company_name'), on='company_name',lsuffix='_left', rsuffix='_right')
comp_invests
# Out:
#                 company_permalink_left          company_name  \
# 8378   /organization/bratpackstyle-llc  #BratPackStyle, LLC.
# 24834            /organization/hashoff              #HASHOFF
# 0                  /organization/-fame                 #fame
# 63168            /organization/waywire              #waywire
# 63168            /organization/waywire              #waywire
# ...                                ...                   ...
# 18338               /organization/enso               Еnso.fm
# 51421              /organization/shwrm               ​Shwrüm
# 63581             /organization/wested               ​WestEd
# 10952          /organization/chishenma         吃神马 ChiShenMa
# 10952          /organization/chishenma         吃神马 ChiShenMa
#
#                        homepage_url  \
# 8378   http://www.bratpackstyle.com
# 24834        http://www.hashoff.com
# 0                http://livfame.com
# 63168        http://www.waywire.com
# 63168        http://www.waywire.com
# ...                             ...
# 18338                http://enso.fm
# 51421         http://www.shwrum.com
# 63581        http://www.wested.org/
# 10952             http://chishen.ma
# 10952             http://chishen.ma
#
#                               company_category_list_left  funding_total_usd  \
# 8378   Content Discovery|E-Commerce|Fashion|Lifestyle...       0.000000e+00
# 24834                Digital Media|Internet|Social Media       9.550000e+05
# 0                                                  Media       1.000000e+07
# 63168           Entertainment|News|Politics|Social Media       1.750000e+06
# 63168           Entertainment|News|Politics|Social Media       1.750000e+06
# ...                                                  ...                ...
# 18338  Algorithms|Casual Games|Content Discovery|Edis...       2.783840e+04
# 51421   Design|Fashion|Internet|Mobile|Shopping|Software       5.000000e+04
# 63581                                         Nonprofits       3.000000e+06
# 10952                 Mobile|Restaurants|Specialty Foods       0.000000e+00
# 10952                 Mobile|Restaurants|Specialty Foods       0.000000e+00
#
#           status company_country_code_left company_city_left  funding_rounds  \
# 8378      closed                       USA          New York               1
# 24834  operating                       USA            Denver               2
# 0      operating                       IND            Mumbai               1
# 63168   acquired                       USA          New York               1
# 63168   acquired                       USA          New York               1
# ...          ...                       ...               ...             ...
# 18338  operating                       BGR             Sofia               1
# 51421  operating                       USA       Gainesville               1
# 63581  operating                       USA     San Francisco               1
# 10952  operating                       CHN          Shanghai               1
# 10952  operating                       CHN          Shanghai               1
#
#                          founded_at  ...  \
# 8378  2015-04-19 00:00:00.000000000  ...
# 24834 2014-04-01 00:00:00.000000000  ...
# 0     2011-04-12 20:46:43.240577680  ...
# 63168 2012-06-01 00:00:00.000000000  ...
# 63168 2012-06-01 00:00:00.000000000  ...
# ...                             ...  ...
# 18338 2015-06-29 00:00:00.000000000  ...
# 51421 2013-01-01 00:00:00.000000000  ...
# 63581 2010-10-27 20:46:43.240577680  ...
# 10952 2014-01-01 00:00:00.000000000  ...
# 10952 2014-01-01 00:00:00.000000000  ...
#
#                                  investor_name investor_country_code  \
# 8378                            Nine Inc. LLC.               missing
# 24834                                      NaN                   NaN
# 0                                          NaN                   NaN
# 63168                            Oprah Winfrey               missing
# 63168                     Innovation Endeavors                   USA
# ...                                        ...                   ...
# 18338  Axel Springer Plug and Play Accelerator                   DEU
# 51421                                      NaN                   NaN
# 63581                                      NaN                   NaN
# 10952                          Chinaccelerator                   CHN
# 10952                                     SOSV                   USA
#
#       investor_state_code investor_city  \
# 8378              missing       missing
# 24834                 NaN           NaN
# 0                     NaN           NaN
# 63168             missing       missing
# 63168                  CA     Palo Alto
# ...                   ...           ...
# 18338                  16        Berlin
# 51421                 NaN           NaN
# 63581                 NaN           NaN
# 10952                  23      Shanghai
# 10952                  NJ     Princeton
#
#                                funding_round_permalink funding_round_type  \
# 8378   /funding-round/7f52613bbda1edcaed3844d806d62757               seed
# 24834                                              NaN                NaN
# 0                                                  NaN                NaN
# 63168  /funding-round/cc409188fa2b63482bd9008f682c2efa               seed
# 63168  /funding-round/cc409188fa2b63482bd9008f682c2efa               seed
# ...                                                ...                ...
# 18338  /funding-round/53becfd9582cda62dcb2a6c9970810b3               seed
# 51421                                              NaN                NaN
# 63581                                              NaN                NaN
# 10952  /funding-round/aa4cde05f64453c60ca85a06a962f381               seed
# 10952  /funding-round/aa4cde05f64453c60ca85a06a962f381               seed
#
#       funding_round_code  funded_at raised_amount_usd  total_raised
# 8378                 NaN 2015-06-01      1.493930e+07           NaN
# 24834                NaN        NaT               NaN           NaN
# 0                    NaN        NaT               NaN           NaN
# 63168                NaN 2012-06-30      1.750000e+06  1.750000e+06
# 63168                NaN 2012-06-30      1.750000e+06  1.750000e+06
# ...                  ...        ...               ...           ...
# 18338                NaN 2015-07-01      2.783840e+04  2.783840e+04
# 51421                NaN        NaT               NaN           NaN
# 63581                NaN        NaT               NaN           NaN
# 10952                NaN 2014-02-28      1.493930e+07           NaN
# 10952                NaN 2014-02-28      1.493930e+07           NaN
#
# [183100 rows x 29 columns]

# %%
comp_invests.T
# Out:
#                                                                          8378   \
# company_permalink_left                         /organization/bratpackstyle-llc
# company_name                                              #BratPackStyle, LLC.
# homepage_url                                      http://www.bratpackstyle.com
# company_category_list_left   Content Discovery|E-Commerce|Fashion|Lifestyle...
# funding_total_usd                                                          0.0
# status                                                                  closed
# company_country_code_left                                                  USA
# company_city_left                                                     New York
# funding_rounds                                                               1
# founded_at                                                 2015-04-19 00:00:00
# first_funding_at                                           2015-06-01 00:00:00
# last_funding_at                                            2015-06-01 00:00:00
# time_before_first_fund                                        43 days 00:00:00
# company_permalink_right                        /organization/bratpackstyle-llc
# company_category_list_right  Content Discovery|E-Commerce|Fashion|Lifestyle...
# company_country_code_right                                                 USA
# company_state_code                                                          NY
# company_city_right                                                    New York
# investor_permalink                                  /organization/nine-inc-llc
# investor_name                                                   Nine Inc. LLC.
# investor_country_code                                                  missing
# investor_state_code                                                    missing
# investor_city                                                          missing
# funding_round_permalink        /funding-round/7f52613bbda1edcaed3844d806d62757
# funding_round_type                                                        seed
# funding_round_code                                                         NaN
# funded_at                                                  2015-06-01 00:00:00
# raised_amount_usd                                              14939298.912426
# total_raised                                                               NaN
#
#                                                            24834  \
# company_permalink_left                     /organization/hashoff
# company_name                                            #HASHOFF
# homepage_url                              http://www.hashoff.com
# company_category_list_left   Digital Media|Internet|Social Media
# funding_total_usd                                       955000.0
# status                                                 operating
# company_country_code_left                                    USA
# company_city_left                                         Denver
# funding_rounds                                                 2
# founded_at                                   2014-04-01 00:00:00
# first_funding_at                             2014-12-08 00:00:00
# last_funding_at                              2015-08-11 00:00:00
# time_before_first_fund                         251 days 00:00:00
# company_permalink_right                                      NaN
# company_category_list_right                                  NaN
# company_country_code_right                                   NaN
# company_state_code                                           NaN
# company_city_right                                           NaN
# investor_permalink                                           NaN
# investor_name                                                NaN
# investor_country_code                                        NaN
# investor_state_code                                          NaN
# investor_city                                                NaN
# funding_round_permalink                                      NaN
# funding_round_type                                           NaN
# funding_round_code                                           NaN
# funded_at                                                    NaT
# raised_amount_usd                                            NaN
# total_raised                                                 NaN
#
#                                                      0      \
# company_permalink_left                 /organization/-fame
# company_name                                         #fame
# homepage_url                            http://livfame.com
# company_category_list_left                           Media
# funding_total_usd                               10000000.0
# status                                           operating
# company_country_code_left                              IND
# company_city_left                                   Mumbai
# funding_rounds                                           1
# founded_at                   2011-04-12 20:46:43.240577680
# first_funding_at                       2015-01-05 00:00:00
# last_funding_at                        2015-01-05 00:00:00
# time_before_first_fund        1363 days 03:13:16.759422320
# company_permalink_right                                NaN
# company_category_list_right                            NaN
# company_country_code_right                             NaN
# company_state_code                                     NaN
# company_city_right                                     NaN
# investor_permalink                                     NaN
# investor_name                                          NaN
# investor_country_code                                  NaN
# investor_state_code                                    NaN
# investor_city                                          NaN
# funding_round_permalink                                NaN
# funding_round_type                                     NaN
# funding_round_code                                     NaN
# funded_at                                              NaT
# raised_amount_usd                                      NaN
# total_raised                                           NaN
#
#                                                                        63168  \
# company_permalink_left                                 /organization/waywire
# company_name                                                        #waywire
# homepage_url                                          http://www.waywire.com
# company_category_list_left          Entertainment|News|Politics|Social Media
# funding_total_usd                                                  1750000.0
# status                                                              acquired
# company_country_code_left                                                USA
# company_city_left                                                   New York
# funding_rounds                                                             1
# founded_at                                               2012-06-01 00:00:00
# first_funding_at                                         2012-06-30 00:00:00
# last_funding_at                                          2012-06-30 00:00:00
# time_before_first_fund                                      29 days 00:00:00
# company_permalink_right                                /organization/waywire
# company_category_list_right         Entertainment|News|Politics|Social Media
# company_country_code_right                                               USA
# company_state_code                                                        NY
# company_city_right                                                  New York
# investor_permalink                                     /person/oprah-winfrey
# investor_name                                                  Oprah Winfrey
# investor_country_code                                                missing
# investor_state_code                                                  missing
# investor_city                                                        missing
# funding_round_permalink      /funding-round/cc409188fa2b63482bd9008f682c2efa
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2012-06-30 00:00:00
# raised_amount_usd                                                  1750000.0
# total_raised                                                       1750000.0
#
#                                                                        63168  \
# company_permalink_left                                 /organization/waywire
# company_name                                                        #waywire
# homepage_url                                          http://www.waywire.com
# company_category_list_left          Entertainment|News|Politics|Social Media
# funding_total_usd                                                  1750000.0
# status                                                              acquired
# company_country_code_left                                                USA
# company_city_left                                                   New York
# funding_rounds                                                             1
# founded_at                                               2012-06-01 00:00:00
# first_funding_at                                         2012-06-30 00:00:00
# last_funding_at                                          2012-06-30 00:00:00
# time_before_first_fund                                      29 days 00:00:00
# company_permalink_right                                /organization/waywire
# company_category_list_right         Entertainment|News|Politics|Social Media
# company_country_code_right                                               USA
# company_state_code                                                        NY
# company_city_right                                                  New York
# investor_permalink                        /organization/innovation-endeavors
# investor_name                                           Innovation Endeavors
# investor_country_code                                                    USA
# investor_state_code                                                       CA
# investor_city                                                      Palo Alto
# funding_round_permalink      /funding-round/cc409188fa2b63482bd9008f682c2efa
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2012-06-30 00:00:00
# raised_amount_usd                                                  1750000.0
# total_raised                                                       1750000.0
#
#                                                                        63168  \
# company_permalink_left                                 /organization/waywire
# company_name                                                        #waywire
# homepage_url                                          http://www.waywire.com
# company_category_list_left          Entertainment|News|Politics|Social Media
# funding_total_usd                                                  1750000.0
# status                                                              acquired
# company_country_code_left                                                USA
# company_city_left                                                   New York
# funding_rounds                                                             1
# founded_at                                               2012-06-01 00:00:00
# first_funding_at                                         2012-06-30 00:00:00
# last_funding_at                                          2012-06-30 00:00:00
# time_before_first_fund                                      29 days 00:00:00
# company_permalink_right                                /organization/waywire
# company_category_list_right         Entertainment|News|Politics|Social Media
# company_country_code_right                                               USA
# company_state_code                                                        NY
# company_city_right                                                  New York
# investor_permalink                         /organization/first-round-capital
# investor_name                                                    First Round
# investor_country_code                                                    USA
# investor_state_code                                                       CA
# investor_city                                                  San Francisco
# funding_round_permalink      /funding-round/cc409188fa2b63482bd9008f682c2efa
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2012-06-30 00:00:00
# raised_amount_usd                                                  1750000.0
# total_raised                                                       1750000.0
#
#                                                                        63168  \
# company_permalink_left                                 /organization/waywire
# company_name                                                        #waywire
# homepage_url                                          http://www.waywire.com
# company_category_list_left          Entertainment|News|Politics|Social Media
# funding_total_usd                                                  1750000.0
# status                                                              acquired
# company_country_code_left                                                USA
# company_city_left                                                   New York
# funding_rounds                                                             1
# founded_at                                               2012-06-01 00:00:00
# first_funding_at                                         2012-06-30 00:00:00
# last_funding_at                                          2012-06-30 00:00:00
# time_before_first_fund                                      29 days 00:00:00
# company_permalink_right                                /organization/waywire
# company_category_list_right         Entertainment|News|Politics|Social Media
# company_country_code_right                                               USA
# company_state_code                                                        NY
# company_city_right                                                  New York
# investor_permalink                                    /organization/afsquare
# investor_name                                                       AFSquare
# investor_country_code                                                    USA
# investor_state_code                                                       CA
# investor_city                                                    Culver City
# funding_round_permalink      /funding-round/cc409188fa2b63482bd9008f682c2efa
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2012-06-30 00:00:00
# raised_amount_usd                                                  1750000.0
# total_raised                                                       1750000.0
#
#                                                                        63168  \
# company_permalink_left                                 /organization/waywire
# company_name                                                        #waywire
# homepage_url                                          http://www.waywire.com
# company_category_list_left          Entertainment|News|Politics|Social Media
# funding_total_usd                                                  1750000.0
# status                                                              acquired
# company_country_code_left                                                USA
# company_city_left                                                   New York
# funding_rounds                                                             1
# founded_at                                               2012-06-01 00:00:00
# first_funding_at                                         2012-06-30 00:00:00
# last_funding_at                                          2012-06-30 00:00:00
# time_before_first_fund                                      29 days 00:00:00
# company_permalink_right                                /organization/waywire
# company_category_list_right         Entertainment|News|Politics|Social Media
# company_country_code_right                                               USA
# company_state_code                                                        NY
# company_city_right                                                  New York
# investor_permalink                                       /person/troy-carter
# investor_name                                                    Troy Carter
# investor_country_code                                                    USA
# investor_state_code                                                  missing
# investor_city                                                    Culver City
# funding_round_permalink      /funding-round/cc409188fa2b63482bd9008f682c2efa
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2012-06-30 00:00:00
# raised_amount_usd                                                  1750000.0
# total_raised                                                       1750000.0
#
#                                                                        63168  \
# company_permalink_left                                 /organization/waywire
# company_name                                                        #waywire
# homepage_url                                          http://www.waywire.com
# company_category_list_left          Entertainment|News|Politics|Social Media
# funding_total_usd                                                  1750000.0
# status                                                              acquired
# company_country_code_left                                                USA
# company_city_left                                                   New York
# funding_rounds                                                             1
# founded_at                                               2012-06-01 00:00:00
# first_funding_at                                         2012-06-30 00:00:00
# last_funding_at                                          2012-06-30 00:00:00
# time_before_first_fund                                      29 days 00:00:00
# company_permalink_right                                /organization/waywire
# company_category_list_right         Entertainment|News|Politics|Social Media
# company_country_code_right                                               USA
# company_state_code                                                        NY
# company_city_right                                                  New York
# investor_permalink                                       /person/jeff-weiner
# investor_name                                                    Jeff Weiner
# investor_country_code                                                    USA
# investor_state_code                                                  missing
# investor_city                                                  Mountain View
# funding_round_permalink      /funding-round/cc409188fa2b63482bd9008f682c2efa
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2012-06-30 00:00:00
# raised_amount_usd                                                  1750000.0
# total_raised                                                       1750000.0
#
#                                                        59865  ...  \
# company_permalink_left       /organization/tv-communications  ...
# company_name                              &TV Communications  ...
# homepage_url                           http://enjoyandtv.com  ...
# company_category_list_left                             Games  ...
# funding_total_usd                                  4000000.0  ...
# status                                             operating  ...
# company_country_code_left                                USA  ...
# company_city_left                                Los Angeles  ...
# funding_rounds                                             2  ...
# founded_at                     2006-09-09 20:46:43.240577680  ...
# first_funding_at                         2010-06-04 00:00:00  ...
# last_funding_at                          2010-09-23 00:00:00  ...
# time_before_first_fund          1363 days 03:13:16.759422320  ...
# company_permalink_right                                  NaN  ...
# company_category_list_right                              NaN  ...
# company_country_code_right                               NaN  ...
# company_state_code                                       NaN  ...
# company_city_right                                       NaN  ...
# investor_permalink                                       NaN  ...
# investor_name                                            NaN  ...
# investor_country_code                                    NaN  ...
# investor_state_code                                      NaN  ...
# investor_city                                            NaN  ...
# funding_round_permalink                                  NaN  ...
# funding_round_type                                       NaN  ...
# funding_round_code                                       NaN  ...
# funded_at                                                NaT  ...
# raised_amount_usd                                        NaN  ...
# total_raised                                             NaN  ...
#
#                                                                          66321  \
# company_permalink_left                                   /organization/Ôasys-2
# company_name                                                             Ôasys
# homepage_url                                              http://www.oasys.io/
# company_category_list_left   Consumer Electronics|Internet of Things|Teleco...
# funding_total_usd                                                      18192.0
# status                                                               operating
# company_country_code_left                                                  USA
# company_city_left                                                San Francisco
# funding_rounds                                                               1
# founded_at                                                 2014-01-01 00:00:00
# first_funding_at                                           2015-01-01 00:00:00
# last_funding_at                                            2015-01-01 00:00:00
# time_before_first_fund                                       365 days 00:00:00
# company_permalink_right                                  /organization/Ôasys-2
# company_category_list_right  Consumer Electronics|Internet of Things|Teleco...
# company_country_code_right                                                 USA
# company_state_code                                                          CA
# company_city_right                                               San Francisco
# investor_permalink                               /organization/startupbootcamp
# investor_name                                                  Startupbootcamp
# investor_country_code                                                      GBR
# investor_state_code                                                         H9
# investor_city                                                           London
# funding_round_permalink        /funding-round/35f09d0794651719b02bbfd859ba9ff5
# funding_round_type                                                        seed
# funding_round_code                                                         NaN
# funded_at                                                  2015-01-01 00:00:00
# raised_amount_usd                                                      18192.0
# total_raised                                                           18192.0
#
#                                                                        6448   \
# company_permalink_left                             /organization/berresearch
# company_name                                                    ÜberResearch
# homepage_url                                         http://uberresearch.com
# company_category_list_left                                       Curated Web
# funding_total_usd                                                        0.0
# status                                                             operating
# company_country_code_left                                                DEU
# company_city_left                                                    Cologne
# funding_rounds                                                             1
# founded_at                                               2013-01-01 00:00:00
# first_funding_at                                         2013-11-11 00:00:00
# last_funding_at                                          2013-11-11 00:00:00
# time_before_first_fund                                     314 days 00:00:00
# company_permalink_right                            /organization/berresearch
# company_category_list_right                                      Curated Web
# company_country_code_right                                               DEU
# company_state_code                                                         7
# company_city_right                                                   Cologne
# investor_permalink                             /organization/digital-science
# investor_name                                                Digital Science
# investor_country_code                                                    GBR
# investor_state_code                                                       H9
# investor_city                                                         London
# funding_round_permalink      /funding-round/79c551d8f3ef2035523910739d1bfbe9
# funding_round_type                                               undisclosed
# funding_round_code                                                       NaN
# funded_at                                                2013-11-11 00:00:00
# raised_amount_usd                                            14939298.912426
# total_raised                                                             NaN
#
#                                                                          66322  \
# company_permalink_left       /organization/İnovatiff-reklam-ve-tanıtım-hizm...
# company_name                        İnovatiff Reklam ve Tanıtım Hizmetleri Tic
# homepage_url                                              http://inovatiff.com
# company_category_list_left                  Consumer Goods|E-Commerce|Internet
# funding_total_usd                                                      14851.0
# status                                                               operating
# company_country_code_left                                              missing
# company_city_left                                                      missing
# funding_rounds                                                               1
# founded_at                                       2010-01-06 20:46:43.240577680
# first_funding_at                                           2013-10-01 00:00:00
# last_funding_at                                            2013-10-01 00:00:00
# time_before_first_fund                            1363 days 03:13:16.759422320
# company_permalink_right      /organization/İnovatiff-reklam-ve-tanıtım-hizm...
# company_category_list_right                 Consumer Goods|E-Commerce|Internet
# company_country_code_right                                             missing
# company_state_code                                                     missing
# company_city_right                                                     missing
# investor_permalink                                      /person/serkan-erdoğan
# investor_name                                                   Serkan Erdoğan
# investor_country_code                                                  missing
# investor_state_code                                                    missing
# investor_city                                                          missing
# funding_round_permalink        /funding-round/af942869878d2cd788ef5189b435ebc4
# funding_round_type                                                       grant
# funding_round_code                                                         NaN
# funded_at                                                  2013-10-01 00:00:00
# raised_amount_usd                                                      14851.0
# total_raised                                                           14851.0
#
#                                                                      31273  \
# company_permalink_left                    /organization/kutusu-video-ajans
# company_name                                        İş kutusu video ajansı
# homepage_url                                       http://www.iskutusu.com
# company_category_list_left   3D|Advertising|Online Video Advertising|Video
# funding_total_usd                                                 100000.0
# status                                                           operating
# company_country_code_left                                              TUR
# company_city_left                                                 Istanbul
# funding_rounds                                                           1
# founded_at                                             2013-01-01 00:00:00
# first_funding_at                                       2014-03-13 00:00:00
# last_funding_at                                        2014-03-13 00:00:00
# time_before_first_fund                                   436 days 00:00:00
# company_permalink_right                                                NaN
# company_category_list_right                                            NaN
# company_country_code_right                                             NaN
# company_state_code                                                     NaN
# company_city_right                                                     NaN
# investor_permalink                                                     NaN
# investor_name                                                          NaN
# investor_country_code                                                  NaN
# investor_state_code                                                    NaN
# investor_city                                                          NaN
# funding_round_permalink                                                NaN
# funding_round_type                                                     NaN
# funding_round_code                                                     NaN
# funded_at                                                              NaT
# raised_amount_usd                                                      NaN
# total_raised                                                           NaN
#
#                                                                          18338  \
# company_permalink_left                                      /organization/enso
# company_name                                                           Еnso.fm
# homepage_url                                                    http://enso.fm
# company_category_list_left   Algorithms|Casual Games|Content Discovery|Edis...
# funding_total_usd                                                  27838.40363
# status                                                               operating
# company_country_code_left                                                  BGR
# company_city_left                                                        Sofia
# funding_rounds                                                               1
# founded_at                                                 2015-06-29 00:00:00
# first_funding_at                                           2015-07-01 00:00:00
# last_funding_at                                            2015-07-01 00:00:00
# time_before_first_fund                                         2 days 00:00:00
# company_permalink_right                                     /organization/enso
# company_category_list_right  Algorithms|Casual Games|Content Discovery|Edis...
# company_country_code_right                                                 BGR
# company_state_code                                                          42
# company_city_right                                                       Sofia
# investor_permalink                                        /organization/eleven
# investor_name                                                           Eleven
# investor_country_code                                                      BGR
# investor_state_code                                                         42
# investor_city                                                            Sofia
# funding_round_permalink        /funding-round/53becfd9582cda62dcb2a6c9970810b3
# funding_round_type                                                        seed
# funding_round_code                                                         NaN
# funded_at                                                  2015-07-01 00:00:00
# raised_amount_usd                                                  27838.40363
# total_raised                                                       27838.40363
#
#                                                                          18338  \
# company_permalink_left                                      /organization/enso
# company_name                                                           Еnso.fm
# homepage_url                                                    http://enso.fm
# company_category_list_left   Algorithms|Casual Games|Content Discovery|Edis...
# funding_total_usd                                                  27838.40363
# status                                                               operating
# company_country_code_left                                                  BGR
# company_city_left                                                        Sofia
# funding_rounds                                                               1
# founded_at                                                 2015-06-29 00:00:00
# first_funding_at                                           2015-07-01 00:00:00
# last_funding_at                                            2015-07-01 00:00:00
# time_before_first_fund                                         2 days 00:00:00
# company_permalink_right                                     /organization/enso
# company_category_list_right  Algorithms|Casual Games|Content Discovery|Edis...
# company_country_code_right                                                 BGR
# company_state_code                                                          42
# company_city_right                                                       Sofia
# investor_permalink           /organization/axel-springer-plug-and-play-acce...
# investor_name                          Axel Springer Plug and Play Accelerator
# investor_country_code                                                      DEU
# investor_state_code                                                         16
# investor_city                                                           Berlin
# funding_round_permalink        /funding-round/53becfd9582cda62dcb2a6c9970810b3
# funding_round_type                                                        seed
# funding_round_code                                                         NaN
# funded_at                                                  2015-07-01 00:00:00
# raised_amount_usd                                                  27838.40363
# total_raised                                                       27838.40363
#
#                                                                         51421  \
# company_permalink_left                                    /organization/shwrm
# company_name                                                          ​Shwrüm
# homepage_url                                            http://www.shwrum.com
# company_category_list_left   Design|Fashion|Internet|Mobile|Shopping|Software
# funding_total_usd                                                     50000.0
# status                                                              operating
# company_country_code_left                                                 USA
# company_city_left                                                 Gainesville
# funding_rounds                                                              1
# founded_at                                                2013-01-01 00:00:00
# first_funding_at                                          2013-01-01 00:00:00
# last_funding_at                                           2013-01-01 00:00:00
# time_before_first_fund                                        0 days 00:00:00
# company_permalink_right                                                   NaN
# company_category_list_right                                               NaN
# company_country_code_right                                                NaN
# company_state_code                                                        NaN
# company_city_right                                                        NaN
# investor_permalink                                                        NaN
# investor_name                                                             NaN
# investor_country_code                                                     NaN
# investor_state_code                                                       NaN
# investor_city                                                             NaN
# funding_round_permalink                                                   NaN
# funding_round_type                                                        NaN
# funding_round_code                                                        NaN
# funded_at                                                                 NaT
# raised_amount_usd                                                         NaN
# total_raised                                                              NaN
#
#                                                      63581  \
# company_permalink_left                /organization/wested
# company_name                                       ​WestEd
# homepage_url                        http://www.wested.org/
# company_category_list_left                      Nonprofits
# funding_total_usd                                3000000.0
# status                                           operating
# company_country_code_left                              USA
# company_city_left                            San Francisco
# funding_rounds                                           1
# founded_at                   2010-10-27 20:46:43.240577680
# first_funding_at                       2014-07-22 00:00:00
# last_funding_at                        2014-07-22 00:00:00
# time_before_first_fund        1363 days 03:13:16.759422320
# company_permalink_right                                NaN
# company_category_list_right                            NaN
# company_country_code_right                             NaN
# company_state_code                                     NaN
# company_city_right                                     NaN
# investor_permalink                                     NaN
# investor_name                                          NaN
# investor_country_code                                  NaN
# investor_state_code                                    NaN
# investor_city                                          NaN
# funding_round_permalink                                NaN
# funding_round_type                                     NaN
# funding_round_code                                     NaN
# funded_at                                              NaT
# raised_amount_usd                                      NaN
# total_raised                                           NaN
#
#                                                                        10952  \
# company_permalink_left                               /organization/chishenma
# company_name                                                   吃神马 ChiShenMa
# homepage_url                                               http://chishen.ma
# company_category_list_left                Mobile|Restaurants|Specialty Foods
# funding_total_usd                                                        0.0
# status                                                             operating
# company_country_code_left                                                CHN
# company_city_left                                                   Shanghai
# funding_rounds                                                             1
# founded_at                                               2014-01-01 00:00:00
# first_funding_at                                         2014-02-28 00:00:00
# last_funding_at                                          2014-02-28 00:00:00
# time_before_first_fund                                      58 days 00:00:00
# company_permalink_right                              /organization/chishenma
# company_category_list_right               Mobile|Restaurants|Specialty Foods
# company_country_code_right                                               CHN
# company_state_code                                                        23
# company_city_right                                                  Shanghai
# investor_permalink                             /organization/chinaccelerator
# investor_name                                                Chinaccelerator
# investor_country_code                                                    CHN
# investor_state_code                                                       23
# investor_city                                                       Shanghai
# funding_round_permalink      /funding-round/aa4cde05f64453c60ca85a06a962f381
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2014-02-28 00:00:00
# raised_amount_usd                                            14939298.912426
# total_raised                                                             NaN
#
#                                                                        10952
# company_permalink_left                               /organization/chishenma
# company_name                                                   吃神马 ChiShenMa
# homepage_url                                               http://chishen.ma
# company_category_list_left                Mobile|Restaurants|Specialty Foods
# funding_total_usd                                                        0.0
# status                                                             operating
# company_country_code_left                                                CHN
# company_city_left                                                   Shanghai
# funding_rounds                                                             1
# founded_at                                               2014-01-01 00:00:00
# first_funding_at                                         2014-02-28 00:00:00
# last_funding_at                                          2014-02-28 00:00:00
# time_before_first_fund                                      58 days 00:00:00
# company_permalink_right                              /organization/chishenma
# company_category_list_right               Mobile|Restaurants|Specialty Foods
# company_country_code_right                                               CHN
# company_state_code                                                        23
# company_city_right                                                  Shanghai
# investor_permalink                                 /organization/sosventures
# investor_name                                                           SOSV
# investor_country_code                                                    USA
# investor_state_code                                                       NJ
# investor_city                                                      Princeton
# funding_round_permalink      /funding-round/aa4cde05f64453c60ca85a06a962f381
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2014-02-28 00:00:00
# raised_amount_usd                                            14939298.912426
# total_raised                                                             NaN
#
# [29 rows x 183100 columns]

# %% [markdown]
# Now, we will categorize the companies according to their status (oprating, closed, aquired)

# %%
closedcomp_invests = comp_invests[comp_invests['status'] == 'closed']
closedcomp_invests
# Out:
#                 company_permalink_left          company_name  \
# 8378   /organization/bratpackstyle-llc  #BratPackStyle, LLC.
# 11986       /organization/club-domains         .Club Domains
# 21439       /organization/fox-networks         .FOX Networks
# 12508         /organization/comdominio           .comDominio
# 34          /organization/10bestthings          10BestThings
# ...                                ...                   ...
# 64786              /organization/xkoto                 xkoto
# 65107             /organization/yes-no                yes.no
# 65246              /organization/yoone                 yoone
# 65248             /organization/yoonew                yoonew
# 66014  /organization/zipcodemailer-com     zipcodemailer.com
#
#                        homepage_url  \
# 8378   http://www.bratpackstyle.com
# 11986              http://nic.club/
# 21439         http://www.dotfox.com
# 12508  http://www.comdominio.com.br
# 34          http://10bestthings.com
# ...                             ...
# 64786          http://www.xkoto.com
# 65107                 http://yes.no
# 65246               http://yoone.de
# 65248         http://www.yoonew.com
# 66014  http://www.zipcodemailer.com
#
#                               company_category_list_left  funding_total_usd  \
# 8378   Content Discovery|E-Commerce|Fashion|Lifestyle...                0.0
# 11986                                           Software          7000000.0
# 21439                                        Advertising          4912393.0
# 12508                                           Internet                0.0
# 34                                           Curated Web            50000.0
# ...                                                  ...                ...
# 64786                                           Software         11035000.0
# 65107                           Q&A|Social Network Media          1000000.0
# 65246                                              Games           197597.0
# 65248                                        Curated Web          4000000.0
# 66014       Postal and Courier Services|Public Relations            15000.0
#
#        status company_country_code_left company_city_left  funding_rounds  \
# 8378   closed                       USA          New York               1
# 11986  closed                       USA      Oakland Park               1
# 21439  closed                   missing           missing               1
# 12508  closed                       BRA          Brazilia               1
# 34     closed                       USA         Cleveland               1
# ...       ...                       ...               ...             ...
# 64786  closed                       USA           Waltham               3
# 65107  closed                       ISR          Tel Aviv               1
# 65246  closed                       DEU         Bielefeld               1
# 65248  closed                       USA          New York               2
# 66014  closed                       USA            Peoria               1
#
#                          founded_at  ...          investor_name  \
# 8378  2015-04-19 00:00:00.000000000  ...         Nine Inc. LLC.
# 11986 2011-10-10 00:00:00.000000000  ...                    NaN
# 21439 2003-04-23 20:46:43.240577680  ...        Foresight Group
# 12508 2000-05-19 20:46:43.240577680  ...  Stratus Investimentos
# 34    2009-04-01 00:00:00.000000000  ...                    NaN
# ...                             ...  ...                    ...
# 64786 2005-01-01 00:00:00.000000000  ...     GrandBanks Capital
# 65107 2015-01-01 00:00:00.000000000  ...             Assaf Levy
# 65246 2010-11-03 00:00:00.000000000  ...                HackFwd
# 65248 2004-01-01 00:00:00.000000000  ...                    NaN
# 66014 2008-10-11 00:00:00.000000000  ...                    NaN
#
#       investor_country_code investor_state_code investor_city  \
# 8378                missing             missing       missing
# 11986                   NaN                 NaN           NaN
# 21439                   GBR                  H9        London
# 12508               missing             missing       missing
# 34                      NaN                 NaN           NaN
# ...                     ...                 ...           ...
# 64786                   USA                  MA     Wellesley
# 65107                   ISR             missing      Tel Aviv
# 65246                   DEU                   4       Hamburg
# 65248                   NaN                 NaN           NaN
# 66014                   NaN                 NaN           NaN
#
#                                funding_round_permalink funding_round_type  \
# 8378   /funding-round/7f52613bbda1edcaed3844d806d62757               seed
# 11986                                              NaN                NaN
# 21439  /funding-round/69a1536a6f4506538afd7aa7241ddbe1        undisclosed
# 12508  /funding-round/f39abc561eeeb14307837363e54d7e16            venture
# 34                                                 NaN                NaN
# ...                                                ...                ...
# 64786  /funding-round/b91008080714512f7c78656ed27238ab            venture
# 65107  /funding-round/e51932c2afebd10c5e8c08b94b57bcb7               seed
# 65246  /funding-round/9ee9e539e722753d4fb6b03e7800fb8a               seed
# 65248                                              NaN                NaN
# 66014                                              NaN                NaN
#
#       funding_round_code  funded_at raised_amount_usd total_raised
# 8378                 NaN 2015-06-01      1.493930e+07          NaN
# 11986                NaN        NaT               NaN          NaN
# 21439                NaN 2007-01-16      4.912393e+06    4912393.0
# 12508                NaN 2004-02-12      1.493930e+07          NaN
# 34                   NaN        NaT               NaN          NaN
# ...                  ...        ...               ...          ...
# 64786                  C 2009-01-26      3.000000e+06    4307000.0
# 65107                NaN 2015-05-01      1.000000e+06    1000000.0
# 65246                NaN 2010-11-03      1.975970e+05     197597.0
# 65248                NaN        NaT               NaN          NaN
# 66014                NaN        NaT               NaN          NaN
#
# [12224 rows x 29 columns]

# %% [markdown]
# We will group by the country to see the number of companies (of each status) in each country to gain insight if there's a massive difference between the number of operating companies and closed ones in a single country.

# %%
closedcomptotal = pd.DataFrame(closedcomp_invests.groupby(['company_country_code_left'])['company_name'].count())
closedcomptotal.drop('missing',inplace=True)
closedcomptotal = closedcomptotal.sort_values('company_name', ascending=False)
closedcomptotal
# Out:
#                            company_name
# company_country_code_left
# USA                                7479
# GBR                                 527
# CAN                                 342
# RUS                                 250
# FRA                                 197
# ...                                 ...
# DOM                                   1
# PRI                                   1
# GHA                                   1
# GTM                                   1
# LKA                                   1
#
# [93 rows x 1 columns]

# %% [markdown]
# Here's a heatmap that illustrates the previous dataframe. It shows us clearly that the US has the most closed companies while others have less. We will take a sample of the first 10 and consider the rest outliers (as their values are 1) because it will be hard to visualize them and their valus won't affect the analysis much.

# %%
closedcomptotalsample = closedcomptotal.head(10)
sns.heatmap(closedcomptotalsample, vmin=100, vmax=7000);

# %% [markdown]
# Now we categorize the operating companies

# %%
operatingcomp_invests = comp_invests[comp_invests['status'] == 'operating']
operatingcomp_invests
# Out:
#                 company_permalink_left        company_name  \
# 24834            /organization/hashoff            #HASHOFF
# 0                  /organization/-fame               #fame
# 59865  /organization/tv-communications  &TV Communications
# 48652    /organization/rock-your-paper   'Rock' Your Paper
# 48652    /organization/rock-your-paper   'Rock' Your Paper
# ...                                ...                 ...
# 18338               /organization/enso             Еnso.fm
# 51421              /organization/shwrm             ​Shwrüm
# 63581             /organization/wested             ​WestEd
# 10952          /organization/chishenma       吃神马 ChiShenMa
# 10952          /organization/chishenma       吃神马 ChiShenMa
#
#                        homepage_url  \
# 24834        http://www.hashoff.com
# 0                http://livfame.com
# 59865         http://enjoyandtv.com
# 48652  http://www.rockyourpaper.org
# 48652  http://www.rockyourpaper.org
# ...                             ...
# 18338                http://enso.fm
# 51421         http://www.shwrum.com
# 63581        http://www.wested.org/
# 10952             http://chishen.ma
# 10952             http://chishen.ma
#
#                               company_category_list_left  funding_total_usd  \
# 24834                Digital Media|Internet|Social Media       9.550000e+05
# 0                                                  Media       1.000000e+07
# 59865                                              Games       4.000000e+06
# 48652                               Education|Publishing       6.038500e+04
# 48652                               Education|Publishing       6.038500e+04
# ...                                                  ...                ...
# 18338  Algorithms|Casual Games|Content Discovery|Edis...       2.783840e+04
# 51421   Design|Fashion|Internet|Mobile|Shopping|Software       5.000000e+04
# 63581                                         Nonprofits       3.000000e+06
# 10952                 Mobile|Restaurants|Specialty Foods       0.000000e+00
# 10952                 Mobile|Restaurants|Specialty Foods       0.000000e+00
#
#           status company_country_code_left company_city_left  funding_rounds  \
# 24834  operating                       USA            Denver               2
# 0      operating                       IND            Mumbai               1
# 59865  operating                       USA       Los Angeles               2
# 48652  operating                       EST           Tallinn               2
# 48652  operating                       EST           Tallinn               2
# ...          ...                       ...               ...             ...
# 18338  operating                       BGR             Sofia               1
# 51421  operating                       USA       Gainesville               1
# 63581  operating                       USA     San Francisco               1
# 10952  operating                       CHN          Shanghai               1
# 10952  operating                       CHN          Shanghai               1
#
#                          founded_at  ...  \
# 24834 2014-04-01 00:00:00.000000000  ...
# 0     2011-04-12 20:46:43.240577680  ...
# 59865 2006-09-09 20:46:43.240577680  ...
# 48652 2012-10-26 00:00:00.000000000  ...
# 48652 2012-10-26 00:00:00.000000000  ...
# ...                             ...  ...
# 18338 2015-06-29 00:00:00.000000000  ...
# 51421 2013-01-01 00:00:00.000000000  ...
# 63581 2010-10-27 20:46:43.240577680  ...
# 10952 2014-01-01 00:00:00.000000000  ...
# 10952 2014-01-01 00:00:00.000000000  ...
#
#                                  investor_name investor_country_code  \
# 24834                                      NaN                   NaN
# 0                                          NaN                   NaN
# 59865                                      NaN                   NaN
# 48652                        Startup Wise Guys                   EST
# 48652                           Start-Up Chile                   CHL
# ...                                        ...                   ...
# 18338  Axel Springer Plug and Play Accelerator                   DEU
# 51421                                      NaN                   NaN
# 63581                                      NaN                   NaN
# 10952                          Chinaccelerator                   CHN
# 10952                                     SOSV                   USA
#
#       investor_state_code investor_city  \
# 24834                 NaN           NaN
# 0                     NaN           NaN
# 59865                 NaN           NaN
# 48652                   1       Tallinn
# 48652                  12      Santiago
# ...                   ...           ...
# 18338                  16        Berlin
# 51421                 NaN           NaN
# 63581                 NaN           NaN
# 10952                  23      Shanghai
# 10952                  NJ     Princeton
#
#                                funding_round_permalink funding_round_type  \
# 24834                                              NaN                NaN
# 0                                                  NaN                NaN
# 59865                                              NaN                NaN
# 48652  /funding-round/f28a7e530f9e4b29783d2c0aa4c68c62               seed
# 48652  /funding-round/f06b420775f7cb6c1541a9db526534bb               seed
# ...                                                ...                ...
# 18338  /funding-round/53becfd9582cda62dcb2a6c9970810b3               seed
# 51421                                              NaN                NaN
# 63581                                              NaN                NaN
# 10952  /funding-round/aa4cde05f64453c60ca85a06a962f381               seed
# 10952  /funding-round/aa4cde05f64453c60ca85a06a962f381               seed
#
#       funding_round_code  funded_at raised_amount_usd total_raised
# 24834                NaN        NaT               NaN          NaN
# 0                    NaN        NaT               NaN          NaN
# 59865                NaN        NaT               NaN          NaN
# 48652                NaN 2013-12-01      2.038500e+04  30192.50000
# 48652                NaN 2012-08-09      4.000000e+04  30192.50000
# ...                  ...        ...               ...          ...
# 18338                NaN 2015-07-01      2.783840e+04  27838.40363
# 51421                NaN        NaT               NaN          NaN
# 63581                NaN        NaT               NaN          NaN
# 10952                NaN 2014-02-28      1.493930e+07          NaN
# 10952                NaN 2014-02-28      1.493930e+07          NaN
#
# [138246 rows x 29 columns]

# %% [markdown]
# We will group by the country and see how many operating companies in each country.

# %%
operatingtotal = pd.DataFrame(operatingcomp_invests.groupby(['company_country_code_left'])['company_name'].count())
operatingtotal.drop('missing',inplace=True)
operatingtotal = operatingtotal.sort_values('company_name', ascending=False)
operatingtotal
# Out:
#                            company_name
# company_country_code_left
# USA                               88697
# GBR                                7645
# CAN                                3496
# IND                                3364
# CHN                                3179
# ...                                 ...
# SEN                                   1
# ROU                                   1
# QAT                                   1
# MSR                                   1
# AND                                   1
#
# [145 rows x 1 columns]

# %% [markdown]
# The heatmap yet again shows that the US has the most operating companies which seems noticable because it also had the most closed companies.We will take a sample of the first 10 and consider the rest outliers (as their values are 1) because it will be hard to visualize them and their valus won't affect the analysis much.

# %%
operatingtotalsample = operatingtotal.head(10)
operatingtotalsample
sns.heatmap(operatingtotalsample, vmin=1000, vmax=10000)
# Out:
# <AxesSubplot:ylabel='company_country_code_left'>

# %% [markdown]
# After looking in the closed and operating companies we see that we still can't determine if the country has more operting companies than the closed or not, so let's take one country and compare. For example, let's look at the USA since it has the highest number of operating companies and closed companies.

# %%
df = comp_invests.loc[comp_invests['company_country_code_left'] == 'USA']
df = pd.DataFrame(df.groupby(['status'])['status'].count())
df
# Out:
#            status
# status
# acquired    21176
# closed       7479
# ipo          5249
# operating   88697

# %% [markdown]
# The dataframe above shows us how although the US has strong economics and massive amount of investor as seen earlier, it has a bulk of closed companies but compared to operting it's only 0.08 (7956/92228) of it. So, this reflects that The US must have facilities and enough fundings for startups.

# %% [markdown]
# If we quickly look at another example and that is the country after the US which is The United Kingdom (GBR) it had 7846 oeprating company with 567 closed companies. Ofcourse, since the US is much bigger the number are biggr but we will look at the ratio between the closed to operating companies to find it 0.07. SIgnificantly it is closed to the US and we can consider that both countries have the same facilities and both show that the lack of investors can affect the companies.

# %% [markdown]
# In conclusion, as the ratio the ratio between the closed to operating companies increases, the more dificult it is for a company to start up. This will lead us to look closed into factors that makes those countries a difficult place to start a company.

# %% [markdown]
# ## Question 3 (Farah)

# %% [markdown]
# ### Does the number of investors in a country affect the number of successful companies in this country?

# %% [markdown]
# First, let's narrow down to the investors that invested in the companies in the same country because there's a posibility that an investor invested in a company in a different country.

# %%
comp_investors = invests[invests['company_country_code'] == invests['investor_country_code']]
comp_investors
# Out:
#                                         company_permalink  \
# 160690                              /organization/waywire
# 160689                              /organization/waywire
# 160688                              /organization/waywire
# 160693                              /organization/waywire
# 160691                              /organization/waywire
# ...                                                   ...
# 60815                            /organization/gps-optics
# 168644                                /organization/Áeron
# 168646  /organization/İnovatiff-reklam-ve-tanıtım-hizm...
# 47814                                  /organization/enso
# 29271                             /organization/chishenma
#
#                                       company_name  \
# 160690                                    #waywire
# 160689                                    #waywire
# 160688                                    #waywire
# 160693                                    #waywire
# 160691                                    #waywire
# ...                                            ...
# 60815                                 µ-GPS Optics
# 168644                                       ÁERON
# 168646  İnovatiff Reklam ve Tanıtım Hizmetleri Tic
# 47814                                      Еnso.fm
# 29271                                吃神马 ChiShenMa
#
#                                     company_category_list  \
# 160690           Entertainment|News|Politics|Social Media
# 160689           Entertainment|News|Politics|Social Media
# 160688           Entertainment|News|Politics|Social Media
# 160693           Entertainment|News|Politics|Social Media
# 160691           Entertainment|News|Politics|Social Media
# ...                                                   ...
# 60815                                 Hardware + Software
# 168644                                            missing
# 168646                 Consumer Goods|E-Commerce|Internet
# 47814   Algorithms|Casual Games|Content Discovery|Edis...
# 29271                  Mobile|Restaurants|Specialty Foods
#
#        company_country_code company_state_code company_city  \
# 160690                  USA                 NY     New York
# 160689                  USA                 NY     New York
# 160688                  USA                 NY     New York
# 160693                  USA                 NY     New York
# 160691                  USA                 NY     New York
# ...                     ...                ...          ...
# 60815                   DEU                 15    Meiningen
# 168644              missing            missing      missing
# 168646              missing            missing      missing
# 47814                   BGR                 42        Sofia
# 29271                   CHN                 23     Shanghai
#
#                                      investor_permalink  \
# 160690               /organization/innovation-endeavors
# 160689                /organization/first-round-capital
# 160688                           /organization/afsquare
# 160693                              /person/troy-carter
# 160691                              /person/jeff-weiner
# ...                                                 ...
# 60815                              /organization/mic-ag
# 168644  /organization/sz-chenyi-capital-fund-management
# 168646                           /person/serkan-erdoğan
# 47814                              /organization/eleven
# 29271                     /organization/chinaccelerator
#
#                             investor_name investor_country_code  \
# 160690               Innovation Endeavors                   USA
# 160689                        First Round                   USA
# 160688                           AFSquare                   USA
# 160693                        Troy Carter                   USA
# 160691                        Jeff Weiner                   USA
# ...                                   ...                   ...
# 60815                              Mic AG                   DEU
# 168644  Széchenyi Capital Fund Management               missing
# 168646                     Serkan Erdoğan               missing
# 47814                              Eleven                   BGR
# 29271                     Chinaccelerator                   CHN
#
#        investor_state_code  investor_city  \
# 160690                  CA      Palo Alto
# 160689                  CA  San Francisco
# 160688                  CA    Culver City
# 160693             missing    Culver City
# 160691             missing  Mountain View
# ...                    ...            ...
# 60815                    2         Munich
# 168644             missing        missing
# 168646             missing        missing
# 47814                   42          Sofia
# 29271                   23       Shanghai
#
#                                 funding_round_permalink funding_round_type  \
# 160690  /funding-round/cc409188fa2b63482bd9008f682c2efa               seed
# 160689  /funding-round/cc409188fa2b63482bd9008f682c2efa               seed
# 160688  /funding-round/cc409188fa2b63482bd9008f682c2efa               seed
# 160693  /funding-round/cc409188fa2b63482bd9008f682c2efa               seed
# 160691  /funding-round/cc409188fa2b63482bd9008f682c2efa               seed
# ...                                                 ...                ...
# 60815   /funding-round/24c3f275dd46990719a1f82a402d8b5c            venture
# 168644  /funding-round/59f4dce44723b794f21ded3daed6e4fe            venture
# 168646  /funding-round/af942869878d2cd788ef5189b435ebc4              grant
# 47814   /funding-round/53becfd9582cda62dcb2a6c9970810b3               seed
# 29271   /funding-round/aa4cde05f64453c60ca85a06a962f381               seed
#
#        funding_round_code  funded_at  raised_amount_usd  total_raised
# 160690                NaN 2012-06-30       1.750000e+06  1.750000e+06
# 160689                NaN 2012-06-30       1.750000e+06  1.750000e+06
# 160688                NaN 2012-06-30       1.750000e+06  1.750000e+06
# 160693                NaN 2012-06-30       1.750000e+06  1.750000e+06
# 160691                NaN 2012-06-30       1.750000e+06  1.750000e+06
# ...                   ...        ...                ...           ...
# 60815                 NaN 2006-12-01       4.000000e+04  4.000000e+04
# 168644                  A 2014-08-01       1.493930e+07           NaN
# 168646                NaN 2013-10-01       1.485100e+04  1.485100e+04
# 47814                 NaN 2015-07-01       2.783840e+04  2.783840e+04
# 29271                 NaN 2014-02-28       1.493930e+07           NaN
#
# [104451 rows x 17 columns]

# %% [markdown]
# Now, let's merge the new dataset with companies so we can get the status.

# %%
comp_investors = comp_investors.join(companies.set_index('company_name'), on='company_name',lsuffix='_left', rsuffix='_right')
comp_investors
# Out:
#                                    company_permalink_left  \
# 160690                              /organization/waywire
# 160689                              /organization/waywire
# 160688                              /organization/waywire
# 160693                              /organization/waywire
# 160691                              /organization/waywire
# ...                                                   ...
# 60815                            /organization/gps-optics
# 168644                                /organization/Áeron
# 168646  /organization/İnovatiff-reklam-ve-tanıtım-hizm...
# 47814                                  /organization/enso
# 29271                             /organization/chishenma
#
#                                       company_name  \
# 160690                                    #waywire
# 160689                                    #waywire
# 160688                                    #waywire
# 160693                                    #waywire
# 160691                                    #waywire
# ...                                            ...
# 60815                                 µ-GPS Optics
# 168644                                       ÁERON
# 168646  İnovatiff Reklam ve Tanıtım Hizmetleri Tic
# 47814                                      Еnso.fm
# 29271                                吃神马 ChiShenMa
#
#                                company_category_list_left  \
# 160690           Entertainment|News|Politics|Social Media
# 160689           Entertainment|News|Politics|Social Media
# 160688           Entertainment|News|Politics|Social Media
# 160693           Entertainment|News|Politics|Social Media
# 160691           Entertainment|News|Politics|Social Media
# ...                                                   ...
# 60815                                 Hardware + Software
# 168644                                            missing
# 168646                 Consumer Goods|E-Commerce|Internet
# 47814   Algorithms|Casual Games|Content Discovery|Edis...
# 29271                  Mobile|Restaurants|Specialty Foods
#
#        company_country_code_left company_state_code company_city_left  \
# 160690                       USA                 NY          New York
# 160689                       USA                 NY          New York
# 160688                       USA                 NY          New York
# 160693                       USA                 NY          New York
# 160691                       USA                 NY          New York
# ...                          ...                ...               ...
# 60815                        DEU                 15         Meiningen
# 168644                   missing            missing           missing
# 168646                   missing            missing           missing
# 47814                        BGR                 42             Sofia
# 29271                        CHN                 23          Shanghai
#
#                                      investor_permalink  \
# 160690               /organization/innovation-endeavors
# 160689                /organization/first-round-capital
# 160688                           /organization/afsquare
# 160693                              /person/troy-carter
# 160691                              /person/jeff-weiner
# ...                                                 ...
# 60815                              /organization/mic-ag
# 168644  /organization/sz-chenyi-capital-fund-management
# 168646                           /person/serkan-erdoğan
# 47814                              /organization/eleven
# 29271                     /organization/chinaccelerator
#
#                             investor_name investor_country_code  \
# 160690               Innovation Endeavors                   USA
# 160689                        First Round                   USA
# 160688                           AFSquare                   USA
# 160693                        Troy Carter                   USA
# 160691                        Jeff Weiner                   USA
# ...                                   ...                   ...
# 60815                              Mic AG                   DEU
# 168644  Széchenyi Capital Fund Management               missing
# 168646                     Serkan Erdoğan               missing
# 47814                              Eleven                   BGR
# 29271                     Chinaccelerator                   CHN
#
#        investor_state_code  ...  \
# 160690                  CA  ...
# 160689                  CA  ...
# 160688                  CA  ...
# 160693             missing  ...
# 160691             missing  ...
# ...                    ...  ...
# 60815                    2  ...
# 168644             missing  ...
# 168646             missing  ...
# 47814                   42  ...
# 29271                   23  ...
#
#                               company_category_list_right funding_total_usd  \
# 160690           Entertainment|News|Politics|Social Media      1.750000e+06
# 160689           Entertainment|News|Politics|Social Media      1.750000e+06
# 160688           Entertainment|News|Politics|Social Media      1.750000e+06
# 160693           Entertainment|News|Politics|Social Media      1.750000e+06
# 160691           Entertainment|News|Politics|Social Media      1.750000e+06
# ...                                                   ...               ...
# 60815                                 Hardware + Software      4.000000e+04
# 168644                                            missing      0.000000e+00
# 168646                 Consumer Goods|E-Commerce|Internet      1.485100e+04
# 47814   Algorithms|Casual Games|Content Discovery|Edis...      2.783840e+04
# 29271                  Mobile|Restaurants|Specialty Foods      0.000000e+00
#
#            status company_country_code_right company_city_right  \
# 160690   acquired                        USA           New York
# 160689   acquired                        USA           New York
# 160688   acquired                        USA           New York
# 160693   acquired                        USA           New York
# 160691   acquired                        USA           New York
# ...           ...                        ...                ...
# 60815   operating                        DEU          Meiningen
# 168644  operating                        HUN            missing
# 168646  operating                    missing            missing
# 47814   operating                        BGR              Sofia
# 29271   operating                        CHN           Shanghai
#
#         funding_rounds                    founded_at first_funding_at  \
# 160690             1.0 2012-06-01 00:00:00.000000000       2012-06-30
# 160689             1.0 2012-06-01 00:00:00.000000000       2012-06-30
# 160688             1.0 2012-06-01 00:00:00.000000000       2012-06-30
# 160693             1.0 2012-06-01 00:00:00.000000000       2012-06-30
# 160691             1.0 2012-06-01 00:00:00.000000000       2012-06-30
# ...                ...                           ...              ...
# 60815              1.0 2006-01-01 00:00:00.000000000       2006-12-01
# 168644             1.0 2011-01-01 00:00:00.000000000       2014-08-01
# 168646             1.0 2010-01-06 20:46:43.240577680       2013-10-01
# 47814              1.0 2015-06-29 00:00:00.000000000       2015-07-01
# 29271              1.0 2014-01-01 00:00:00.000000000       2014-02-28
#
#        last_funding_at       time_before_first_fund
# 160690      2012-06-30             29 days 00:00:00
# 160689      2012-06-30             29 days 00:00:00
# 160688      2012-06-30             29 days 00:00:00
# 160693      2012-06-30             29 days 00:00:00
# 160691      2012-06-30             29 days 00:00:00
# ...                ...                          ...
# 60815       2006-12-01            334 days 00:00:00
# 168644      2014-08-01           1308 days 00:00:00
# 168646      2013-10-01 1363 days 03:13:16.759422320
# 47814       2015-07-01              2 days 00:00:00
# 29271       2014-02-28             58 days 00:00:00
#
# [105663 rows x 29 columns]

# %% [markdown]
# Then we will categorize our data according to its status.

# %%
operatingcomp_invests = comp_investors[comp_investors['status'] == 'operating']
operatingcomp_invests
# Out:
#                                    company_permalink_left  \
# 123699                      /organization/rock-your-paper
# 25583                              /organization/caravelo
# 0                                   /organization/0-6-com
# 2                        /organization/01games-technology
# 30                              /organization/1-2-3-listo
# ...                                                   ...
# 60815                            /organization/gps-optics
# 168644                                /organization/Áeron
# 168646  /organization/İnovatiff-reklam-ve-tanıtım-hizm...
# 47814                                  /organization/enso
# 29271                             /organization/chishenma
#
#                                       company_name  \
# 123699                           'Rock' Your Paper
# 25583                                 ( caravelo (
# 0                                          0-6.com
# 2                               01Games Technology
# 30                                     1,2,3 Listo
# ...                                            ...
# 60815                                 µ-GPS Optics
# 168644                                       ÁERON
# 168646  İnovatiff Reklam ve Tanıtım Hizmetleri Tic
# 47814                                      Еnso.fm
# 29271                                吃神马 ChiShenMa
#
#                                company_category_list_left  \
# 123699                               Education|Publishing
# 25583                Information Technology|Online Travel
# 0                                             Curated Web
# 2                                                   Games
# 30                                             E-Commerce
# ...                                                   ...
# 60815                                 Hardware + Software
# 168644                                            missing
# 168646                 Consumer Goods|E-Commerce|Internet
# 47814   Algorithms|Casual Games|Content Discovery|Edis...
# 29271                  Mobile|Restaurants|Specialty Foods
#
#        company_country_code_left company_state_code company_city_left  \
# 123699                       EST                  1           Tallinn
# 25583                        ESP                 56         Barcelona
# 0                            CHN                 22           Beijing
# 2                            HKG            missing         Hong Kong
# 30                           CHL                 12        Las Condes
# ...                          ...                ...               ...
# 60815                        DEU                 15         Meiningen
# 168644                   missing            missing           missing
# 168646                   missing            missing           missing
# 47814                        BGR                 42             Sofia
# 29271                        CHN                 23          Shanghai
#
#                                      investor_permalink  \
# 123699                  /organization/startup-wise-guys
# 25583    /organization/fundacin-jos-manuel-entrecanales
# 0                     /organization/dt-capital-partners
# 2                     /organization/cyberport-hong-kong
# 30                         /organization/start-up-chile
# ...                                                 ...
# 60815                              /organization/mic-ag
# 168644  /organization/sz-chenyi-capital-fund-management
# 168646                           /person/serkan-erdoğan
# 47814                              /organization/eleven
# 29271                     /organization/chinaccelerator
#
#                              investor_name investor_country_code  \
# 123699                   Startup Wise Guys                   EST
# 25583   Fundación José Manuel Entrecanales                   ESP
# 0                      DT Capital Partners                   CHN
# 2                      Cyberport Hong Kong                   HKG
# 30                          Start-Up Chile                   CHL
# ...                                    ...                   ...
# 60815                               Mic AG                   DEU
# 168644   Széchenyi Capital Fund Management               missing
# 168646                      Serkan Erdoğan               missing
# 47814                               Eleven                   BGR
# 29271                      Chinaccelerator                   CHN
#
#        investor_state_code  ...  \
# 123699                   1  ...
# 25583                   29  ...
# 0                       23  ...
# 2                  missing  ...
# 30                      12  ...
# ...                    ...  ...
# 60815                    2  ...
# 168644             missing  ...
# 168646             missing  ...
# 47814                   42  ...
# 29271                   23  ...
#
#                               company_category_list_right funding_total_usd  \
# 123699                               Education|Publishing      6.038500e+04
# 25583                Information Technology|Online Travel      1.089811e+06
# 0                                             Curated Web      2.000000e+06
# 2                                                   Games      4.125000e+04
# 30                                             E-Commerce      4.000000e+04
# ...                                                   ...               ...
# 60815                                 Hardware + Software      4.000000e+04
# 168644                                            missing      0.000000e+00
# 168646                 Consumer Goods|E-Commerce|Internet      1.485100e+04
# 47814   Algorithms|Casual Games|Content Discovery|Edis...      2.783840e+04
# 29271                  Mobile|Restaurants|Specialty Foods      0.000000e+00
#
#            status company_country_code_right company_city_right  \
# 123699  operating                        EST            Tallinn
# 25583   operating                        ESP          Barcelona
# 0       operating                        CHN            Beijing
# 2       operating                        HKG          Hong Kong
# 30      operating                        CHL         Las Condes
# ...           ...                        ...                ...
# 60815   operating                        DEU          Meiningen
# 168644  operating                        HUN            missing
# 168646  operating                    missing            missing
# 47814   operating                        BGR              Sofia
# 29271   operating                        CHN           Shanghai
#
#         funding_rounds                    founded_at first_funding_at  \
# 123699             2.0 2012-10-26 00:00:00.000000000       2012-08-09
# 25583              2.0 2010-05-01 00:00:00.000000000       2012-01-01
# 0                  1.0 2007-01-01 00:00:00.000000000       2008-03-19
# 2                  1.0 2010-10-06 20:46:43.240577680       2014-07-01
# 30                 1.0 2012-01-01 00:00:00.000000000       2013-02-18
# ...                ...                           ...              ...
# 60815              1.0 2006-01-01 00:00:00.000000000       2006-12-01
# 168644             1.0 2011-01-01 00:00:00.000000000       2014-08-01
# 168646             1.0 2010-01-06 20:46:43.240577680       2013-10-01
# 47814              1.0 2015-06-29 00:00:00.000000000       2015-07-01
# 29271              1.0 2014-01-01 00:00:00.000000000       2014-02-28
#
#        last_funding_at       time_before_first_fund
# 123699      2013-12-01           -78 days +00:00:00
# 25583       2015-07-22            610 days 00:00:00
# 0           2008-03-19            443 days 00:00:00
# 2           2014-07-01 1363 days 03:13:16.759422320
# 30          2013-02-18            414 days 00:00:00
# ...                ...                          ...
# 60815       2006-12-01            334 days 00:00:00
# 168644      2014-08-01           1308 days 00:00:00
# 168646      2013-10-01 1363 days 03:13:16.759422320
# 47814       2015-07-01              2 days 00:00:00
# 29271       2014-02-28             58 days 00:00:00
#
# [73622 rows x 29 columns]

# %%
closedcomp_invests = comp_investors[comp_investors['status'] == 'closed']
closedcomp_invests
# Out:
#              company_permalink_left          company_name  \
# 128     /organization/11i-solutions         11i Solutions
# 238        /organization/1c-company            1C Company
# 239             /organization/1cast                 1Cast
# 341     /organization/2100b-com-llc  2100b Sausalito LLC.
# 422           /organization/25eight               25eight
# ...                             ...                   ...
# 164453     /organization/xlander-ru            xLander.ru
# 164443          /organization/xkoto                 xkoto
# 164444          /organization/xkoto                 xkoto
# 165195         /organization/yes-no                yes.no
# 165610          /organization/yoone                 yoone
#
#                                company_category_list_left  \
# 128                                   Enterprise Software
# 238                            Games|Software|Video Games
# 239                          Content|Lifestyle|News|Video
# 341             Advertising|Direct Marketing|Social Media
# 422                              DIY|Electronics|Software
# ...                                                   ...
# 164453  Adventure Travel|Reviews and Recommendations|S...
# 164443                                           Software
# 164444                                           Software
# 165195                           Q&A|Social Network Media
# 165610                                              Games
#
#        company_country_code_left company_state_code company_city_left  \
# 128                          USA                 AL        Huntsville
# 238                          RUS                 48            Moscow
# 239                          USA                 WA          Kirkland
# 341                          USA                 CA         Sausalito
# 422                          USA                 CA     San Francisco
# ...                          ...                ...               ...
# 164453                   missing            missing           missing
# 164443                       USA                 MA           Waltham
# 164444                       USA                 MA           Waltham
# 165195                       ISR                  5          Tel Aviv
# 165610                       DEU                  7         Bielefeld
#
#                                   investor_permalink  \
# 128        /organization/steel-pier-capital-advisors
# 238     /organization/baring-vostok-capital-partners
# 239               /organization/eagle-river-holdings
# 341                       /organization/seikouri-inc
# 422                   /organization/innovation-works
# ...                                              ...
# 164453     /organization/aurora-venture-capital-fund
# 164443              /organization/grandbanks-capital
# 164444              /organization/grandbanks-capital
# 165195                          /person/assaf-levy-3
# 165610                         /organization/hackfwd
#
#                          investor_name investor_country_code  \
# 128        Steel Pier Capital Advisors                   USA
# 238     Baring Vostok Capital Partners                   RUS
# 239               Eagle River Holdings                   USA
# 341                     SEIKOURI, Inc.                   USA
# 422                   Innovation Works                   USA
# ...                                ...                   ...
# 164453     Aurora Venture Capital Fund               missing
# 164443              GrandBanks Capital                   USA
# 164444              GrandBanks Capital                   USA
# 165195                      Assaf Levy                   ISR
# 165610                         HackFwd                   DEU
#
#        investor_state_code  ...  \
# 128                     NY  ...
# 238                     48  ...
# 239                     WA  ...
# 341                     NY  ...
# 422                     PA  ...
# ...                    ...  ...
# 164453             missing  ...
# 164443                  MA  ...
# 164444                  MA  ...
# 165195             missing  ...
# 165610                   4  ...
#
#                               company_category_list_right funding_total_usd  \
# 128                                   Enterprise Software         1800000.0
# 238                            Games|Software|Video Games       200000000.0
# 239                          Content|Lifestyle|News|Video               0.0
# 341             Advertising|Direct Marketing|Social Media           50000.0
# 422                              DIY|Electronics|Software           25000.0
# ...                                                   ...               ...
# 164453  Adventure Travel|Reviews and Recommendations|S...         1000000.0
# 164443                                           Software        11035000.0
# 164444                                           Software        11035000.0
# 165195                           Q&A|Social Network Media         1000000.0
# 165610                                              Games          197597.0
#
#         status company_country_code_right company_city_right  funding_rounds  \
# 128     closed                        USA         Huntsville             1.0
# 238     closed                        RUS             Moscow             1.0
# 239     closed                        USA           Kirkland             1.0
# 341     closed                        USA          Sausalito             2.0
# 422     closed                        USA      San Francisco             1.0
# ...        ...                        ...                ...             ...
# 164453  closed                    missing            missing             1.0
# 164443  closed                        USA            Waltham             3.0
# 164444  closed                        USA            Waltham             3.0
# 165195  closed                        ISR           Tel Aviv             1.0
# 165610  closed                        DEU          Bielefeld             1.0
#
#                           founded_at first_funding_at last_funding_at  \
# 128    2007-06-27 20:46:43.240577680       2011-03-22      2011-03-22
# 238    1991-01-01 00:00:00.000000000       2011-10-03      2011-10-03
# 239    2006-06-01 00:00:00.000000000       2008-08-12      2008-08-12
# 341    2011-06-15 00:00:00.000000000       2013-01-01      2013-01-01
# 422    2006-05-03 20:46:43.240577680       2010-01-26      2010-01-26
# ...                              ...              ...             ...
# 164453 2008-10-09 20:46:43.240577680       2012-07-04      2012-07-04
# 164443 2005-01-01 00:00:00.000000000       2005-11-01      2009-01-26
# 164444 2005-01-01 00:00:00.000000000       2005-11-01      2009-01-26
# 165195 2015-01-01 00:00:00.000000000       2015-05-01      2015-05-01
# 165610 2010-11-03 00:00:00.000000000       2010-11-03      2010-11-03
#
#              time_before_first_fund
# 128    1363 days 03:13:16.759422320
# 238              7580 days 00:00:00
# 239               803 days 00:00:00
# 341               566 days 00:00:00
# 422    1363 days 03:13:16.759422320
# ...                             ...
# 164453 1363 days 03:13:16.759422320
# 164443            304 days 00:00:00
# 164444            304 days 00:00:00
# 165195            120 days 00:00:00
# 165610              0 days 00:00:00
#
# [6195 rows x 29 columns]

# %% [markdown]
# Next, we will group by the investor's country to see how many investors in each country invested in the operating companies.

# %%
operatingcomp_investstotal = pd.DataFrame(operatingcomp_invests.groupby(['investor_country_code'])['investor_name'].count())
operatingcomp_investstotal.drop('missing',inplace=True)
operatingcomp_investstotal = operatingcomp_investstotal.sort_values('investor_name', ascending=False)
operatingcomp_investstotal
# Out:
#                        investor_name
# investor_country_code
# USA                            56263
# GBR                             3412
# CHN                             1343
# CAN                             1268
# FRA                             1227
# ...                              ...
# CYP                                1
# LUX                                1
# PSE                                1
# LKA                                1
# GTM                                1
#
# [72 rows x 1 columns]

# %% [markdown]
# Let's visualize our findinfs through a sample of the dataframe

# %%
operatingcomp_investstotal = operatingcomp_investstotal.head(10)
sns.heatmap(operatingcomp_investstotal, vmin=100, vmax=10000)
# Out:
# <AxesSubplot:ylabel='investor_country_code'>

# %% [markdown]
# We will do the same for the closed companies

# %%
closedcomp_investstotal = pd.DataFrame(closedcomp_invests.groupby(['investor_country_code'])['investor_name'].count())
closedcomp_investstotal.drop('missing',inplace=True)
closedcomp_investstotal = closedcomp_investstotal.sort_values('investor_name', ascending=False)
closedcomp_investstotal
# Out:
#                        investor_name
# investor_country_code
# USA                             4784
# GBR                              261
# CAN                              130
# RUS                               97
# FRA                               88
# ISR                               74
# DEU                               70
# SWE                               38
# ESP                               34
# IND                               26
# JPN                               20
# FIN                               19
# NLD                               19
# BEL                               18
# AUS                               17
# CHE                               16
# ARG                               15
# IRL                               13
# CHN                               13
# BRA                               12
# BGR                               12
# CHL                               12
# SGP                               10
# ITA                               10
# DNK                                9
# AUT                                8
# NOR                                7
# POL                                7
# EST                                5
# HKG                                4
# SAU                                3
# NZL                                3
# MEX                                3
# PRT                                3
# ZAF                                3
# KOR                                3
# CZE                                2
# HUN                                2
# SVN                                2
# MYS                                2
# TUR                                2
# PHL                                1
# GHA                                1
# BLM                                1
# SVK                                1
# THA                                1
# GRC                                1
# VNM                                1
# LVA                                1

# %%
closedcomp_investstotal = closedcomp_investstotal.head(10)
sns.heatmap(closedcomp_investstotal, vmin=10, vmax=1000)
# Out:
# <AxesSubplot:ylabel='investor_country_code'>

# %% [markdown]
# We can see from the data obtained how the number of investors in general in the closed companies is significantlly lower than the those who invested in the operating ones. This can be seen by establishing a ratio between the investors in closed companies to the investors in the operating companies and we will see the difference.

# %%
ratio_df = operatingcomp_investstotal/closedcomp_investstotal
ratio_df
# Out:
#                        investor_name
# investor_country_code
# CAN                         9.753846
# CHN                              NaN
# DEU                        16.771429
# ESP                        21.970588
# FRA                        13.943182
# GBR                        13.072797
# IND                        29.769231
# ISR                        10.324324
# JPN                              NaN
# RUS                              NaN
# SWE                              NaN
# USA                        11.760661

# %% [markdown]
# Constructing a ratio between the number of investors who invested in the operating companies and the investors who invested in closed companies and it is clearly seen that all of the ratios are > than 1 which means that more investors invested in those companies that helped them in sustaining being operating.

# %% [markdown]
# In conclusion, investing plays an important part in keeping the company operating. As the number of investors increases, the chance of success increases.

# %% [markdown]
# ## Rest of Questions (Aisha)

# %% [markdown]
# Heads-up:
# 1) Here I didn't use the cleaned dataset version, as we can infer some insights from the null values
# 2)Some of the data could have been better if they were represented in charts but due to their data types it wasn't really possible and some of the others with favorable data types had labelling merging with one another making it impossible to read.

# %% [markdown]
# ### Question 4 : Analyzing Funding Rounds

# %% [markdown]
# We'll check the number of times funding is repeated overall irrespective of the differenece in company status and then we will see the company statuses.

# %% [markdown]
# #### Companies data set

# %%
import pandas as pd
df=pd.read_csv('datasets/startups/companies.csv')
df.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list funding_total_usd  \
# 0                                              Media          10000000
# 1  Application Platforms|Real Time|Social Network...            700000
# 2                                  Apps|Games|Mobile           3406878
# 3                                        Curated Web           2000000
# 4                                           Software                 -
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN                    NaN            NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
#
#    funding_rounds founded_at first_funding_at last_funding_at
# 0               1        NaN         1/5/2015        1/5/2015
# 1               2   9/4/2014         3/1/2014      10/14/2014
# 2               1        NaN        1/30/2014       1/30/2014
# 3               1   1/1/2007        3/19/2008       3/19/2008
# 4               1   1/1/2010        7/24/2014       7/24/2014

# %%
df.drop(['state_code', 'region'],axis=1,inplace=True)
df['first_funding_at']=df['first_funding_at'].fillna("not available")
df.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list funding_total_usd  \
# 0                                              Media          10000000
# 1  Application Platforms|Real Time|Social Network...            700000
# 2                                  Apps|Games|Mobile           3406878
# 3                                        Curated Web           2000000
# 4                                           Software                 -
#
#       status country_code           city  funding_rounds founded_at  \
# 0  operating          IND         Mumbai               1        NaN
# 1  operating          USA  Delaware City               2   9/4/2014
# 2  operating          NaN            NaN               1        NaN
# 3  operating          CHN        Beijing               1   1/1/2007
# 4  operating          USA      Champaign               1   1/1/2010
#
#   first_funding_at last_funding_at
# 0         1/5/2015        1/5/2015
# 1         3/1/2014      10/14/2014
# 2        1/30/2014       1/30/2014
# 3        3/19/2008       3/19/2008
# 4        7/24/2014       7/24/2014

# %%
import matplotlib.pyplot as plt
df.status.hist()
plt.title('status difference')
# Out:
# Text(0.5, 1.0, 'status difference')

# %% [markdown]
# As the histogram above shows, we have more companies operating as compared to acquired ones which would imply that they received far more funding and produced more than those which were acquired.

# %% [markdown]
# #### IPO companies?

# %% [markdown]
# It's a situation in which one starts a business by soliciting capital from family, friends, and investors in exchange for a portion of the company. We go to an investor bank and inform them about the idea or product to raise money for this company. They will then introduce us to institutional investors / people who are interested in this idea or product, and they will sell some of the business's shares to assist in bringing the company to the public market. This helps raise a lot of money, sell shares at a reasonable price that suits the shareholder, raise more money through additional rounds of investment, and promote the brand because IPOs deliver a good credibility boost.
# The disadvantages include:
# When it comes to matters like openness, the SEC (Securities and Exchange Commission is the US federal agency in charge of regulating and managing financial markets) and exchanges have stringent criteria. As a result, public firms are required to reveal a great deal of business-related information, which may result in competitors obtaining access to material that is the company's trade secret.
# Less control as shareholders will now affect decision making.

# %% [markdown]
# We'll now separate companies in to 3 status categories; operating, acquired, and ipo. Then we'll compare the funding rounds based on these statuses.

# %%
operating=df.loc[df['status']=='operating']
acquired=df.loc[df['status']=='acquired']
ipo=df.loc[df['status']=='ipo']

# %% [markdown]
# #### 1-Operating companies

# %%
import matplotlib.pyplot as plt
operating.funding_rounds.value_counts().plot(kind="bar",alpha=0.5)
plt.title('Funding rounds')
plt.xlabel('funding')
plt.ylabel('funding frequency') 
plt.show()

# %% [markdown]
# The above curve can be matched to the values below and we can deduce that operating companies get more one time funding rounds that two.

# %%
operating['funding_rounds'].value_counts()
# Out:
# 1     34367
# 2      9871
# 3      4366
# 4      2066
# 5      1119
# 6       554
# 7       312
# 8       150
# 9        91
# 10       55
# 11       31
# 12       24
# 13       11
# 16        5
# 14        4
# 15        3
# 17        2
# 18        2
# 19        1
# Name: funding_rounds, dtype: int64

# %% [markdown]
# Now we will see how this differs from acquired companies.

# %% [markdown]
# #### 2-Acquired companies

# %%
#acquired companies

plt.title('funding rounds for aqcuired companies')
acquired.funding_rounds.value_counts().plot(kind="bar",alpha=0.5)
plt.title('Funding rounds')
plt.xlabel('funding')
plt.ylabel('funding frequency') 
plt.show()

# %% [markdown]
# This can be confirmed and further understood with the values below.

# %%
acquired['funding_rounds'].value_counts()
# Out:
# 1     2664
# 2     1287
# 3      772
# 4      411
# 5      194
# 6      115
# 7       54
# 8       15
# 10      13
# 9       11
# 11       9
# 15       1
# 12       1
# 18       1
# 17       1
# Name: funding_rounds, dtype: int64

# %% [markdown]
# As we can see, both operating and acquired companies get more one time funding rounds than 2 with operating companies having by far the largest fundings. For IPO companies is illustrated below.

# %% [markdown]
# #### 3-IPO companies

# %%
#ipo companies
import matplotlib.pyplot as plt

plt.title('funding rounds for IPO companies')
ipo.funding_rounds.value_counts().plot(kind="bar",alpha=0.5)
plt.title('Funding rounds')
plt.xlabel('funding')
plt.ylabel('funding frequency') 
plt.show()

# %%
ipo['funding_rounds'].value_counts()
# Out:
# 1     646
# 2     277
# 3     192
# 4     137
# 5     100
# 6      72
# 7      39
# 8      36
# 9      18
# 10     10
# 11      9
# 13      4
# 12      3
# 15      2
# 16      1
# 14      1
# Name: funding_rounds, dtype: int64

# %% [markdown]
# We can conclude that operating companies exceed in founding rounds but all have higher one time fundings.

# %% [markdown]
# #### Investments data set part

# %%
d=pd.read_csv('datasets/startups/investments.csv')
d.head()
# Out:
#                   company_permalink        company_name company_category_list  \
# 0             /organization/0-6-com             0-6.com           Curated Web
# 1    /organization/004-technologies    004 Technologies              Software
# 2  /organization/01games-technology  01Games Technology                 Games
# 3              /organization/0xdata              H2O.ai             Analytics
# 4              /organization/0xdata              H2O.ai             Analytics
#
#   company_country_code company_state_code         company_region  \
# 0                  CHN                 22                Beijing
# 1                  USA                 IL  Springfield, Illinois
# 2                  HKG                NaN              Hong Kong
# 3                  USA                 CA            SF Bay Area
# 4                  USA                 CA            SF Bay Area
#
#     company_city                    investor_permalink  \
# 0        Beijing     /organization/dt-capital-partners
# 1      Champaign       /organization/venturecapital-de
# 2      Hong Kong     /organization/cyberport-hong-kong
# 3  Mountain View             /organization/capital-one
# 4  Mountain View  /organization/nexus-venture-partners
#
#             investor_name investor_country_code investor_state_code  \
# 0     DT Capital Partners                   CHN                  23
# 1   VCDE Venture Partners                   DEU                   5
# 2     Cyberport Hong Kong                   HKG                 NaN
# 3             Capital One                   USA                  VA
# 4  Nexus Venture Partners                   USA                  CA
#
#     investor_region investor_city  \
# 0          Shanghai      Shanghai
# 1         Frankfurt     Frankfurt
# 2         Hong Kong     Hong Kong
# 3  Washington, D.C.        Mclean
# 4       SF Bay Area    Menlo Park
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 1  /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830            venture
# 2  /funding-round/7d53696f2b4f607a2f2a8cbb83d01839        undisclosed
# 3  /funding-round/3bb2ee4a2d89251a10aaa735b1180e44            venture
# 4  /funding-round/383a9bd2c04f7038bb543ccef5ba3eae               seed
#
#   funding_round_code  funded_at  raised_amount_usd
# 0                  A  3/19/2008          2000000.0
# 1                NaN  7/24/2014                NaN
# 2                NaN   7/1/2014            41250.0
# 3                  B  11/9/2015         20000000.0
# 4                NaN  5/22/2013          3000000.0

# %%
d.drop([ 'company_state_code','company_region','investor_state_code','investor_region'],axis=1,inplace=True)
d['raised_amount_usd']=d['raised_amount_usd'].fillna("not available")
d['funding_round_code']=d['funding_round_code'].fillna("not available")
d['company_country_code']=d['company_country_code'].fillna("not provided")
d['investor_country_code']=d['investor_country_code'].fillna("not provided")
d.head()
# Out:
#                   company_permalink        company_name company_category_list  \
# 0             /organization/0-6-com             0-6.com           Curated Web
# 1    /organization/004-technologies    004 Technologies              Software
# 2  /organization/01games-technology  01Games Technology                 Games
# 3              /organization/0xdata              H2O.ai             Analytics
# 4              /organization/0xdata              H2O.ai             Analytics
#
#   company_country_code   company_city                    investor_permalink  \
# 0                  CHN        Beijing     /organization/dt-capital-partners
# 1                  USA      Champaign       /organization/venturecapital-de
# 2                  HKG      Hong Kong     /organization/cyberport-hong-kong
# 3                  USA  Mountain View             /organization/capital-one
# 4                  USA  Mountain View  /organization/nexus-venture-partners
#
#             investor_name investor_country_code investor_city  \
# 0     DT Capital Partners                   CHN      Shanghai
# 1   VCDE Venture Partners                   DEU     Frankfurt
# 2     Cyberport Hong Kong                   HKG     Hong Kong
# 3             Capital One                   USA        Mclean
# 4  Nexus Venture Partners                   USA    Menlo Park
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 1  /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830            venture
# 2  /funding-round/7d53696f2b4f607a2f2a8cbb83d01839        undisclosed
# 3  /funding-round/3bb2ee4a2d89251a10aaa735b1180e44            venture
# 4  /funding-round/383a9bd2c04f7038bb543ccef5ba3eae               seed
#
#   funding_round_code  funded_at raised_amount_usd
# 0                  A  3/19/2008         2000000.0
# 1      not available  7/24/2014     not available
# 2      not available   7/1/2014           41250.0
# 3                  B  11/9/2015        20000000.0
# 4      not available  5/22/2013         3000000.0

# %%
d.drop_duplicates(subset=['company_country_code'])
d.drop_duplicates(subset=['investor_country_code'])
d.head()
# Out:
#                   company_permalink        company_name company_category_list  \
# 0             /organization/0-6-com             0-6.com           Curated Web
# 1    /organization/004-technologies    004 Technologies              Software
# 2  /organization/01games-technology  01Games Technology                 Games
# 3              /organization/0xdata              H2O.ai             Analytics
# 4              /organization/0xdata              H2O.ai             Analytics
#
#   company_country_code   company_city                    investor_permalink  \
# 0                  CHN        Beijing     /organization/dt-capital-partners
# 1                  USA      Champaign       /organization/venturecapital-de
# 2                  HKG      Hong Kong     /organization/cyberport-hong-kong
# 3                  USA  Mountain View             /organization/capital-one
# 4                  USA  Mountain View  /organization/nexus-venture-partners
#
#             investor_name investor_country_code investor_city  \
# 0     DT Capital Partners                   CHN      Shanghai
# 1   VCDE Venture Partners                   DEU     Frankfurt
# 2     Cyberport Hong Kong                   HKG     Hong Kong
# 3             Capital One                   USA        Mclean
# 4  Nexus Venture Partners                   USA    Menlo Park
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 1  /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830            venture
# 2  /funding-round/7d53696f2b4f607a2f2a8cbb83d01839        undisclosed
# 3  /funding-round/3bb2ee4a2d89251a10aaa735b1180e44            venture
# 4  /funding-round/383a9bd2c04f7038bb543ccef5ba3eae               seed
#
#   funding_round_code  funded_at raised_amount_usd
# 0                  A  3/19/2008         2000000.0
# 1      not available  7/24/2014     not available
# 2      not available   7/1/2014           41250.0
# 3                  B  11/9/2015        20000000.0
# 4      not available  5/22/2013         3000000.0

# %% [markdown]
# #### Question 5: How many investors do we have in different countries and which country dominates?

# %% [markdown]
# We will do this by checking the amount of times country codes repeat in the investor tables and the company country location names which could tell a little more about the country's financial and business status.

# %%
d.investor_country_code.value_counts()
# Out:
# USA             96341
# not provided    30939
# GBR              7616
# DEU              3256
# FRA              3007
#                 ...
# TTO                 1
# MAR                 1
# IRN                 1
# BAH                 1
# GIB                 1
# Name: investor_country_code, Length: 99, dtype: int64

# %%
d.company_country_code.value_counts()
# Out:
# USA             112283
# not provided     10521
# GBR               8579
# CAN               4009
# CHN               3778
#                  ...
# NPL                  1
# MDA                  1
# ALB                  1
# GGY                  1
# MCO                  1
# Name: company_country_code, Length: 126, dtype: int64

# %% [markdown]
# The above data shows that we have more investors in the USA and companies receiving investments as compared to other countries.
# We can deduce that this country has a better financial and business status as compared to the rest making it appear like pool of gain for investors.

# %% [markdown]
# #### Which investor dominates the market?

# %%
d['investor_name'].value_counts()
# Out:
# Sequoia Capital               1033
# Wayra                          936
# 500 Startups                   932
# New Enterprise Associates      902
# Intel Capital                  861
#                               ...
# Shazad Mohammed                  1
# Rick Gibson                      1
# Smurfit Family Investments       1
# Naren Nachiappan                 1
# Serkan Erdoğan                   1
# Name: investor_name, Length: 30189, dtype: int64

# %% [markdown]
# As we can see, Sequoia Capital dominates the market. Wayra and 500 Startups seem to be quit close in count from which we could deduce that they are competitors just like the rest of the companies in the list but the fact that their count have a 4 point gap could mean that they follow up on one another.

# %% [markdown]
# #### Question 6: Which company is most famous amongst investors?

# %%
d['company_name'].value_counts()
# Out:
# Uber                                          64
# DocuSign                                      61
# Fab                                           61
# Pinterest                                     60
# Mattermark                                    59
#                                               ..
# Kirondo                                        1
# Kiras Kiss                                     1
# Kipu Systems                                   1
# Kippt                                          1
# İnovatiff Reklam ve Tanıtım Hizmetleri Tic     1
# Name: company_name, Length: 44578, dtype: int64

# %% [markdown]
# The above data shows that the Uber company dominates the market with DocuSign and Fab having the same count which may infere that one is as trust worth as the other. The fact Uber is at the top of the list also tells us that this company has a lot of credibility in the eyes of investors.

# %% [markdown]
# #### Question 7: What about these company's specialization as compared to investment?Which category (field) attracts more funding?

# %% [markdown]
#  We will check the category list for both companies and investments dataframes.

# %%
#companies
df = df[df.category_list!= 'NaN']
df.category_list.value_counts()
# Out:
# Software                                                                       3995
# Biotechnology                                                                  3615
# E-Commerce                                                                     1332
# Mobile                                                                         1177
# Clean Technology                                                               1133
#                                                                                ...
# Consumer Internet|Marketplaces|Mobile|Mobile Payments|Transportation|Travel       1
# Apps|Mobile|Private Social Networking                                             1
# Cloud Computing|Enterprise Software|Infrastructure|PaaS|Social Media              1
# Content|SaaS|Social Media Marketing|Software                                      1
# Consumer Goods|E-Commerce|Internet                                                1
# Name: category_list, Length: 27296, dtype: int64

# %%
#investments
d = d[d.company_category_list!= 'NaN']
d.company_category_list.value_counts()
# Out:
# Biotechnology                                               10041
# Software                                                     8931
# Mobile                                                       3178
# Enterprise Software                                          3002
# E-Commerce                                                   2980
#                                                             ...
# Curated Web|E-Commerce|Online Reservations|Online Travel        1
# Hedge Funds|Market Research|Trading                             1
# Curated Web|Home & Garden                                       1
# E-Commerce|Furniture|Home & Garden|Lighting                     1
# Consumer Goods|E-Commerce|Internet                              1
# Name: company_category_list, Length: 19453, dtype: int64

# %% [markdown]
# As we can see, although biotechnology is more ofinterest to investors, companies seem to have more interest in software which could be due to expensive and delicate nature of biotechnology.

# %% [markdown]
# #### Question 8: Are most of the investors also acquirers?

# %%
p=pd.read_csv("datasets/startups/acquisitions.csv")
p.head()
# Out:
#                                    company_permalink  \
# 0                               /organization/003-ru
# 1                      /organization/0958572-b-c-ltd
# 2                 /organization/1-800-communications
# 3                       /organization/1-800-contacts
# 4  /organization/1-844-446-4460-pogo-customer-ser...
#
#                                         company_name  \
# 0                                             003.RU
# 1                                  0958572 B.C. Ltd.
# 2                               1-800 Communications
# 3                                     1-800 Contacts
# 4  Games Support +1-800-311-5934 Pogo Games techn...
#
#                        company_category_list company_country_code  \
# 0  Consumer Electronics|Electronics|Internet                  RUS
# 1                                        NaN                  NaN
# 2                                        NaN                  USA
# 3                      Consumer Goods|Retail                  USA
# 4                                        NaN                  NaN
#
#   company_state_code  company_region company_city  \
# 0                 48          Moscow       Moscow
# 1                NaN             NaN          NaN
# 2                 NY     Long Island   Hicksville
# 3                 UT  Salt Lake City       Draper
# 4                NaN             NaN          NaN
#
#                                   acquirer_permalink  \
# 0                         /organization/media-saturn
# 1  /organization/atlas-intellectual-property-mana...
# 2                       /organization/carsdirect-com
# 3                /organization/thomas-h-lee-partners
# 4  /organization/pogo-customer-service-number-1-8...
#
#                                        acquirer_name  \
# 0                                       Media Saturn
# 1         ATLAS Intellectual Property Management Co.
# 2                                     CarsDirect.com
# 3                             Thomas H. Lee Partners
# 4  Games Support +1-800-311-5934 Pogo Games techn...
#
#                               acquirer_category_list acquirer_country_code  \
# 0      Enterprise Software|Media|Sales and Marketing                   ESP
# 1          Finance|FinTech|Mobile|Telecommunications                   USA
# 2                                         E-Commerce                   USA
# 3  Business Development|Impact Investing|Investme...                   USA
# 4                                                NaN                   USA
#
#   acquirer_state_code acquirer_region acquirer_city acquired_at  \
# 0                  56       Barcelona     Barcelona   7/23/2012
# 1                  WA         Seattle       Seattle    2/2/2012
# 2                  CA     Los Angeles    El Segundo   6/12/2005
# 3                  MA          Boston        Boston    1/7/2014
# 4                  NY   New York City    Mamaroneck    2/2/2001
#
#   acquired_month  price_amount price_currency_code
# 0        2012-07           NaN                 USD
# 1        2012-02     9000000.0                 USD
# 2        2005-06           NaN                 USD
# 3        2014-01           NaN                 USD
# 4        2001-02           NaN                 USD

# %%
p.drop(['company_state_code', 'company_region','acquirer_state_code','acquirer_region'],axis=1,inplace=True)
p['company_category_list']=p['company_category_list'].fillna("not provided")
p['company_country_code']=p['company_country_code'].fillna("not provided")


p.head()
# Out:
#                                    company_permalink  \
# 0                               /organization/003-ru
# 1                      /organization/0958572-b-c-ltd
# 2                 /organization/1-800-communications
# 3                       /organization/1-800-contacts
# 4  /organization/1-844-446-4460-pogo-customer-ser...
#
#                                         company_name  \
# 0                                             003.RU
# 1                                  0958572 B.C. Ltd.
# 2                               1-800 Communications
# 3                                     1-800 Contacts
# 4  Games Support +1-800-311-5934 Pogo Games techn...
#
#                        company_category_list company_country_code  \
# 0  Consumer Electronics|Electronics|Internet                  RUS
# 1                               not provided         not provided
# 2                               not provided                  USA
# 3                      Consumer Goods|Retail                  USA
# 4                               not provided         not provided
#
#   company_city                                 acquirer_permalink  \
# 0       Moscow                         /organization/media-saturn
# 1          NaN  /organization/atlas-intellectual-property-mana...
# 2   Hicksville                       /organization/carsdirect-com
# 3       Draper                /organization/thomas-h-lee-partners
# 4          NaN  /organization/pogo-customer-service-number-1-8...
#
#                                        acquirer_name  \
# 0                                       Media Saturn
# 1         ATLAS Intellectual Property Management Co.
# 2                                     CarsDirect.com
# 3                             Thomas H. Lee Partners
# 4  Games Support +1-800-311-5934 Pogo Games techn...
#
#                               acquirer_category_list acquirer_country_code  \
# 0      Enterprise Software|Media|Sales and Marketing                   ESP
# 1          Finance|FinTech|Mobile|Telecommunications                   USA
# 2                                         E-Commerce                   USA
# 3  Business Development|Impact Investing|Investme...                   USA
# 4                                                NaN                   USA
#
#   acquirer_city acquired_at acquired_month  price_amount price_currency_code
# 0     Barcelona   7/23/2012        2012-07           NaN                 USD
# 1       Seattle    2/2/2012        2012-02     9000000.0                 USD
# 2    El Segundo   6/12/2005        2005-06           NaN                 USD
# 3        Boston    1/7/2014        2014-01           NaN                 USD
# 4    Mamaroneck    2/2/2001        2001-02           NaN                 USD

# %% [markdown]
# Now we'll count the frequency of appearance of acquirer names to determine which one of them is also an investor and compare it to the company names to figure out if the same companies are famous with investors too in this data set.

# %%
p.acquirer_name.value_counts()
# Out:
# Cisco                                    193
# Google                                   176
# Microsoft                                161
# IBM (International Business Machines)    138
# Yahoo!                                   118
#                                         ...
# Prime Active Capital                       1
# Wilcon                                     1
# Eco Green Auto Clean                       1
# Iotum                                      1
# 2000                                       1
# Name: acquirer_name, Length: 9475, dtype: int64

# %%
p.company_name.value_counts()
# Out:
# Unveil Technologies              6
# Ufree                            6
# California Apostille Services    5
# Travel Channel                   4
# Ziff Davis                       4
#                                 ..
# Focal Labs                       1
# Focus                            1
# Focus Group                      1
# Focus Systems                    1
# USA                              1
# Name: company_name, Length: 18503, dtype: int64

# %% [markdown]
# Shockingly, the first to top the list is Cisco unlike in the investor data set where Sequoia Capital tops the list. Also, it can be noticed that the companies which have had the most share acquisitions are Unveil Technologies and Ufree.

# %% [markdown]
# #### Footnote: What can some of the null or missing values infer?

# %% [markdown]
# To do this we'll check the total missing values in the acquisitions data set.

# %%
p.isna().sum()
# Out:
# company_permalink             0
# company_name                  1
# company_category_list         0
# company_country_code          0
# company_city               4911
# acquirer_permalink            1
# acquirer_name                 1
# acquirer_category_list     2389
# acquirer_country_code      1171
# acquirer_city              1360
# acquired_at                  13
# acquired_month               15
# price_amount              13957
# price_currency_code           7
# dtype: int64

# %% [markdown]
# * The null values in the price_amount column may mean that the acquisition process have not being completed, was cancelled, or the files containing this information are not available.
#
# * Null in company_city may point out that either the location of the company is unexact or that the acquisition process was cancelled. The reverse may be true in case with the acquirer_city.

# %% [markdown]
# # Answering Questions By Web Scraping

# %% [markdown]
# ## Scraping Steps done for the rest of the questions (Used [Apollo](https://app.apollo.io/#/) )

# %% [markdown]
# ### Steps for obtaining cookies: <br>
# Sign up on Apollo, and then open the main page, and follow these steps:

# %% [markdown]
# Step 0: <br>
# <img src="Phase 2/apollo0.png" width=300>

# %% [markdown]
# Step 1: <br>
# <img src="Phase 2/apollo1.png" width=400>

# %% [markdown]
# Step 2 & 3: <br>
# <img src="Phase 2/apollo2.png" width=400>

# %% [markdown]
# Step 4: <br>
# <img src="Phase 2/apollo3.png" width=500>

# %% [markdown]
# Step 5: <br>
# <img src="Phase 2/apollo4.png" width=300>

# %% [markdown]
# ### Code:

# %%
companiesC = pd.read_csv("datasets/startupsCleaned/companiesCleaned.csv", parse_dates=['founded_at', 'first_funding_at', 'last_funding_at', 'time_before_first_fund'])

# %%
headers = {
        "Content-Type": "application/json",
        "Cookie": "zp__initial_utm_source=www.google.com; ZP_Pricing_Split_Test_Variant=21Q3_EC_V49; __stripe_mid=06eaafd7-76d2-4770-908b-d8f07c1cbebe36217d; drift_aid=894ff341-9c75-424b-a0b1-4b8f79432cee; driftt_aid=894ff341-9c75-424b-a0b1-4b8f79432cee; GCLB=CKvHg8ibj4-lSg; drift_campaign_refresh=d9170960-a05f-42c2-ba9a-78b2101a0d03; remember_token_leadgenie_v2=IjYyNzJiY2EzYzUyODZmMDBmNTk1OGQzYV9sZWFkZ2VuaWVjb29raWVoYXNoIg==--be0341a530e3503f6c70c148746898bb6bfff89f; app_token=50e2ead7f035b1b4bfeabd4df560628f; zp__utm_source=accounts.google.com; drift_eid=6272bca3c5286f00f5958d3a; X-CSRF-TOKEN=IoCHQJkGov78uGd85Tyvd8pU3R71X9kpmMeSZN07rLrxxFMq+rbBmtbcZWCh8aU13yi9oTw8LTrqovrJpZELJg==; _leadgenie_session=RVBYT0t3ZmpPQXJKa3h4MVFuMFR2Sy9MMllTQTYxMlZXT1hJcE5CUmFPYSt2N1BqbVdNSElvWFZFZFphRjBQQld3MTZPQjlMZ3AwTHpXZXhLZm5ob1RxWnJOSXJEcVRPa2lGUDdJeXM5VllrQmx1THhnUmlqMmg3T0xGNEVpVG55OGRTNnQvSFowUUR1dzhFdTNERXZ3PT0tLXF3dWxxZ2RsV1hSRHl6cklJOHJlY0E9PQ==--4be95298d42bde7502dbd1c813100ffaff01ca0b; __stripe_sid=7bad678d-16d3-4a39-9b09-02a62fbbd1c73e0f1d",
        "Origin": "https://app.apollo.io",
        "Referer": "https://app.apollo.io/",
    }

# %%
session = requests.Session()
lock = threading.Lock()
def searchByUrl(homepage_url):
    """
    Searches for the company in Apollo's API using the homepage_url, and retreives its ID 
    Note: homepage_url was used instead of the company's name as sometimes, 
    Apollo doesn't retrieve the correct company using the name
    """
    url = "https://app.apollo.io/api/v1/omnisearch/search"
    data = {
        "query":f"{homepage_url}",
        "num_fetch_result":1,
        "cacheKey":1650463168797
    }
    try:
        lock.acquire()
        response = session.post(url, headers=headers, data=json.dumps(data), timeout=5)
        lock.release()
    except:
        lock.release()
        return "ACCOUNT BLOCKED"

    try:
        if not len(response.json()['organizations']):
            return "NOT FOUND"
        else:
            return response.json()['organizations'][0]['id']
    except:
        return "ACCOUNT BLOCKED"

# %%
lock = threading.Lock()
def getCompany(id):
    """
    Returns Company Info by using the ID (of Apollo website) retrieved from searchByURL()
    """
    if id in ["NOT FOUND", "ACCOUNT BLOCKED"]:
        return "NOT FOUND"
    else:
        url = 'https://app.apollo.io/api/v1/organizations/'+id
        try:
            lock.acquire()
            response = session.get(url, headers=headers, timeout=5)
            lock.release()
        except:
            lock.release()
            return "NOT FOUND"
        return response.text

# %%
import threading
from threading import Thread
import time
lock = threading.Lock()

def getCompanyInfo(idx, searchTerm):
    """
    Converts `res` to dictionary, and appends the following values as a tuple in 
    global variable `compInfoTups` (note that these data are for the company in the companiesC dataframe where the index = `idx`):
    * idx (stored again, so that when we create a dataframe from this list of tuples, we can use the `index` column to join the scraped info with companiesC)
    * estimated_num_employees in a company
    * country where company is stationed
    * number of technologies used by the company
    * company's annual_revenue
    """
    res = getCompany(searchByUrl(searchTerm))
    try:
        res = json.loads(res) #converts json string to dictionary called `res`
    except:
        print('NO', idx)
        return None #usually returns None if getCompany() returns "NOT FOUND"
    print('YES', idx)
    try:
        employee_count = res['organization']['estimated_num_employees']
    except:
        employee_count = np.NaN
    try:
        country = res['organization']['country']
    except:
        country = np.NaN #This should have been: "", but we discovered that after we were unable to scrape again (due to getting blocked)
    try:
        number_of_technologies = len(res['organization']['technology_names'])
    except:
        number_of_technologies = np.NaN
    try:
        annual_rev = res['organization']['annual_revenue']
    except:
        annual_rev = np.NaN
    lock.acquire()
    compInfoTups.append((idx, employee_count, country, number_of_technologies, annual_rev))
    lock.release()

# %%
df1 = companiesC.loc[0:10000]
df2 = companiesC.loc[30001:30010]
#df2 = companiesC.loc[30001:40000]
#df2 = companiesC.loc[30001:61267]

# %%
def startThreads():
    """
    two loops:
    inner loop scraps ten companies parallely (using threads)
    outer loop fetches the next 10 rows to be scraped (using j += i*10),
    you can adjust the range() in the outer loop to suit the companies 
    that you want to get scraped info for in companiesC
    """
    for i in range(1): 
        threads = []
        global compInfoTups #global in order to be visible to getCompanyInfo()
        compInfoTups = []
        try:
            for j in range(10):
                j += i*10
                searchTerm = df2['homepage_url'][j+30001]
                th = Thread(target=getCompanyInfo, args=(j+30001, searchTerm))
                threads.append(th)
                th.start()
            for th in threads: 
                th.join()
        finally:
            dfTups = pd.DataFrame(compInfoTups, columns=[
                'index', 'employee_count', 'country', 'number_of_technologies', 'annual_rev'
                ])
            dfTups.to_csv('Scrapped Companies/scrapped_companies_test.csv', 
                    mode='a', index=False, header=False)

# %% [markdown]
# Note that startThreads() has been adjusted to retrieve only 10 rows (from 30001 to 30010) to display the output when running all cells <br>
# But before, it was used to retrieve 10k rows at a time and store them in csv files. <br>
# For example, `scrapped_companies_1.csv` contains approximately all rows from index 0 to 10000, <br>
# `scrapped_companies_2.csv` should have contained  rows from index 10001 to 20000, and so on.

# %%
startThreads()
# Out:
# NO 30001
# YES 30002
# YES 30003
# YES 30004
# YES 30005
# YES 30006
# YES 30007
# YES 30008
# YES 30009
# YES 30010

# %%
compInfoTups
# Out:
# [(30002, 0, 'United States', 0, nan),
#  (30003, 5, 'United States', 1, 195000.0),
#  (30004, 14, 'United States', 7, 5000000.0),
#  (30005, 0, None, 1, nan),
#  (30006, 10, 'United States', 3, 25000000.0),
#  (30007, 11, 'United States', 9, 3328000.0),
#  (30008, 2, 'Ecuador', 6, nan),
#  (30009, 0, 'Germany', 4, nan),
#  (30010, 30, 'United States', 12, 11232000.0)]

# %% [markdown]
# ### Side notes: failed attempts

# %% [markdown]
# Note 1: Notice that in the folder `Scrapped Companies`, you will only find `scrapped_companies_1.csv`, 4, and 5 (not complete) <br>
# This was because initially, we were going to split first 3 10k rows on Farah's PC, and the last 3 10k rows on my PC (as Aisha had poor internet connection) <br>
# However, all the accounts that we used (to get cookies) got blocked (by Apollo's server) after we retrieved rows from 0 to 10k, and 30k to 40k, <br>
# and very few rows from 40k to 50k

# %% [markdown]
# Note 2: The `getCompanyInfo()` and `startThreads()` was initially this for loop:

# %%
testTups = []

for i in range(5): #len(df2)
    res = getCompany(searchByUrl(df1['homepage_url'][i]))
    emp = re.search(r"\"estimated_num_employees\" :([0-9]+)" , res)
    if emp is not None:
        employee_count = emp.group(1)
    elif emp is None:
        employee_count = np.NaN

    country = re.search(r"(\"country\"\:)\"(\w+.*)\"\,\"o" , res)
    if country is not None:
        country_extracted = country.group(2)
    elif country is None:
        country_extracted = ""

    tech = re.findall(r"\"current_technologies\"\:.*\]" , res)
    tech = re.findall(r"\"name\"\:", str(tech))
    tech_count = sum('name' in t for t in tech)

    revenue = re.search(r"\"annual_revenue\"\:([0-9]+)" , res)
    if revenue is not None:
        revenue_extracted = revenue.group(1)
    elif revenue is None:
        revenue_extracted = np.NaN
    testTups.append((employee_count, country_extracted, tech_count, revenue_extracted))

# %% [markdown]
# We changed it because of 2 things:
# 1. It took a very long time to scrape very few amount of rows
#     - So we introduced multi-threading
# 2. The regex was hard to read
#     - So we changed it to accessing keys of a dictionary <br> when we discovered that `json.loads(res)` converts a string (response.text) to dictionary

# %% [markdown]
# However, the regex still works:

# %%
testTups
# Out:
# [(nan, 'India', 1, '1500000'),
#  (nan, 'United States', 3, nan),
#  (nan, 'Japan', 10, nan),
#  (nan, 'Morocco', 5, nan),
#  (nan, 'Germany', 10, '5000000')]

# %% [markdown]
# ### Concatenating the scraped csv files and joining them with `CompaniesC`

# %%
companiesS1 = pd.read_csv("Scrapped Companies/scrapped_companies_1.csv")
companiesS4 = pd.read_csv("Scrapped Companies/scrapped_companies_4.csv")
companiesS5 = pd.read_csv("Scrapped Companies/scrapped_companies_5.csv")
companiesS = pd.concat([companiesS1, companiesS4, companiesS5])
companiesS
# Out:
#      index  employee_count        country  number_of_technologies  \
# 0        0              57          India                       1
# 1        1               4  United States                       3
# 2        2              18          Japan                      10
# 3        3               0        Morocco                       5
# 4        4              67        Germany                      10
# ..     ...             ...            ...                     ...
# 295  40326               0  United States                       1
# 296  40327            6000  United States                      26
# 297  40328               0  United States                       0
# 298  40329               0  United States                       1
# 299  40330               0  United States                       9
#
#        annual_rev
# 0    1.500000e+06
# 1             NaN
# 2             NaN
# 3             NaN
# 4    5.000000e+06
# ..            ...
# 295  2.000000e+06
# 296  2.436989e+09
# 297           NaN
# 298           NaN
# 299  1.400000e+06
#
# [16516 rows x 5 columns]

# %%
companiesC['index'] = companiesC.index
companiesCS = pd.merge(companiesC, companiesS, how='inner', on='index')
companiesCS.drop(['index'], axis=1, inplace=True)

# %%
companiesCS.head(3)
# Out:
#                      company_permalink            company_name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
#
#              homepage_url                              company_category_list  \
# 0      http://livfame.com                                              Media
# 1  http://www.qounter.com  Application Platforms|Real Time|Social Network...
# 2     http://oneofthem.jp                                  Apps|Games|Mobile
#
#    funding_total_usd     status company_country_code   company_city  \
# 0         10000000.0  operating                  IND         Mumbai
# 1           700000.0  operating                  USA  Delaware City
# 2          3406878.0  operating                  JPN        missing
#
#    funding_rounds                    founded_at first_funding_at  \
# 0               1 2011-04-12 20:46:43.240577680       2015-01-05
# 1               2 2014-09-04 00:00:00.000000000       2014-03-01
# 2               1 2010-05-07 20:46:43.240577680       2014-01-30
#
#   last_funding_at        time_before_first_fund  employee_count  \
# 0      2015-01-05  1363 days 03:13:16.759422320              57
# 1      2014-10-14           -187 days +00:00:00               4
# 2      2014-01-30  1363 days 03:13:16.759422320              18
#
#          country  number_of_technologies  annual_rev
# 0          India                       1   1500000.0
# 1  United States                       3         NaN
# 2          Japan                      10         NaN

# %% [markdown]
# ### Imputing `missing` country values from `country` column

# %% [markdown]
# We have 1167 missing country codes in `companiesCS`

# %%
companiesCS[companiesCS['company_country_code'] == 'missing'].shape
# Out:
# (1167, 17)

# %% [markdown]
# And we have 15843 countries in `companiesCS`

# %%
len(companiesCS) - companiesCS['country'].isnull().sum()
# Out:
# 15843

# %% [markdown]
# Let's see the rows where there are country names but no country codes

# %%
companiesCS[(companiesCS['company_country_code'] == 'missing') & (companiesCS['country'].notna())].shape
# Out:
# (1062, 17)

# %% [markdown]
# Thankfully, we were able to retrieve most of the missing countries (1062 out of 1167):

# %%
import pycountry
def toAlphaCode3(row):
    if row['company_country_code'] != 'missing' or type(row['country']) == type(np.nan): #means that country is NaN so it will be read as float not str
        return row
    countryInfo = pycountry.countries.get(name=row['country'])
    if (countryInfo is None):
        row['company_country_code'] = row['country'][0:3].upper()
    else:
        row['company_country_code'] = countryInfo.alpha_3
    print(row['company_country_code'])
    return row

# %%
companiesCS = companiesCS.apply(lambda x : toAlphaCode3(x), axis=1)
# Out:
# CHN
# RUS
# CHN
# USA
# USA
# DEU
# RUS
# DEU
# ITA
# DEU
# USA
# ARG
# NLD
# THA
# CHN
# CZE
# CHN
# IND
# RUS
# ESP
# USA
# USA
# USA
# AUS
# POL
# USA
# USA
# CHN
# CHN
# CHN
# CHN
# CHN
# TUR
# ARE
# CHN
# CHN
# DEU
# USA
# SGP
# CHN
# USA
# HKG
# ISR
# KWT
# SWE
# CHN
# DEU
# FRA
# IND
# USA
# IND
# GBR
# USA
# USA
# HKG
# CZE
# USA
# USA
# USA
# USA
# USA
# AUS
# TAI
# GBR
# USA
# SGP
# USA
# SWE
# AUS
# USA
# USA
# USA
# USA
# DNK
# SOU
# USA
# USA
# BRA
# GBR
# EST
# GBR
# DEU
# USA
# MEX
# USA
# ITA
# USA
# USA
# USA
# USA
# USA
# USA
# DEU
# BRA
# USA
# DEU
# BGR
# RUS
# GBR
# IRL
# LVA
# DEU
# USA
# AUS
# USA
# USA
# GBR
# USA
# USA
# USA
# USA
# GBR
# USA
# USA
# USA
# AUT
# ZAF
# USA
# DNK
# POL
# SWE
# USA
# USA
# USA
# USA
# DEU
# CHN
# ITA
# CHE
# CAN
# GBR
# CHN
# JOR
# NLD
# USA
# USA
# USA
# FRA
# USA
# USA
# USA
# USA
# USA
# USA
# GRC
# SWE
# FRA
# CAN
# USA
# USA
# JPN
# ITA
# IRL
# DEU
# SWE
# GBR
# BGD
# DEU
# DEU
# USA
# LVA
# USA
# GBR
# CHN
# DEU
# AUT
# SOU
# USA
# BEL
# USA
# USA
# CHN
# USA
# CHN
# CHN
# SOU
# ISR
# USA
# USA
# POL
# GBR
# GBR
# USA
# USA
# CHN
# CHN
# USA
# USA
# USA
# BGR
# USA
# USA
# USA
# CHN
# ESP
# CHN
# MEX
# EST
# USA
# USA
# GBR
# ITA
# DEU
# USA
# USA
# NZL
# ISR
# USA
# USA
# BRA
# GRC
# USA
# TUR
# USA
# GBR
# CYP
# USA
# JOR
# CHN
# USA
# USA
# USA
# USA
# USA
# RUS
# USA
# USA
# AUS
# DEU
# USA
# CHN
# USA
# GBR
# IND
# GBR
# USA
# USA
# USA
# GBR
# GBR
# CHE
# USA
# GBR
# IND
# CAN
# USA
# HKG
# USA
# ESP
# CAN
# CAN
# USA
# USA
# BEL
# USA
# DEU
# GBR
# USA
# USA
# USA
# USA
# USA
# USA
# USA
# USA
# SWE
# JPN
# DEU
# USA
# USA
# USA
# USA
# DEU
# GBR
# ITA
# SVK
# FRA
# GBR
# IND
# USA
# USA
# DEU
# GBR
# USA
# USA
# TUR
# USA
# PAK
# CHN
# RUS
# AUS
# USA
# USA
# JPN
# USA
# CHN
# USA
# SOU
# USA
# DEU
# RUS
# IND
# USA
# DNK
# USA
# CAN
# CHN
# USA
# GBR
# CHL
# USA
# CHN
# USA
# MYS
# USA
# USA
# USA
# CAN
# USA
# USA
# USA
# FRA
# USA
# USA
# CHN
# CHN
# CHN
# CHN
# CHN
# CHN
# USA
# GBR
# DEU
# USA
# USA
# UKR
# DEU
# USA
# GBR
# USA
# USA
# ZAF
# CHN
# CHN
# HKG
# USA
# USA
# CHN
# USA
# GBR
# CHN
# USA
# AUS
# DEU
# USA
# USA
# ESP
# USA
# IND
# NLD
# NLD
# AUT
# USA
# USA
# USA
# GBR
# GBR
# GBR
# NLD
# USA
# USA
# USA
# USA
# USA
# ESP
# USA
# SVK
# TAI
# USA
# ESP
# BRA
# USA
# USA
# USA
# CHN
# USA
# BRA
# ESP
# SGP
# GBR
# NLD
# FRA
# USA
# GBR
# DEU
# CHE
# ESP
# GBR
# CHN
# CHN
# GBR
# USA
# USA
# CAN
# USA
# GBR
# CHN
# USA
# GBR
# USA
# DNK
# USA
# PER
# USA
# HUN
# USA
# DEM
# USA
# USA
# DEU
# USA
# DEU
# ZAF
# RUS
# BRA
# USA
# USA
# PHL
# USA
# USA
# FRA
# GBR
# USA
# USA
# USA
# GBR
# USA
# FRA
# USA
# USA
# DNK
# USA
# CHN
# GBR
# USA
# NLD
# ISR
# CAN
# NZL
# USA
# USA
# DEU
# SAU
# AUS
# USA
# EST
# BGR
# USA
# USA
# USA
# AUS
# GBR
# USA
# USA
# USA
# USA
# BEL
# USA
# USA
# CHN
# USA
# SGP
# USA
# NLD
# ESP
# CAN
# USA
# FRA
# USA
# USA
# USA
# USA
# USA
# USA
# FRA
# USA
# USA
# USA
# USA
# USA
# USA
# USA
# USA
# USA
# CHL
# USA
# DEU
# GBR
# GBR
# AUS
# USA
# GBR
# FIN
# GBR
# USA
# USA
# USA
# GBR
# HUN
# USA
# USA
# USA
# DNK
# USA
# USA
# USA
# USA
# FRA
# BRA
# USA
# USA
# DEU
# JPN
# USA
# USA
# USA
# CHN
# USA
# SGP
# USA
# CHN
# USA
# ISR
# USA
# DEU
# USA
# TAI
# USA
# USA
# ESP
# USA
# GRC
# USA
# USA
# CHN
# UKR
# USA
# USA
# DEU
# ESP
# GBR
# USA
# USA
# USA
# GBR
# USA
# GBR
# ISR
# IND
# HUN
# RUS
# CHN
# IDN
# GBR
# GBR
# CHN
# GBR
# CHL
# PRT
# USA
# USA
# GBR
# USA
# USA
# FRA
# USA
# GBR
# LVA
# GBR
# CAN
# USA
# USA
# USA
# USA
# CYM
# USA
# BRA
# USA
# CHN
# CHN
# GBR
# HKG
# USA
# GBR
# BRA
# SAU
# GBR
# USA
# DEU
# JPN
# FIN
# GBR
# IND
# USA
# IND
# FIN
# CHN
# USA
# RUS
# USA
# USA
# USA
# SGP
# USA
# IND
# USA
# USA
# BRA
# USA
# USA
# RUS
# RUS
# USA
# DEU
# USA
# SWE
# USA
# USA
# UKR
# TUR
# USA
# USA
# USA
# USA
# USA
# USA
# GBR
# USA
# JPN
# USA
# ITA
# FRA
# USA
# USA
# USA
# USA
# USA
# ISR
# USA
# CAN
# USA
# DEU
# USA
# USA
# AUS
# JPN
# USA
# ARE
# GBR
# USA
# USA
# RUS
# USA
# IND
# GBR
# USA
# POL
# USA
# ITA
# USA
# DEU
# BEL
# USA
# USA
# GBR
# USA
# USA
# CHN
# TAI
# USA
# CHN
# ZAF
# GBR
# USA
# ESP
# USA
# CHE
# IND
# USA
# GHA
# USA
# USA
# DEU
# NLD
# GBR
# GBR
# DEU
# ARG
# RUS
# TUR
# BRA
# IRL
# DNK
# ISR
# USA
# USA
# DEU
# FRA
# IND
# CAN
# ESP
# CHN
# USA
# USA
# CHN
# USA
# USA
# USA
# LVA
# USA
# USA
# AUT
# CHE
# DNK
# DEU
# USA
# EST
# BRA
# USA
# USA
# USA
# USA
# USA
# CHN
# ARE
# GBR
# CHN
# CHN
# RUS
# GBR
# USA
# GBR
# GBR
# USA
# URY
# AUS
# USA
# USA
# USA
# PHL
# IND
# GBR
# PER
# USA
# DEU
# USA
# FRA
# JPN
# USA
# LVA
# DNK
# USA
# USA
# USA
# USA
# GBR
# IND
# DEU
# USA
# GBR
# FRA
# USA
# USA
# USA
# GBR
# USA
# USA
# FRA
# USA
# GBR
# FRA
# USA
# USA
# USA
# AUS
# UKR
# NGA
# USA
# USA
# BRA
# CAN
# USA
# USA
# USA
# NLD
# BRA
# USA
# USA
# USA
# CHN
# GBR
# TAI
# USA
# USA
# USA
# IRL
# DEU
# USA
# CAN
# USA
# USA
# USA
# TUR
# USA
# DNK
# USA
# USA
# GBR
# CAN
# USA
# USA
# USA
# USA
# IND
# CHN
# SWE
# ISR
# CHN
# MEX
# GBR
# ESP
# DEU
# USA
# USA
# ZAF
# USA
# ESP
# HKG
# USA
# AUS
# USA
# USA
# MEX
# SWE
# USA
# EGY
# DEU
# NGA
# USA
# USA
# CHN
# CHN
# USA
# FRA
# JPN
# NGA
# GBR
# DEU
# GBR
# RUS
# SWE
# USA
# USA
# USA
# IND
# USA
# SOU
# USA
# USA
# USA
# IND
# USA
# CHN
# CAN
# USA
# USA
# CHN
# RUS
# AUS
# CHN
# BRA
# FRA
# USA
# USA
# USA
# USA
# CHN
# USA
# BRA
# USA
# IND
# SWE
# FRA
# ESP
# USA
# IND
# USA
# USA
# USA
# USA
# USA
# USA
# USA
# IND
# USA
# USA
# DNK
# USA
# BGR
# GBR
# USA
# USA
# USA
# USA
# CHN
# DEU
# ARE
# USA
# USA
# USA
# USA
# USA
# BEL
# JPN
# BEL
# USA
# USA
# GBR
# USA
# USA
# USA
# DNK
# USA
# TUR
# USA
# CAN
# CHN
# DEU
# USA
# USA
# ITA
# DEU
# CAN
# HKG
# USA
# DEU
# USA
# RUS
# USA
# USA
# ESP
# USA
# USA
# RUS
# BRA
# GBR
# CHL
# PER
# USA
# USA
# MAR
# USA
# FRA
# USA
# DEU
# USA
# USA
# ZAF
# NLD
# GBR
# MYS
# CRI
# USA
# USA
# FIN
# USA
# DEU
# USA
# USA
# DEU
# USA
# VIE
# CHE
# DEU
# GBR
# SOU
# CHL
# USA
# USA
# USA
# USA
# DEU
# USA
# USA
# USA
# DEU
# PRT
# MEX
# USA
# USA
# USA
# NZL
# USA
# USA
# USA
# BRA
# GBR
# USA
# USA
# SWE
# AUS
# ISR
# DEU
# USA
# FRA
# USA
# IRL
# FRA
# USA
# IDN
# FRA
# DEU
# GBR
# USA
# USA
# SOU
# BRA
# USA
# USA
# USA
# IRL
# USA
# USA
# SWE
# USA
# USA
# RUS
# USA
# VIE
# JPN
# CHN
# GBR
# RUS
# USA
# CHN
# USA
# USA
# USA
# BRB
# USA
# DEU
# IND
# USA
# USA
# USA
# DEU
# BEL
# FRA
# USA
# GBR
# SGP
# USA

# %%
companiesCS[companiesCS['company_country_code'] == 'missing'].shape
# Out:
# (105, 17)

# %% [markdown]
# As you can see, only 105 rows had both `company_country_code` and `country` columns as missing <br>
# Now, we don't need the `country` column anymore:

# %%
companiesCS.drop(columns=['country'], inplace=True)

# %% [markdown]
# ### Saving the new dataframe in the cleaned datasets folder

# %%
#prefix = 'datasets/startupsCleaned/'
#suffix = 'CleanedAndScraped.csv'
#companiesCS.to_csv(prefix+'companies'+suffix, index=False)

# %% [markdown]
# ## The Web-Scraping Based Questions

# %% [markdown]
# ## Question 1 (Ashraf)

# %% [markdown]
# * Do country taxes play an important factor in deciding a start-up’s success?
#     - This can be determined by gathering information about a country’s tax rates <br> and correlating the results with the status of a start-up.
#     - An average of the total fundings raised could also be correlated with the country's tax rates

# %%
# Getting the Cleaned Datasets
companiesC = pd.read_csv("datasets/startupsCleaned/companiesCleaned.csv", parse_dates=['founded_at', 'first_funding_at', 'last_funding_at', 'time_before_first_fund'])
companiesCS = pd.read_csv("datasets/startupsCleaned/companiesCleanedAndScraped.csv", parse_dates=['founded_at', 'first_funding_at', 'last_funding_at', 'time_before_first_fund'])

# %% [markdown]
# ### Working on USA taxes (failed attempt)

# %% [markdown]
# #### Scraping Taxes

# %% [markdown]
# Using the website [kpmg](https://home.kpmg/eg/en/home/services/tax/tax-tools-and-resources/tax-rates-online/corporate-tax-rates-table.html) to get the taxes, we will choose the country to perform the analysis on based on two criteria:
# 1. there are relatively a lot of companies in `companies` dataset that are based in this country
# 2. the change to tax rate throughout the years for this country is noticable

# %% [markdown]
# Using `()` to chain methods and getting the **number** of countries present in `companies` dataset

# %%
(
    companiesC
    .groupby('company_country_code')['company_name']
    .count()
    .sort_values(ascending=False)[0:7] #Sorting to generate a series with USA as first country, then missing, and so on
    .plot(kind="barh")
    .invert_yaxis() #using invert_yaxis() to make sure USA appears at the top, not at the bottom 
)
plt.xlabel("Number of Companies")
plt.ylabel("Country");

# %% [markdown]
# Getting the **ratio** of countries present in `companies` dataset

# %%
# note that "autopct" displays percentage of slices, 
# while "explode" gives a little space between each corresponding slice in the pie chart
(
    companiesC
    .groupby('company_country_code')['company_name']
    .count()
    .sort_values(ascending=False)[0:7]
    .plot(kind="pie", autopct='%1.0f%%', explode=[0.00,0.1,0.3,0.3,0.3,0.3,0.3], shadow=True)
);

# %% [markdown]
# Since `USA` represents 70% of the top 7 countries that have companies based in them. <br>
# Therefore, `USA` satisfies condition `1.`

# %%
req = requests.get('https://home.kpmg/eg/en/home/services/tax/tax-tools-and-resources/tax-rates-online/corporate-tax-rates-table.html')
soup = BeautifulSoup(req.text, 'html.parser')
with open('kpmg.html', 'w', encoding="utf-8") as f:
    f.write(str(soup))

# %% [markdown]
# Displaying the retrieved page on chrome, we find the following: <br>
# <img src='Phase 2/kpmgNotWorking.png' width=800 height=500>

# %% [markdown]
# Since the website uses javascript, `selenium` will be used instead of `requests`

# %%
from selenium import webdriver
import time
import warnings
warnings.filterwarnings('ignore') # to suppress warnings about internal code deprecations
options=webdriver.ChromeOptions()
options.add_argument('--incognito')
options.add_argument('--headless')
userAgent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
options.add_argument(f'user-agent={userAgent}')
driver=webdriver.Chrome(options=options)
driver.get('https://home.kpmg/eg/en/home/services/tax/tax-tools-and-resources/tax-rates-online/corporate-tax-rates-table.html')

# %%
while True:
    time.sleep(3) # sleeping to render javascript code before parsing to BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    if soup is not None:
        break

# %%
print(soup.prettify())
# Out:
# <html class="chrome" lang="en-US">
#  <head class="chrome at-element-marker">
#   <meta class="chrome" content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta class="chrome" content="Tue, 02 Aug 2016 11:22:32 GMT" http-equiv="date"/>
#   <meta class="chrome" content="en-US" http-equiv="content-language"/>
#   <meta class="chrome" content="text/html" http-equiv="content-encoding"/>
#   <meta class="chrome" content="KPMG’s corporate tax table provides a view of corporate tax rates around the world." name="description"/>
#   <meta charset="utf-8" class="chrome"/>
#   <meta class="chrome" content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <link class="chrome" crossorigin="" href="https://assets.kpmg" rel="preconnect"/>
#   <link class="chrome" crossorigin="" href="https://scripts.demandbase.com" rel="preconnect"/>
#   <link class="chrome" crossorigin="" href="https://cdns.gigya.com" rel="preconnect"/>
#   <link class="chrome" crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link as="style" class="chrome" href="https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;600&amp;display=swap" rel="preload"/>
#   <link as="style" class="chrome" href="https://fonts.googleapis.com/css2?family=Open+Sans+Condensed:wght@300&amp;display=swap" rel="preload"/>
#   <link class="chrome" href="https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;600&amp;display=swap" rel="stylesheet"/>
#   <link class="chrome" href="https://fonts.googleapis.com/css2?family=Open+Sans+Condensed:wght@300&amp;display=swap" rel="stylesheet"/>
#   <link as="script" class="chrome" href="//assets.adobedtm.com/c5009cf2993d2402c89c2ae42e47f61897f82891/satelliteLib-8a974e2324210e133a0919e634748a6d88ed3ccc.js" rel="preload"/>
#   <link as="script" class="chrome" href="/etc/clientlibs/kpmgpublic/pages/global.min-112289.js" rel="preload"/>
#   <link class="chrome" href="/etc/designs/default/kpmg/favicons/apple-touch-icon-180x180-precomposed.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link class="chrome" href="/etc/designs/default/kpmg/favicons/apple-touch-icon-167x167-precomposed.png" rel="apple-touch-icon" sizes="167x167"/>
#   <link class="chrome" href="/etc/designs/default/kpmg/favicons/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link class="chrome" href="/etc/designs/default/kpmg/favicons/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link class="chrome" href="/etc/designs/default/kpmg/favicons/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link class="chrome" href="/etc/designs/default/kpmg/favicons/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link class="chrome" href="/etc/designs/default/kpmg/favicons/apple-touch-icon-precomposed.png" rel="apple-touch-icon"/>
#   <link class="chrome" href="/etc/designs/default/kpmg/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link class="chrome" href="/etc/designs/default/kpmg/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link class="chrome" href="/etc/designs/default/kpmg/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link class="chrome" href="/etc/designs/default/kpmg/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link class="chrome" href="/etc/designs/default/kpmg/favicons/manifest.json" rel="manifest"/>
#   <link class="chrome" color="#00338D" href="/etc/designs/default/kpmg/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
#   <link class="chrome" href="/etc/designs/default/kpmg/favicon.ico" rel="shortcut icon"/>
#   <link class="chrome" href="https://home.kpmg/eg/en/home/services/tax/tax-tools-and-resources/tax-rates-online/corporate-tax-rates-table.html" rel="canonical"/>
#   <meta class="chrome" content="https://assets.kpmg/is/image/kpmg/miguel-angel-castello-landscape:cq5dam.web.1200.630" property="og:image"/>
#   <meta class="chrome" content="summary_large_image" name="twitter:card"/>
#   <meta class="chrome" content="KPMG" property="og:site_name"/>
#   <meta class="chrome" content="tax rates tool test page" property="og:description"/>
#   <meta class="chrome" content="@KPMG" name="twitter:creator"/>
#   <meta class="chrome" content="index, follow" name="robots"/>
#   <meta class="chrome" content="en_us" property="og:locale"/>
#   <meta class="chrome" content="https://assets.kpmg/is/image/kpmg/miguel-angel-castello-landscape:cq5dam.web.1200.630" name="twitter:image"/>
#   <meta class="chrome" content="Tue, 02 Aug 2016 11:22:15 GMT" http-equiv="last-modified"/>
#   <meta class="chrome" content="KPMG’s corporate tax table provides a view of corporate tax rates around the world." name="DC.Description"/>
#   <meta class="chrome" content="@KPMG" name="twitter:site"/>
#   <meta class="chrome" content="text/html" name="DC.Format"/>
#   <meta class="chrome" content="website" property="og:type"/>
#   <meta class="chrome" content="tax rates tool test page" name="twitter:title"/>
#   <meta class="chrome" content="tax rates tool test page" property="og:title"/>
#   <meta class="chrome" content="Corporate tax rates table - KPMG Egypt" name="DC.Title"/>
#   <meta class="chrome" content="tax rates tool test page" name="twitter:description"/>
#   <meta class="chrome" content="en-US" name="DC.Language"/>
#   <meta class="chrome" content="2016-08-02" name="DC.Date"/>
#   <meta class="chrome" content="https://home.kpmg/eg/en/home/services/tax/tax-tools-and-resources/tax-rates-online/corporate-tax-rates-table.html" property="og:url"/>
#   <script async="" class="chrome" id="db_form_module" src="https://tag.demandbase.com/shared/forms_2748a4eef8.min.js">
#   </script>
#   <script async="" class="chrome" id="demandbase_js_lib" src="https://tag.demandbase.com/pZy5a2F8.min.js">
#   </script>
#   <script async="" class="chrome" crossorigin="anonymous" integrity="sha384-ViRSoPeEUan2O4h07x9IksdeF0E7Rmq7CP+gICf/oQ6eU8xvnQ66dg4Pl6wE3xRz" src="https://www.gstatic.com/recaptcha/releases/nEGwmCAyCoKVn9PSwAGnQWhY/recaptcha__en.js" type="text/javascript">
#   </script>
#   <script class="chrome" type="text/javascript">
#    var kpmgMetaData={"KPMG_Business_Owner":"Weibe, Greg","KPMG_Short_Desc":"KPMG’s corporate tax table provides a view of corporate tax rates around the world.","KPMG_Change_Frequency":"weekly","KPMG_Template":"/apps/kpmgpublic/templates/toopage-template","KPMG_Geographic_Origin_ID":"XX","KPMG_Article_ReadTime":"","KPMG_URL":"/eg/en/home/services/tax/tax-tools-and-resources/tax-rates-online/corporate-tax-rates-table.html","KPMG_Image_Alt":"tax rates","KPMG_BANNER_FLAG":"false","KPMG_Media_Typ_Path":"Media formats/Interactive","KPMG_Description":"KPMG’s corporate tax table provides a view of corporate tax rates around the world.","KPMG_Persona_Path":"Personas/Clients,Personas/Potential Clients","KPMG_Cont_Type_Path":"Content type/Tools","KPMG_Persona_ID":"59205189396461572826360,60541426764903813537507","KPMG_Business_Owner_Group":"EN – Global – Tax","KPMG_Title":"Corporate tax rates table","KPMG_Tab_Type":"Generic","KPMG_Analytics_PageName":"eg:en:home:services:tax:tax-tools-and-resources:tax-rates-online:corporate-tax-rates-table","KPMG_Med_For_Type_ID":"133321711976978237502674","KPMG_Document_Id":"OC01N1432198737234","KPMG_Content_Type_ID":"163334297256384225123674","KPMG_Live_Source":"https://home.kpmg/content/kpmgpublic/master/en/home/services/tax/tax-tools-and-resources/tax-rates-online/corporate-tax-rates-table","KPMG_Live_Copy":"true","KPMG_Short_Title":"Corporate tax rates table","KPMG_FONT":"false","KPMG_HTML_Title":"Corporate tax rates table","KPMG_Canonical_URL":"https://home.kpmg/eg/en/home/services/tax/tax-tools-and-resources/tax-rates-online/corporate-tax-rates-table.html","KPMG_Seo_Priority":"1.0","KPMG_Template_Type":"toopage-template","KPMG_last_mod_rank":"1470136935115","KPMG_Image":"/content/dam/kpmg/images/2015/02/tax-rates-tool-banner.jpg","KPMG_Blog_Topics":"",}
#   </script>
#   <script class="chrome" type="text/javascript">
#    var appSearchConfigs={"pagination":{"page":{"current":2,"size":5}},"sortParamsMapping":{"trending":"kpmg_page_views_trending","KPMG_MOST_PLR":"kpmg_avg_time_spent","mostviewed":"kpmg_page_views","KPMG_Filter_Date":"kpmg_filter_date","relavance":"_score"},"fieldsMapping":{"contacttabs":[{"kpmg_image":{"raw":{}},"kpmg_article_date_time":{"raw":{}},"kpmg_short_desc":{"raw":{}},"kpmg_article_readtime":{"raw":{}},"kpmg_title":{"raw":{}},"kpmg_image_alt":{"raw":{}},"kpmg_url":{"raw":{}}}],"partnerlocator":[{"kpmg_contact_fn":{"raw":{}},"kpmg_contact_ln":{"raw":{}},"kpmg_contact_job_ttl":{"raw":{}},"kpmg_url":{"raw":{}}}],"toppicks":[{"kpmg_image":{"raw":{}},"kpmg_template":{"raw":{}},"kpmg_primary_tag":{"raw":{}},"kpmg_short_title":{"raw":{}},"kpmg_short_desc":{"raw":{}},"kpmg_article_type":{"raw":{}},"kpmg_article_primary_format":{"raw":{}},"kpmg_article_readtime":{"raw":{}},"kpmg_image_alt":{"raw":{}},"kpmg_url":{"raw":{}}}],"blog":[{"kpmg_image":{"raw":{}},"kpmg_description":{"raw":{}},"kpmg_blog_topics":{"raw":{}},"kpmg_short_desc":{"raw":{}},"kpmg_blog_date":{"raw":{}},"kpmg_article_readtime":{"raw":{}},"kpmg_title":{"raw":{}},"kpmg_image_alt":{"raw":{}},"kpmg_url":{"raw":{}}}],"relatedcontent":[{"kpmg_image":{"raw":{}},"kpmg_short_desc":{"raw":{}},"kpmg_article_type":{"raw":{}},"kpmg_title":{"raw":{}},"kpmg_image_alt":{"raw":{}},"kpmg_url":{"raw":{}},"kpmg_template_type":{"raw":{}}}],"contactcarousel":[{"kpmg_image":{"raw":{}},"kpmg_cont_mem_firm":{"raw":{}},"kpmg_contact_job_ttl":{"raw":{}},"kpmg_title":{"raw":{}},"kpmg_contact_fn":{"raw":{}},"kpmg_suffix":{"raw":{}},"kpmg_contact_ln":{"raw":{}},"kpmg_contact_mn":{"raw":{}},"kpmg_contact_city":{"raw":{}},"kpmg_salutation":{"raw":{}},"kpmg_state":{"raw":{}},"kpmg_short_desc":{"raw":{}},"kpmg_image_alt":{"raw":{}},"kpmg_url":{"raw":{}}}],"articlecarousel":[{"kpmg_image":{"raw":{}},"kpmg_contact_fn":{"raw":{}},"kpmg_contact_ln":{"raw":{}},"kpmg_short_title":{"raw":{}},"kpmg_article_date_time":{"raw":{}},"kpmg_contact_country":{"raw":{}},"kpmg_short_desc":{"raw":{}},"kpmg_image_alt":{"raw":{}},"kpmg_url":{"raw":{}}}],"articlequery":[{"kpmg_image":{"raw":{}},"kpmg_description":{"raw":{}},"kpmg_filter_date":{"raw":{}},"kpmg_banner_flag":{"raw":{}},"kpmg_primary_tag":{"raw":{}},"kpmg_article_date":{"raw":{}},"kpmg_article_readtime":{"raw":{}},"kpmg_title":{"raw":{}},"kpmg_article_date_time":{"raw":{}},"kpmg_page_views":{"raw":{}},"kpmg_tab_type":{"raw":{}},"kpmg_short_desc":{"raw":{}},"kpmg_avg_time_spent":{"raw":{}},"kpmg_article_primary_format":{"raw":{}},"kpmg_article_type":{"raw":{}},"kpmg_url":{"raw":{}},"kpmg_template_type":{"raw":{}},"kpmg_sl_gl_id":{"raw":{}}}],"trendinglistnew":[{"kpmg_image":{"raw":{}},"kpmg_description":{"raw":{}},"kpmg_article_date_time":{"raw":{}},"kpmg_title":{"raw":{}},"kpmg_image_alt":{"raw":{}},"kpmg_url":{"raw":{}}}],"latestthinking":[{"kpmg_image":{"raw":{}},"kpmg_description":{"raw":{}},"kpmg_title":{"raw":{}},"kpmg_url":{"raw":{}}}],"broader":[{"kpmg_image":{"raw":{}},"kpmg_description":{"raw":{}},"kpmg_banner_flag":{"raw":{}},"kpmg_primary_tag":{"raw":{}},"kpmg_article_date":{"raw":{}},"kpmg_contact_job_ttl":{"raw":{}},"kpmg_article_readtime":{"raw":{}},"kpmg_title":{"raw":{}},"kpmg_contact_fn":{"raw":{}},"kpmg_contact_ln":{"raw":{}},"kpmg_event_type":{"raw":{}},"kpmg_contact_city":{"raw":{}},"kpmg_event_start_time":{"raw":{}},"kpmg_article_date_time":{"raw":{}},"kpmg_contact_country":{"raw":{}},"kpmg_tab_type":{"raw":{}},"kpmg_short_desc":{"raw":{}},"kpmg_article_primary_format":{"raw":{}},"kpmg_article_type":{"raw":{}},"kpmg_event_startdate":{"raw":{}},"kpmg_url":{"raw":{}},"kpmg_template_type":{"raw":{}}}],"listing":[{"kpmg_title":{"raw":{}},"kpmg_url":{"raw":{}}}],"shorter":[{"kpmg_image":{"raw":{}},"kpmg_description":{"raw":{}},"kpmg_banner_flag":{"raw":{}},"kpmg_primary_tag":{"raw":{}},"kpmg_article_date":{"raw":{}},"kpmg_short_desc":{"raw":{}},"kpmg_article_primary_format":{"raw":{}},"kpmg_article_type":{"raw":{}},"kpmg_title":{"raw": ...
# var appSearchClientEnv=''
# var isadmactive='true'
# var isAdvanceSemaphoreEnabled='true'
# var kpmgAssetDomain='https://assets.kpmg',calanderProperties={"longMonths":["January","February","March","April","May","June","July","August","September","October","November","December"],"shortMonths":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"timeMeridiems":["AM","PM"]},dateFormatProperties={"showMeridiem":true,"transformations":{"dayType":"d","monthType":"mmmm","hourType":"hh","monthCase":"cc","yearType":"y"},"timeSeparator":":","fields":[{"item1":"day"},{"item2":"month"},{"item3":"year"}],"separators":[{"item1":" "},{"item2":" "},{"item3":""}]};var kpmgDateFormat='d [full month] yyyy:Day Month Year'
# var kpmgDateSeperator1=' '
# var kpmgDateSeperator2=' '
# var kpmgDateSeperator3=''
# var KPMG=KPMG||{};KPMG.isAuthor=false;var searchFacetsFlag=true;if(navigator.userAgent.match(/iPad/i)===null){var meta;meta=document.createElement('meta');meta.name="viewport";meta.id='kpmgViewport';meta.content="width=device-width, initial-scale=1.0, user-scalable=1.0";document.getElementsByTagName("head")[0].appendChild(meta);}
# if(navigator.userAgent.match(/iPhone/i)){var meta;meta=document.createElement('meta');meta.name="viewport";meta.id='kpmgViewport';meta.content="width=device-width, initial-scale=1.0, user-scalable=no";document.getElementsByTagName("head")[0].appendChild(meta);}
#   </script>
#   <script class="chrome" type="text/javascript">
#    window.regexValues=window.regexValues||{nameJs:"[0\u002D9|\x22~`!@#$%^\x26()_={}[\\]:;\x27,.<>+*\\\/\\\\?]"?new RegExp("[0\u002D9|\x22~`!@#$%^\x26()_={}[\\]:;\x27,.<>+*\\\/\\\\?]"):"",cityJs:""?new RegExp(""):"",emailJs:"^([a\u002DzA\u002DZ0\u002D9.+_\u002D]*@([0\u002D9a\u002DzA\u002DZ][\u002D\\w]*[0\u002D9a\u002DzA\u002DZ]\\.)+[a\u002DzA\u002DZ]{2,9})$"?new RegExp("^([a\u002DzA\u002DZ0\u002D9.+_\u002D]*@([0\u002D9a\u002DzA\u002DZ][\u002D\\w]*[0\u002D9a\u002DzA\u002DZ]\\.)+[a\u002DzA\u002DZ]{2,9})$"):"",phoneJs:""?new RegExp(""):"",cnameJs:""?new RegExp(""):"",roleJs:""?new RegExp(""):"",messageJs:"^[^%{}<>]+$"?new RegExp("^[^%{}<>]+$"):"",};
#   </script>
#   <link class="chrome" href="/etc/clientlibs/kpmgpublic/global/css/global-049ebd.css" rel="stylesheet"/>
#   <script class="chrome" type="text/javascript">
#    window.kpmgPath=window.location.pathname.toLowerCase();var preferredSite='';function getCookie(cname){var name=cname+"=";var cArray=document.cookie.split(';');for(var i=0;i<cArray.length;i++){var c=cArray[i];while(c.charAt(0)==' '){c=c.substring(1);}
# if(c.indexOf(name)==0){preferredSite=c.substring(name.length,c.length);preferredSite=preferredSite.indexOf(".html")>-1?preferredSite:"";return true;}}}
# if(window.kpmgPath==="/xx/en/home.html"&&document.referrer===""){getCookie("p_source");if(preferredSite.length>0&&preferredSite!=="/xx/en/home.html"){var geoUserSite=encodeURI(preferredSite)
# window.location=geoUserSite;}}
# window.kpmgPersonalize=window.kpmgPersonalize||{hideLogicTree:false,displayNameFormat:"",isPersonalize:false,isSitePersonalize:true,isPageTagsFlagEnabled:false,isContentRefreshEnabled:false,isPPC:false,firstnameLastnameSwitch:false,isBlog:false,blogHomePage:"",blogPath:""||"blogs",blogResultCount:"90"||"0",userAccInfoExpiry:24,fetchDataAndPersonalize:null,getCaptchaKey:"6LfauzAUAAAAAKtLWpawmB-D5LslW_V5ul7Q_dUM",isCaptchaEnabled:"true",downloadDataExpiryWindow:24,resendVerifyEmailDefaultTime:"60",db:{CDCWrapper:null,data:null,},mapping:{url:""},snp:{url:"",timeout:0,data:null,params:{languageCode:"en"||"en",countryCode:"eg"||"xx",sortType:"",sortTypeKey:"",tagCategory:"",timeBoxParameter:""}},registrationPromoOverlay:{revisitCounter:"3",returnWindowInMinutes:"30",returnWindowInDays:"14"},misc:{isAuthor:false,ageVerificationReq:false,isSitePersonalizeAndRhfEnabled:"true"||false,dashboardLimitNo:0,triggerRefreshFeedback:0,triggerHideFeedback:0,cellLevelCombinedHideRefresh:0,rejectedListLimit:0,locationNavigatorPage:"",RfpFormLocationSelector:""},i18n:{gigyaMsgs:{kpmg_sign_up_header:"Sign up with an existing account",kpmg_sign_up_text:"Get started by using an existing social media account or fill in the fields below to gain access to articles, research and resources.",kpmg_already_have_an_account:"Already have an account?",kpmg_log_in:"Log in",kpmg_learn_more:"Learn more",kpmg_create_an_account:"Create an account",kpmg_required:"Required",kpmg_info_email:"This email address will be used when logging into your KPMG account.",kpmg_info_password:"Password must contain at least 8 characters including 1 number, 1 upper-case, 1 lower-case letter.",kpmg_privacy_statement_text:"I acknowledge that I have read and understood the terms stated in the",kpmg_privacy_statement_link_text:"KPMG Online Privacy Statement",kpmg_captcha_text:"Please confirm your registration by entering the two words in the field below, separated by a space.",kpmg_cancel:"Cancel",kpmg_continue:"Continue",kpmg_social_sign_in_header:"Signed in with",kpmg_social_sign_in_text:"You are signed in with the social account that you registered with",kpmg_cancel_registration_header:"Cancel Registration?",kpmg_cancel_registration_text:"Are you sure you want to cancel your registration?",kpmg_go_back:"Go Back",kpmg_registration_done_header:"Thank You For Registering.",kpmg_thank_you_text:"Thank you for registering. You can explore your dashboard or you can return to the article you just saved.",kpmg_go_to_mykpmg:"Go to dashboard",kpmg_return_to_my_article:"Return to my article",kpmg_error_tc_authored_msg_tc1:"Please provide acknowledgement for the online privacy statement",kpmg_error_tc_authored_msg_tc2:"Please select this checkbox to continue.",kpmg_error_tc_authored_msg_tc3:"Please select this checkbox to continue.",kpmg_privacy_acceptance_error_msg_tc1:"Please provide acknowledgement for the online privacy statement",kpmg_welcome_back:"Welcome back, ",kpmg_sign_in_header:"Sign in with an existing account",kpmg_not_yet_registered:"Not yet registered?",kpmg_use_your_kpmg_login_credentials:"Use your KPMG login credentials",kpmg_i_forgot_my_password:"I forgot my password",kpmg_keep_me_signed_in:"Keep me signed in",kpmg_forgot_password_header:"Please enter your email address to reset your password.",kpmg_forgot_password_text:"Please enter your email address to reset your password.",kpmg_reset_password:"Reset Password",kpmg_forgot_password_thank_you_text:"Thank you. If the email address provided is registered with KPMG, we will send an email containing a link to reset your password.",kpmg_return_to_login:"Return to login",kpmg_info_password_first:"Password must contain at least:",kpmg_info_password_second:"8 characters including 1 number, 1 upper-case, 1 lower-case letter and must be different from the previous 5 passwords.",kpmg_reset_password_thank_you_text:"Thank you. Your password has been reset.",kpmg_too_many_failed_attempts_header:"Too Many Failed Attempts",kpmg_too_many_faile ...
# try{eventObj=new Event("dbData.received");}
# catch(error){eventObj=document.createEvent("Event");eventObj.initEvent("dbData.received",false,false);}
# document.dispatchEvent(eventObj);};window.__gigyaConf=window.__gigyaConf||{};window.__gigyaConf.customLang=window.kpmgPersonalize.i18n.gigyaMsgs;
#   </script>
#   <link class="chrome" href="/etc/clientlibs/kpmgpublic/tmpl-tool/css/tmpl-tool-88ccf8.css" rel="stylesheet"/>
#   <meta class="chrome" content="#00338D" name="msapplication-TileColor"/>
#   <meta class="chrome" content="/etc/designs/default/kpmg/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta class="chrome" content="/etc/designs/default/kpmg/favicons/browserconfig.xml" name="msapplication-config"/>
#   <meta class="chrome" content="#00338D" name="theme-color"/>
#   <title class="chrome">
#    Corporate tax rates table - KPMG Egypt
#   </title>
#   <link class="chrome" href="/content/dam/kpmg/others/css/privacy_fix.css" rel="stylesheet" type="text/css"/>
#   <script class="chrome" src="/etc/clientlibs/kpmgpublic/global/js/updateLoadedPartialHeader-322c7b.js" type="text/javascript">
#   </script>
#   <style class="at-flicker-control chrome" id="at-makers-style">
#    .mboxDefault {visibility: hidden;}
#   </style>
#   <script class="chrome" defer="" src="/etc/scripts/runtime.7142a9466fe6caec3da0.js">
#   </script>
#   <script class="chrome" defer="" src="/etc/scripts/vendor.8cb9bad8708bf6ee2ece.js">
#   </script>
#   <script class="chrome" defer="" src="/etc/scripts/stickybar.711bd51106d193a4f071.js">
#   </script>
#   <script class="chrome" defer="" src="/etc/scripts/oppmodal.ab2848bf196c0bd8a9d3.js">
#   </script>
#   <style class="chrome" type="text/css">
#    @media (min-width: 641px){body .template .container {padding-top: 57px;} }
#   </style>
#   <script async="" charset="utf-8" class="chrome" data-requirecontext="_" data-requiremodule="main" src="/etc/clientlibs/kpmgpublic/main.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" class="chrome" data-requirecontext="_" data-requiremodule="gigyaUrl" src="https://cdns.gigya.com/js/gigya.js?apiKey=3_VyMqpWHqLLXp5GxP4hr_mjtF4DLrrHwkesmXXYENo_JX5GzK3mAxG5FLocdrfv-n " type="text/javascript">
#   </script>
#   <script async="" class="chrome" src="https://assets.adobedtm.com/9ff0694f1438/e9dbe950915c/0e616ede7dc6/RC51bc7e1ebedf4194947c08ad952d91b9-source.min.js">
#   </script>
#   <script async="" charset="utf-8" class="chrome" data-requirecontext="_" data-requiremodule="/etc/clientlibs/kpmgpublic/pages/global.min-112289.js" src="/etc/clientlibs/kpmgpublic/pages/global.min-112289.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" class="chrome" data-requirecontext="_" data-requiremodule="gigyaExt" src="https://cdn.gigya-ext.com/screenset-validation.min.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" class="chrome" data-requirecontext="_" data-requiremodule="/etc/clientlibs/kpmgpublic/pages/tmpl-tool.min-a4fc49.js" src="/etc/clientlibs/kpmgpublic/pages/tmpl-tool.min-a4fc49.js" type="text/javascript">
#   </script>
#   <script async="" class="chrome" src="https://assets.adobedtm.com/9ff0694f1438/e9dbe950915c/0e616ede7dc6/RCb572579793c74d28b56ef84cf8869fde-source.min.js">
#   </script>
#   <style class="chrome" data-styled="active" data-styled-version="5.3.3">
#   </style>
#   <style type="text/css">
#    .gigya-form-error-msg.gigya-error-msg-active { margin-top: 25px !important; } .gigya-composite-control-submit { padding-bottom: 0 !important; } .gigya-layout-row.link-row { margin-top: 25px; !important; }
#   </style>
#   <script async="" src="https://assets.adobedtm.com/9ff0694f1438/e9dbe950915c/0e616ede7dc6/RC404bbf1324fd41829cddfcba2e380844-source.min.js">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="_" data-requiremodule="registration-promo-overlay" src="/etc/clientlibs/kpmgpublic/registration-promo-overlay/js/registration-promo-overlay-f22abf.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="_" data-requiremodule="basicpagetitle" src="/etc/clientlibs/kpmgpublic/basicpagetitle/js/basicpagetitle-1a131f.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="_" data-requiremodule="share" src="/etc/clientlibs/kpmgpublic/share/js/share-b089f5.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="_" data-requiremodule="bodytext" src="/etc/clientlibs/kpmgpublic/bodytext/js/bodytext-562f56.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="_" data-requiremodule="htmlcontainer" src="/etc/clientlibs/kpmgpublic/htmlcontainer/js/htmlcontainer-2d4dbe.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="_" data-requiremodule="footersubscriptionrfp" src="/etc/clientlibs/kpmgpublic/footersubscriptionrfp/js/footersubscriptionrfp-a0e442.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="_" data-requiremodule="addtolibrary" src="/etc/clientlibs/kpmgpublic/addtolibrary/js/addtolibrary-6d085f.js" type="text/javascript">
#   </script>
#  </head>
#  <!--[if IE 9]>         <body class="lt-ie10"> <![endif]-->
#  <!--[if gt IE 9]><!-->
#  <body class="navigation-v2 chrome">
#   <div class="privacy-container chrome">
#    <div class="privacy-inner chrome">
#     <p class="privacy-prefix chrome">
#      This website uses cookies to provide a personalized browsing experience and necessary site functionality. Do you agree to the use of cookies as outlined in
#      <a class="privacy-anchor chrome" href="/eg/en/home/misc/privacy.html" target="_blank">
#       KPMG's privacy statement
#      </a>
#      ?
#     </p>
#     <a class="privacy-overlay half-width chrome" href="javascript:void(0)">
#      <input checked="" class="form-control chrome" id="policyConsent" type="checkbox"/>
#      <label class="chrome" for="policyConsent">
#       I agree
#      </label>
#     </a>
#     <a aria-label="I agree to KPMG online privacy statement" class="btn-close-main chrome" href="javascript:;">
#      <span class="btn-close chrome">
#       <span class="icon-chevron-right chrome">
#       </span>
#       <span class="btn-copy chrome">
#        Close
#       </span>
#      </span>
#     </a>
#    </div>
#   </div>
#   <iframe aria-hidden="true" class="chrome" style="width: 1em; height: 1px; border-width: 0px; position: absolute; overflow: hidden; white-space: nowrap; margin: -1px;" tabindex="-1">
#   </iframe>
#   <!--<![endif]-->
#   <!--<script type="text/javascript"> mboxCreate('myMbox'); </script>
# <!--<div class="mboxDefault"></div>-->
#   <div class="template chrome">
#    <div class="gig-simpleShareUI fixed-and-off-page chrome" id="gig_showSimpleShareUI">
#     <div class="gig-simpleShareUI-inner chrome">
#      <span class="icon-gig-simpleShareUI-closeButton chrome">
#       <span class="sr-only chrome">
#        close
#       </span>
#      </span>
#      <div class="gig-simpleShareUI-caption chrome">
#       <div class="gig-simpleShareUI-caption-text chrome">
#        Share with your friends
#       </div>
#      </div>
#      <div class="gig-simpleShareUI-content chrome" id="show-share-bar-container">
#      </div>
#     </div>
#    </div>
#    <header class="global-navigation chrome" data-link-location="Navigation-V2" style="position: absolute;">
#     <div class="bs5 chrome" data-site-info='{
# 		"assetsDomain": "https://assets.kpmg",
# 		"isAuthor": false,
# 		"isPersonalized": true,
# 		"isTemplatePersonalized": false,
# 		"isBlog":  false
# 	}' id="navigation-v2-data" style="position:fixed">
#      <!-- LOGO -->
#      <div class="chrome" data-logo='{
# 			  "imgURL": "/is/image/kpmg/EG_KPMG_BLUE",
# 			  "altText": "KPMG EG",
# 			  "linkURL": "/eg/en/home.html"
# 		}' id="navigation-v2-data-logo">
#      </div>
#      <!-- Blog header data -->
#      <!-- NABAR-NAV -->
#      <div class="chrome" data-navbar-nav='{
# 			"insights": {
# 				"id": "insights-flyout",
# 				"i18nLabel": 	" Insights ",
# 				"linkURL" : 	"/eg/en/home/insights.html"
# 			},
# 			"industries": {
# 				"id": "industries-flyout",
# 				"i18nLabel": " Industries ",
# 				"linkURL" : "/eg/en/home/industries.html"
# 			},
# 			"services": {
# 				"id": "services-flyout",
# 				"i18nLabel": " Services ",
# 				"linkURL": "/eg/en/home/services.html"
# 			},
# 			"optional": {
# 				"id": "optional-flyout",
# 				"i18nLabel": "Events",
# 				"linkURL": "/eg/en/home/events.html",
# 				"internalLinkFlag": "true",
# 				"newTabAllow": "Open in new tab or window"
# 			},
# 			"optional1": {
# 				"id": "optional2-flyout",
# 				"i18nLabel": "Invest in Egypt",
# 				"linkURL": "/eg/en/home/services/invest-in-egypt.html",
# 				"internalLinkFlag": "true",
# 				"newTabAllow": "Open in new tab or window"
# 			},
# 			"optional2": {
# 				"id": "optional3-flyout",
# 				"i18nLabel": "About Us",
# 				"linkURL": "/eg/en/home/about.html",
# 				"internalLinkFlag": "true",
# 				"newTabAllow": "Open in new tab or window"
# 			}
# 		}' id="navigation-v2-data-navbar-nav">
#      </div>
#      <div class="chrome" data-secondary-nav='[
# 			{
# 				"id": "careers",
# 				"label": " Careers ",
# 				"linkURL": ""
# 			},
#
#
# 					{
# 						"id": "alumni",
# 						"label": " Alumni ",
# 						"linkURL": ""
# 					},
#
#
# 			{
# 				"id": "media",
# 				"label": " Media ",
# 				"linkURL": ""
# 			},
#
#
# 					{
# 						"id": "social",
# 						"label": " Social ",
# 						"linkURL": ""
# 					},
#
#
#
# 			{
# 				"id": "about",
# 				"label": " About ",
# 				"linkURL": ""
# 			}
# 		]' id="navigation-v2-data-secondary-nav">
#      </div>
#      <ul class="chrome" id="navigation-v2-data-nav-flyout">
#       <li class="chrome" id="navigation-v2-author-insights-flyout-editor">
#        <div class="nav-flyout-component-data chrome" data-cell1='{
# 			"type": "nav-list",
# 			"links":[
#
#
# 					{
# 						"label": "KPMG Egypt Hazem Hassan update on COVID-19",
# 						"url": "/content/kpmgpublic/eg/en/home/insights/2020/03/kpmg-egypt-hazem-hassan-update-on-covid-19.html",
# 						"internalFlag": "false",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
#
# 						,
#
# 					{
# 						"label": "MESA Tax Update - June 2018",
# 						"url": "/eg/en/home/insights/2018/06/mesa-tax-update-june-2018.html",
# 						"internalFlag": "true",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
#
# 						,
#
# 					{
# 						"label": "Despite new challenges, CEOs confident in growth through transformation",
# 						"url": "/content/kpmgpublic/eg/en/home/insights/2016/06/despite-new-challenges-ceos-confident-in-growth-through-transformation",
# 						"internalFlag": "false",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
#
# 						,
#
# 					{
# 						"label": "TaxNewsFlash-Africa ",
# 						"url": "/eg/en/home/insights/2015/03/taxnewsflash-africa.html",
# 						"internalFlag": "true",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
# 			]
#
# 			,"viewAll": {
# 			  "linkURL": "/eg/en/home/insights0.html",
# 			  "label": "View All",
# 			  "internalLinkFlag": "true",
# 			  "newTabAllow": "Open in new tab or window"
# 			}
#
# 		}' data-cell2='{
# 				"type": "card-link",
# 				"title": "KPMG Egypt Hazem Hassan update on COVID-19",
# 				"linkUrl": "/content/kpmgpublic/eg/en/home/insights/2020/03/kpmg-egypt-hazem-hassan-update-on-covid-19.html",
# 				"description": "Coronavirus is a global health crisis with far reaching implications, the extent of which are still becoming apparent. The overwhelming priority is now to contain the virus and minimize its spread, reducing the impact it will have on individuals, families and communities around the world. Our thoughts are with all those that have been affected.",
# 				"altText": "KPMG Egypt Hazem Hassan update on COVID-19",
# 				"imgUrl": "/is/image/kpmg/man-working-on-laptop-in-office",
# 				"internalLinkFlag": "false",
# 				"newTabAllow": "Open in new tab or window",
# 				"primaryTag" : "",
# 				"isVideo" : ""
#
# 			}' data-cell3='{
# 				"type": "card-link",
# 				"title": "CEO Outlook 2021",
# 				"linkUrl": "/eg/en/home/insights/2021/08/kpmg-2021-ceo-outlook.html",
# 				"description": "Preparing for new reality.",
# 				"altText": "CEO Outlook 2021",
# 				"imgUrl": "/is/image/kpmg/women-using-tablet-2",
# 				"internalLinkFlag": "true",
# 				"newTabAllow": "Open in new tab or window",
# 				"primaryTag" : "",
# 				"isVideo" : "Page"
#
# 			}' data-featured-variation="true" data-nav-flyout='{
# 			"cell1":{
# 				"type": "nav-list",
# 				"links":[
#
#
# 						{
# 							"label": "KPMG Egypt Hazem Hassan update on COVID-19",
# 							"url": "/content/kpmgpublic/eg/en/home/insights/2020/03/kpmg-egypt-hazem-hassan-update-on-covid-19.html",
# 							"internalFlag": "false",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "MESA Tax Update - June 2018",
# 							"url": "/eg/en/home/insights/2018/06/mesa-tax-update-june-2018.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "Despite new challenges, CEOs confident in growth through transformation",
# 							"url": "/content/kpmgpublic/eg/en/home/insights/2016/06/despite-new-challenges-ceos-confident-in-growth-through-transformation",
# 							"internalFlag": "false",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "TaxNewsFlash-Africa ",
# 							"url": "/eg/en/home/insights/2015/03/taxnewsflash-africa.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
# 				]
#
# 				,"viewAll": {
# 				  "linkURL": "/eg/en/home/insights0.html",
# 				  "label": "View All",
# 				  "internalLinkFlag": "true",
# 				  "newTabAllow": "Open in new tab or window"
#
# 				}
#
# 			}
# 		}' data-path="/content/kpmgpublic/eg/en/home/services/tax/tax-tools-and-resources/tax-rates-online/corporate-tax-rates-table/jcr:content/navigation-v2/insights">
#        </div>
#       </li>
#       <li class="chrome" id="navigation-v2-author-industries-flyout-editor">
#        <div class="nav-flyout-component-data chrome" data-cell1='{
# 			"type": "nav-list",
# 			"links":[
#
#
# 					{
# 						"label": "Financial Services",
# 						"url": "/content/kpmgpublic/eg/en/home/industries/financial-services",
# 						"internalFlag": "false",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
#
# 						,
#
# 					{
# 						"label": "Consumer &amp; Retail Markets",
# 						"url": "/eg/en/home/industries/food-drink-consumer-goods1.html",
# 						"internalFlag": "true",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
#
# 						,
#
# 					{
# 						"label": "Family Business",
# 						"url": "/content/kpmgpublic/eg/en/home/industries/insurance",
# 						"internalFlag": "false",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
#
# 						,
#
# 					{
# 						"label": "Technology",
# 						"url": "/eg/en/home/industries/technology.html",
# 						"internalFlag": "true",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
#
# 						,
#
# 					{
# 						"label": "Telecommunication ",
# 						"url": "/eg/en/home/industries/telecommunications.html",
# 						"internalFlag": "true",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
# 			]
#
# 			,"viewAll": {
# 			  "linkURL": "/eg/en/home/industries.html",
# 			  "label": "View All",
# 			  "internalLinkFlag": "true",
# 			  "newTabAllow": "Open in new tab or window"
# 			}
#
# 		}' data-cell2='{
# 				"type": "nav-list",
# 				"links":[
#
#
# 						{
# 							"label": "Industrial Markets",
# 							"url": "/content/kpmgpublic/eg/en/home/industries/industrial-markets",
# 							"internalFlag": "false",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "Building and Construction",
# 							"url": "/eg/en/home/industries/building-construction.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "Travel Leisure and Tourism",
# 							"url": "/eg/en/home/industries/travel-leisure-and-tourism.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
# 				]
#
# 				}' data-cell3='{
# 				"type": "card-link",
# 				"title": "Building &amp; construction",
# 				"linkUrl": "/eg/en/home/industries/building-construction.html",
# 				"description": "KPMG’s global Building &amp; Construction practice is a network of experienced professionals based in member firms around the world.",
# 				"altText": "Building &amp; construction",
# 				"imgUrl": "/is/image/kpmg/Conceptual Framework Image",
# 				"internalLinkFlag": "true",
# 				"newTabAllow": "Open in new tab or window",
# 				"primaryTag" : "",
# 				"isVideo" : ""
#
# 			}' data-mixed-variation="true" data-nav-flyout='{
# 			"cell1":{
# 				"type": "nav-list",
# 				"links":[
#
#
# 						{
# 							"label": "Financial Services",
# 							"url": "/content/kpmgpublic/eg/en/home/industries/financial-services",
# 							"internalFlag": "false",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "Consumer &amp; Retail Markets",
# 							"url": "/eg/en/home/industries/food-drink-consumer-goods1.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "Family Business",
# 							"url": "/content/kpmgpublic/eg/en/home/industries/insurance",
# 							"internalFlag": "false",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "Technology",
# 							"url": "/eg/en/home/industries/technology.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "Telecommunication ",
# 							"url": "/eg/en/home/industries/telecommunications.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
# 				]
#
# 				,"viewAll": {
# 				  "linkURL": "/eg/en/home/industries.html",
# 				  "label": "View All",
# 				  "internalLinkFlag": "true",
# 				  "newTabAllow": "Open in new tab or window"
#
# 				}
#
# 			},
#
#
# 			"cell2": {
# 				"type": "nav-list",
# 				"links":[
#
#
# 						{
# 							"label": "Industrial Markets",
# 							"url": "/content/kpmgpublic/eg/en/home/industries/industrial-markets",
# 							"internalFlag": "false",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "Building and Construction",
# 							"url": "/eg/en/home/industries/building-construction.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "Travel Leisure and Tourism",
# 							"url": "/eg/en/home/industries/travel-leisure-and-tourism.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
# 				]
#
# 				},
# 			"cell3": {
# 				"type": "card-link",
# 				"title": "Building &amp; construction",
# 				"linkUrl": "/eg/en/home/industries/building-construction.html",
# 				"description": "KPMG’s global Building &amp; Construction practice is a network of experienced professionals based in member firms around the world.",
# 				"altText": "Building &amp; construction",
# 				"imgUrl": "/is/image/kpmg/Conceptual Framework Image",
# 				"internalLinkFlag": "true",
# 				"newTabAllow": "Open in new tab or window",
# 				"primaryTag" : "",
# 				"isVideo" : ""
#
#
# 			},
# 			"cell2": {
# 				"type": "nav-list",
# 				"links":[
#
#
# 						{
# 							"label": "Industrial Markets",
# 							"url": "/content/kpmgpublic/eg/en/home/industries/industrial-markets",
# 							"internalFlag": "false",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "Building and Construction",
# 							"url": "/eg/en/home/industries/building-construction.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "Travel Leisure and Tourism",
# 							"url": "/eg/en/home/industries/travel-leisure-and-tourism.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
# 				]
#
# 			},
# 			"cell3":{
# 				"type": "nav-list",
# 				"links":[
#
# 				]
#
# 				}
#
# 		}' data-path="/content/kpmgpublic/eg/en/home/services/tax/tax-tools-and-resources/tax-rates-online/corporate-tax-rates-table/jcr:content/navigation-v2/industries">
#        </div>
#       </li>
#       <li class="chrome" id="navigation-v2-author-services-flyout-editor">
#        <div class="nav-flyout-component-data chrome" data-cell1='{
# 			"type": "nav-list",
# 			"links":[
#
#
# 					{
# 						"label": "Audit",
# 						"url": "/eg/en/home/services/audit1.html",
# 						"internalFlag": "true",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
#
# 						,
#
# 					{
# 						"label": "Tax",
# 						"url": "/eg/en/home/services/tax.html",
# 						"internalFlag": "true",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
#
# 						,
#
# 					{
# 						"label": "Advisory ",
# 						"url": "/eg/en/home/services/advisory.html",
# 						"internalFlag": "true",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
#
# 						,
#
# 					{
# 						"label": "Investment in Egypt",
# 						"url": "/eg/en/home/investment-in-egypt.html",
# 						"internalFlag": "true",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
# 			]
#
# 			,"viewAll": {
# 			  "linkURL": "/eg/en/home/services.html",
# 			  "label": "View All",
# 			  "internalLinkFlag": "true",
# 			  "newTabAllow": "Open in new tab or window"
# 			}
#
# 		}' data-cell2='{
# 				"type": "card-link",
# 				"title": "Statement from KPMG Hazem Hassan",
# 				"linkUrl": "/eg/en/home/services/statement-from-the-managing-partner.html",
# 				"description": "Hazem Hassan is considered to be one of the largest national professional firms in Egypt and is a member firm of KPMG International",
# 				"altText": "Statement from KPMG",
# 				"imgUrl": "/is/image/kpmg/2-2-1",
# 				"internalLinkFlag": "true",
# 				"newTabAllow": "Open in new tab or window",
# 				"primaryTag" : "",
# 				"isVideo" : ""
#
# 			}' data-cell3='{
# 				"type": "card-link",
# 				"title": "Tax Rates Online",
# 				"linkUrl": "/eg/en/home/services/tax/tax-tools-and-resources/tax-rates-online.html",
# 				"description": "The online rates tool compares corporate, indirect, individual income, and social security tax rates within a country or across multiple countries.",
# 				"altText": "Tax Rates Online",
# 				"imgUrl": "/is/image/kpmg/tax-rate-tool",
# 				"internalLinkFlag": "true",
# 				"newTabAllow": "Open in new tab or window",
# 				"primaryTag" : "",
# 				"isVideo" : ""
#
# 			}' data-featured-variation="true" data-nav-flyout='{
# 			"cell1":{
# 				"type": "nav-list",
# 				"links":[
#
#
# 						{
# 							"label": "Audit",
# 							"url": "/eg/en/home/services/audit1.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "Tax",
# 							"url": "/eg/en/home/services/tax.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "Advisory ",
# 							"url": "/eg/en/home/services/advisory.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "Investment in Egypt",
# 							"url": "/eg/en/home/investment-in-egypt.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
# 				]
#
# 				,"viewAll": {
# 				  "linkURL": "/eg/en/home/services.html",
# 				  "label": "View All",
# 				  "internalLinkFlag": "true",
# 				  "newTabAllow": "Open in new tab or window"
#
# 				}
#
# 			}
# 		}' data-path="/content/kpmgpublic/eg/en/home/services/tax/tax-tools-and-resources/tax-rates-online/corporate-tax-rates-table/jcr:content/navigation-v2/services">
#        </div>
#       </li>
#       <li class="chrome" id="navigation-v2-author-optional-flyout-editor">
#        <div class="nav-flyout-component-data chrome" data-cell1='{
# 			"type": "nav-list",
# 			"links":[
#
#
# 					{
# 						"label": "KPMG Egypt Fun Day",
# 						"url": "/eg/en/home/events/2018/12/kpmg-egypt-fun-day.html",
# 						"internalFlag": "true",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
#
# 						,
#
# 					{
# 						"label": "16th KPMG MESA ",
# 						"url": "/eg/en/home/events/2017/11/kpmg-mesa.html",
# 						"internalFlag": "true",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
#
# 						,
#
# 					{
# 						"label": "IFRS (9) Workshop ",
# 						"url": "/content/kpmgpublic/eg/en/home/events/2017/11/ifrs-9-workshop",
# 						"internalFlag": "false",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
# 			]
#
# 			,"viewAll": {
# 			  "linkURL": "/eg/en/home/events.html",
# 			  "label": "View All",
# 			  "internalLinkFlag": "true",
# 			  "newTabAllow": "Open in new tab or window"
# 			}
#
# 		}' data-cell2='{
# 				"type": "card-link",
# 				"title": "16th KPMG MESA",
# 				"linkUrl": "content/kpmgpublic/eg/en/home/events/2017/11/kpmg-mesa.html",
# 				"description": "The 16th KPMG MESA Partners’ Conference took place on November 8th and 9th in Cairo, Egypt,",
# 				"altText": "16th KPMG MESA",
# 				"imgUrl": "/is/image/kpmg/eg-mesa-day3",
# 				"internalLinkFlag": "true",
# 				"newTabAllow": "Open in new tab or window",
# 				"primaryTag" : "",
# 				"isVideo" : ""
#
# 			}' data-cell3='{
# 				"type": "card-link",
# 				"title": "KPMG and Enactus inspire the next generation",
# 				"linkUrl": "content/kpmgpublic/eg/en/home/events/2017/12/kpmg-and-enactus-drive-lifelong-learning-positive-and-change.html",
# 				"description": "KPMG and Enactus drive lifelong learning and positive change worldwide.",
# 				"altText": "KPMG and Enactus inspire the next generation",
# 				"imgUrl": "/is/image/kpmg/wearing-business-suits-holding-trophy-india-banner",
# 				"internalLinkFlag": "false",
# 				"newTabAllow": "Open in new tab or window",
# 				"primaryTag" : "",
# 				"isVideo" : ""
#
# 			}' data-featured-variation="true" data-nav-flyout='{
# 			"cell1":{
# 				"type": "nav-list",
# 				"links":[
#
#
# 						{
# 							"label": "KPMG Egypt Fun Day",
# 							"url": "/eg/en/home/events/2018/12/kpmg-egypt-fun-day.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "16th KPMG MESA ",
# 							"url": "/eg/en/home/events/2017/11/kpmg-mesa.html",
# 							"internalFlag": "true",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
#
# 							,
#
# 						{
# 							"label": "IFRS (9) Workshop ",
# 							"url": "/content/kpmgpublic/eg/en/home/events/2017/11/ifrs-9-workshop",
# 							"internalFlag": "false",
# 							"newTabAllow": "Open in new tab or window"
# 						}
#
# 				]
#
# 				,"viewAll": {
# 				  "linkURL": "/eg/en/home/events.html",
# 				  "label": "View All",
# 				  "internalLinkFlag": "true",
# 				  "newTabAllow": "Open in new tab or window"
#
# 				}
#
# 			}
# 		}' data-path="/content/kpmgpublic/eg/en/home/services/tax/tax-tools-and-resources/tax-rates-online/corporate-tax-rates-table/jcr:content/navigation-v2/optional">
#        </div>
#       </li>
#       <li class="chrome" id="navigation-v2-author-optional2-flyout-editor">
#        <div class="nav-flyout-component-data chrome" data-cell1='{
# 			"type": "nav-list",
# 			"links":[
#
#
# 					{
# 						"label": "Business Environment ",
# 						"url": "/eg/en/home/services/invest-in-egypt/business-environment.html",
# 						"internalFlag": "true",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
#
# 						,
#
# 					{
# 						"label": "Mega Sectors &amp; Projects",
# 						"url": "/content/kpmgpublic/eg/en/home/services/invest-in-egypt/mega-sectors-and-projects",
# 						"internalFlag": "false",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
#
# 						,
#
# 					{
# 						"label": "How Can we Help",
# 						"url": "/eg/en/home/services/invest-in-egypt/how-we-can-help-.html",
# 						"internalFlag": "true",
# 						"newTabAllow": "Open in new tab or window"
# 					}
#
# 			]
#
# 			,"viewAll": {
# 			  "linkURL": "/eg/en/home/services/invest-in-egypt.html",
# 			  "label": "View All",
# 			  "internalLinkFlag": "true",
# 			  "newTabAllow": "Open in new tab or window"
# 			}
#
# 		}' data-cell2='{
# 				"type": "card-link",
# 				"title": "Starting or Acquiring a Business?",
# 				"linkUrl": "/eg/en/home/investment-in-egypt/starting-or-acquiring-a-business.html",
# 				"description": "Egyptian regulations encourage inward investment and start-ups, ease transition, stimulate commerce and show no bias...",
# 				"altText": "starting-or-acquiring-a-business",
# 				"imgUrl": "/is/image/kpmg/business-woman-walking-with-tab-in-her-hand",
# 				"internalLinkFlag": "true",
# 				"newTabAllow": "Open in new tab or window",
# 				"primaryTag" : "",
# 				"isVideo" : ""
#
# 			}' data-cell3='{
# 				"type": "card-link",
# 				"title": "Listing on Egyptian Exchange",
# ...
#         }
#       }
#       /*if(console && console.log) {
#         console.log('Gigya event:', e);
#       }*/
#     };
#
#     // Create event map here:
#     var customEventMap = {
#       defaultMethod: onGigyaEvent,
#         eventMap : [
#         {
#           events: '*'
#           , args: ['$event']
#         }
#       ]
#     };
#
#     // DO NOT TOUCH BELOW THIS LINE
#     // Bind event map to Gigya
#     if(window && window.gigya) {
#       // Gigya SDK already loaded, add to existing event map
#       gigya.events.addMap(customEventMap);
#     } else {
#       // Gigya SDK not yet loaded, use global conf
#       if(window && window.__gigyaConf) {
#         // Don't overwrite an existing gigyaConf
#         window.__gigyaConf.customEventMap = customEventMap;
#       } else {
#         window.__gigyaConf = {customEventMap: customEventMap};
#       }
#     }
#
#   } catch(e) {
#     if(console && console.error) {
#       console.error('Issue with Gigya event map', e);
#     }
#   }
# })();
# });
#   </script>
#   <script class="chrome">
#    digitalData.country=_satellite.getVar("Member Firm"),digitalData.in_cond1="in/en/home/trainings/advisorytrainings/businessexcellencetrainings/design-thinking-practitioners-workshop.html",digitalData.in_cond2="/in/en/home/services/learning-academy/course-learning-development-professionals-training.html";var in_cond3="/in/en/home/trainings/certified-personal-tax-professional-programme.html",in_cond4="in:en:home:services:learning-academy:certified-payroll-professional-course",in_cond5="in:en:home:services:learning-academy:course-learning-development-professionals-training",in_cond6="in:en:home:services:tax:tax-technology",in_cond7="in:en:home:services:tax:tax-technology:technology-enabled-tax-solutions:kpmg-tax-data-hub",in_cond8="in:en:home:services:tax:tax-technology:technology-enabled-tax-solutions:kpmg-transfer-pricing-document-maintenance-tool",in_cond9="in:en:home:services:tax:tax-technology:technology-enabled-tax-solutions:dividend-tds-technology-enabled-solution",in_cond10="in:en:home:services:learning-academy:business-excellence-trainings:artificial-intelligence-deep-learning-industry-programme",in_cond11="in:en:home:services:learning-academy:business-excellence-trainings:lean-six-sigma-master-black-belt-certification-programme",in_cond12="in:en:home:services:learning-academy:business-excellence-trainings:lean-six-sigma-black-belt-training-programme",in_cond13="in:en:home:services:learning-academy:business-excellence-trainings:lean-six-sigma-schedule",in_cond14="in:en:home:services:learning-academy:business-excellence-trainings:lean-six-sigma-training-faqs",in_cond15="in:en:home:services:learning-academy:business-excellence-trainings:lean-six-sigma-green-belt-training-programme",pageName=_satellite.getVar("Page Name");switch(digitalData.country){case"dk":var _linkedin_partner_id="96587";window._linkedin_data_partner_ids=window._linkedin_data_partner_ids||[],window._linkedin_data_partner_ids.push(_linkedin_partner_id),function(){var t=document.getElementsByTagName("script")[0],e=document.createElement("script");e.type="text/javascript",e.async=!0,e.src="https://snap.licdn.com/li.lms-analytics/insight.min.js",t.parentNode.insertBefore(e,t)}(),function(){var t=document.createElement("img");t.height="1",t.width="1",t.style="display:none;",t.alt="",t.src="https://px.ads.linkedin.com/collect/?pid=96587&fmt=gif",document.getElementById("body")&&document.getElementById("body").appendChild(t)}(),function(t,e,a,i,n,c,s){t.fbq||(n=t.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)},t._fbq||(t._fbq=n),n.push=n,n.loaded=!0,n.version="2.0",n.queue=[],(c=e.createElement(a)).async=!0,c.src=i,(s=e.getElementsByTagName(a)[0]).parentNode.insertBefore(c,s))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js"),fbq("init","341814570506020"),fbq("track","PageView"),function(){var t=document.createElement("img");t.height="1",t.width="1",t.style="display:none;",t.alt="",t.src="https://www.facebook.com/tr?id=341814570506020&ev=PageView&noscript=1",document.getElementById("body")&&document.getElementById("body").appendChild(t)}();break;case"xx":_linkedin_data_partner_id="2449858",function(){var t=document.getElementsByTagName("script")[0],e=document.createElement("script");e.type="text/javascript",e.async=!0,e.src="https://snap.licdn.com/li.lms-analytics/insight.min.js",t.parentNode.insertBefore(e,t)}();break;case"fr":_linkedin_data_partner_id="1752618",function(){var t=document.getElementsByTagName("script")[0],e=document.createElement("script");e.type="text/javascript",e.async=!0,e.src="https://snap.licdn.com/li.lms-analytics/insight.min.js",t.parentNode.insertBefore(e,t)}();var gbJsScript=document.createElement("script");gbJsScript.src="https://cdn.goldenbees.fr/proxy?url=http%3A//static.goldenbees.fr/cdn/js/gtag/goldentag-min.js&attachment=0",document.head&&document.head.appendChild(gbJsScript),gbJsScript.addEventListener("load",(function(){GbTagBuilder.build("am92z1").fire()})),piAI ...
#   </script>
#   <iframe class="aamIframeLoaded chrome" id="destination_publishing_iframe_kpmg_0" name="destination_publishing_iframe_kpmg_0_name" sandbox="allow-scripts allow-same-origin" src="https://kpmg.demdex.net/dest5.html?d_nsid=0#https%3A%2F%2Fhome.kpmg" style="display: none; width: 0px; height: 0px;" title="Adobe ID Syncing iFrame">
#   </iframe>
#   <img alt="" aria-hidden="true" class="chrome" height="0" id="db_bw_pixel_ad" src="https://match.prod.bidr.io/cookie-sync/demandbase" style="display:none" width="0"/>
#   <img alt="" aria-hidden="true" class="chrome" height="0" id="db_lr_pixel_ad" src="https://id.rlcdn.com/464526.gif" style="display:none" width="0"/>
#   <div class="loading-container chrome" style="width:96%; position:absolute; z-index:999; top:1%; height:68%; display:none">
#    <img alt="loading image" class="chrome" src="/etc/designs/kpmgpublic/images/loading.gif" style="margin:200px auto;"/>
#   </div>
#   <script>
#    _satellite["__runScript4"](function(event, target) {
# var regCheck=_satellite.cookie.get("userReg"),logCheck=digitalData.login.loginStatus,CookieDate=new Date;CookieDate.setFullYear(CookieDate.getFullYear()+2),"Logged-In"===logCheck&&"registered"!=regCheck&&_satellite.cookie.set("userReg","registered",CookieDate);
# });
#   </script>
#   <script>
#    if(plus(".module-videogallery").length){var count=0;!function e(){window.bcov&&window.bcov.gal&&"function"==typeof window.bcov.gal.getEmbed?plus(".module-videogallery").each((function(){var e=plus(this).data("experienceid"),o=window.bcov.gal.getEmbed("bc-embed-"+e).clientApi,t=o.getCurrentVideo();o.on("videoChanged",(function(){t=o.getCurrentVideo()})),o.on("videoStarted",(function(){console.log("video started"),_satellite.track("BrightCoveVideoStart",{Video:t.name,ID:e}),console.log(t.name)}))})):count<=20&&(count++,setTimeout(e,500))}()}
#   </script>
#   <div class="modal fade genericOppModal opp-modal" role="dialog" tabindex="0">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <span class="icon-close btn-close close" data-bs-dismiss="modal">
#        <span class="sr-only">
#         Close
#        </span>
#       </span>
#       <h2 class="salutation" data-hi="Notice of updates">
#        Notice of updates
#        <span class="user-name">
#        </span>
#        !
#       </h2>
#      </div>
#      <div class="modal-body">
#       <div class="modified-msg">
#        <div class="oppchange-text text1">
#         Notice of updates
#        </div>
#       </div>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-continue col-md-12 continueButton" data-bs-dismiss="modal" type="button">
#        <span>
#         Continue
#        </span>
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade rsOppModal opp-modal" role="dialog" tabindex="0">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <span class="icon-close btn-close close rsoppclose">
#        <span class="sr-only">
#         Close
#        </span>
#       </span>
#       <h2 class="salutation" data-hi="Hi" id="myModalLabel">
#        Hi
#        <span class="user-name">
#        </span>
#        !
#       </h2>
#      </div>
#      <div class="modal-body">
#       <div class="modified-msg">
#        <div class="oppchange-text text1">
#         Our privacy policy has been updated since the last time you logged in
#        </div>
#        <div class="oppchange-text text2">
#         We want to make sure you're kept up to date. Please take a moment to review these changes. You will not receive KPMG subscription messages until you agree to the new policy.
#        </div>
#       </div>
#      </div>
#      <div class="modal-footer">
#       <div class="col-md-6 col-xs-12 pull-left">
#        <button class="btn btn-default ignoreandlogout" data-bs-dismiss="modal" type="button">
#         <span>
#          Ignore and log out
#         </span>
#        </button>
#       </div>
#       <div class="col-md-6 col-xs-12 pull-right">
#        <button class="btn btn-continue continueButton" data-bs-dismiss="modal" type="button">
#         <span>
#          Continue
#         </span>
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade ssOppModal opp-modal" role="dialog" tabindex="0">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <span class="icon-close btn-close close" data-bs-dismiss="modal">
#        <span class="sr-only">
#         Close
#        </span>
#       </span>
#       <h2 class="salutation" data-hi="Hi">
#        <span class="salutation-title">
#         Hi
#        </span>
#        <span class="user-name">
#        </span>
#        !
#       </h2>
#      </div>
#      <div class="modal-body">
#       <div class="modified-msg">
#        <div class="oppchange-text text1">
#        </div>
#        <div class="oppchange-text text2">
#        </div>
#        <div class="checkbox terms">
#         <label class="opp-checkbox" for="terms2">
#          <span class="ss-opp">
#          </span>
#          <input id="terms2" type="checkbox" value="yes"/>
#          <span class="checkmark">
#          </span>
#          <span class="sr-only">
#           CheckBox
#          </span>
#         </label>
#        </div>
#       </div>
#      </div>
#      <div class="modal-footer">
#       <div class="col-md-5 col-xs-12 pull-left">
#        <button class="btn btn-default closeButton" data-bs-dismiss="modal" type="button">
#         <span class="close-text">
#          Close
#         </span>
#        </button>
#       </div>
#       <div class="col-md-5 col-xs-12 pull-right">
#        <button class="btn btn-continue continueButton" data-bs-dismiss="modal" type="button">
#         <span class="continue-text">
#          Continue
#         </span>
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade registration-promo-overlay chrome" role="dialog" tabindex="0">
#    <div class="modal-dialog chrome">
#     <div class="modal-content chrome">
#      <div class="modal-header chrome">
#       <h2 class="title chrome">
#        KPMG Personalization
#       </h2>
#       <span aria-label="Close" class="icon-close btn-close close chrome" data-bs-dismiss="modal" role="button" tabindex="0">
#       </span>
#      </div>
#      <div class="modal-body chrome">
#       <div class="overlay-image chrome">
#        <img alt="Register an account" class="chrome" src="https://assets.kpmg/is/image/kpmg/promo-overlay?scl=1" title="Register an account"/>
#       </div>
#       <div class="overlay-content chrome">
#        Get the latest KPMG thought leadership directly to your individual personalized dashboard
#       </div>
#      </div>
#      <div class="modal-footer chrome">
#       <button class="btn col-md-12 register-btn chrome" data-bs-dismiss="modal" type="button">
#        <span class="chrome">
#         Register now
#        </span>
#       </button>
#       <button class="btn col-md-12 login-btn chrome" data-bs-dismiss="modal" type="button">
#        <span class="chrome">
#         Login
#        </span>
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" aria-labelledby="myModalLabel" class="modal fade chrome" data-events-init="true" data-mounted="true" id="kpmgModal" role="dialog" tabindex="-1">
#    <div class="modal-dialog container chrome">
#     <a class="btn-close chrome" data-bs-dismiss="modal" href="#">
#      <span class="icon-close chrome">
#       <span class="sr-only chrome">
#        close
#       </span>
#      </span>
#     </a>
#     <div class="modal-content chrome">
#     </div>
#    </div>
#   </div>
#   <div class="modal fade generic-error-dialog chrome" data-role="dialog" id="generic-error-dialog">
#    <div class="modal-dialog chrome">
#     <div class="modal-content chrome">
#      <div class="modal-header chrome">
#       <span class="modal-title chrome" tabindex="0">
#       </span>
#       <span class="icon-close btn-close close chrome" data-bs-dismiss="modal" tabindex="0">
#       </span>
#      </div>
#      <div class="modal-body chrome" tabindex="0">
#       <span class="msg-holder chrome">
#       </span>
#      </div>
#      <div class="cta-holder chrome">
#       <span aria-label="Ok" class="ok-cta chrome" role="button" tabindex="0">
#       </span>
#       <span class="clear-floating chrome">
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade verfyEmailModal chrome" data-link-location="ResendVerificationEmail" id="verfyEmailModal" role="alert" tabindex="0">
#    <div class="modal-dialog chrome">
#     <div aria-labelledby="verifyEmailTitle" class="modal-content chrome" role="dialog">
#      <div class="modal-header chrome">
#       <span class="icon-close btn-close close chrome" data-bs-dismiss="modal">
#        <span class="sr-only modal-title chrome">
#        </span>
#       </span>
#       <h3 class="verfyEmailModal-title chrome" id="verifyEmailTitle">
#        Verify Email
#       </h3>
#      </div>
#      <div class="modal-body chrome">
#       <p class="chrome" id="verifyEmailContent">
#        Please verify your email address to continue accessing your account.
#       </p>
#      </div>
#      <div class="modal-footer chrome">
#       <button class="btn btn-default chrome" data-bs-dismiss="modal" data-bs-target="#verfyEmailModal" data-bs-toggle="modal" id="verifyEmail" type="button">
#        <span class="ok-cta chrome">
#         Resend verification email
#        </span>
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade verfyEmailModal chrome" id="verfyEmailSuccessModal" role="dialog" tabindex="0">
#    <div class="modal-dialog chrome">
#     <div class="modal-content chrome">
#      <div class="modal-header chrome">
#       <span class="icon-close btn-close close chrome" data-bs-dismiss="modal">
#        <span class="sr-only chrome">
#         Close
#        </span>
#       </span>
#       <h3 class="verfyEmailModal-title chrome">
#        Verify Email
#       </h3>
#      </div>
#      <div class="modal-body chrome">
#       <p class="success-msg alert-success chrome">
#        <span class="icon-checkmark chrome">
#        </span>
#        We've sent another confirmation message to:
#        <span class="success-email chrome">
#        </span>
#       </p>
#      </div>
#      <div class="modal-footer chrome">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade verfyEmailAlreadySentModal chrome" id="errModal" role="dialog" tabindex="0">
#    <div class="modal-dialog chrome">
#     <div class="modal-content chrome">
#      <div class="modal-header chrome">
#       <span class="icon-close btn-close close chrome" data-bs-dismiss="modal">
#        <span class="sr-only chrome">
#         Close
#        </span>
#       </span>
#       <h3 class="verfyEmailAlreadySentModal-title chrome">
#        Email already sent
#       </h3>
#      </div>
#      <div class="modal-body chrome">
#       <p class="success-msg alert-success chrome">
#        <span class="icon-checkmark chrome">
#        </span>
#        Verification email already sent. Please check your mail.
#       </p>
#      </div>
#      <div class="modal-footer chrome">
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# Iframe problem:<br>
# The obtained html doesn't show the content inside `iframe` tag, as `iframe` basically calls a new web page: <br>
# <img src='Phase 2/emptyIframeUsingSelenium.png'>
# <br><br>
# actual content inside the iframe:<br>
# <img src='Phase 2/notEmptyIframeGoogleInspector.png'>

# %% [markdown]
# Solution: retrieve page inside `src` key

# %%
iframe = soup.find('iframe', {'title':'taxrates'})
iframe
# Out:
# <iframe class="chrome" frameborder="0" height="6500px" scrolling="no" src="//s3.amazonaws.com/kpmg-global/tax-rates-tool/index_Corporate.html" title="taxrates" width="100%"></iframe>

# %%
tableLink = iframe.get('src')
tableLink
# Out:
# '//s3.amazonaws.com/kpmg-global/tax-rates-tool/index_Corporate.html'

# %%
tableLink = 'https:' + tableLink
while True:
    time.sleep(5) # sleeping a little longer, as the page loads in relatively longer time
    driver.get(tableLink)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    if soup is not None:
        break

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    KPMG
#   </title>
#   <script language="JavaScript">
#    var selectedTax = "Corporate"
#   </script>
#   <script language="JavaScript" src="js/jquery-1.6.2.min.js">
#   </script>
#   <script language="JavaScript" src="js/js-GM-PRGM-009.js">
#   </script>
#   <link href="css/style-GM-PRGM-009.css" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#   <div class="GMPRGM009ResponsiveTable">
#    <table width="100%">
#     <tbody>
#      <tr>
#       <th class="GMPRGM009xslTHLocation">
#        Location
#       </th>
#       <th class="GMPRGM009xslTHFootnotes">
#        Footnotes
#       </th>
#      </tr>
#     </tbody>
#    </table>
#   </div>
#  </body>
# </html>

# %% [markdown]
# part of the page's output: <br>
# <img src='Phase 2/iframePage.png'>

# %% [markdown]
# `pd.read_html` takes a link or html as argument and converts all tables that it finds into dataframes <br>
# But since the webpage only has one table, we will directly access it using `[0]`

# %%
taxesTable = pd.read_html(driver.page_source)
while (len(taxesTable[0]) == 0): # just a check, as sometimes javascript needs longer time to load
    time.sleep(5)
    taxesTable = pd.read_html(driver.page_source)
dfTaxes = taxesTable[0]
dfTaxes
# Out:
#                   Location   2012   2013   2014   2015   2016   2017   2018  \
# 0              Afghanistan  20.00  20.00  20.00  20.00  20.00  20.00  20.00
# 1                  Albania  10.00  10.00  15.00  15.00  15.00  15.00  15.00
# 2                  Algeria    NaN  25.00  19.00  26.00  26.00  26.00  26.00
# 3                  Andorra    NaN    NaN    NaN    NaN    NaN  10.00  10.00
# 4                   Angola  35.00  35.00  35.00  30.00  30.00  30.00  30.00
# ..                     ...    ...    ...    ...    ...    ...    ...    ...
# 178  Latin America average  28.30  27.96  27.31  27.16  27.29  27.98  28.20
# 179  North America average  33.00  33.00  33.25  33.25  33.25  33.25  26.75
# 180        Oceania average  28.60  27.00  27.00  27.00  27.00  28.43  28.43
# 181           OECD average  25.18  25.32  24.98  24.77  24.69  23.95  23.53
# 182  South America average  28.30  27.96  27.31  27.16  27.29  27.98  28.20
#
#       2019   2020 Footnotes
# 0    20.00  20.00    + Show
# 1    15.00  15.00    + Show
# 2    26.00  26.00    + Show
# 3    10.00  10.00    + Show
# 4    30.00  30.00    + Show
# ..     ...    ...       ...
# 178  27.39  27.36       NaN
# 179  26.75  26.75       NaN
# 180  28.43  28.43       NaN
# 181  23.23  23.05       NaN
# 182  27.39  27.36       NaN
#
# [183 rows x 11 columns]

# %% [markdown]
# ### Cleaning

# %%
# "footnotes" is useless, so we will remove it:
dfTaxes.drop(columns='Footnotes', inplace=True)

# %% [markdown]
# using `apply()` and user-defined function on each row:

# %%
#converting country names to country codes:
import pycountry
def toCountryCode(row):
    country = row[0]
    try:
        row[0] = pycountry.countries.get(name=country).alpha_3
    except:
        row[0] = country[0:3].upper() #if not found in pycountry, assume that it is the first 3 letters of the country name
    return row

# %% [markdown]
# Recall:
# * **Axis 0** will act on all the rows in **each column**
# * **Axis 1** will act on all the columns in **each row**
# <br>
# [source](https://stackoverflow.com/questions/22149584/what-does-axis-in-pandas-mean#:~:text=it%20this%20way%3A-,Axis%200%20will%20act,COLUMNS%20in%20each%20ROW,-So%20a%20mean)

# %%
dfTaxesCountryCodes = dfTaxes.apply(toCountryCode, axis=1)
dfTaxesCountryCodes
# Out:
#     Location   2012   2013   2014   2015   2016   2017   2018   2019   2020
# 0        AFG  20.00  20.00  20.00  20.00  20.00  20.00  20.00  20.00  20.00
# 1        ALB  10.00  10.00  15.00  15.00  15.00  15.00  15.00  15.00  15.00
# 2        DZA    NaN  25.00  19.00  26.00  26.00  26.00  26.00  26.00  26.00
# 3        AND    NaN    NaN    NaN    NaN    NaN  10.00  10.00  10.00  10.00
# 4        AGO  35.00  35.00  35.00  30.00  30.00  30.00  30.00  30.00  30.00
# ..       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 178      LAT  28.30  27.96  27.31  27.16  27.29  27.98  28.20  27.39  27.36
# 179      NOR  33.00  33.00  33.25  33.25  33.25  33.25  26.75  26.75  26.75
# 180      OCE  28.60  27.00  27.00  27.00  27.00  28.43  28.43  28.43  28.43
# 181      OEC  25.18  25.32  24.98  24.77  24.69  23.95  23.53  23.23  23.05
# 182      SOU  28.30  27.96  27.31  27.16  27.29  27.98  28.20  27.39  27.36
#
# [183 rows x 10 columns]

# %% [markdown]
# using `melt()` to change years in the header to values under the new column name `Year`

# %%
dfTaxesMelted = dfTaxesCountryCodes.melt(id_vars='Location', var_name='Year', value_name='TaxRate')
dfTaxesMelted
# Out:
#      Location  Year  TaxRate
# 0         AFG  2012    20.00
# 1         ALB  2012    10.00
# 2         DZA  2012      NaN
# 3         AND  2012      NaN
# 4         AGO  2012    35.00
# ...       ...   ...      ...
# 1642      LAT  2020    27.36
# 1643      NOR  2020    26.75
# 1644      OCE  2020    28.43
# 1645      OEC  2020    23.05
# 1646      SOU  2020    27.36
#
# [1647 rows x 3 columns]

# %%
dfTaxesMelted.dtypes
# Out:
# Location     object
# Year         object
# TaxRate     float64
# dtype: object

# %% [markdown]
# converting to `int` to be able to merge with `founded_at_year` (obtained later)

# %%
dfTaxesMelted.Year = dfTaxesMelted.Year.astype(int)
dfTaxesMelted.dtypes
# Out:
# Location     object
# Year          int32
# TaxRate     float64
# dtype: object

# %% [markdown]
# Checking that `USA` has a nice gap between tax rates

# %%
dfTaxesMelted[dfTaxesMelted['Location'] == 'USA']
# Out:
#      Location  Year  TaxRate
# 163       USA  2012     40.0
# 346       USA  2013     40.0
# 529       USA  2014     40.0
# 712       USA  2015     40.0
# 895       USA  2016     40.0
# 1078      USA  2017     40.0
# 1261      USA  2018     27.0
# 1444      USA  2019     27.0
# 1627      USA  2020     27.0

# %% [markdown]
# Thus, `USA` satisfies condition `2.` and thus will be used for this question

# %%
companiesC.founded_at.head(3)
# Out:
# 0   2011-04-12 20:46:43.240577680
# 1   2014-09-04 00:00:00.000000000
# 2   2010-05-07 20:46:43.240577680
# Name: founded_at, dtype: datetime64[ns]

# %% [markdown]
# Using `dt.year` to extract the year only from `datetime` datatype

# %%
companiesC.founded_at.dt.year.head(3)
# Out:
# 0    2011
# 1    2014
# 2    2010
# Name: founded_at, dtype: int64

# %%
companiesC.founded_at.isnull().sum()
# Out:
# 0

# %% [markdown]
# dropping `NaNs` so that we can create `founded_at_year` as `int`

# %%
companiesC.dropna(subset='founded_at', inplace=True)
companiesC.founded_at.isnull().sum()
# Out:
# 0

# %%
companiesC['founded_at_year'] = companiesC.founded_at.dt.year.astype(int)
companiesC.founded_at_year
# Out:
# 0        2011
# 1        2014
# 2        2010
# 3        2007
# 4        2010
#          ...
# 61263    2008
# 61264    2012
# 61265    2011
# 61266    2014
# 61267    2010
# Name: founded_at_year, Length: 61268, dtype: int32

# %% [markdown]
# ### Integrating (Merging)

# %% [markdown]
# First, let's impute some of the missing countries from the scraping done on Apollo

# %%
permalinks = companiesCS[companiesCS['company_country_code'] != 'missing'][['company_permalink', 'company_country_code']]
permalinks
# Out:
#                           company_permalink company_country_code
# 0                       /organization/-fame                  IND
# 1                    /organization/-qounter                  USA
# 2       /organization/-the-one-of-them-inc-                  JPN
# 3                     /organization/0-6-com                  CHN
# 4            /organization/004-technologies                  USA
# ...                                     ...                  ...
# 16511    /organization/pintail-technologies                  USA
# 16512               /organization/pinterest                  USA
# 16513  /organization/pintex-pharmaceuticals                  USA
# 16514                 /organization/pintics                  USA
# 16515                 /organization/pintley                  USA
#
# [16411 rows x 2 columns]

# %%
links = [link[0] for link in permalinks.values] #the '[0]' is because otherwise, the output is an array. e.g. "array(['/organization/10-minutes-with'], dtype=object)"
codes = [link[1] for link in permalinks.values]
linkToCode = dict(zip(links, codes))
linkToCode
# Out:
# {'/organization/-fame': 'IND',
#  '/organization/-qounter': 'USA',
#  '/organization/-the-one-of-them-inc-': 'JPN',
#  '/organization/0-6-com': 'CHN',
#  '/organization/004-technologies': 'USA',
#  '/organization/01games-technology': 'HKG',
#  '/organization/0ndine-biomedical-inc': 'CAN',
#  '/organization/0xdata': 'USA',
#  '/organization/1': 'USA',
#  '/organization/1-2-3-listo': 'CHL',
#  '/organization/1-800-dentist': 'USA',
#  '/organization/1-800-doctors': 'USA',
#  '/organization/1-800-publicrelations-inc-': 'USA',
#  '/organization/1-mainstream': 'USA',
#  '/organization/10-20-media': 'USA',
#  '/organization/10-minutes-with': 'GBR',
#  '/organization/1000-corks': 'USA',
#  '/organization/1000-markets': 'USA',
#  '/organization/1000chi': 'CHN',
#  '/organization/1000lookz': 'IND',
#  '/organization/1000memories': 'USA',
#  '/organization/1000museums-com': 'USA',
#  '/organization/1001-menus': 'FRA',
#  '/organization/1001pharmacies-com': 'FRA',
#  '/organization/1006-tv': 'CHN',
#  '/organization/100du-tv': 'CHN',
#  '/organization/100e-com': 'CHN',
#  '/organization/100health': 'USA',
#  '/organization/100plus': 'USA',
#  '/organization/1010data': 'USA',
#  '/organization/10alike': 'CAN',
#  '/organization/10bestthings': 'USA',
#  '/organization/10sec': 'USA',
#  '/organization/10seconds-software': 'AUS',
#  '/organization/10six': 'USA',
#  '/organization/10tracks-2': 'RUS',
#  '/organization/10x-genomics': 'USA',
#  '/organization/10x-technologies': 'USA',
#  '/organization/10x10-room': 'USA',
#  '/organization/11-health': 'GBR',
#  '/organization/115-network-disks': 'CHN',
#  '/organization/117go': 'CHN',
#  '/organization/11i-solutions': 'USA',
#  '/organization/12-labs': 'USA',
#  '/organization/12-star-survival': 'DNK',
#  '/organization/120-sports': 'USA',
#  '/organization/121cast': 'AUS',
#  '/organization/1234enter': 'BRA',
#  '/organization/123feng-com': 'CHN',
#  '/organization/123greetings': 'USA',
#  '/organization/123people': 'AUT',
#  '/organization/128-technology': 'USA',
#  '/organization/12bis': 'FRA',
#  '/organization/12cm': 'KOR',
#  '/organization/12return': 'NLD',
#  '/organization/12society': 'USA',
#  '/organization/139shop': 'CHN',
#  '/organization/13th-lab': 'SWE',
#  '/organization/140-proof': 'USA',
#  '/organization/140fire': 'USA',
#  '/organization/1417': 'USA',
#  '/organization/15fen': 'CHN',
#  '/organization/15five': 'USA',
#  '/organization/15minutesnow': 'USA',
#  '/organization/15shopstop': 'USA',
#  '/organization/169-st': 'USA',
#  '/organization/16lab-inc-': 'JPN',
#  '/organization/17-media': 'DEU',
#  '/organization/170-systems': 'USA',
#  '/organization/17hats': 'USA',
#  '/organization/17u-cn': 'CHN',
#  '/organization/17zuoye': 'USA',
#  '/organization/1871': 'USA',
#  '/organization/19pay': 'CHN',
#  '/organization/1bib': 'CHN',
#  '/organization/1bog': 'USA',
#  '/organization/1c-company': 'RUS',
#  '/organization/1calendar': 'DNK',
#  '/organization/1cast': 'USA',
#  '/organization/1click': 'IND',
#  '/organization/1cloudstar-asia': 'SGP',
#  '/organization/1commmedical': 'USA',
#  '/organization/1d4-pty': 'NOR',
#  '/organization/1day1song': 'KOR',
#  '/organization/1daylater': 'AUS',
#  '/organization/1daymakeover': 'USA',
#  '/organization/1doc3': 'COL',
#  '/organization/1docway': 'USA',
#  '/organization/1energy-systems': 'USA',
#  '/organization/1eq': 'USA',
#  '/organization/1jiajie': 'CHN',
#  '/organization/1lay': 'RUS',
#  '/organization/1life-healthcare': 'USA',
#  '/organization/1mind': 'USA',
#  '/organization/1mpact-revolution-powering-helpfreely-org': 'ESP',
#  '/organization/1mxians': 'CHN',
#  '/organization/1o1media': 'DEU',
#  '/organization/1ring': 'ITA',
#  '/organization/1sdk': 'DEU',
#  '/organization/1spire': 'USA',
#  '/organization/1st-merchant-funding': 'USA',
#  '/organization/1stdibs': 'USA',
#  '/organization/1stgig-com': 'USA',
#  '/organization/1v1-draft-gaems': 'USA',
#  '/organization/1world-online': 'USA',
#  '/organization/2-minutes': 'FRA',
#  '/organization/2-observe': 'BEL',
#  '/organization/2-pro-media-group': 'HKG',
#  '/organization/20-20-gene-systems-inc': 'USA',
#  '/organization/20-20-mobile': 'IRL',
#  '/organization/20lines': 'ITA',
#  '/organization/20n': 'USA',
#  '/organization/20x200': 'USA',
#  '/organization/2100b-com-llc': 'USA',
#  '/organization/21cake-food-co': 'CHN',
#  '/organization/21diamonds-india': 'IND',
#  '/organization/21e6': 'USA',
#  '/organization/21st-century-oncology': 'USA',
#  '/organization/21vianet': 'CHN',
#  '/organization/22nd-century-group': 'USA',
#  '/organization/22seeds': 'ISR',
#  '/organization/2345-com': 'CHN',
#  '/organization/2359-media': 'SGP',
#  '/organization/23andme': 'USA',
#  '/organization/23press': 'CAN',
#  '/organization/24-7-card': 'USA',
#  '/organization/24-7-customer': 'USA',
#  '/organization/24-hour-pro-muscle-gym': 'USA',
#  '/organization/24-media-network': 'SWE',
#  '/organization/247-learning-private': 'IND',
#  '/organization/247-techies': 'USA',
#  '/organization/24fab': 'ESP',
#  '/organization/24fundraiser-com': 'USA',
#  '/organization/24h00': 'FRA',
#  '/organization/24i': 'NLD',
#  '/organization/24m-technologies': 'USA',
#  '/organization/24me': 'MNE',
#  '/organization/24pagebooks': 'USA',
#  '/organization/24symbols': 'ESP',
#  '/organization/24tidy': 'CHN',
#  '/organization/250ok': 'USA',
#  '/organization/25eight': 'USA',
#  '/organization/265-network': 'CHN',
#  '/organization/27-bards': 'USA',
#  '/organization/27-perry': 'USA',
#  '/organization/280-north': 'USA',
#  '/organization/28msec': 'USA',
#  '/organization/29west': 'USA',
#  '/organization/2b-angels': 'ISR',
#  '/organization/2c2p': 'SGP',
#  '/organization/2can': 'RUS',
#  '/organization/2checkout-com': 'USA',
#  '/organization/2code-online': 'ARG',
#  '/organization/2crisk': 'AUS',
#  '/organization/2d2c': 'USA',
#  '/organization/2degreesmobile': 'NZL',
#  '/organization/2dheat': 'GBR',
#  '/organization/2duche': 'CHN',
#  '/organization/2go-software-solutions': 'USA',
#  '/organization/2heuresavant': 'FRA',
#  '/organization/2houses': 'BEL',
#  '/organization/2lemetry': 'USA',
#  '/organization/2morrow-mobile': 'USA',
#  '/organization/2nd-screen-games': 'USA',
#  '/organization/2nd-story-software-inc': 'USA',
#  '/organization/2nd-watch': 'USA',
#  '/organization/2nite2nite-net': 'USA',
#  '/organization/2redbeans': 'USA',
#  '/organization/2sms': 'USA',
#  '/organization/2theloo': 'NLD',
#  '/organization/2threads': 'AUS',
#  '/organization/2u': 'USA',
#  '/organization/2vancouver': 'CAN',
#  '/organization/2win-solutions': 'ISR',
#  '/organization/2wire': 'USA',
#  '/organization/3-day-blinds': 'USA',
#  '/organization/3-four-5-group': 'USA',
#  '/organization/3-minute': 'JPN',
#  '/organization/3-v-biosciences': 'USA',
#  '/organization/30-second-showcase': 'USA',
#  '/organization/303-luxury-car-service': 'USA',
#  '/organization/30secondstofly-claire': 'THA',
#  '/organization/312-capital': 'USA',
#  '/organization/31dover': 'GBR',
#  '/organization/321lend-inc': 'USA',
#  '/organization/33across': 'USA',
#  '/organization/33coupons': 'IND',
#  '/organization/360cities': 'CZE',
#  '/organization/360fly-inc': 'USA',
#  '/organization/360guanxi': 'CHN',
#  '/organization/360imaging': 'USA',
#  '/organization/360incentives-com': 'CAN',
#  '/organization/360learning': 'FRA',
#  '/organization/360quan': 'CHN',
#  '/organization/360t': 'DEU',
#  '/organization/365-data-centers': 'USA',
#  '/organization/365-docobites': 'AUS',
#  '/organization/365-retail-markets': 'USA',
#  '/organization/365looks': 'ESP',
#  '/organization/365scores': 'GBR',
#  '/organization/365webcall': 'CHN',
#  '/organization/36kr': 'CHN',
#  '/organization/37coins': 'USA',
#  '/organization/37mhealth': 'CHN',
#  '/organization/37signals': 'USA',
#  '/organization/38-zeros': 'USA',
#  '/organization/382-communications': 'USA',
#  '/organization/39-health': 'CHN',
#  '/organization/3baysover': 'CHE',
#  '/organization/3c-interactive': 'USA',
#  '/organization/3c-plus': 'BRA',
#  '/organization/3ci': 'ITA',
#  '/organization/3claps-the-fastest-baby-fashion': 'USA',
#  '/organization/3clickemr-corporation': 'USA',
#  '/organization/3clogic': 'USA',
#  '/organization/3crowd-technologies': 'USA',
#  '/organization/3d-4u': 'USA',
#  '/organization/3d-biomatrix': 'USA',
#  '/organization/3d-by-flow': 'NLD',
#  '/organization/3d-control-systems': 'USA',
#  '/organization/3d-data': 'USA',
#  '/organization/3d-eye-solutions': 'USA',
#  '/organization/3d-future-vision-ii': 'USA',
#  '/organization/3d-heights': 'USA',
#  '/organization/3d-industri-es': 'GBR',
#  '/organization/3d-operations-inc': 'USA',
#  '/organization/3d-product-imaging': 'USA',
#  '/organization/3d-robotics': 'USA',
#  '/organization/3d-simo-2': 'CZE',
#  '/organization/3d-sound-labs': 'FRA',
#  '/organization/3d-sports-technology': 'USA',
#  '/organization/3d-systems': 'USA',
#  '/organization/3d4medical-com': 'IRL',
#  '/organization/3dbin': 'USA',
#  '/organization/3dc': 'BGR',
#  '/organization/3dduo': 'FRA',
#  '/organization/3derm-systems': 'USA',
#  '/organization/3diligent': 'USA',
#  '/organization/3dim': 'SVN',
#  '/organization/3discovered': 'USA',
#  '/organization/3divaz-2': 'CHE',
#  '/organization/3divaz-3': 'CHE',
#  '/organization/3dlt-com': 'USA',
#  '/organization/3dmena': 'JOR',
#  '/organization/3dmgame': 'CHN',
#  '/organization/3dphotoworks': 'USA',
#  '/organization/3dphy-com': 'IND',
#  '/organization/3dplusme': 'USA',
#  '/organization/3dprintus': 'RUS',
#  '/organization/3dshook-2': 'ISR',
#  '/organization/3dsoc': 'IND',
#  '/organization/3dt': 'USA',
#  '/organization/3dvista': 'ESP',
#  '/organization/3floz-com': 'USA',
#  '/organization/3funnel': 'IRL',
#  '/organization/3g-multimedia': 'HUN',
#  '/organization/3gear-systems': 'USA',
#  '/organization/3gv8-international-inc': 'CHN',
#  '/organization/3i-systems': 'CHN',
#  '/organization/3is': 'USA',
#  '/organization/3jam': 'USA',
#  '/organization/3keyit': 'USA',
#  '/organization/3leaf': 'USA',
#  '/organization/3lm': 'USA',
#  '/organization/3nder': 'GBR',
#  '/organization/3p-biopharmaceuticals': 'ESP',
#  '/organization/3par': 'USA',
#  '/organization/3pillar-global': 'USA',
#  '/organization/3pl-central': 'USA',
#  '/organization/3play-media': 'USA',
#  '/organization/3point5-com': 'USA',
#  '/organization/3pointdata': 'USA',
#  '/organization/3power-energy-group': 'GBR',
#  '/organization/3rd-planet': 'CHN',
#  '/organization/3rdkind': 'JPN',
#  '/organization/3roam': 'FRA',
#  '/organization/3scale': 'USA',
#  '/organization/3scan': 'USA',
#  '/organization/3seventy': 'USA',
#  '/organization/3si-security-systems': 'USA',
#  '/organization/3sourcing': 'USA',
#  '/organization/3sp-group': 'FRA',
#  '/organization/3sun': 'GBR',
#  '/organization/3ten8': 'USA',
#  '/organization/3tier-environmental-forecast-group': 'USA',
#  '/organization/3touch': 'IRL',
#  '/organization/3v-transaction-services': 'IRL',
#  '/organization/3ware': 'USA',
#  '/organization/3x-systems': 'USA',
#  '/organization/3yy-game-platform': 'CHN',
#  '/organization/4-33-creative-lab': 'KOR',
#  '/organization/4-animals-alsterscience-gmbh': 'DEU',
#  '/organization/4-cast-broadcasting-corporation': 'USA',
#  '/organization/4-the-stars': 'BWA',
#  '/organization/40-partners-ltd': 'GBR',
#  '/organization/405labs': 'USA',
#  '/organization/40billion-com': 'USA',
#  '/organization/410-labs': 'USA',
#  '/organization/41st-parameter': 'USA',
#  '/organization/42': 'USA',
#  '/organization/425-307-3480': 'USA',
#  '/organization/42floors': 'USA',
#  '/organization/42matters-ag': 'CHE',
#  '/organization/42networks': 'SWE',
#  '/organization/43things': 'USA',
#  '/organization/447-461-broadway-partners': 'USA',
#  '/organization/44lab5': 'USA',
#  '/organization/46elks': 'SWE',
#  '/organization/480-biomedical': 'USA',
#  '/organization/48domain': 'USA',
#  '/organization/4blox': 'USA',
#  '/organization/4c-insights': 'USA',
#  '/organization/4cable-tv': 'USA',
#  '/organization/4d-energetics': 'USA',
#  '/organization/4d-molecular-therapeutics': 'USA',
#  '/organization/4deep': 'CAN',
#  '/organization/4dk-technologies': 'USA',
#  '/organization/4front-security': 'AUS',
#  '/organization/4home': 'USA',
#  '/organization/4info': 'USA',
#  '/organization/4less': 'AUS',
#  '/organization/4meee': 'JPN',
#  '/organization/4moms': 'USA',
#  '/organization/4psa': 'ROM',
#  '/organization/4runners-entertainment': 'GBR',
#  '/organization/4s91-com': 'CHN',
#  '/organization/4sc': 'DEU',
#  '/organization/4scotty-gmbh': 'DEU',
#  '/organization/4screens': 'POL',
#  '/organization/4soils': 'USA',
#  '/organization/4tell-solutions': 'USA',
#  '/organization/4th-aspect': 'GBR',
#  '/organization/4th-office': 'GBR',
#  '/organization/4thetable': 'USA',
#  '/organization/4tiitoo': 'DEU',
#  '/organization/4urspace': 'USA',
#  '/organization/4wave': 'USA',
#  '/organization/4x4-aviation': 'GBR',
#  '/organization/5-cups-and-some-sugar': 'DEU',
#  '/organization/5-examples': 'USA',
#  '/organization/5-million-shoppers': 'USA',
#  '/organization/5-oclock-records': 'USA',
#  '/organization/5-star-mobile': 'USA',
#  '/organization/5-star-quarterback': 'USA',
#  '/organization/50-cubes': 'USA',
#  '/organization/50-partners': 'FRA',
#  '/organization/500friends': 'USA',
#  '/organization/500px': 'CAN',
#  '/organization/500shops': 'NGA',
#  '/organization/51-auto': 'CHN',
#  '/organization/51-com': 'CHN',
#  '/organization/51-give': 'CHN',
#  '/organization/51-qiangzuo': 'CHN',
#  '/organization/5151tuan': 'CHN',
#  '/organization/5173-com': 'CHN',
#  '/organization/51credit-com': 'CHN',
#  '/organization/51cto': 'CHN',
#  '/organization/51edj': 'CHN',
#  '/organization/51edu': 'CHN',
#  '/organization/51hejia-com': 'CHN',
#  '/organization/51intern-com-2': 'CHN',
#  '/organization/51talk': 'CHN',
#  '/organization/51tour': 'CHN',
#  '/organization/51wan': 'CHN',
#  '/organization/51wofang-无忧我房': 'CHN',
#  '/organization/51yongche': 'CHN',
#  '/organization/51zhangdan': 'CHN',
#  '/organization/5211game': 'CHN',
#  '/organization/525j-com-cn': 'CHN',
#  '/organization/52masterworks': 'DEU',
#  '/organization/55tuan-com': 'CHN',
#  '/organization/56-com': 'CHN',
#  '/organization/58-com': 'CHN',
#  '/organization/58daojia': 'CHN',
#  '/organization/591wed': 'CHN',
#  '/organization/59saniye': 'TUR',
#  '/organization/5app': 'GBR',
#  '/organization/5barz-international': 'USA',
#  '/organization/5by': 'USA',
#  '/organization/5ensesinfood': 'ARE',
#  '/organization/5gig': 'ESP',
#  '/organization/5i-sciences': 'USA',
#  '/organization/5m-ventures': 'FRA',
#  '/organization/5min': 'USA',
#  '/organization/5minutes': 'GBR',
#  '/organization/5nine-software': 'USA',
#  '/organization/5o9': 'USA',
#  '/organization/5rocks': 'KOR',
#  '/organization/5skills': 'MNE',
#  '/organization/5th-finger': 'USA',
#  '/organization/5th-planet-games': 'USA',
#  '/organization/5to1': 'USA',
#  '/organization/60frames-entertainment': 'USA',
#  '/organization/640-labs': 'USA',
#  '/organization/66-com': 'CHN',
#  '/organization/6apt': 'CHN',
#  '/organization/6connect': 'USA',
#  '/organization/6cube': 'USA',
#  '/organization/6d-global-technologies': 'USA',
#  '/organization/6degrees': 'SGP',
#  '/organization/6ep': 'GBR',
#  '/organization/6fusion': 'USA',
#  '/organization/6n-silicon': 'CAN',
#  '/organization/6px': 'USA',
#  '/organization/6renyou-com': 'CHN',
#  '/organization/6rooms': 'CHN',
#  '/organization/6scan': 'ISR',
#  '/organization/6sense': 'USA',
#  '/organization/6sensor-labs': 'USA',
#  '/organization/6sicuro-it': 'ITA',
#  '/organization/6th-sense-analytics': 'USA',
#  '/organization/6th-wave-innovations-corporation': 'USA',
#  '/organization/6tribes': 'GBR',
#  '/organization/6wunderkinder': 'DEU',
#  '/organization/7-billion-people': 'USA',
#  '/organization/7-bites': 'JPN',
#  '/organization/7-cups-of-tea': 'USA',
#  '/organization/7-elements-studios': 'ISR',
#  '/organization/7-oaks-pharmaceutical': 'USA',
#  '/organization/7-star-entertainment': 'USA',
#  '/organization/700bike': 'CHN',
#  '/organization/71lbs': 'USA',
#  '/organization/72798-com': 'CHN',
#  '/organization/72lux': 'USA',
#  '/organization/72xuan': 'CHN',
#  '/organization/77-pieces': 'NZL',
#  '/organization/79-group': 'USA',
#  '/organization/7ac-technologies': 'USA',
#  '/organization/7digital': 'GBR',
#  '/organization/7fgame': 'CHN',
#  '/organization/7k7k-com': 'CHN',
#  '/organization/7park-data': 'USA',
#  '/organization/7signal-solutions': 'USA',
#  '/organization/7write': 'NLD',
#  '/organization/8-50-sports': 'GBR',
#  '/organization/8-inc': 'USA',
#  '/organization/8-securities-limited': 'HKG',
#  '/organization/80-20-solutions': 'CAN',
#  '/organization/80-degrees-west': 'USA',
#  '/organization/800-com': 'USA',
#  '/organization/800app': 'CHN',
#  '/organization/800razors': 'USA',
#  '/organization/8020publishing': 'USA',
#  '/organization/8020select': 'USA',
#  '/organization/818-sports-entertainment': 'USA',
#  '/organization/8868': 'CHN',
#  '/organization/88tc88': 'DEU',
#  '/organization/89-bits-entertainment-studio': 'ESP',
#  '/organization/8bit-2': 'GBR',
#  '/organization/8digits': 'TUR',
#  '/organization/8dworld': 'USA',
#  '/organization/8eighty-wear': 'USA',
#  '/organization/8fit-fitness-for-the-rest-of-us': 'USA',
#  '/organization/8hands': 'ISR',
#  '/organization/8i': 'USA',
#  '/organization/8packs': 'SGP',
#  '/organization/8th-story': 'USA',
#  '/organization/8tracks': 'USA',
#  '/organization/8trip': 'CHN',
#  '/organization/8villages': 'SGP',
#  '/organization/8x8-inc': 'USA',
#  '/organization/9-plus-studio': 'USA',
#  '/organization/908-devices': 'USA',
#  '/organization/909c': 'FRA',
#  '/organization/90min': 'GBR',
#  '/organization/90sec-technologies': 'ISR',
#  '/organization/91-boyuan-wireles': 'CHN',
#  '/organization/91-golf': 'CHN',
#  '/organization/91-wireless': 'CHN',
#  '/organization/911-pets': 'USA',
#  '/organization/915-labs-llc': 'USA',
#  '/organization/9158-julur-com': 'CHN',
#  '/organization/91app': 'CHN',
#  '/organization/91datong-com': 'CHN',
#  '/organization/91jinrong': 'CHN',
#  '/organization/91mobiles': 'IND',
#  '/organization/955-dreams': 'USA',
#  '/organization/99-co': 'SGP',
#  '/organization/99bill': 'CHN',
#  '/organization/99chairs': 'DEU',
#  '/organization/99cloud': 'CHN',
#  '/organization/99degrees-custom': 'USA',
#  '/organization/99designs': 'USA',
#  '/organization/99dresses': 'AUS',
#  '/organization/99drones': 'NLD',
#  '/organization/99gamers': 'USA',
#  '/organization/99games-online-private-limited': 'IND',
#  '/organization/99inn-cc': 'CHN',
#  '/organization/99jobs': 'BRA',
#  '/organization/99motos': 'BRA',
#  '/organization/99presents': 'IND',
#  '/organization/99taojin-com': 'CHN',
#  '/organization/99taxis': 'BRA',
#  '/organization/99tests': 'IND',
#  '/organization/99times-cn': 'CHN',
#  '/organization/9car-technology-llc': 'CHN',
#  '/organization/9cookies': 'DEU',
#  '/organization/9diamond': 'CHN',
#  '/organization/9facts': 'RUS',
#  '/organization/9flats': 'SGP',
#  '/organization/9gag': 'HKG',
#  '/organization/9lenses': 'USA',
#  '/organization/9mile-labs': 'USA',
#  '/organization/9sky-com': 'CHN',
#  '/organization/9slides': 'USA',
#  '/organization/9star-research': 'USA',
#  '/organization/9tong-com': 'CHN',
#  '/organization/9you': 'CHN',
#  '/organization/a': 'USA',
#  '/organization/a-76-technologies': 'USA',
#  '/organization/a-a-custom-cornhole': 'USA',
#  '/organization/a-a-manufacturing': 'USA',
#  '/organization/a-and-a-travel-service': 'USA',
#  '/organization/a-bit-lucky': 'USA',
#  '/organization/a-class-limos': 'USA',
#  '/organization/a-crowd-of-monsters': 'ESP',
#  '/organization/a-curated-world': 'USA',
#  '/organization/a-d-a-m-inc': 'USA',
#  '/organization/a-d-propane': 'USA',
#  '/organization/a-dance-for-me': 'USA',
#  '/organization/a-e-complete-home-services': 'USA',
#  '/organization/a-family-first-community-services': 'USA',
#  '/organization/a-fourth-act': 'USA',
#  '/organization/a-g-pharmaceutical': 'USA',
#  '/organization/a-gas': 'GBR',
#  '/organization/a-green-nights-sleep': 'USA',
#  '/organization/a-h-software-house': 'USA',
#  '/organization/a-la-mobile': 'USA',
#  '/organization/a-life-medical': 'USA',
#  '/organization/a-list-games': 'USA',
#  '/organization/a-little-easier-recovery': 'USA',
#  '/organization/a-little-world': 'IND',
#  '/organization/a-max-technology': 'HKG',
#  '/organization/a-p-pharma': 'USA',
#  '/organization/a-place-for-rover': 'USA',
#  '/organization/a-power-energy-generation': 'CHN',
#  '/organization/a-star': 'JPN',
#  '/organization/a-star-pets': 'GBR',
#  '/organization/a-suite-salon': 'USA',
#  '/organization/a-tex': 'DNK',
#  '/organization/a-v-e-t-s-c-a-r-e': 'USA',
#  '/organization/a-vu-media': 'USA',
#  '/organization/a10-capital': 'USA',
#  '/organization/a10-networks': 'USA',
#  '/organization/a123systems': 'USA',
#  '/organization/a2zlogix': 'USA',
#  '/organization/a4vision': 'USA',
#  '/organization/a8-digital-music': 'CHN',
#  '/organization/aa-carpooling-website': 'CHN',
#  '/organization/aa-party': 'CHN',
#  '/organization/aac-technologies-holdings': 'CHN',
#  '/organization/aaipharma-services': 'USA',
#  '/organization/aampp': 'USA',
#  '/organization/aarden-pharmaceuticals': 'USA',
#  '/organization/aarki': 'USA',
#  '/organization/aarohi-communication': 'USA',
#  '/organization/aaron-andrews-apparel': 'USA',
#  '/organization/aasaanjobs-com': 'IND',
#  '/organization/aat-communications': 'USA',
#  '/organization/aatag': 'BRA',
#  '/organization/aava-mobile': 'FIN',
#  '/organization/aavlife': 'FRA',
#  '/organization/aavya-health': 'USA',
#  '/organization/ab-microfinance-bank-nigeria': 'NGA',
#  '/organization/ab-tasty': 'FRA',
#  '/organization/aba-english': 'ESP',
#  '/organization/abaad-embodied-design-llc': 'ARE',
#  '/organization/abacast-inc': 'USA',
#  '/organization/abacus-e-media': 'GBR',
#  '/organization/abacus-labs': 'USA',
#  '/organization/abacuz-limited': 'HKG',
#  '/organization/abakan-inc': 'USA',
#  '/organization/abakus': 'USA',
#  '/organization/abaltat': 'IRL',
#  '/organization/abaris': 'USA',
#  '/organization/abaris-investment-management': 'USA',
#  '/organization/abarta-oil-gas': 'USA',
#  '/organization/abattis-bioceuticals': 'CAN',
#  '/organization/abaxia': 'FRA',
#  '/organization/abb': 'CHE',
#  '/organization/abb-road': 'USA',
#  '/organization/abbeypost': 'USA',
#  '/organization/abboom': 'CYP',
#  '/organization/abbott': 'USA',
#  '/organization/abbyy': 'RUS',
#  '/organization/abbyy-language-services': 'RUS',
#  '/organization/abc-data': 'POL',
#  '/organization/abc-live': 'IND',
#  '/organization/abcam': 'GBR',
#  '/organization/abcdexperts': 'CRI',
#  '/organization/abcelex-technologies': 'CAN',
#  '/organization/abcellute': 'GBR',
#  '/organization/abcodia': 'GBR',
#  '/organization/abebooks': 'CAN',
#  '/organization/abeelo': 'ISR',
#  '/organization/abelite-design-automation-inc': 'USA',
#  '/organization/abeo': 'USA',
#  '/organization/abeona-therapeutics': 'USA',
#  '/organization/abes-market': 'USA',
#  '/organization/abfit-products': 'USA',
#  '/organization/abgenomics': 'USA',
#  '/organization/abhinav-outsourcings-pvt-ltd': 'IND',
#  '/organization/abide-therapeutics': 'USA',
#  '/organization/abidoc': 'KWT',
#  '/organization/abigail-stewart': 'USA',
#  '/organization/ability-dynamics': 'USA',
#  '/organization/ability-network': 'USA',
#  '/organization/abimate-ee': 'EST',
#  '/organization/abine': 'USA',
#  '/organization/abiobot': 'USA',
#  '/organization/abiogenix': 'USA',
#  '/organization/abionic': 'CHE',
#  '/organization/abios-gaming': 'SWE',
#  '/organization/abiquo-group': 'USA',
#  '/organization/abizinabox': 'USA',
#  '/organization/abk-biomedical': 'CAN',
#  '/organization/ablative-solutions': 'USA',
#  '/organization/able': 'USA',
#  '/organization/able-device': 'USA',
#  '/organization/able-imaging': 'USA',
#  '/organization/able-planet': 'USA',
#  '/organization/ablecloud': 'CHN',
#  '/organization/ablesky': 'USA',
#  '/organization/ablexis': 'USA',
#  '/organization/ablynx': 'BEL',
#  '/organization/abode': 'USA',
#  '/organization/abodo': 'USA',
#  '/organization/abound-logic': 'USA',
#  '/organization/abound-resources': 'USA',
#  '/organization/abound-solar': 'USA',
#  '/organization/about-glamourrent-gmbh': 'DEU',
#  '/organization/aboutlife': 'USA',
#  '/organization/aboutme': 'USA',
#  '/organization/aboutmystar': 'FRA',
#  '/organization/aboutone': 'USA',
#  '/organization/aboutourwork-com': 'USA',
#  '/organization/above-security': 'CHE',
#  '/organization/above-solutions': 'USA',
#  '/organization/abpathfinder': 'USA',
#  '/organization/abracon': 'USA',
#  '/organization/abraresto': 'IDN',
#  '/organization/abreakplease': 'IND',
#  '/organization/abreos-biosciences': 'USA',
#  '/organization/abril': 'BRA',
#  '/organization/abroad101': 'USA',
#  '/organization/abs': 'USA',
#  '/organization/abs-medical': 'USA',
#  '/organization/absentia': 'IND',
#  '/organization/absmaterials': 'USA',
#  '/organization/absolicon-solar-concentrator': 'SWE',
#  '/organization/absolutdata': 'USA',
#  '/organization/absolute-antibody': 'GBR',
#  '/organization/absolute-commerce': 'USA',
#  '/organization/absolute-sports-pvt-ltd': 'IND',
#  '/organization/absolutely-training': 'GBR',
#  '/organization/absolvent': 'POL',
#  '/organization/absorption-pharmaceuticals': 'USA',
#  '/organization/absynth-biologics': 'GBR',
#  '/organization/abt-molecular-imaging': 'USA',
#  '/organization/abtech-holdings': 'USA',
#  '/organization/abtran': 'IRL',
#  '/organization/abukai': 'USA',
#  '/organization/abundant-closet': 'USA',
#  '/organization/abury': 'DEU',
#  '/organization/abusix': 'USA',
#  '/organization/abyz': 'KOR',
#  '/organization/abzena': 'GBR',
#  '/organization/abzorba-games': 'USA',
#  '/organization/ac-immune-sa': 'CHE',
#  '/organization/ac-moore-craft-store': 'USA',
#  '/organization/acacia': 'USA',
#  '/organization/acacia-communications': 'USA',
#  '/organization/acacia-interactive': 'USA',
#  '/organization/acacia-living': 'USA',
#  '/organization/acacia-pharma': 'GBR',
#  '/organization/acacia-research': 'USA',
#  '/organization/academia': 'SVN',
#  '/organization/academia-edu': 'USA',
#  '/organization/academia-rfid': 'CAN',
#  '/organization/academic-earth': 'USA',
#  '/organization/academica': 'FIN',
#  '/organization/academix-direct-go-internet-media': 'USA',
#  '/organization/academize': 'USA',
#  '/organization/academy123': 'USA',
#  '/organization/acadia-pharmaceuticals': 'USA',
#  '/organization/acadiasoft': 'USA',
#  '/organization/acadient': 'USA',
#  '/organization/acadine-technologies': 'HKG',
#  '/organization/acaia-corp': 'USA',
#  '/organization/acal-energy': 'GBR',
#  '/organization/acal-enterprise-solutions': 'GBR',
#  '/organization/acamica': 'ARG',
#  '/organization/acarix': 'DNK',
#  '/organization/acast': 'SWE',
#  '/organization/acb-india-limited': 'IND',
#  '/organization/accalio': 'CZE',
#  '/organization/acccess-technology-solutions': 'USA',
#  '/organization/accedian-networks': 'CAN',
#  '/organization/accedo-broadband': 'SWE',
#  '/organization/accel-diagnostics': 'USA',
#  '/organization/accela': 'USA',
#  '/organization/accelalox': 'USA',
#  '/organization/accelario': 'ISR',
#  '/organization/accelecare': 'USA',
#  '/organization/accelera': 'USA',
#  '/organization/accelera-innovations': 'USA',
#  '/organization/accelerate-diagnostics': 'USA',
#  '/organization/accelerate-mobile-apps': 'USA',
#  '/organization/accelerated-io': 'USA',
#  '/organization/accelerated-orthopedic-technologies': 'USA',
#  '/organization/accelerated-pictures': 'USA',
#  '/organization/accelerated-vision-group': 'USA',
#  '/organization/accelerator-centre': 'CAN',
#  '/organization/accelerator-corp': 'USA',
#  '/organization/accelereach': 'USA',
#  '/organization/accelergy': 'USA',
#  '/organization/acceleron-pharma': 'USA',
#  '/organization/accelgolf': 'USA',
#  '/organization/accelitec': 'USA',
#  '/organization/accella-learning-llc': 'USA',
#  '/organization/accellion': 'USA',
#  '/organization/accellos': 'USA',
#  '/organization/accelone': 'USA',
#  '/organization/accelops': 'USA',
#  '/organization/accendo-technologies': 'IND',
#  '/organization/accengage': 'FRA',
#  '/organization/accent': 'BRA',
#  '/organization/accent-media-ltd': 'GBR',
#  '/organization/accent-optical-technologies': 'USA',
#  '/organization/accentia-biopharmaceuticals-inc': 'USA',
#  '/organization/accentium-web': 'IND',
#  '/organization/accenx-technologies': 'USA',
#  '/organization/acceptd': 'USA',
#  '/organization/accertify': 'USA',
#  '/organization/access-bill-pay-services': 'USA',
#  '/organization/access-closure': 'USA',
#  '/organization/access-integrated-healthcare': 'USA',
#  '/organization/access-intelligence': 'USA',
#  '/organization/access-media': 'USA',
#  '/organization/access-mediquip': 'USA',
#  '/organization/access-mobile': 'USA',
#  '/organization/access-northeast': 'USA',
#  '/organization/access-pharmaceuticals': 'USA',
#  '/organization/access-point': 'ROM',
#  '/organization/access-psychiatry-solutions': 'USA',
#  '/organization/access-sports-media-2': 'USA',
#  '/organization/access-uk': 'GBR',
#  '/organization/accessbio': 'USA',
#  '/organization/accessdata': 'USA',
#  '/organization/accessdna': 'USA',
#  '/organization/accesslan-communications': 'USA',
#  '/organization/accessnetwork': 'USA',
#  '/organization/accessory-addict-society': 'USA',
#  '/organization/accesspay': 'GBR',
#  '/organization/accio-energy': 'USA',
#  '/organization/accion-international': 'USA',
#  '/organization/accion-systems': 'USA',
#  '/organization/accion-texas': 'USA',
#  '/organization/accipiter': 'USA',
#  '/organization/accipiter-radar': 'USA',
#  '/organization/accipiter-systems': 'USA',
#  '/organization/acclaim-games': 'USA',
#  '/organization/acclaimd': 'USA',
#  '/organization/acclarent': 'USA',
#  '/organization/acclaris-holdings': 'USA',
#  '/organization/acco-brands': 'USA',
#  '/organization/acco-sa': 'USA',
#  '/organization/acco-semiconductor': 'USA',
#  '/organization/accolade': 'USA',
#  '/organization/accolo': 'USA',
#  '/organization/accompany': 'USA',
#  '/organization/accord': 'USA',
#  '/organization/accord-biomaterials': 'USA',
#  '/organization/accordent-technologies': 'USA',
#  '/organization/accordion-health': 'USA',
#  '/organization/accountable': 'USA',
#  '/organization/accounting-saas-japan': 'JPN',
#  '/organization/accountnow': 'USA',
#  '/organization/accredible': 'USA',
#  '/organization/accreon': 'USA',
#  '/organization/accriva-diagnostics': 'USA',
#  '/organization/accrue-search-concepts-dba-boounce': 'USA',
#  '/organization/accruent': 'USA',
#  '/organization/accruit': 'USA',
#  '/organization/accu-break-pharmaceuticals': 'USA',
#  '/organization/accubuild-it': 'USA',
#  '/organization/accudial-pharmaceutical': 'USA',
#  '/organization/accudraft': 'USA',
#  '/organization/accuhealth-partners': 'USA',
#  '/organization/accuitis': 'USA',
#  '/organization/acculitx': 'USA',
#  '/organization/accumed-technologies': 'USA',
#  '/organization/accumedia': 'AUS',
#  '/organization/accumen': 'USA',
#  '/organization/accumetrics': 'USA',
#  '/organization/accumulate': 'SWE',
#  '/organization/accumuli-security': 'GBR',
#  '/organization/accunostics': 'GBR',
#  '/organization/accupal': 'USA',
#  '/organization/accupass': 'TAI',
#  '/organization/accuradio': 'USA',
#  '/organization/accurate-group': 'USA',
#  '/organization/accurence': 'USA',
#  '/organization/accurev': 'USA',
#  '/organization/accuri-cytometers': 'USA',
#  '/organization/accuric': 'GBR',
#  '/organization/accuris-networks': 'IRL',
#  '/organization/accusilicon': 'USA',
#  '/organization/accusoft-pegasus': 'USA',
#  '/organization/accutherm-systems': 'USA',
#  '/organization/accutrainee': 'GBR',
#  '/organization/accuvant': 'USA',
#  '/organization/accuvein': 'USA',
#  '/organization/accuwater': 'USA',
#  '/organization/ace': 'USA',
#  '/organization/ace-2': 'NGA',
#  '/organization/ace-comm': 'USA',
#  '/organization/ace-consensus': 'GBR',
#  '/organization/ace-health': 'IRL',
#  '/organization/ace-learning-company-inc': 'USA',
#  '/organization/ace-metrix': 'USA',
#  '/organization/ace-portal': 'USA',
#  '/organization/acea-bio': 'USA',
#  '/organization/aceable': 'USA',
#  '/organization/acelero-learning': 'USA',
#  '/organization/acell': 'USA',
#  '/organization/acelrx-pharmaceuticals': 'USA',
#  '/organization/acempire': 'GBR',
#  '/organization/acer': 'TWN',
#  '/organization/acer-therapeutics': 'USA',
#  '/organization/acerta-pharma': 'USA',
#  '/organization/acesion-pharma': 'DNK',
#  '/organization/acesis': 'USA',
#  '/organization/acetylon-pharmaceuticals': 'USA',
#  '/organization/achala': 'BRA',
#  '/organization/achaogen': 'USA',
#  '/organization/achates-power': 'USA',
#  '/organization/acheev-it': 'CHN',
#  '/organization/acheive-cca': 'USA',
#  '/organization/achelios-therapeutics': 'USA',
#  '/organization/achica': 'GBR',
#  '/organization/achieve-financial-services': 'USA',
#  '/organization/achieve-lending': 'USA',
#  '/organization/achieve-x': 'USA',
#  '/organization/achieve3000': 'USA',
#  '/organization/achieved-co': 'NLD',
#  '/organization/achieveit-online': 'USA',
#  '/organization/achiever': 'SGP',
#  '/organization/achievers': 'USA',
#  '/organization/achievo': 'USA',
#  '/organization/achievo-r-corporation': 'USA',
#  '/organization/achilles-group': 'GBR',
#  '/organization/achillion-pharmaceuticals': 'USA',
#  '/organization/achronix-semiconductor': 'USA',
#  '/organization/achvr': 'USA',
#  '/organization/aci-solutions': 'USA',
#  '/organization/acid-labs': 'USA',
#  '/organization/aciex-therapeutics': 'USA',
#  '/organization/acinion': 'USA',
#  '/organization/acision': 'IND',
#  '/organization/ackme-networks': 'USA',
#  '/organization/aclaris-therapeutics': 'USA',
#  '/organization/acleda-bank': 'KHM',
#  '/organization/acm-capital-partners': 'USA',
#  '/organization/acme-packet': 'USA',
#  '/organization/acne-studios': 'SWE',
#  '/organization/acologix': 'USA',
#  '/organization/acommerce': 'THA',
#  '/organization/acomni-llc': 'USA',
#  '/organization/acompli-inc': 'USA',
#  '/organization/acon': 'DNK',
#  '/organization/aconex': 'AUS',
#  '/organization/aconite-technology': 'GBR',
#  '/organization/acorda-therapeutics': 'USA',
#  '/organization/acorio': 'USA',
#  '/organization/acorn-applications': 'USA',
#  '/organization/acorns-grow': 'USA',
#  '/organization/acosta-sales-marketing': 'USA',
#  '/organization/acoustic-sensing-technology': 'GBR',
#  '/organization/acousticeye': 'USA',
#  '/organization/acqua-innovations': 'USA',
#  '/organization/acqua-telecom-ltd': 'GBR',
#  '/organization/acquaintable': 'USA',
#  '/organization/acquia': 'USA',
#  '/organization/acquire-real-estate': 'USA',
#  '/organization/acquisio': 'CAN',
#  '/organization/acre-2': 'USA',
#  '/organization/acrecent-financial': 'CRI',
#  '/organization/acrinta': 'USA',
#  '/organization/acrisure': 'USA',
#  '/organization/acro-aircraft-seating': 'GBR',
#  '/organization/acrobatiq': 'USA',
#  '/organization/acrolinx-gmbh': 'USA',
#  '/organization/acronis': 'SGP',
#  '/organization/acronym-media-inc': 'USA',
#  '/organization/acs-athletics': 'USA',
#  '/organization/acs-biomarker': 'NLD',
#  '/organization/acs-clothing': 'GBR',
#  '/organization/acs-global': 'USA',
#  '/organization/acsendo': 'COL',
#  '/organization/act-atria-convergence-technologies-pvt-ltd-': 'IND',
#  '/organization/act-biotech': 'USA',
#  '/organization/act-genomics': 'TWN',
#  '/organization/act-md': 'USA',
#  '/organization/act-on-software': 'USA',
#  '/organization/act-teleconferencing-inc': 'USA',
#  '/organization/acta-technology': 'USA',
#  '/organization/actacell': 'USA',
#  '/organization/actblue': 'USA',
#  '/organization/acteavo': 'IRL',
#  '/organization/actelis-networks': 'USA',
#  '/organization/actiance': 'USA',
#  '/organization/actifi': 'USA',
#  '/organization/actifile': 'ISR',
#  '/organization/actifio': 'USA',
#  '/organization/actimagine': 'FRA',
#  '/organization/actimis-pharmaceuticals': 'USA',
#  '/organization/actimize': 'USA',
#  '/organization/actimo': 'DNK',
#  '/organization/actinobac-biomed': 'USA',
#  '/organization/action-audio-apps': 'USA',
#  '/organization/action-auto-sales': 'USA',
#  '/organization/action-for-children': 'GBR',
#  '/organization/action-online-publishing': 'USA',
#  '/organization/action-pharma': 'DNK',
#  '/organization/action-plan-manager-a-s': 'SVK',
#  '/organization/action-products-international': 'USA',
#  '/organization/action-square': 'SOU',
#  '/organization/actionbase': 'ISR',
#  '/organization/actionengine': 'USA',
#  '/organization/actioniq': 'USA',
#  '/organization/actionplanner': 'DNK',
#  '/organization/actionrun': 'USA',
#  '/organization/actions': 'ITA',
#  '/organization/actions-semiconductor': 'CHN',
#  '/organization/actionsoft': 'CHN',
#  '/organization/actionsprout': 'USA',
#  '/organization/actiontax-ca': 'CAN',
#  '/organization/actionx': 'USA',
#  '/organization/actito': 'BEL',
#  '/organization/activ': 'COL',
#  '/organization/activ-financial-systems': 'USA',
#  '/organization/activ-technologies': 'USA',
#  '/organization/activaero': 'DEU',
#  '/organization/activaided-orthotics': 'USA',
#  '/organization/activate-healthcare': 'USA',
#  '/organization/activate-hub': 'USA',
#  '/organization/activation-life': 'USA',
#  '/organization/activation-media': 'USA',
#  '/organization/activation-solutions': 'USA',
#  '/organization/activbiotics': 'USA',
#  '/organization/active-circle': 'FRA',
#  '/organization/active-dsp': 'NOR',
#  '/organization/active-endpoints': 'USA',
#  '/organization/active-implants': 'USA',
#  '/organization/active-international': 'USA',
#  '/organization/active-junky': 'USA',
#  '/organization/active-location-inc': 'USA',
#  '/organization/active-media': 'CHN',
#  '/organization/active-mind-technology': 'USA',
#  '/organization/active-optical-mems': 'USA',
#  '/organization/active-scaler': 'USA',
#  '/organization/active-semi': 'USA',
#  '/organization/active-sonar-inc': 'JPN',
#  '/organization/active-tax-accounting': 'USA',
#  '/organization/activeeon': 'FRA',
#  '/organization/activegift': 'UKR',
#  '/organization/activegrid': 'USA',
#  '/organization/activehours': 'USA',
#  '/organization/activelifescientific': 'USA',
#  '/organization/actively-learn': 'USA',
#  '/organization/activenetwork': 'USA',
#  '/organization/activeo': 'USA',
#  '/organization/activepath': 'USA',
#  '/organization/activerain': 'USA',
#  '/organization/activesec': 'LTU',
#  '/organization/activestrategy': 'USA',
#  '/organization/activetrak': 'USA',
#  '/organization/activeusa-com': 'BRA',
#  '/organization/actividentity': 'USA',
#  '/organization/activiews': 'ISR',
#  '/organization/activiomics': 'GBR',
#  '/organization/activism-com': 'GBR',
#  '/organization/activity-rocket': 'USA',
#  '/organization/activity-stream': 'ISL',
#  '/organization/activityhero': 'USA',
#  '/organization/actiwave': 'SWE',
#  '/organization/actix': 'GBR',
#  '/organization/actlight': 'CHE',
#  '/organization/actogenix': 'BEL',
#  '/organization/acton': 'USA',
#  '/organization/acton-pharmaceuticals': 'USA',
#  '/organization/actsocial': 'SGP',
#  '/organization/actual-experience': 'GBR',
#  '/organization/actual-reports': 'EST',
#  '/organization/actualmeds': 'USA',
#  '/organization/actualsun': 'USA',
#  '/organization/actuatedmedical': 'USA',
#  '/organization/acturis': 'GBR',
#  '/organization/actus-digital': 'ISR',
#  ...}

# %%
def missingToCode(row):
    try:
        row['company_country_code'] = linkToCode[row['company_permalink']]
    finally:
        return row

# %%
companiesC = companiesC.apply(lambda x: missingToCode(x), axis=1)

# %% [markdown]
# Using `pd.merge()` to merge `companiesC` and `dfTaxesMelted` based on the country and the year

# %%
companiesTaxes = pd.merge(companiesC, dfTaxesMelted, how='inner', left_on=['company_country_code', 'founded_at_year'], right_on=['Location', 'Year'])
companiesTaxes.shape
# Out:
# (16992, 17)

# %%
companiesTaxesOuter = pd.merge(companiesC, dfTaxesMelted, how='outer', left_on=['company_country_code', 'founded_at_year'], right_on=['Location', 'Year'])
companiesTaxesOuter.shape
# Out:
# (62618, 17)

# %% [markdown]
# Notice that when we used inner join, the number of companies decreased from 62618 to 16992; <br>
# that's because the rest of the companies were founded before 2012 (first date in `dfTaxesMelted` dataframe) <br>
# However, 10000+ are still a lot of companies, so we'll continue the analysis on this scraped data

# %%
companiesTaxes.columns
# Out:
# Index(['company_permalink', 'company_name', 'homepage_url',
#        'company_category_list', 'funding_total_usd', 'status',
#        'company_country_code', 'company_city', 'funding_rounds', 'founded_at',
#        'first_funding_at', 'last_funding_at', 'time_before_first_fund',
#        'founded_at_year', 'Location', 'Year', 'TaxRate'],
#       dtype='object')

# %% [markdown]
# dropping `Location` and `Year` since they're redundent info

# %%
companiesTaxes.drop(columns=['Location', 'Year'], inplace=True)
companiesTaxes.columns
# Out:
# Index(['company_permalink', 'company_name', 'homepage_url',
#        'company_category_list', 'funding_total_usd', 'status',
#        'company_country_code', 'company_city', 'funding_rounds', 'founded_at',
#        'first_funding_at', 'last_funding_at', 'time_before_first_fund',
#        'founded_at_year', 'TaxRate'],
#       dtype='object')

# %% [markdown]
# using `pop()` and `insert()` to shift the `founded_at_year` column to be next to `founded_at` column for aesthetic reasons :]

# %%
columnValues = companiesTaxes.pop("founded_at_year")
companiesTaxes.insert(10, "founded_at_year", columnValues)
companiesTaxes.columns
# Out:
# Index(['company_permalink', 'company_name', 'homepage_url',
#        'company_category_list', 'funding_total_usd', 'status',
#        'company_country_code', 'company_city', 'funding_rounds', 'founded_at',
#        'founded_at_year', 'first_funding_at', 'last_funding_at',
#        'time_before_first_fund', 'TaxRate'],
#       dtype='object')

# %% [markdown]
# Using only companies in `USA`

# %%
usaCompaniesTaxes = companiesTaxes[companiesTaxes['company_country_code'] == 'USA']
usaCompaniesTaxes.shape
# Out:
# (9519, 15)

# %% [markdown]
# 9k are still a lot of companies, so we will continue the analysis on `USA`

# %% [markdown]
# ### Visualizing

# %% [markdown]
# Now, let's evaluate how taxes affect companies. 3 features will be chosen for the evaluation:
# 1. `funding_total_usd`
# 2. `status`

# %% [markdown]
# Correlating taxes with total fundings by getting their average in each year

# %%
usaCompaniesTaxes.founded_at_year.unique()
# Out:
# array([2014, 2013, 2012, 2015, 2016], dtype=int64)

# %%
taxTotalFundsUSA = (usaCompaniesTaxes[['founded_at_year', 'TaxRate', 'funding_total_usd']]
                    .groupby(['founded_at_year', 'TaxRate'])
                    .mean()
                    .round(0)
                    .style.format("{:,}"))
taxTotalFundsUSA
# Out:
# <style type="text/css">
# </style>
# <table id="T_0a64e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a64e_level0_col0" class="col_heading level0 col0" >funding_total_usd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >founded_at_year</th>
#       <th class="index_name level1" >TaxRate</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a64e_level0_row0" class="row_heading level0 row0" >2012</th>
#       <th id="T_0a64e_level1_row0" class="row_heading level1 row0" >40.000000</th>
#       <td id="T_0a64e_row0_col0" class="data row0 col0" >7,229,034.0</td>
#     </tr>
#     <tr>
#       <th id="T_0a64e_level0_row1" class="row_heading level0 row1" >2013</th>
#       <th id="T_0a64e_level1_row1" class="row_heading level1 row1" >40.000000</th>
#       <td id="T_0a64e_row1_col0" class="data row1 col0" >5,651,029.0</td>
#     </tr>
#     <tr>
#       <th id="T_0a64e_level0_row2" class="row_heading level0 row2" >2014</th>
#       <th id="T_0a64e_level1_row2" class="row_heading level1 row2" >40.000000</th>
#       <td id="T_0a64e_row2_col0" class="data row2 col0" >2,762,574.0</td>
#     </tr>
#     <tr>
#       <th id="T_0a64e_level0_row3" class="row_heading level0 row3" >2015</th>
#       <th id="T_0a64e_level1_row3" class="row_heading level1 row3" >40.000000</th>
#       <td id="T_0a64e_row3_col0" class="data row3 col0" >1,787,911.0</td>
#     </tr>
#     <tr>
#       <th id="T_0a64e_level0_row4" class="row_heading level0 row4" >2016</th>
#       <th id="T_0a64e_level1_row4" class="row_heading level1 row4" >40.000000</th>
#       <td id="T_0a64e_row4_col0" class="data row4 col0" >0.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Problem: turns out that in our dataset, `USA` companies that are after 2016 are not present, <br>
# and the tax rate for the countries before that were constant (40%)

# %%
#getting the number of companies that were founded after the end of 2015
len(
    companiesC[
        (companiesC.company_country_code == 'USA') 
        & 
        (companiesC.founded_at >= pd.Timestamp(2016, 1, 1))
        ]
    )
# Out:
# 1

# %% [markdown]
# Therefore, let's look at other countries

# %% [markdown]
# ### Working on GBR taxes (working attempt)

# %% [markdown]
# Scraping, Cleaning, and Integration are already done above <br>
# the output was the dataframe called `companiesTaxes`

# %% [markdown]
# Using only companies in `GBR`

# %%
gbrCompaniesTaxes = companiesTaxes[companiesTaxes['company_country_code'] == 'GBR']
gbrCompaniesTaxes.shape
# Out:
# (1125, 15)

# %% [markdown]
# Only 1125 companies, unfortunately scraping `Apollo` is now not an option (due to getting blocked) <br>
# so we can only rely on these companies

# %%
gbrCompaniesTaxes.founded_at_year.unique()
# Out:
# array([2013, 2015, 2012, 2014], dtype=int64)

# %% [markdown]
# all the 1k companies in GBR were founded in the range between 2012 and 2015 <br>
# Let's check the taxes at that time:

# %%
dfStep = dfTaxesMelted[(dfTaxesMelted['Location'] == 'GBR') & (dfTaxesMelted['Year'].between(2012,2015))][['Year', 'TaxRate']]
plt.plot(dfStep['Year'], dfStep['TaxRate'], marker='o', linestyle='-', color='r', linewidth=2)
plt.xlabel('year')
plt.ylabel('tax rate in GBR (%)')
plt.xticks([2012,2013,2014,2015]);

# %% [markdown]
# Since the tax rate has been gradually decreasing <br>
# Thus, we expect better company performance throughout the years

# %% [markdown]
# ### Visualizing

# %% [markdown]
# As before, 2 approaches will be chosen to evaluate how taxes affect companies:
# 1. (`TaxRate`, `founded_at_year`) vs number of closed companies
# 2. (`TaxRate`, `founded_at_year`) vs average of `funding_total_usd`

# %% [markdown]
# Correlating taxes with total number of operating/acquired/closed companies in each year

# %%
gbrCompaniesStatus = (gbrCompaniesTaxes[['founded_at_year', 'TaxRate', 'status', 'company_permalink']]
                            .groupby(['status', 'founded_at_year', 'TaxRate'])
                            .count())
gbrCompaniesStatus
# Out:
#                                    company_permalink
# status    founded_at_year TaxRate
# acquired  2012            24.0                     8
#           2013            23.0                     2
#           2014            21.0                     1
# closed    2012            24.0                    19
#           2013            23.0                     5
#           2014            21.0                    17
#           2015            20.0                    12
# ipo       2012            24.0                     1
#           2015            20.0                     1
# operating 2012            24.0                   372
#           2013            23.0                   379
#           2014            21.0                   239
#           2015            20.0                    69

# %%
gbrCompaniesStatus.plot(kind='barh')
plt.xlabel('number of companies')
plt.ylabel('')
plt.title('status, founded year, tax rate', x=-0.2)
# Out:
# Text(-0.2, 1.0, 'status, founded year, tax rate')

# %% [markdown]
# Since most companies were operating, and there are negligible number of companies are IPO, <br>
# Therefore we will focus on closed companies:

# %%
gbrClosedCompaniesTaxes = gbrCompaniesTaxes[gbrCompaniesTaxes['status'] == 'closed']
gbrCompaniesClosed = (gbrClosedCompaniesTaxes[['founded_at_year', 'TaxRate', 'company_permalink']]
                            .groupby(['founded_at_year', 'TaxRate'])
                            .count())
gbrCompaniesClosed = gbrCompaniesClosed.reset_index()
gbrCompaniesClosed
# Out:
#    founded_at_year  TaxRate  company_permalink
# 0             2012     24.0                 19
# 1             2013     23.0                  5
# 2             2014     21.0                 17
# 3             2015     20.0                 12

# %%
gbrCompaniesClosedPivoted = gbrCompaniesClosed.pivot(index='founded_at_year', columns='TaxRate', values='company_permalink')
gbrCompaniesClosedPivoted
# Out:
# TaxRate          20.0  21.0  23.0  24.0
# founded_at_year
# 2012              NaN   NaN   NaN  19.0
# 2013              NaN   NaN   5.0   NaN
# 2014              NaN  17.0   NaN   NaN
# 2015             12.0   NaN   NaN   NaN

# %%
sns.color_palette("Blues", as_cmap=True)
sns.heatmap(gbrCompaniesClosedPivoted, annot=True, cmap="Blues")
# Out:
# <AxesSubplot:xlabel='TaxRate', ylabel='founded_at_year'>

# %% [markdown]
# Notice that even though the tax rate decreases each year, "a lot" of companies closed in 2014 and 2015 <br>
# when compared to 2012 which had the highest tax rate

# %% [markdown]
# However, we have to bear in mind that the 1k companies aren't equally distributed throghout the years:

# %%
(
    gbrCompaniesTaxes
    .groupby('founded_at_year')['company_name']
    .count()
    .plot(kind='bar')
)
plt.xlabel('founded year')
plt.ylabel('number of companies')
plt.yticks(range(0,401,50))
plt.axhline(80, color='r', linestyle='--')
plt.axhline(260, color='brown', linestyle='--')
plt.axhline(390, color='y', linestyle='--')
plt.axhline(400, color='g', linestyle='--');

# %% [markdown]
# Therefore let's compare by the ratio of the closed companies to all companies in each year

# %%
gbrCompaniesAllStatus = (gbrCompaniesTaxes[['founded_at_year', 'TaxRate', 'company_permalink']]
                            .groupby(['founded_at_year', 'TaxRate'])
                            .count())
gbrCompaniesAllStatus = gbrCompaniesAllStatus.reset_index()
gbrCompaniesAllStatus
# Out:
#    founded_at_year  TaxRate  company_permalink
# 0             2012     24.0                400
# 1             2013     23.0                386
# 2             2014     21.0                257
# 3             2015     20.0                 82

# %%
gbrCompaniesClosed['CountRatio'] = 0.0
gbrCompaniesClosed
# Out:
#    founded_at_year  TaxRate  company_permalink  CountRatio
# 0             2012     24.0                 19         0.0
# 1             2013     23.0                  5         0.0
# 2             2014     21.0                 17         0.0
# 3             2015     20.0                 12         0.0

# %%
for i in range(len(gbrCompaniesClosed)):
    gbrCompaniesClosed.at[i,'CountRatio'] = gbrCompaniesClosed.at[i,'company_permalink'] / gbrCompaniesAllStatus.at[i,'company_permalink']
gbrCompaniesClosed['CountRatio'] *= 100 #converting ratio to percentage

gbrCompaniesClosed.drop(columns=['company_permalink'], inplace=True)

# %%
gbrCompaniesClosed = gbrCompaniesClosed.round(1) #rounding percentage ('CountRatio') to 1 decimal point
gbrCompaniesClosed
# Out:
#    founded_at_year  TaxRate  CountRatio
# 0             2012     24.0         4.8
# 1             2013     23.0         1.3
# 2             2014     21.0         6.6
# 3             2015     20.0        14.6

# %%
gbrCompaniesClosed.set_index('founded_at_year').plot(kind='bar')
plt.xlabel('founded year')
plt.ylabel('Percentage %');

# %% [markdown]
# When we compare by ratios, still the same insight applies: <br>
# "a lot" of companies closed in 2014 and 2015 <br>
# when compared to 2012 which had the highest tax rate

# %% [markdown]
# Thus we can deduce that the wellfare of companies isn't determined by the country's current tax rate <br>

# %% [markdown]
# Second apporach: Let's correlate taxes with total fundings by getting their average in each year

# %%
gbrCompaniesTotalFunds = (gbrCompaniesTaxes[['founded_at_year', 'TaxRate', 'funding_total_usd']]
                            .groupby(['founded_at_year', 'TaxRate'])
                            .mean()
                            .round(0)
                            #.style.format("{:,}") #formats float with commas, commented out because "gbrCompaniesTotalFunds" will become a styler object, not a DataFrame 
                            )
gbrCompaniesTotalFunds
# Out:
#                          funding_total_usd
# founded_at_year TaxRate
# 2012            24.0             4833843.0
# 2013            23.0             2110957.0
# 2014            21.0             1670704.0
# 2015            20.0             1297203.0

# %%
gbrCompaniesTotalFunds.plot(kind='barh')
plt.xlabel('total usd funding in millions (1e6)')
plt.ylabel('')
plt.title('founded at, tax rate', x=-0.1);

# %% [markdown]
# Again, this is not accurate because the 1k companies aren't equally distributed throghout the years <br>
# However, looking back at the distribution:

# %%
(
    gbrCompaniesTaxes
    .groupby('founded_at_year')['company_name']
    .count()
    .plot(kind='bar')
)
plt.xlabel('founded year')
plt.ylabel('number of companies')
plt.yticks(range(0,401,50))
plt.axhline(80, color='r', linestyle='--')
plt.axhline(260, color='brown', linestyle='--')
plt.axhline(390, color='y', linestyle='--')
plt.axhline(400, color='g', linestyle='--');

# %% [markdown]
# One can notice that even though 250+ companies were founded in 2014 and only 70+ were founded in 2015 <Br>
# The difference in the total funding is only around 100k USD, which is not much <br>
# Therefore, these few companies in 2015 got relatively a lot of fundings, and at the same time, the taxes went down by 1% <br>
# Thus, there could be a *slight correlation* between decreasing the rate of taxes, and increasing the possibility <br> that stakeholders give more funding to the startup company

# %% [markdown]
# So in conclusion to the whole question, taxes don't affect the wellfare of companies (in terms of status), <br>
# but have a slight inverse relation with the amount of fundings given to companies

# %% [markdown]
# ## Question 2 (Farah)

# %% [markdown]
# #### Does the number of Employees affect the success of company?

# %%
# Getting the Cleaned Datasets
companiesC = pd.read_csv("datasets/startupsCleaned/companiesCleaned.csv", parse_dates=['founded_at', 'first_funding_at', 'last_funding_at', 'time_before_first_fund'])
companiesCS = pd.read_csv("datasets/startupsCleaned/companiesCleanedAndScraped.csv", parse_dates=['founded_at', 'first_funding_at', 'last_funding_at', 'time_before_first_fund'])
investsC = pd.read_csv("datasets/startupsCleaned/investmentsCleaned.csv")

# %%
companiesCS
# Out:
#                           company_permalink            company_name  \
# 0                       /organization/-fame                   #fame
# 1                    /organization/-qounter                :Qounter
# 2       /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                     /organization/0-6-com                 0-6.com
# 4            /organization/004-technologies        004 Technologies
# ...                                     ...                     ...
# 16511    /organization/pintail-technologies    Pintail Technologies
# 16512               /organization/pinterest               Pinterest
# 16513  /organization/pintex-pharmaceuticals  Pintex Pharmaceuticals
# 16514                 /organization/pintics                 Pintics
# 16515                 /organization/pintley                 Pintley
#
#                              homepage_url  \
# 0                      http://livfame.com
# 1                  http://www.qounter.com
# 2                     http://oneofthem.jp
# 3                      http://www.0-6.com
# 4       http://004gmbh.de/en/004-interact
# ...                                   ...
# 16511  http://www.pintailtechnologies.com
# 16512               https://pinterest.com
# 16513          http://www.pintexpharm.com
# 16514              http://www.pintics.com
# 16515              http://www.pintley.com
#
#                                    company_category_list  funding_total_usd  \
# 0                                                  Media       1.000000e+07
# 1      Application Platforms|Real Time|Social Network...       7.000000e+05
# 2                                      Apps|Games|Mobile       3.406878e+06
# 3                                            Curated Web       2.000000e+06
# 4                                               Software       0.000000e+00
# ...                                                  ...                ...
# 16511                                           Software       1.000000e+07
# 16512        Curated Web|Social Bookmarking|Social Media       1.315500e+09
# 16513                                    Pharmaceuticals       7.250000e+06
# 16514                                        Curated Web       1.000000e+04
# 16515                         Craft Beer|Internet|Mobile       1.049990e+05
#
#           status company_country_code   company_city  funding_rounds  \
# 0      operating                  IND         Mumbai               1
# 1      operating                  USA  Delaware City               2
# 2      operating                  JPN        missing               1
# 3      operating                  CHN        Beijing               1
# 4      operating                  USA      Champaign               1
# ...          ...                  ...            ...             ...
# 16511  operating                  USA     Richardson               2
# 16512  operating                  USA  San Francisco              10
# 16513   acquired                  USA      Watertown               1
# 16514     closed                  USA       San Jose               1
# 16515  operating                  USA         Boston               1
#
#                          founded_at first_funding_at last_funding_at  \
# 0     2011-04-12 20:46:43.240577680       2015-01-05      2015-01-05
# 1     2014-09-04 00:00:00.000000000       2014-03-01      2014-10-14
# 2     2010-05-07 20:46:43.240577680       2014-01-30      2014-01-30
# 3     2007-01-01 00:00:00.000000000       2008-03-19      2008-03-19
# 4     2010-01-01 00:00:00.000000000       2014-07-24      2014-07-24
# ...                             ...              ...             ...
# 16511 2000-01-01 00:00:00.000000000       2005-03-08      2006-09-29
# 16512 2009-01-01 00:00:00.000000000       2010-01-01      2015-06-01
# 16513 2000-05-01 00:00:00.000000000       2002-12-24      2002-12-24
# 16514 2012-01-10 00:00:00.000000000       2012-05-18      2012-05-18
# 16515 2006-12-28 20:46:43.240577680       2010-09-22      2010-09-22
#
#              time_before_first_fund  employee_count  number_of_technologies  \
# 0      1363 days 03:13:16.759422320              57                       1
# 1               -187 days +00:00:00               4                       3
# 2      1363 days 03:13:16.759422320              18                      10
# 3                 443 days 00:00:00               0                       5
# 4                1665 days 00:00:00              67                      10
# ...                             ...             ...                     ...
# 16511            1893 days 00:00:00               0                       1
# 16512             365 days 00:00:00            6000                      26
# 16513             967 days 00:00:00               0                       0
# 16514             129 days 00:00:00               0                       1
# 16515  1363 days 03:13:16.759422320               0                       9
#
#          annual_rev
# 0      1.500000e+06
# 1               NaN
# 2               NaN
# 3               NaN
# 4      5.000000e+06
# ...             ...
# 16511  2.000000e+06
# 16512  2.436989e+09
# 16513           NaN
# 16514           NaN
# 16515  1.400000e+06
#
# [16516 rows x 16 columns]

# %% [markdown]
# ### Cleaning

# %% [markdown]
# As seen below, annual revenues has nulls in it so it will be dropped when this feature is needed.

# %%
companiesCS.isnull().sum()
# Out:
# company_permalink            0
# company_name                 0
# homepage_url                 0
# company_category_list        0
# funding_total_usd            0
# status                       0
# company_country_code         0
# company_city                 0
# funding_rounds               0
# founded_at                   0
# first_funding_at             0
# last_funding_at              0
# time_before_first_fund       0
# employee_count               0
# number_of_technologies       0
# annual_rev                4986
# dtype: int64

# %% [markdown]
# Let's see if the relationship between the number of employees is proportional with the suceess of the company in other words operating or not.
# Unfortunately, we don't have details on employees' salaries but we have their number in each company. if it's directly proportional then the number of employees present an important asset to building a new company, while if it's directly proportional then it proves that employing many employees can be only a burden to kick off the company

# %%
operating_comps = companiesCS[companiesCS['status'] == 'operating']
operating_comps.sort_values(by=['employee_count'], ascending=False, inplace=True)
operating_comps
# Out:
#                       company_permalink         company_name  \
# 16328           /organization/pickatale            Pickatale
# 5367               /organization/beme-2                 Beme
# 4715   /organization/b-famous-media-llc  b*famous Media, LLC
# 10902            /organization/megajosh             MEGAJOSH
# 9671           /organization/maaish-inc           Maaish Inc
# ...                                 ...                  ...
# 13557            /organization/native-4           Now Native
# 13558          /organization/native-tap           Native Tap
# 8630                 /organization/cbca                 CBCA
# 2282   /organization/alphacare-holdings   AlphaCare Holdings
# 16515             /organization/pintley              Pintley
#
#                                             homepage_url  \
# 16328  http://itunes.apple.com/en/app/100+-interactiv...
# 5367   https://itunes.apple.com/us/app/beme-share-vid...
# 4715   https://itunes.apple.com/us/app/b*famous/id929...
# 10902                               http://goo.gl/7vAvYj
# 9671   https://drive.google.com/file/d/0B1Nzn7sbX92fN...
# ...                                                  ...
# 13557                               http://nownative.com
# 13558                               http://nativetap.io/
# 8630                                http://www.cbca.com/
# 2282                                http://alphacare.com
# 16515                             http://www.pintley.com
#
#                                    company_category_list  funding_total_usd  \
# 16328              Education|iPad|Kids|Language Learning          1000000.0
# 5367                                               Video          2000000.0
# 4715                          Apps|Internet|Mobile Games                0.0
# 10902  Bitcoin|Classifieds|E-Commerce|Marketplaces|Mo...                0.0
# 9671                                             missing            50000.0
# ...                                                  ...                ...
# 13557                                        Advertising                0.0
# 13558                                               Apps           100000.0
# 8630   Employer Benefits Programs|Health and Insuranc...         30000000.0
# 2282                                       Biotechnology         17415364.0
# 16515                         Craft Beer|Internet|Mobile           104999.0
#
#           status company_country_code   company_city  funding_rounds  \
# 16328  operating                  USA        missing               1
# 5367   operating                  USA       New York               1
# 4715   operating                  USA         Boston               1
# 10902  operating                  USA        Orlando               1
# 9671   operating                  USA        missing               1
# ...          ...                  ...            ...             ...
# 13557  operating                  GBR         London               1
# 13558  operating                  USA  San Francisco               1
# 8630   operating                  USA        Oakland               1
# 2282   operating                  USA       Brooklyn               2
# 16515  operating                  USA         Boston               1
#
#                          founded_at first_funding_at last_funding_at  \
# 16328 2013-01-01 00:00:00.000000000       2013-01-01      2013-01-01
# 5367  2011-11-02 20:46:43.240577680       2015-07-28      2015-07-28
# 4715  2010-09-17 20:46:43.240577680       2014-06-12      2014-06-12
# 10902 2015-01-01 00:00:00.000000000       2015-06-01      2015-06-01
# 9671  2015-07-01 00:00:00.000000000       2015-07-15      2015-07-15
# ...                             ...              ...             ...
# 13557 2011-03-10 20:46:43.240577680       2014-12-03      2014-12-03
# 13558 2011-02-06 20:46:43.240577680       2014-11-01      2014-11-01
# 8630  1998-08-07 20:46:43.240577680       2002-05-02      2002-05-02
# 2282  2012-01-01 00:00:00.000000000       2013-08-14      2014-01-14
# 16515 2006-12-28 20:46:43.240577680       2010-09-22      2010-09-22
#
#              time_before_first_fund  employee_count  number_of_technologies  \
# 16328               0 days 00:00:00          428000                      12
# 5367   1363 days 03:13:16.759422320          428000                      12
# 4715   1363 days 03:13:16.759422320          428000                      12
# 10902             151 days 00:00:00          281000                     147
# 9671               14 days 00:00:00          281000                     147
# ...                             ...             ...                     ...
# 13557  1363 days 03:13:16.759422320               0                       3
# 13558  1363 days 03:13:16.759422320               0                      33
# 8630   1363 days 03:13:16.759422320               0                       1
# 2282              591 days 00:00:00               0                       6
# 16515  1363 days 03:13:16.759422320               0                       9
#
#          annual_rev
# 16328  3.783230e+11
# 5367   3.783230e+11
# 4715   3.783230e+11
# 10902  2.580000e+08
# 9671   2.580000e+08
# ...             ...
# 13557           NaN
# 13558           NaN
# 8630   1.750000e+08
# 2282   7.000000e+06
# 16515  1.400000e+06
#
# [13120 rows x 16 columns]

# %%
closed_comps = companiesCS[companiesCS['status'] == 'closed']
closed_comps.sort_values(by=['employee_count'], ascending=False, inplace=True)
closed_comps
# Out:
#                        company_permalink         company_name  \
# 15276           /organization/omnino-llp           Omnino LLP
# 8407     /organization/carrot-rocket-ltd    Carrot Rocket Ltd
# 9447   /organization/lululemon-athletica  lululemon athletica
# 12059            /organization/mobintent            mobintent
# 15711          /organization/openreach-2            OpenReach
# ...                                  ...                  ...
# 7638            /organization/buyosphere           Buyosphere
# 7640            /organization/buyplaywin           BuyPlayWin
# 7646             /organization/buysimple            BuySimple
# 7647              /organization/buystand             BUYSTAND
# 16514              /organization/pintics              Pintics
#
#                                             homepage_url  \
# 15276        https://www.linkedin.com/company/omnino-llp
# 8407   https://www.linkedin.com/company/carrot-rocket...
# 9447                            http://www.lululemon.com
# 12059  http://www.businessinsider.com/mobintent-dies-...
# 15711                          http://www.openreach.com/
# ...                                                  ...
# 7638                               http://buyosphere.com
# 7640                               http://buyplaywin.com
# 7646                            http://www.buysimple.com
# 7647                                 http://buystand.com
# 16514                             http://www.pintics.com
#
#                                    company_category_list  funding_total_usd  \
# 15276                                            missing                0.0
# 8407                         Apps|Entertainment|Internet           450000.0
# 9447         Fitness|Health and Wellness|Online Shopping         93000000.0
# 12059                                Advertising|Finance                0.0
# 15711                                         Networking          7000000.0
# ...                                                  ...                ...
# 7638   E-Commerce|Fashion|Search|Shopping|Social Comm...           325000.0
# 7640                                 Curated Web|Finance                0.0
# 7646                                          E-Commerce           700000.0
# 7647                    Big Data|E-Commerce|Marketplaces           450000.0
# 16514                                        Curated Web            10000.0
#
#        status company_country_code company_city  funding_rounds  \
# 15276  closed                  USA      missing               1
# 8407   closed                  GBR       London               1
# 9447   closed                  CAN    Vancouver               1
# 12059  closed                  USA     New York               1
# 15711  closed                  USA       Woburn               1
# ...       ...                  ...          ...             ...
# 7638   closed                  CAN     Montréal               1
# 7640   closed                  USA      missing               1
# 7646   closed                  USA    Palo Alto               1
# 7647   closed                  USA       Durham               1
# 16514  closed                  USA     San Jose               1
#
#                          founded_at first_funding_at last_funding_at  \
# 15276 2008-01-01 00:00:00.000000000       2008-02-15      2008-02-15
# 8407  2015-03-13 00:00:00.000000000       2015-02-02      2015-02-02
# 9447  1998-01-01 00:00:00.000000000       2005-12-14      2005-12-14
# 12059 2010-08-01 00:00:00.000000000       2011-07-01      2011-07-01
# 15711 2000-05-06 20:46:43.240577680       2004-01-30      2004-01-30
# ...                             ...              ...             ...
# 7638  2010-01-01 00:00:00.000000000       2012-01-05      2012-01-05
# 7640  2004-08-06 20:46:43.240577680       2008-05-01      2008-05-01
# 7646  2011-01-01 00:00:00.000000000       2011-05-31      2011-05-31
# 7647  2011-11-01 00:00:00.000000000       2012-12-17      2012-12-17
# 16514 2012-01-10 00:00:00.000000000       2012-05-18      2012-05-18
#
#              time_before_first_fund  employee_count  number_of_technologies  \
# 15276              45 days 00:00:00           25000                      36
# 8407             -39 days +00:00:00           25000                      36
# 9447             2904 days 00:00:00           17000                      25
# 12059             334 days 00:00:00           17000                      42
# 15711  1363 days 03:13:16.759422320           14000                      14
# ...                             ...             ...                     ...
# 7638              734 days 00:00:00               0                       4
# 7640   1363 days 03:13:16.759422320               0                       3
# 7646              150 days 00:00:00               0                       6
# 7647              412 days 00:00:00               0                       3
# 16514             129 days 00:00:00               0                       1
#
#          annual_rev
# 15276  1.030000e+10
# 8407   1.030000e+10
# 9447   5.857053e+09
# 12059  1.100000e+08
# 15711  6.558020e+09
# ...             ...
# 7638   1.400000e+06
# 7640            NaN
# 7646            NaN
# 7647            NaN
# 16514           NaN
#
# [1443 rows x 16 columns]

# %%
acquired_comps = companiesCS[companiesCS['status'] == 'acquired']
acquired_comps.sort_values(by=['employee_count'], ascending=False, inplace=True)
acquired_comps
# Out:
#                           company_permalink            company_name  \
# 7466               /organization/buildforge              BuildForge
# 1245                    /organization/admob                   AdMob
# 13805        /organization/neopath-networks        NeoPath Networks
# 9706               /organization/macromedia              Macromedia
# 15088            /organization/office-depot            Office Depot
# ...                                     ...                     ...
# 8753               /organization/liquidtalk              LiquidTalk
# 8833              /organization/live-matrix             Live Matrix
# 8835           /organization/live-on-the-go          Live On The Go
# 8929              /organization/livio-radio             Livio Radio
# 16513  /organization/pintex-pharmaceuticals  Pintex Pharmaceuticals
#
#                              homepage_url  \
# 7466   http://ibm.com/awdtools/buildforge
# 1245          http://www.google.com/admob
# 13805                    http://cisco.com
# 9706                 http://www.adobe.com
# 15088              http://officedepot.com
# ...                                   ...
# 8753            http://www.liquidtalk.com
# 8833            http://www.livematrix.com
# 8835           http://www.liveonthego.com
# 8929                http://livioradio.com
# 16513          http://www.pintexpharm.com
#
#                             company_category_list  funding_total_usd  \
# 7466                                     Software          6000000.0
# 1245                           Advertising|Mobile         46800000.0
# 13805                         Enterprise Software         29000000.0
# 9706                                     Software         44000000.0
# 15088                                  E-Commerce                0.0
# ...                                           ...                ...
# 8753                          Enterprise Software          2430000.0
# 8833          Curated Web|Online Scheduling|Video                0.0
# 8835                      Curated Web|Restaurants            60000.0
# 8929   Apps|Electronics|Hardware + Software|Music          5796518.0
# 16513                             Pharmaceuticals          7250000.0
#
#          status company_country_code   company_city  funding_rounds  \
# 7466   acquired                  USA         Austin               1
# 1245   acquired                  USA  Mountain View               4
# 13805  acquired                  USA  Mountain View               3
# 9706   acquired                  USA  San Francisco               1
# 15088  acquired                  USA     Boca Raton               1
# ...         ...                  ...            ...             ...
# 8753   acquired                  USA        Chicago               1
# 8833   acquired                  USA    Los Angeles               1
# 8835   acquired                  USA        Anaheim               1
# 8929   acquired                  USA       Ferndale               4
# 16513  acquired                  USA      Watertown               1
#
#                          founded_at first_funding_at last_funding_at  \
# 7466  2001-01-01 00:00:00.000000000       2005-09-12      2005-09-12
# 1245  2006-12-01 00:00:00.000000000       2006-09-01      2009-01-29
# 13805 2002-01-01 00:00:00.000000000       2004-03-08      2006-05-22
# 9706  1992-01-01 00:00:00.000000000       1999-12-03      1999-12-03
# 15088 1986-01-01 00:00:00.000000000       1989-06-01      1989-06-01
# ...                             ...              ...             ...
# 8753  2006-01-01 00:00:00.000000000       2007-03-05      2007-03-05
# 8833  2009-01-01 00:00:00.000000000       2009-01-01      2009-01-01
# 8835  2005-09-03 20:46:43.240577680       2009-05-29      2009-05-29
# 8929  2008-01-01 00:00:00.000000000       2010-06-17      2013-07-18
# 16513 2000-05-01 00:00:00.000000000       2002-12-24      2002-12-24
#
#              time_before_first_fund  employee_count  number_of_technologies  \
# 7466             1715 days 00:00:00          528000                      47
# 1245             -91 days +00:00:00          281000                     147
# 13805             797 days 00:00:00           99000                      54
# 9706             2893 days 00:00:00           31000                      72
# 15088            1247 days 00:00:00           31000                      22
# ...                             ...             ...                     ...
# 8753              428 days 00:00:00               0                       1
# 8833                0 days 00:00:00               0                       2
# 8835   1363 days 03:13:16.759422320               0                       1
# 8929              898 days 00:00:00               0                       5
# 16513             967 days 00:00:00               0                       0
#
#          annual_rev
# 7466   5.735000e+10
# 1245   2.580000e+08
# 13805  4.920000e+10
# 9706   1.578500e+10
# 15088  8.465000e+09
# ...             ...
# 8753   2.400000e+06
# 8833   2.400000e+06
# 8835   1.750000e+07
# 8929   2.400000e+06
# 16513           NaN
#
# [1492 rows x 16 columns]

# %%
ipo_comps = companiesCS[companiesCS['status'] == 'ipo']
ipo_comps.sort_values(by=['employee_count'], ascending=False, inplace=True)
ipo_comps
# Out:
#                               company_permalink  \
# 2438                       /organization/amazon
# 591                        /organization/abbott
# 587                           /organization/abb
# 9078              /organization/lockheed-martin
# 1272                          /organization/adp
# ...                                         ...
# 2053      /organization/alexion-pharmaceuticals
# 8185          /organization/carbylan-biosurgery
# 5857                     /organization/bioheart
# 7721  /organization/c-bridge-internet-solutions
# 4510                       /organization/avista
#
#                          company_name                          homepage_url  \
# 2438                           Amazon                     http://amazon.com
# 591                       Abbott Labs                 http://www.abbott.com
# 587                               ABB                    http://www.abb.com
# 9078                  Lockheed Martin         http://www.lockheedmartin.com
# 1272  ADP (Automatic Data Processing)                    http://www.adp.com
# ...                               ...                                   ...
# 2053          Alexion Pharmaceuticals          http://www.alexionpharma.com
# 8185            Carbylan Therapeutics               http://www.carbylan.com
# 5857                         Bioheart            http://www.bioheartinc.com
# 7721      C-Bridge Internet Solutions  http://www.c-bridge.com/about_us.htm
# 4510                           Avista                 http://avistacorp.com
#
#                                   company_category_list  funding_total_usd  \
# 2438  Consumer Goods|Crowdsourcing|Delivery|E-Commer...       8.000000e+06
# 591   Biotechnology|Health and Wellness|Medical|Vent...       6.790000e+06
# 587       Automotive|Clean Technology|Energy|Technology       2.700000e+06
# 9078                                    Design|Security       2.740000e+07
# 1272           Business Services|Consulting|Outsourcing       2.000000e+06
# ...                                                 ...                ...
# 2053          Biotechnology|Health and Wellness|Medical       3.132281e+04
# 8185                                        Health Care       3.500000e+07
# 5857                                      Biotechnology       9.465200e+05
# 7721                                         Consulting       3.747923e+08
# 4510                                   Clean Technology       3.200000e+06
#
#      status company_country_code company_city  funding_rounds  \
# 2438    ipo                  USA      Seattle               1
# 591     ipo                  USA  Des Plaines               2
# 587     ipo                  CHE       Zürich               1
# 9078    ipo                  USA     Bethesda               2
# 1272    ipo                  USA     Roseland               1
# ...     ...                  ...          ...             ...
# 2053    ipo                  USA     Cheshire               1
# 8185    ipo                  USA    Palo Alto               4
# 5857    ipo                  USA      Sunrise               5
# 7721    ipo                  USA    Cambridge               3
# 4510    ipo                  USA      Spokane               1
#
#                         founded_at first_funding_at last_funding_at  \
# 2438 1994-07-05 00:00:00.000000000       1995-07-01      1995-07-01
# 591  1991-01-01 00:00:00.000000000       2009-03-16      2011-03-15
# 587  1988-01-01 00:00:00.000000000       2013-09-23      2013-09-23
# 9078 1995-03-01 00:00:00.000000000       2009-07-06      2010-11-22
# 1272 1949-01-01 00:00:00.000000000       2005-12-30      2005-12-30
# ...                            ...              ...             ...
# 2053 1992-01-01 00:00:00.000000000       2015-04-02      2015-04-02
# 8185 2005-01-01 00:00:00.000000000       2007-11-26      2015-03-06
# 5857 1999-01-01 00:00:00.000000000       2001-06-12      2013-06-05
# 7721 1996-01-01 00:00:00.000000000       1999-01-01      2000-01-01
# 4510 2010-10-13 20:46:43.240577680       2014-07-08      2014-07-08
#
#             time_before_first_fund  employee_count  number_of_technologies  \
# 2438             361 days 00:00:00         1057000                      35
# 591             6649 days 00:00:00          166000                      22
# 587             9397 days 00:00:00          125000                      55
# 9078            5241 days 00:00:00          111000                      16
# 1272           20817 days 00:00:00           91000                      34
# ...                            ...             ...                     ...
# 2053            8492 days 00:00:00               0                      15
# 8185            1059 days 00:00:00               0                      14
# 5857             893 days 00:00:00               0                      10
# 7721            1096 days 00:00:00               0                       0
# 4510  1363 days 03:13:16.759422320               0                       9
#
#         annual_rev
# 2438  4.698220e+11
# 591   4.307500e+10
# 587   2.856000e+10
# 9078  6.704400e+10
# 1272  1.569670e+10
# ...            ...
# 2053           NaN
# 8185           NaN
# 5857           NaN
# 7721  7.000000e+06
# 4510           NaN
#
# [461 rows x 16 columns]

# %%
operating_comps['employee_count'].value_counts(ascending=False)
# Out:
# 0       2752
# 2        839
# 3        632
# 1        518
# 4        448
#         ...
# 7500       1
# 7700       1
# 8000       1
# 9100       1
# 3500       1
# Name: employee_count, Length: 276, dtype: int64

# %%
closed_comps['employee_count'].value_counts(ascending=False)
# Out:
# 0      719
# 2       74
# 1       67
# 3       61
# 10      52
#       ...
# 230      1
# 240      1
# 250      1
# 380      1
# 71       1
# Name: employee_count, Length: 137, dtype: int64

# %%
acquired_comps['employee_count'].value_counts(ascending=False)
# Out:
# 0      381
# 2       78
# 10      52
# 3       45
# 1       43
#       ...
# 780      1
# 790      1
# 860      1
# 900      1
# 93       1
# Name: employee_count, Length: 182, dtype: int64

# %%
ipo_comps['employee_count'].value_counts(ascending=False)
# Out:
# 0          21
# 5          15
# 2          14
# 150         9
# 9           8
#            ..
# 3300        1
# 3200        1
# 3100        1
# 180         1
# 1057000     1
# Name: employee_count, Length: 188, dtype: int64

# %% [markdown]
# We can consider the companies with 0 employees that the founder did not employ anyone and we will see later the impact of this decision on the company.
# To see how impactful the number of employees on the success of a company, we will coorelate it with the annual revenue of the company. The annual revenue will definetly show how the company is doing.

# %%
companiesCS_ann = companiesCS.dropna(subset=['annual_rev'])
companiesCS_ann
# Out:
#                          company_permalink            company_name  \
# 0                      /organization/-fame                   #fame
# 4           /organization/004-technologies        004 Technologies
# 6      /organization/0ndine-biomedical-inc  Ondine Biomedical Inc.
# 7                     /organization/0xdata                  H2O.ai
# 8                          /organization/1                One Inc.
# ...                                    ...                     ...
# 16508              /organization/pinstripe               Pinstripe
# 16509            /organization/pint-please             Pint Please
# 16511   /organization/pintail-technologies    Pintail Technologies
# 16512              /organization/pinterest               Pinterest
# 16515                /organization/pintley                 Pintley
#
#                              homepage_url  \
# 0                      http://livfame.com
# 4       http://004gmbh.de/en/004-interact
# 6                    http://ondinebio.com
# 7                          http://h2o.ai/
# 8                      http://whatis1.com
# ...                                   ...
# 16508      http://www.pinstripetalent.com
# 16509           http://www.pintplease.com
# 16511  http://www.pintailtechnologies.com
# 16512               https://pinterest.com
# 16515              http://www.pintley.com
#
#                              company_category_list  funding_total_usd  \
# 0                                            Media       1.000000e+07
# 4                                         Software       0.000000e+00
# 6                                    Biotechnology       7.628510e+05
# 7                                        Analytics       3.360000e+07
# 8                                           Mobile       1.150050e+06
# ...                                            ...                ...
# 16508                                   Consulting       3.000000e+06
# 16509                Android|Craft Beer|iOS|Mobile       4.546730e+05
# 16511                                     Software       1.000000e+07
# 16512  Curated Web|Social Bookmarking|Social Media       1.315500e+09
# 16515                   Craft Beer|Internet|Mobile       1.049990e+05
#
#           status company_country_code   company_city  funding_rounds  \
# 0      operating                  IND         Mumbai               1
# 4      operating                  USA      Champaign               1
# 6      operating                  CAN      Vancouver               2
# 7      operating                  USA  Mountain View               4
# 8      operating                  USA  San Francisco               3
# ...          ...                  ...            ...             ...
# 16508  operating                  USA     Brookfield               2
# 16509  operating                  FIN           Oulu               1
# 16511  operating                  USA     Richardson               2
# 16512  operating                  USA  San Francisco              10
# 16515  operating                  USA         Boston               1
#
#                          founded_at first_funding_at last_funding_at  \
# 0     2011-04-12 20:46:43.240577680       2015-01-05      2015-01-05
# 4     2010-01-01 00:00:00.000000000       2014-07-24      2014-07-24
# 6     1997-01-01 00:00:00.000000000       2009-09-11      2009-12-21
# 7     2011-01-01 00:00:00.000000000       2013-01-03      2015-11-09
# 8     2011-08-01 00:00:00.000000000       2011-07-20      2014-02-05
# ...                             ...              ...             ...
# 16508 2002-03-21 20:46:43.240577680       2005-12-14      2012-08-02
# 16509 2014-01-10 00:00:00.000000000       2014-08-13      2014-08-13
# 16511 2000-01-01 00:00:00.000000000       2005-03-08      2006-09-29
# 16512 2009-01-01 00:00:00.000000000       2010-01-01      2015-06-01
# 16515 2006-12-28 20:46:43.240577680       2010-09-22      2010-09-22
#
#              time_before_first_fund  employee_count  number_of_technologies  \
# 0      1363 days 03:13:16.759422320              57                       1
# 4                1665 days 00:00:00              67                      10
# 6                4636 days 00:00:00              30                       6
# 7                 733 days 00:00:00             370                      32
# 8                -12 days +00:00:00               3                       3
# ...                             ...             ...                     ...
# 16508  1363 days 03:13:16.759422320              60                      17
# 16509             215 days 00:00:00              10                       8
# 16511            1893 days 00:00:00               0                       1
# 16512             365 days 00:00:00            6000                      26
# 16515  1363 days 03:13:16.759422320               0                       9
#
#          annual_rev
# 0      1.500000e+06
# 4      5.000000e+06
# 6      8.575000e+06
# 7      3.210000e+07
# 8      2.200000e+07
# ...             ...
# 16508  1.676400e+07
# 16509  2.932000e+06
# 16511  2.000000e+06
# 16512  2.436989e+09
# 16515  1.400000e+06
#
# [11530 rows x 16 columns]

# %% [markdown]
# ### Visualization & Analysis

# %% [markdown]
# Coorelating between the number of employees and the annual revenue of a company for each type of company whethere operating, closed,etc.

# %%
sns.set_theme(style="whitegrid")
sns.lineplot(data=companiesCS_ann, x="employee_count", y="annual_rev", hue="status", palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='employee_count', ylabel='annual_rev'>

# %% [markdown]
# As seen above, there's seemingly a direct proportional relation between the number of employees and the annual revenue. It supports the fact of hiring intels is for the sake of the company's success, yet  it is seen that each company with different status can be slightly different. Let's analyze at each status seperately.

# %%
sns.lineplot(data=companiesCS_ann[companiesCS_ann['status'] == 'operating'], x="employee_count", y="annual_rev", palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='employee_count', ylabel='annual_rev'>

# %% [markdown]
# From the last grap it is seen that with the increase in the number of employees, the annual revenue increases with it. Looking at the graph there is what seems like a point where if it's reached, there is a clear direct relation between both attributes, meaning that companies may suffer in acheiving high profit until a certain point. In this sample, a few companies made profit with employees less than around 2700000 but once this number of employees is reached, it is almost garenteed of high profits.

# %%
sns.lineplot(data=companiesCS_ann[companiesCS_ann['status'] == 'closed'], x="employee_count", y="annual_rev", palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='employee_count', ylabel='annual_rev'>

# %% [markdown]
# From the previous graph, a similar pattern is recognized from the previous graph. Here, the closed companies the maximum number of employees and annual revenue reached is noticebly way less than the operatiing companies which is reasonable. Having more than 5000 acheive reasonable profits.

# %%
sns.lineplot(data=companiesCS_ann[companiesCS_ann['status'] == 'ipo'], x="employee_count", y="annual_rev", palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='employee_count', ylabel='annual_rev'>

# %% [markdown]
# Regarding the ipo companies, they can have a huge number of employees since they are publically offered for stock sharing, they may have the ability to hire great amount of employees, and from the pattern seen from past graphs, hiring more employees help in increasing annual revenues. By this graph, it is clearly seen that the number of employees is directly proportional with the number of employees.

# %%
sns.lineplot(data=companiesCS_ann[companiesCS_ann['status'] == 'acquired'],x="employee_count", y="annual_rev", palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='employee_count', ylabel='annual_rev'>

# %% [markdown]
# Since those companies are aquired so having much employees should be acheivable due to the addtion of the old employees to the ones working in the aquired one. So, the increase of employees definetly helped in increasing the annual revenue of the company.

# %% [markdown]
# #### Conclusion

# %% [markdown]
# In conclusion, the number of employees can be considered directly proportional with the annual revenue although of course there are other factors that affect the revenue, but hiring intels and labor can increase productivity and its cost does’t impact the company in a negative manner.

# %% [markdown]
# ## Question 2.1: Which category acheives highest revenue? (Farah)

# %% [markdown]
# Let's take a look at which category attracts most funding

# %% [markdown]
# #### Cleaning

# %% [markdown]
# Now we will remove the missing valiues from the category list and employee count that is equal to zero bcause we will formulate a ratio and cannot be divided by 0.

# %%
rev_employee = companiesCS_ann[companiesCS_ann.employee_count != 0]
rev_employee.sort_values(by=['company_category_list', 'annual_rev'],ascending=False, inplace=True)
rev_employee = rev_employee[rev_employee.company_category_list != 'missing']
rev_employee
# Out:
#                    company_permalink     company_name  \
# 5507            /organization/betify           Betify
# 5251           /organization/befunky          BeFunky
# 8055      /organization/canwenetwork     CanWeNetwork
# 1903          /organization/aixuedai         Aixuedai
# 4165          /organization/audanika         Audanika
# ...                              ...              ...
# 3978        /organization/astroprint       AstroPrint
# 9925          /organization/makerarm         Makerarm
# 6540       /organization/blueprinter      BluePrinter
# 12983  /organization/my-mini-factory  My Mini Factory
# 462                 /organization/8i               8i
#
#                        homepage_url  \
# 5507           http://getbetify.com
# 5251         http://www.befunky.com
# 8055    http://www.canwenetwork.com
# 1903       http://www.aixuedai.com/
# 4165        http://www.audanika.com
# ...                             ...
# 3978     https://www.astroprint.com
# 9925            http://makerarm.com
# 6540          http://blueprinter.dk
# 12983  http://www.myminifactory.com
# 462                  http://8i.com/
#
#                              company_category_list  funding_total_usd  \
# 5507   iPhone|Mobile|Social Network Media|Software          250000.00
# 5251       iPhone|Mobile|Photography|Photo Sharing         1650000.00
# 8055                      iPhone|Mobile|Networking         3000000.00
# 1903       iPhone|Lifestyle|Online Shopping|Retail        40000000.00
# 4165                      iPad|iPhone|Mobile|Music               0.00
# ...                                            ...                ...
# 3978                                   3D Printing          250000.00
# 9925                                   3D Printing           85000.00
# 6540                                   3D Printing               0.00
# 12983                                  3D Printing         1200000.00
# 462                                             3D        14481680.93
#
#           status company_country_code company_city  funding_rounds  \
# 5507   operating                  GBR       London               1
# 5251   operating                  USA      missing               3
# 8055   operating                  USA       Austin               1
# 1903   operating                  GBR     Rayleigh               1
# 4165   operating                  DEU      Ilmenau               1
# ...          ...                  ...          ...             ...
# 3978   operating                  USA    San Diego               1
# 9925   operating                  USA      missing               1
# 6540   operating                  DNK   Copenhagen               2
# 12983  operating                  GBR       London               1
# 462    operating                  USA      missing               2
#
#                          founded_at first_funding_at last_funding_at  \
# 5507  2013-05-13 00:00:00.000000000       2013-12-21      2013-12-21
# 5251  2007-01-01 00:00:00.000000000       2007-01-01      2012-03-01
# 8055  2011-11-01 00:00:00.000000000       2012-03-01      2012-03-01
# 1903  2011-04-19 20:46:43.240577680       2015-01-12      2015-01-12
# 4165  2010-01-01 00:00:00.000000000       2010-01-01      2010-01-01
# ...                             ...              ...             ...
# 3978  2013-09-01 00:00:00.000000000       2014-11-01      2014-11-01
# 9925  2015-01-01 00:00:00.000000000       2015-10-05      2015-10-05
# 6540  2009-01-01 00:00:00.000000000       2013-03-01      2015-05-26
# 12983 2013-06-18 00:00:00.000000000       2015-10-25      2015-10-25
# 462   2014-05-01 00:00:00.000000000       2014-08-07      2015-10-14
#
#              time_before_first_fund  employee_count  number_of_technologies  \
# 5507              222 days 00:00:00               6                       0
# 5251                0 days 00:00:00              21                      11
# 8055              121 days 00:00:00              50                       7
# 1903   1363 days 03:13:16.759422320             320                       0
# 4165                0 days 00:00:00               4                       2
# ...                             ...             ...                     ...
# 3978              426 days 00:00:00               5                      23
# 9925              277 days 00:00:00               5                       7
# 6540             1520 days 00:00:00               8                       8
# 12983             859 days 00:00:00              44                      21
# 462                98 days 00:00:00              42                      13
#
#        annual_rev
# 5507     117000.0
# 5251    3400000.0
# 8055    1504000.0
# 1903   65250000.0
# 4165     672000.0
# ...           ...
# 3978    5000000.0
# 9925     637000.0
# 6540     555000.0
# 12983    409000.0
# 462     1100000.0
#
# [10279 rows x 16 columns]

# %% [markdown]
# Calculating the revenue per employee is a meaningful analytical tool because it measures how efficiently a particular firm utilizes its employees. Ideally, a company wants the highest ratio of revenue per employee possible because a higher ratio indicates greater productivity.

# %%
rev_employee['rev/employee'] = rev_employee['annual_rev']/rev_employee['employee_count']
rev_employee
# Out:
#                    company_permalink     company_name  \
# 5507            /organization/betify           Betify
# 5251           /organization/befunky          BeFunky
# 8055      /organization/canwenetwork     CanWeNetwork
# 1903          /organization/aixuedai         Aixuedai
# 4165          /organization/audanika         Audanika
# ...                              ...              ...
# 3978        /organization/astroprint       AstroPrint
# 9925          /organization/makerarm         Makerarm
# 6540       /organization/blueprinter      BluePrinter
# 12983  /organization/my-mini-factory  My Mini Factory
# 462                 /organization/8i               8i
#
#                        homepage_url  \
# 5507           http://getbetify.com
# 5251         http://www.befunky.com
# 8055    http://www.canwenetwork.com
# 1903       http://www.aixuedai.com/
# 4165        http://www.audanika.com
# ...                             ...
# 3978     https://www.astroprint.com
# 9925            http://makerarm.com
# 6540          http://blueprinter.dk
# 12983  http://www.myminifactory.com
# 462                  http://8i.com/
#
#                              company_category_list  funding_total_usd  \
# 5507   iPhone|Mobile|Social Network Media|Software          250000.00
# 5251       iPhone|Mobile|Photography|Photo Sharing         1650000.00
# 8055                      iPhone|Mobile|Networking         3000000.00
# 1903       iPhone|Lifestyle|Online Shopping|Retail        40000000.00
# 4165                      iPad|iPhone|Mobile|Music               0.00
# ...                                            ...                ...
# 3978                                   3D Printing          250000.00
# 9925                                   3D Printing           85000.00
# 6540                                   3D Printing               0.00
# 12983                                  3D Printing         1200000.00
# 462                                             3D        14481680.93
#
#           status company_country_code company_city  funding_rounds  \
# 5507   operating                  GBR       London               1
# 5251   operating                  USA      missing               3
# 8055   operating                  USA       Austin               1
# 1903   operating                  GBR     Rayleigh               1
# 4165   operating                  DEU      Ilmenau               1
# ...          ...                  ...          ...             ...
# 3978   operating                  USA    San Diego               1
# 9925   operating                  USA      missing               1
# 6540   operating                  DNK   Copenhagen               2
# 12983  operating                  GBR       London               1
# 462    operating                  USA      missing               2
#
#                          founded_at first_funding_at last_funding_at  \
# 5507  2013-05-13 00:00:00.000000000       2013-12-21      2013-12-21
# 5251  2007-01-01 00:00:00.000000000       2007-01-01      2012-03-01
# 8055  2011-11-01 00:00:00.000000000       2012-03-01      2012-03-01
# 1903  2011-04-19 20:46:43.240577680       2015-01-12      2015-01-12
# 4165  2010-01-01 00:00:00.000000000       2010-01-01      2010-01-01
# ...                             ...              ...             ...
# 3978  2013-09-01 00:00:00.000000000       2014-11-01      2014-11-01
# 9925  2015-01-01 00:00:00.000000000       2015-10-05      2015-10-05
# 6540  2009-01-01 00:00:00.000000000       2013-03-01      2015-05-26
# 12983 2013-06-18 00:00:00.000000000       2015-10-25      2015-10-25
# 462   2014-05-01 00:00:00.000000000       2014-08-07      2015-10-14
#
#              time_before_first_fund  employee_count  number_of_technologies  \
# 5507              222 days 00:00:00               6                       0
# 5251                0 days 00:00:00              21                      11
# 8055              121 days 00:00:00              50                       7
# 1903   1363 days 03:13:16.759422320             320                       0
# 4165                0 days 00:00:00               4                       2
# ...                             ...             ...                     ...
# 3978              426 days 00:00:00               5                      23
# 9925              277 days 00:00:00               5                       7
# 6540             1520 days 00:00:00               8                       8
# 12983             859 days 00:00:00              44                      21
# 462                98 days 00:00:00              42                      13
#
#        annual_rev    rev/employee
# 5507     117000.0    19500.000000
# 5251    3400000.0   161904.761905
# 8055    1504000.0    30080.000000
# 1903   65250000.0   203906.250000
# 4165     672000.0   168000.000000
# ...           ...             ...
# 3978    5000000.0  1000000.000000
# 9925     637000.0   127400.000000
# 6540     555000.0    69375.000000
# 12983    409000.0     9295.454545
# 462     1100000.0    26190.476190
#
# [10279 rows x 17 columns]

# %% [markdown]
# It is seen that companies working in software and tech in general has the most annual revenues. This shows that the makrket of this kind of feild is profitable and has higher

# %%
tmpp = rev_employee[rev_employee['company_category_list'].str.contains("Software")]
tmpp
# Out:
#                         company_permalink    company_name  \
# 5507                 /organization/betify          Betify
# 5248                  /organization/beetv           BeeTV
# 2234         /organization/alluring-logic  Alluring Logic
# 119                /organization/21vianet        21viaNet
# 14264  /organization/nexaweb-technologies    Nexaweb Inc.
# ...                                   ...             ...
# 336                 /organization/4tiitoo    4tiitoo GmbH
# 1796           /organization/aio-robotics    AIO Robotics
# 9003           /organization/local-motors    Local Motors
# 9616               /organization/lyteshot        LyteShot
# 5603           /organization/biart-studio           Biart
#
#                      homepage_url  \
# 5507         http://getbetify.com
# 5248                http://bee.tv
# 2234     http://alluringlogic.com
# 119    http://www.ch.21vianet.com
# 14264      http://www.nexaweb.com
# ...                           ...
# 336        http://www.4tiitoo.com
# 1796   http://www.aiorobotics.com
# 9003       http://localmotors.com
# 9616      http://www.lyteshot.com
# 5603        http://www.biart7.com
#
#                                    company_category_list  funding_total_usd  \
# 5507         iPhone|Mobile|Social Network Media|Software           250000.0
# 5248   iPad|Reviews and Recommendations|Social Televi...          9500000.0
# 2234   iPad|Mobile|Point of Sale|Retail|SaaS|Software...                0.0
# 119                                 Software|Web Hosting        396000000.0
# 14264                           Software|Web Development         14603757.0
# ...                                                  ...                ...
# 336    3D Technology|Augmented Reality|Computers|Comp...                0.0
# 1796                     3D Printing|Hardware + Software                0.0
# 9003   3D Printing|Crowdfunding|Crowdsourcing|Educati...           250000.0
# 9616   3D Printing|Advertising|Augmented Reality|Digi...           635000.0
# 5603   3D Printing|3D Technology|Android|Games|iOS|Mo...          4750000.0
#
#           status company_country_code company_city  funding_rounds founded_at  \
# 5507   operating                  GBR       London               1 2013-05-13
# 5248      closed                  ITA        Milan               2 2007-08-01
# 2234      closed                  USA     New York               1 2009-08-22
# 119          ipo                  CHN      Beijing               5 2009-10-16
# 14264  operating                  USA   Burlington               3 2000-01-01
# ...          ...                  ...          ...             ...        ...
# 336    operating                  DEU       Munich               3 2013-12-10
# 1796   operating                  USA  Los Angeles               1 2013-05-24
# 9003   operating                  USA     Chandler               2 2007-07-01
# 9616   operating                  USA      Chicago               1 2012-12-26
# 5603   operating                  USA      Houston               2 2007-02-02
#
#       first_funding_at last_funding_at time_before_first_fund  employee_count  \
# 5507        2013-12-21      2013-12-21      222 days 00:00:00               6
# 5248        2009-06-03      2011-05-17      672 days 00:00:00               4
# 2234        2013-07-25      2013-07-25     1433 days 00:00:00             540
# 119         2008-02-13      2014-12-04    -611 days +00:00:00             630
# 14264       2003-05-19      2012-08-21     1234 days 00:00:00              15
# ...                ...             ...                    ...             ...
# 336         2011-11-15      2014-08-18    -756 days +00:00:00              12
# 1796        2015-07-01      2015-07-01      768 days 00:00:00               3
# 9003        2012-06-06      2014-07-01     1802 days 00:00:00             380
# 9616        2014-11-14      2014-11-14      688 days 00:00:00              75
# 5603        2006-01-01      2012-01-01    -397 days +00:00:00               2
#
#        number_of_technologies   annual_rev  rev/employee
# 5507                        0     117000.0  1.950000e+04
# 5248                        3    5400000.0  1.350000e+06
# 2234                        3   37426000.0  6.930741e+04
# 119                         9  797666000.0  1.266137e+06
# 14264                      10   18906000.0  1.260400e+06
# ...                       ...          ...           ...
# 336                        10     161000.0  1.341667e+04
# 1796                        5   10000000.0  3.333333e+06
# 9003                       29   32000000.0  8.421053e+04
# 9616                        3    3985000.0  5.313333e+04
# 5603                        0    5761000.0  2.880500e+06
#
# [2292 rows x 17 columns]

# %% [markdown]
# ### Question 3: Does the annual Revenue attract investors? (Farah)

# %% [markdown]
# Let's first look at the investments and see if number of investors affect those proifts or not

# %% [markdown]
# #### Merging

# %% [markdown]
# First, we merge between the two datasets

# %%
comps_invests = companiesCS_ann.join(investsC[['raised_amount_usd', 'investor_name']])
comps_invests
# Out:
#                          company_permalink            company_name  \
# 0                      /organization/-fame                   #fame
# 4           /organization/004-technologies        004 Technologies
# 6      /organization/0ndine-biomedical-inc  Ondine Biomedical Inc.
# 7                     /organization/0xdata                  H2O.ai
# 8                          /organization/1                One Inc.
# ...                                    ...                     ...
# 16508              /organization/pinstripe               Pinstripe
# 16509            /organization/pint-please             Pint Please
# 16511   /organization/pintail-technologies    Pintail Technologies
# 16512              /organization/pinterest               Pinterest
# 16515                /organization/pintley                 Pintley
#
#                              homepage_url  \
# 0                      http://livfame.com
# 4       http://004gmbh.de/en/004-interact
# 6                    http://ondinebio.com
# 7                          http://h2o.ai/
# 8                      http://whatis1.com
# ...                                   ...
# 16508      http://www.pinstripetalent.com
# 16509           http://www.pintplease.com
# 16511  http://www.pintailtechnologies.com
# 16512               https://pinterest.com
# 16515              http://www.pintley.com
#
#                              company_category_list  funding_total_usd  \
# 0                                            Media       1.000000e+07
# 4                                         Software       0.000000e+00
# 6                                    Biotechnology       7.628510e+05
# 7                                        Analytics       3.360000e+07
# 8                                           Mobile       1.150050e+06
# ...                                            ...                ...
# 16508                                   Consulting       3.000000e+06
# 16509                Android|Craft Beer|iOS|Mobile       4.546730e+05
# 16511                                     Software       1.000000e+07
# 16512  Curated Web|Social Bookmarking|Social Media       1.315500e+09
# 16515                   Craft Beer|Internet|Mobile       1.049990e+05
#
#           status company_country_code   company_city  funding_rounds  \
# 0      operating                  IND         Mumbai               1
# 4      operating                  USA      Champaign               1
# 6      operating                  CAN      Vancouver               2
# 7      operating                  USA  Mountain View               4
# 8      operating                  USA  San Francisco               3
# ...          ...                  ...            ...             ...
# 16508  operating                  USA     Brookfield               2
# 16509  operating                  FIN           Oulu               1
# 16511  operating                  USA     Richardson               2
# 16512  operating                  USA  San Francisco              10
# 16515  operating                  USA         Boston               1
#
#                          founded_at first_funding_at last_funding_at  \
# 0     2011-04-12 20:46:43.240577680       2015-01-05      2015-01-05
# 4     2010-01-01 00:00:00.000000000       2014-07-24      2014-07-24
# 6     1997-01-01 00:00:00.000000000       2009-09-11      2009-12-21
# 7     2011-01-01 00:00:00.000000000       2013-01-03      2015-11-09
# 8     2011-08-01 00:00:00.000000000       2011-07-20      2014-02-05
# ...                             ...              ...             ...
# 16508 2002-03-21 20:46:43.240577680       2005-12-14      2012-08-02
# 16509 2014-01-10 00:00:00.000000000       2014-08-13      2014-08-13
# 16511 2000-01-01 00:00:00.000000000       2005-03-08      2006-09-29
# 16512 2009-01-01 00:00:00.000000000       2010-01-01      2015-06-01
# 16515 2006-12-28 20:46:43.240577680       2010-09-22      2010-09-22
#
#              time_before_first_fund  employee_count  number_of_technologies  \
# 0      1363 days 03:13:16.759422320              57                       1
# 4                1665 days 00:00:00              67                      10
# 6                4636 days 00:00:00              30                       6
# 7                 733 days 00:00:00             370                      32
# 8                -12 days +00:00:00               3                       3
# ...                             ...             ...                     ...
# 16508  1363 days 03:13:16.759422320              60                      17
# 16509             215 days 00:00:00              10                       8
# 16511            1893 days 00:00:00               0                       1
# 16512             365 days 00:00:00            6000                      26
# 16515  1363 days 03:13:16.759422320               0                       9
#
#          annual_rev  raised_amount_usd              investor_name
# 0      1.500000e+06       2.000000e+06        DT Capital Partners
# 4      5.000000e+06       3.000000e+06     Nexus Venture Partners
# 6      8.575000e+06       1.700000e+06     Nexus Venture Partners
# 7      3.210000e+07       8.900000e+06     Nexus Venture Partners
# 8      2.200000e+07       2.000000e+07    Paxion Capital Partners
# ...             ...                ...                        ...
# 16508  1.676400e+07       1.493930e+07  Highland Capital Partners
# 16509  2.932000e+06       1.493930e+07             Revel Partners
# 16511  2.000000e+06       1.493930e+07                   SV Angel
# 16512  2.436989e+09       1.493930e+07            Ann Arbor SPARK
# 16515  1.400000e+06       1.500000e+06                   Innogest
#
# [11530 rows x 18 columns]

# %% [markdown]
# We might notice that there is a possiblity of a direct proportional relationship between the amount of money invested in a company and its annual revenue. We will test it by visualizing the relationship.

# %% [markdown]
# #### Visualization & Analysis

# %%
ax = sns.lineplot(data=comps_invests,x="annual_rev", y="raised_amount_usd", palette="tab10", linewidth=2.5)

# %% [markdown]
# The barplot disproves the hypothesis that the annual revenue may attract investors to invest more money into those companies. As seen the relationship between the annual revenue and investing amount isn't directly proportional.

# %% [markdown]
# ## Question 4 (Aisha)

# %% [markdown]
# Can the number of technologies used by companies affect the rate of its success or failure?

# %%
# Getting the Cleaned Datasets
companiesC = pd.read_csv("datasets/startupsCleaned/companiesCleaned.csv", parse_dates=['founded_at', 'first_funding_at', 'last_funding_at', 'time_before_first_fund'])
companiesCS = pd.read_csv("datasets/startupsCleaned/companiesCleanedAndScraped.csv", parse_dates=['founded_at', 'first_funding_at', 'last_funding_at', 'time_before_first_fund'])

# %% [markdown]
# Explanation and visualization:

# %% [markdown]
#  This can be seen by checking the funding each company received based on their status and technology count.First we extract these columns from the companies table.

# %%
miniTable=companiesCS.loc[:, ['status','number_of_technologies','funding_total_usd']]

# %% [markdown]
# Secondly we'll start analysing this data based on status.
#
#
# 1- Operating Companies

# %%
operating=miniTable.loc[miniTable['status']=="operating"]
operating.iloc[0:40,:]
# Out:
#        status  number_of_technologies  funding_total_usd
# 0   operating                       1         10000000.0
# 1   operating                       3           700000.0
# 2   operating                      10          3406878.0
# 3   operating                       5          2000000.0
# 4   operating                      10                0.0
# 5   operating                       6            41250.0
# 6   operating                       6           762851.0
# 7   operating                      32         33600000.0
# 8   operating                       3          1150050.0
# 9   operating                       5            40000.0
# 10  operating                      30                0.0
# 11  operating                      13          1750000.0
# 12  operating                      15          6000000.0
# 14  operating                       2          2050000.0
# 15  operating                       5          4400000.0
# 16  operating                      12            40000.0
# 18  operating                       0         43923865.0
# 19  operating                       6                0.0
# 21  operating                      18          6795451.0
# 22  operating                      30         10661772.9
# 23  operating                      15          8900000.0
# 24  operating                       1         10000000.0
# 25  operating                       2          3000000.0
# 26  operating                       3          4500000.0
# 27  operating                      23          4000000.0
# 30  operating                       3                0.0
# 32  operating                       0           100000.0
# 33  operating                       5          1600000.0
# 34  operating                      10           100000.0
# 35  operating                       3                0.0
# 36  operating                       4                0.0
# 37  operating                      27         55000000.0
# 38  operating                      26          3550000.0
# 39  operating                       9            77500.0
# 40  operating                      18          1958909.0
# 41  operating                       4                0.0
# 42  operating                       0         20000000.0
# 44  operating                       5           935000.0
# 45  operating                       0                0.0
# 46  operating                       4                0.0

# %% [markdown]
# From the table above we can notice that on the first row the funding is a large amount and the company only uses one technology.
# The second row has only 3 technologies but the difference seems quite noticeable.
# In the third row how ever,we have 10 technologies being used and a quite large amount of funding. Though not as large as in row one. We can deduce that with technologies there a need for funding technological maintainance too unlike the first row which will need much less of that and hence has all funds going to other busines needs. This can be confirmed with the graphs below.

# %%
plt.hexbin(operating.number_of_technologies,operating.funding_total_usd,gridsize = 25, cmap ='Greens')
plt.xlabel('Tech count')
plt.ylabel('Funds USD')
plt.ylim([0,1.2e8])
plt.title("Operating companies and their technologies")
# Out:
# Text(0.5, 1.0, 'Operating companies and their technologies')

# %%
plt.scatter(operating.funding_total_usd,operating.number_of_technologies,c="green", alpha=0.4, linewidth=6)
plt.title("Operating companies and their technologies")
plt.ylabel('Tech count')
plt.xlabel('Funds USD') 
plt.show()

# %% [markdown]
# As shown above, most operating companies have funds in the range approximately [0,0.5]e9 USD with technology count ranging from 0 to approximately 90. Few have technologies above 90 and funding above 1e9 USD just like we were able to deduce from the table.

# %% [markdown]
# 2- Acquired companies

# %%
acquired=miniTable.loc[miniTable['status']=="acquired"]
acquired.iloc[0:40,:]
# Out:
#        status  number_of_technologies  funding_total_usd
# 13   acquired                       4       5.000000e+06
# 17   acquired                       4       5.000000e+05
# 20   acquired                       3       2.535000e+06
# 28   acquired                      19       1.250000e+06
# 29   acquired                      21       3.500000e+07
# 51   acquired                       8       0.000000e+00
# 56   acquired                       6       0.000000e+00
# 58   acquired                       5       7.000000e+05
# 69   acquired                       2       1.400000e+07
# 80   acquired                      13       0.000000e+00
# 88   acquired                      11       1.700000e+06
# 146  acquired                      13       2.500000e+05
# 148  acquired                      36       0.000000e+00
# 162  acquired                       2       4.000000e+06
# 165  acquired                      16       8.500000e+07
# 175  acquired                       1       1.620000e+08
# 176  acquired                      13       0.000000e+00
# 195  acquired                       6       0.000000e+00
# 216  acquired                       0       7.289000e+06
# 235  acquired                       4       0.000000e+00
# 257  acquired                       5       2.249999e+06
# 263  acquired                       1       6.500000e+07
# 264  acquired                       0       1.500000e+06
# 267  acquired                       0       1.480000e+08
# 285  acquired                       9       1.500000e+07
# 287  acquired                       0       5.095890e+07
# 288  acquired                       1       2.600000e+07
# 299  acquired                       3       3.806457e+07
# 304  acquired                      16       2.258720e+06
# 317  acquired                       3       3.378975e+06
# 319  acquired                       1       9.416354e+06
# 322  acquired                       4       5.000000e+05
# 349  acquired                       6       1.290000e+07
# 376  acquired                       1       3.000000e+07
# 384  acquired                       0       0.000000e+00
# 389  acquired                       2       1.280000e+07
# 393  acquired                       6       3.987693e+06
# 395  acquired                       4       7.000000e+06
# 397  acquired                       2       1.712976e+07
# 399  acquired                      22       3.050000e+06

# %% [markdown]
# The same logic seem to hold just like the operating companies and we can conclude that companies having high technology count with not very high amounts of funding possess technologies which require high maintainance.  This can be illustrated as follows.

# %%
plt.plot( 'funding_total_usd','number_of_technologies', data=acquired,  marker='', color='purple', linewidth=2, linestyle='dashed')
plt.ylabel('Tech count')
plt.xlabel('Funds USD') 
plt.title("Acquired companies and their technologies")
# Out:
# Text(0.5, 1.0, 'Acquired companies and their technologies')

# %% [markdown]
# The deduction of the same understanding repeating itself for acquired companies has now been confirmed with the graph above. We can view that most acquired companies have [0-40] technologies and [0-0.3]e9 USD of funding most of the time. Just to make sure that this logic is indeed the right one we will repeat the process for ipo companies.

# %% [markdown]
# 3- IPO companies

# %%
ipo=miniTable.loc[miniTable['status']=="ipo"]
ipo.iloc[0:40,:]
# Out:
#      status  number_of_technologies  funding_total_usd
# 119     ipo                       9       3.960000e+08
# 120     ipo                      10       1.503475e+07
# 172     ipo                      15       9.587500e+07
# 232     ipo                      29       1.695000e+08
# 377     ipo                       7       8.767800e+08
# 383     ipo                       8       6.100000e+06
# 404     ipo                      11       1.105250e+07
# 468     ipo                      27       1.260000e+08
# 551     ipo                      24       1.180000e+08
# 552     ipo                       7       5.028600e+08
# 555     ipo                      11       5.000000e+07
# 558     ipo                       5       0.000000e+00
# 585     ipo                       6       4.009880e+05
# 587     ipo                      55       2.700000e+06
# 591     ipo                      22       6.790000e+06
# 632     ipo                      12       1.860362e+08
# 667     ipo                      13       1.400000e+06
# 674     ipo                      16       6.464015e+07
# 677     ipo                      24       1.000000e+07
# 683     ipo                      14       2.551000e+08
# 692     ipo                      16       1.263850e+08
# 713     ipo                       5       2.000000e+08
# 714     ipo                      23       6.301624e+07
# 724     ipo                      15       1.137011e+08
# 737     ipo                       5       7.750000e+05
# 773     ipo                      20       1.000000e+07
# 834     ipo                      17       9.365490e+07
# 843     ipo                       3       1.166057e+08
# 860     ipo                      15       9.110000e+07
# 869     ipo                       7       8.200000e+07
# 881     ipo                      22       7.680000e+07
# 906     ipo                       7       3.162000e+06
# 943     ipo                       6       8.000000e+07
# 1030    ipo                       6       1.030000e+07
# 1032    ipo                       4       1.000000e+07
# 1060    ipo                      28       8.200000e+07
# 1061    ipo                      11       1.637708e+07
# 1072    ipo                      11       1.075000e+08
# 1077    ipo                       6       1.240000e+07
# 1104    ipo                       3       3.604370e+07

# %%
boxplot = ipo.boxplot(column=['number_of_technologies'])

# %%
boxplot = ipo.boxplot(column=['funding_total_usd'])

# %%
plt.hexbin(ipo.number_of_technologies,ipo.funding_total_usd,gridsize = 25, cmap ='Greens')
plt.xlabel('Tech count')
plt.ylabel('Funds USD') 
plt.ylim([0,3e8])
plt.title("IPO companies and their technologies")
# Out:
# Text(0.5, 1.0, 'IPO companies and their technologies')

# %% [markdown]
# We can now conclude that;
# * Companies with high funding and little or no technology count are more focused on products and other business services.
# * Companies with high funding and high technological count imply that these technologies require high maintainance which the shareholders are willing to provide.
# *  Companies with low funding and high  technological count imply that these technologies don't require high maintainance.
#
#  We can also conclude that some companies get acquired due to low funding and high technological demands whose maintainace the shareholders are not willing to pay extra money for.

# %% [markdown]
# # Hypothsis using T Test

# %% [markdown]
# Using T test, we will test if the effect of the number of employees and the effect of the number of technologies used on the company's success are equal

# %% [markdown]
# H0: The effect of the number of employees and the effect of the number of technologies used on the company's success are equal i.e., μ1 = μ2
#
# H1: The effect of the number of employees and the effect of the number of technologies used on the company's success are not equal i.e., μ1 ≠ μ2

# %% [markdown]
# first we will take a sample of 51 rows from the dataset

# %%
import scipy
sample = companiesCS.head(51)
emp = sample['employee_count']
tech = sample['number_of_technologies']

# %% [markdown]
# Calculating the t score

# %%
t_score = scipy.stats.ttest_ind(tech, emp).statistic
t_score
# Out:
# -1.747505269912122

# %% [markdown]
# A negative t-value indicates a reversal in the directionality of the effect, which has no bearing on the significance of the difference between groups, so we take its absolute value

# %% [markdown]
# Calculating the degree of freedom

# %%
Degree_of_freedom = len(tech) + len(emp) - 2
Degree_of_freedom
# Out:
# 100

# %%
alpha = 0.05
scipy.stats.t.ppf(1-alpha, Degree_of_freedom)
# Out:
# 1.66023432606575

# %% [markdown]
# As seen above the absolute value of the t-score is > the t-value from the table so the null hypothesis is rejected

# %% [markdown]
# therefore, The effect of the number of employees and the effect of the number of technologies used on the company's success are not equal
