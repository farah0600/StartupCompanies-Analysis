# %% [markdown]
# # Notes to Improve Workflow

# %%
# Setup matplotlib to plot inline (within the notebook)
# %matplotlib inline
# Import the pyplot module of Matplotlib as plt
import matplotlib.pyplot as plt
# Import pandas under the abbreviation 'pd'
import pandas as pd
# Import NumPy under the abbreviation 'np'
import numpy as np
# Libraries to aid in web scraping
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import seaborn as sns;
#Notes for efficienccy:
#shift + tab when cursor is in arguments to bring up its documentation
#ex: pd.DataFrame(Shift+tab here)
#recall: Json == Dictionary
#to know functions of pandas:
#dir(pd)

# %% [markdown]
# # Reading The Data

# %%
# using pandas and read_csv()
acquis = pd.read_csv("datasets/startups/acquisitions.csv")
additions = pd.read_csv("datasets/startups/additions.csv")
companies = pd.read_csv("datasets/startups/companies.csv")
invests = pd.read_csv("datasets/startups/investments.csv")
rounds = pd.read_csv("datasets/startups/rounds.csv")
dfAll = [acquis, additions, companies, invests, rounds]

# %%
#shapes (rows x cols) of each dataset
for ele in dfAll:
    print(ele.shape)
# Out:
# (18969, 18)
# (2213, 4)
# (66368, 14)
# (168647, 18)
# (114949, 12)

# %% [markdown]
# # Samples of the datasets

# %%
acquis.sample(5).transpose()
# Out:
#                                                                  16724  \
# company_permalink       /organization/the-national-underwriter-company
# company_name                          The National Underwriter Company
# company_category_list                                              NaN
# company_country_code                                               USA
# company_state_code                                                  KY
# company_region                                              KY - Other
# company_city                                                  Erlanger
# acquirer_permalink                        /organization/highline-media
# acquirer_name                                           Highline Media
# acquirer_category_list                                             NaN
# acquirer_country_code                                              NaN
# acquirer_state_code                                                NaN
# acquirer_region                                                    NaN
# acquirer_city                                                      NaN
# acquired_at                                                  10/3/2003
# acquired_month                                                 2003-10
# price_amount                                                       NaN
# price_currency_code                                                USD
#
#                                                                     17726  \
# company_permalink                                   /organization/v2green
# company_name                                                      V2Green
# company_category_list                                 Hardware + Software
# company_country_code                                                  USA
# company_state_code                                                     WA
# company_region                                                    Seattle
# company_city                                                      Seattle
# acquirer_permalink                                /organization/gridpoint
# acquirer_name                                                   GridPoint
# acquirer_category_list  Clean Technology|Energy Management|Sustainability
# acquirer_country_code                                                 USA
# acquirer_state_code                                                    VA
# acquirer_region                                          Washington, D.C.
# acquirer_city                                                   Arlington
# acquired_at                                                     9/23/2008
# acquired_month                                                    2008-09
# price_amount                                                          NaN
# price_currency_code                                                   USD
#
#                                                4601   \
# company_permalink            /organization/dealerups
# company_name                               DealerUps
# company_category_list                       Software
# company_country_code                             NaN
# company_state_code                               NaN
# company_region                                   NaN
# company_city                                     NaN
# acquirer_permalink            /organization/ecarlist
# acquirer_name                               eCarList
# acquirer_category_list  Automotive|Cars|Distribution
# acquirer_country_code                            USA
# acquirer_state_code                               TX
# acquirer_region                               Dallas
# acquirer_city                                 Dallas
# acquired_at                                 1/5/2011
# acquired_month                               2011-01
# price_amount                                     NaN
# price_currency_code                              USD
#
#                                                                     1661   \
# company_permalink                           /organization/aurora-networks
# company_name                                              Aurora Networks
# company_category_list                                              Mobile
# company_country_code                                                  USA
# company_state_code                                                     CA
# company_region                                                SF Bay Area
# company_city                                                  Santa Clara
# acquirer_permalink                                     /organization/pace
# acquirer_name                                                        Pace
# acquirer_category_list  Consumer Electronics|Electronics|Hardware + So...
# acquirer_country_code                                                 DEU
# acquirer_state_code                                                     7
# acquirer_region                                               DEU - Other
# acquirer_city                                                     England
# acquired_at                                                    10/23/2013
# acquired_month                                                    2013-10
# price_amount                                                  310000000.0
# price_currency_code                                                   USD
#
#                                                               3858
# company_permalink       /organization/compression-polymers-holdings
# company_name                          Compression Polymers Holdings
# company_category_list                                           NaN
# company_country_code                                            USA
# company_state_code                                               PA
# company_region                                             Scranton
# company_city                                                 Moosic
# acquirer_permalink                      /organization/aea-investors
# acquirer_name                                         AEA Investors
# acquirer_category_list                                          NaN
# acquirer_country_code                                           USA
# acquirer_state_code                                              NY
# acquirer_region                                       New York City
# acquirer_city                                              New York
# acquired_at                                               3/18/2005
# acquired_month                                              2005-03
# price_amount                                                    NaN
# price_currency_code                                             USD

# %%
additions.sample(5).transpose()
# Out:
#                           2016     703                       1372  \
# content    Rounds: undisclosed     IPOs  Rounds: convertible_note
# month_str              2008-04  2013-04                   2012-04
# year_str                  2008     2013                      2012
# value                        3       26                         2
#
#                       2142                 2025
# content    Rounds: venture  Rounds: undisclosed
# month_str          2010-02              2009-01
# year_str              2010                 2009
# value                  550                   10

# %%
companies.sample(5).transpose()
# Out:
#                                         34508                       42615  \
# permalink               /organization/materia        /organization/paymio
# name                                  Materia                      paymio
# homepage_url       http://www.materia-inc.com           http://paymio.com
# category_list                   Manufacturing  Finance|Financial Services
# funding_total_usd                    14900000                       50000
# status                              operating                      closed
# country_code                              USA                         USA
# state_code                                 CA                          NY
# region                            Los Angeles               New York City
# city                                 Pasadena                    New York
# funding_rounds                              1                           1
# founded_at                           1/1/1998                    7/1/2009
# first_funding_at                    3/14/2014                    8/1/2009
# last_funding_at                     3/14/2014                    8/1/2009
#
#                                                           63974  \
# permalink          /organization/will-bermender-equity-partners
# name                             Will Bermender Equity Partners
# homepage_url         http://www.willbermenderequitypartners.com
# category_list                                               NaN
# funding_total_usd                                             -
# status                                                   closed
# country_code                                                USA
# state_code                                                   NY
# region                                            New York City
# city                                                   New York
# funding_rounds                                                1
# founded_at                                             1/1/2013
# first_funding_at                                       7/7/2015
# last_funding_at                                        7/7/2015
#
#                                                                7776   \
# permalink                                    /organization/bluetalon
# name                                                       BlueTalon
# homepage_url                                    http://bluetalon.com
# category_list      Big Data|Data Security|Information Security|In...
# funding_total_usd                                           11399994
# status                                                     operating
# country_code                                                     USA
# state_code                                                        CA
# region                                                   SF Bay Area
# city                                                    Redwood City
# funding_rounds                                                     3
# founded_at                                                  7/1/2013
# first_funding_at                                           2/21/2014
# last_funding_at                                            7/17/2015
#
#                                        7477
# permalink          /organization/blippy-gifs
# name                                  Blippy
# homepage_url               http://blippy.com
# category_list                    Apps|Mobile
# funding_total_usd                          -
# status                             operating
# country_code                             USA
# state_code                                CA
# region                           SF Bay Area
# city                           San Francisco
# funding_rounds                             1
# founded_at                               NaN
# first_funding_at                    3/7/2012
# last_funding_at                     3/7/2012

# %%
invests.sample(5).transpose()
# Out:
#                                                                   76486   \
# company_permalink                      /organization/kaufmann-mercantile
# company_name                                         Kaufmann Mercantile
# company_category_list        E-Commerce|Lifestyle|Online Shopping|Retail
# company_country_code                                                 USA
# company_state_code                                                    NY
# company_region                                             New York City
# company_city                                                    New York
# investor_permalink                                /person/justin-shaffer
# investor_name                                             Justin Shaffer
# investor_country_code                                                NaN
# investor_state_code                                                  NaN
# investor_region                                                      NaN
# investor_city                                                        NaN
# funding_round_permalink  /funding-round/6ce33ee6aade88b55c485d6f322a3ee4
# funding_round_type                                               venture
# funding_round_code                                                     A
# funded_at                                                     11/20/2014
# raised_amount_usd                                              3200000.0
#
#                                                                   82458   \
# company_permalink                               /organization/liv-blends
# company_name                                                   LivBlends
# company_category_list                                Health and Wellness
# company_country_code                                                 USA
# company_state_code                                                    CA
# company_region                                               SF Bay Area
# company_city                                               San Francisco
# investor_permalink                                  /person/jeff-rusinow
# investor_name                                               Jeff Rusinow
# investor_country_code                                                USA
# investor_state_code                                                  NaN
# investor_region                                                      NaN
# investor_city                                                  Milwaukee
# funding_round_permalink  /funding-round/becc766c1087d5449d549931e416f1ba
# funding_round_type                                                  seed
# funding_round_code                                                   NaN
# funded_at                                                      5/28/2014
# raised_amount_usd                                               745000.0
#
#                                                                   48341   \
# company_permalink                               /organization/epicentric
# company_name                                                  Epicentric
# company_category_list             Computers|Internet|Software Compliance
# company_country_code                                                 USA
# company_state_code                                                    CA
# company_region                                               SF Bay Area
# company_city                                               San Francisco
# investor_permalink                                 /organization/reuters
# investor_name                                                    Reuters
# investor_country_code                                                USA
# investor_state_code                                                   NY
# investor_region                                            New York City
# investor_city                                                   New York
# funding_round_permalink  /funding-round/5f0316e5d8c4df7df148903fa0152eec
# funding_round_type                                               venture
# funding_round_code                                                     B
# funded_at                                                      9/13/1999
# raised_amount_usd                                              8000000.0
#
#                                                                   102733  \
# company_permalink                                  /organization/onedrop
# company_name                                                     OneDrop
# company_category_list                                   Apps|Health Care
# company_country_code                                                 USA
# company_state_code                                                    NY
# company_region                                             New York City
# company_city                                                    New York
# investor_permalink                                /organization/boxgroup
# investor_name                                                   BoxGroup
# investor_country_code                                                USA
# investor_state_code                                                   NY
# investor_region                                            New York City
# investor_city                                                   New York
# funding_round_permalink  /funding-round/14714ac5b4e77b36b0acb6e221116ccb
# funding_round_type                                               venture
# funding_round_code                                                     A
# funded_at                                                       6/4/2015
# raised_amount_usd                                              8000000.0
#
#                                                                   112845
# company_permalink                                   /organization/polsie
# company_name                                                      Polsie
# company_category_list         E-Commerce|Mobile Commerce|Social Commerce
# company_country_code                                                 MEX
# company_state_code                                                    19
# company_region                                                 Monterrey
# company_city                                                   Monterrey
# investor_permalink                /organization/startup-studio-monterrey
# investor_name                                   Startup Studio Monterrey
# investor_country_code                                                MEX
# investor_state_code                                                   19
# investor_region                                                Monterrey
# investor_city                                                  Monterrey
# funding_round_permalink  /funding-round/ca91a4a0dc1cf7a4a18703c115158cd0
# funding_round_type                                                  seed
# funding_round_code                                                   NaN
# funded_at                                                      3/13/2015
# raised_amount_usd                                                26000.0

# %%
rounds.sample(5).transpose()
# Out:
#                                                                    95115  \
# company_permalink                               /organization/stonewedge
# company_name                                                  Stonewedge
# company_category_list                                           Software
# company_country_code                                                 USA
# company_state_code                                                    MA
# company_region                                                    Boston
# company_city                                                     Andover
# funding_round_permalink  /funding-round/7a61a6f6f68cb8cd39f108292c57aff9
# funding_round_type                                               venture
# funding_round_code                                                     C
# funded_at                                                     12/12/2011
# raised_amount_usd                                               500000.0
#
#                                                                    34886  \
# company_permalink                                  /organization/fashfix
# company_name                                                     Fashfix
# company_category_list                        E-Commerce|Fashion|Software
# company_country_code                                                 SGP
# company_state_code                                                   NaN
# company_region                                                 Singapore
# company_city                                                   Singapore
# funding_round_permalink  /funding-round/9d0e449e3a5a26afb6dede91758cbe0c
# funding_round_type                                               venture
# funding_round_code                                                     A
# funded_at                                                      2/21/2013
# raised_amount_usd                                                    NaN
#
#                                                                    13571  \
# company_permalink                        /organization/bluedata-software
# company_name                                     BlueData Software, Inc.
# company_category_list               Big Data|Big Data Analytics|Software
# company_country_code                                                 USA
# company_state_code                                                    CA
# company_region                                               SF Bay Area
# company_city                                               Mountain View
# funding_round_permalink  /funding-round/19761ae9586e3711d1aa209fe836d0d1
# funding_round_type                                               venture
# funding_round_code                                                     A
# funded_at                                                      2/14/2013
# raised_amount_usd                                              4000000.0
#
#                                                                    87367  \
# company_permalink                               /organization/sellaround
# company_name                                                  Sellaround
# company_category_list                              Social Media|Software
# company_country_code                                                 NaN
# company_state_code                                                   NaN
# company_region                                                       NaN
# company_city                                                         NaN
# funding_round_permalink  /funding-round/6377c4f6f900f9ac39334b10eeadc593
# funding_round_type                                                  seed
# funding_round_code                                                   NaN
# funded_at                                                       3/1/2011
# raised_amount_usd                                                    NaN
#
#                                                                      2695
# company_permalink                                    /organization/adstage
# company_name                                                       AdStage
# company_category_list    Advertising|Enterprises|Internet|Machine Learn...
# company_country_code                                                   USA
# company_state_code                                                      CA
# company_region                                                 SF Bay Area
# company_city                                                 San Francisco
# funding_round_permalink    /funding-round/13cb5637809ac42e48357c96082827ce
# funding_round_type                                          debt_financing
# funding_round_code                                                     NaN
# funded_at                                                         6/1/2015
# raised_amount_usd                                                1500000.0

# %% [markdown]
# # Seeing the columns in the datasets

# %%
def datasetsCols(dfList, datasetNames, pad=""):
    """
    Takes dataframes and returns a dataframe (df) with each column having a df's
    column names. The "pad" is to make sure all lists of columns have 
    the same length padded out with "pad"
    Example
    pad = "XX", datasetNames = ["cars", "planes"]
    dfList = [carsDF, planesDF]
    returned data frame:
            cars            planes
    0       numOfWheels     numOfWings
    1       manufacturer    manufacturer
    2       make            XX
    """
    cols = []
    maxArrayLen = 0
    for i, df in enumerate(dfList):
        cols.append(df.columns.tolist())
        maxArrayLen = max(maxArrayLen, len(cols[i]))
    
    dictCsvs = {}
    for i, df in enumerate(dfList):
        cols[i] += [pad] * (maxArrayLen - len(cols[i])) #padding the lists to make them have equal lengths 
        dictCsvs.update({datasetNames[i] : cols[i]})

    return pd.DataFrame(dictCsvs)

# %%
lstCsvNames = ["acquisitions", "additions", "companies", "investments", "rounds"]

dfAllCols = datasetsCols(dfAll, lstCsvNames)
dfAllCols
# Out:
#               acquisitions  additions          companies  \
# 0        company_permalink    content          permalink
# 1             company_name  month_str               name
# 2    company_category_list   year_str       homepage_url
# 3     company_country_code      value      category_list
# 4       company_state_code             funding_total_usd
# 5           company_region                        status
# 6             company_city                  country_code
# 7       acquirer_permalink                    state_code
# 8            acquirer_name                        region
# 9   acquirer_category_list                          city
# 10   acquirer_country_code                funding_rounds
# 11     acquirer_state_code                    founded_at
# 12         acquirer_region              first_funding_at
# 13           acquirer_city               last_funding_at
# 14             acquired_at
# 15          acquired_month
# 16            price_amount
# 17     price_currency_code
#
#                 investments                   rounds
# 0         company_permalink        company_permalink
# 1              company_name             company_name
# 2     company_category_list    company_category_list
# 3      company_country_code     company_country_code
# 4        company_state_code       company_state_code
# 5            company_region           company_region
# 6              company_city             company_city
# 7        investor_permalink  funding_round_permalink
# 8             investor_name       funding_round_type
# 9     investor_country_code       funding_round_code
# 10      investor_state_code                funded_at
# 11          investor_region        raised_amount_usd
# 12            investor_city
# 13  funding_round_permalink
# 14       funding_round_type
# 15       funding_round_code
# 16                funded_at
# 17        raised_amount_usd

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# First, lets change the columns in the `companies` dataset <br>
# to be the similar to all other datasets: <br>
# (we're doing this in case we merge the datasets together, we want them to have the same column names)

# %%
companies.rename(columns = {'permalink' : 'company_permalink', 
                            'name' : 'company_name',
                            'category_list' : 'company_category_list',
                            'country_code' : 'company_country_code',
                            'state_code' : 'company_state_code',
                            'region' : 'company_region',
                            'city' : 'company_city'}, inplace = True)

# %%
dfAll[2] = companies
dfAllCols = datasetsCols(dfAll, lstCsvNames)
dfAllCols
# Out:
#               acquisitions  additions              companies  \
# 0        company_permalink    content      company_permalink
# 1             company_name  month_str           company_name
# 2    company_category_list   year_str           homepage_url
# 3     company_country_code      value  company_category_list
# 4       company_state_code                 funding_total_usd
# 5           company_region                            status
# 6             company_city              company_country_code
# 7       acquirer_permalink                company_state_code
# 8            acquirer_name                    company_region
# 9   acquirer_category_list                      company_city
# 10   acquirer_country_code                    funding_rounds
# 11     acquirer_state_code                        founded_at
# 12         acquirer_region                  first_funding_at
# 13           acquirer_city                   last_funding_at
# 14             acquired_at
# 15          acquired_month
# 16            price_amount
# 17     price_currency_code
#
#                 investments                   rounds
# 0         company_permalink        company_permalink
# 1              company_name             company_name
# 2     company_category_list    company_category_list
# 3      company_country_code     company_country_code
# 4        company_state_code       company_state_code
# 5            company_region           company_region
# 6              company_city             company_city
# 7        investor_permalink  funding_round_permalink
# 8             investor_name       funding_round_type
# 9     investor_country_code       funding_round_code
# 10      investor_state_code                funded_at
# 11          investor_region        raised_amount_usd
# 12            investor_city
# 13  funding_round_permalink
# 14       funding_round_type
# 15       funding_round_code
# 16                funded_at
# 17        raised_amount_usd

# %% [markdown]
# Let's start by analyzing `additions` dataset, as it has unusual format of columns

# %% [markdown]
# ## Removing "additions" Dataset

# %%
additions.sample(5)
# Out:
#                       content month_str  year_str  value
# 856   Profiles: Organizations   2008-09      2008    953
# 1322            Rounds: angel   2012-11      2012     44
# 1967             Rounds: seed   2012-02      2012    138
# 571                      IPOs   2002-04      2002     12
# 1841   Rounds: private_equity   2015-08      2015     56

# %%
additions["content"].unique()
# Out:
# array(['Acquisitions', 'IPOs', 'Profiles', 'Profiles: Organizations',
#        'Profiles: People', 'Profiles: Products', 'Rounds',
#        'Rounds: angel', 'Rounds: convertible_note',
#        'Rounds: debt_financing', 'Rounds: equity_crowdfunding',
#        'Rounds: grant', 'Rounds: non_equity_assistance',
#        'Rounds: post_ipo_debt', 'Rounds: post_ipo_equity',
#        'Rounds: private_equity', 'Rounds: product_crowdfunding',
#        'Rounds: secondary_market', 'Rounds: seed', 'Rounds: undisclosed',
#        'Rounds: venture'], dtype=object)

# %%
dfAllCols
# Out:
#               acquisitions  additions              companies  \
# 0        company_permalink    content      company_permalink
# 1             company_name  month_str           company_name
# 2    company_category_list   year_str           homepage_url
# 3     company_country_code      value  company_category_list
# 4       company_state_code                 funding_total_usd
# 5           company_region                            status
# 6             company_city              company_country_code
# 7       acquirer_permalink                company_state_code
# 8            acquirer_name                    company_region
# 9   acquirer_category_list                      company_city
# 10   acquirer_country_code                    funding_rounds
# 11     acquirer_state_code                        founded_at
# 12         acquirer_region                  first_funding_at
# 13           acquirer_city                   last_funding_at
# 14             acquired_at
# 15          acquired_month
# 16            price_amount
# 17     price_currency_code
#
#                 investments                   rounds
# 0         company_permalink        company_permalink
# 1              company_name             company_name
# 2     company_category_list    company_category_list
# 3      company_country_code     company_country_code
# 4        company_state_code       company_state_code
# 5            company_region           company_region
# 6              company_city             company_city
# 7        investor_permalink  funding_round_permalink
# 8             investor_name       funding_round_type
# 9     investor_country_code       funding_round_code
# 10      investor_state_code                funded_at
# 11          investor_region        raised_amount_usd
# 12            investor_city
# 13  funding_round_permalink
# 14       funding_round_type
# 15       funding_round_code
# 16                funded_at
# 17        raised_amount_usd

# %%
additions.shape
# Out:
# (2213, 4)

# %%
companies.shape, rounds.shape
# Out:
# ((66368, 14), (114949, 12))

# %% [markdown]
# So apparently there are no columns that could be used to join with the other datasets. <br>
# Furthermore, the "value" column is too vague to be useful. <br>
# Therefore, the "additions" dataset will be discarded.

# %%
dfAll.pop(1)
lstCsvNames.pop(1)
len(dfAll), lstCsvNames
# Out:
# (4, ['acquisitions', 'companies', 'investments', 'rounds'])

# %% [markdown]
# ## `rounds` Dataset

# %%
dfAllCols.iloc[:, -2:]
# Out:
#                 investments                   rounds
# 0         company_permalink        company_permalink
# 1              company_name             company_name
# 2     company_category_list    company_category_list
# 3      company_country_code     company_country_code
# 4        company_state_code       company_state_code
# 5            company_region           company_region
# 6              company_city             company_city
# 7        investor_permalink  funding_round_permalink
# 8             investor_name       funding_round_type
# 9     investor_country_code       funding_round_code
# 10      investor_state_code                funded_at
# 11          investor_region        raised_amount_usd
# 12            investor_city
# 13  funding_round_permalink
# 14       funding_round_type
# 15       funding_round_code
# 16                funded_at
# 17        raised_amount_usd

# %%
invests.shape, rounds.shape
# Out:
# ((168634, 17), (114948, 11))

# %%
invests.head()
# Out:
#                   company_permalink        company_name company_category_list  \
# 0             /organization/0-6-com             0-6.com           Curated Web
# 1    /organization/004-technologies    004 Technologies              Software
# 2  /organization/01games-technology  01Games Technology                 Games
# 3              /organization/0xdata              H2O.ai             Analytics
# 4              /organization/0xdata              H2O.ai             Analytics
#
#   company_country_code company_state_code   company_city  \
# 0                  CHN                 22        Beijing
# 1                  USA                 IL      Champaign
# 2                  HKG            missing      Hong Kong
# 3                  USA                 CA  Mountain View
# 4                  USA                 CA  Mountain View
#
#                      investor_permalink           investor_name  \
# 0     /organization/dt-capital-partners     DT Capital Partners
# 1       /organization/venturecapital-de   VCDE Venture Partners
# 2     /organization/cyberport-hong-kong     Cyberport Hong Kong
# 3             /organization/capital-one             Capital One
# 4  /organization/nexus-venture-partners  Nexus Venture Partners
#
#   investor_country_code investor_state_code investor_city  \
# 0                   CHN                  23      Shanghai
# 1                   DEU                   5     Frankfurt
# 2                   HKG             missing     Hong Kong
# 3                   USA                  VA        Mclean
# 4                   USA                  CA    Menlo Park
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 1  /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830            venture
# 2  /funding-round/7d53696f2b4f607a2f2a8cbb83d01839        undisclosed
# 3  /funding-round/3bb2ee4a2d89251a10aaa735b1180e44            venture
# 4  /funding-round/383a9bd2c04f7038bb543ccef5ba3eae               seed
#
#   funding_round_code  funded_at  raised_amount_usd  total_raised
# 0                  A 2008-03-19       2.000000e+06  2.000000e+06
# 1                NaN 2014-07-24       1.493930e+07           NaN
# 2                NaN 2014-07-01       4.125000e+04  4.125000e+04
# 3                  B 2015-11-09       2.000000e+07  1.010714e+07
# 4                NaN 2013-05-22       3.000000e+06  1.010714e+07

# %%
rounds.head()
# Out:
#                      company_permalink            company_name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2               /organization/-qounter                :Qounter
# 3  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 4                /organization/0-6-com                 0-6.com
#
#                                company_category_list company_country_code  \
# 0                                              Media                  IND
# 1  Application Platforms|Real Time|Social Network...                  USA
# 2  Application Platforms|Real Time|Social Network...                  USA
# 3                                  Apps|Games|Mobile              missing
# 4                                        Curated Web                  CHN
#
#   company_state_code   company_city  \
# 0                 16         Mumbai
# 1                 DE  Delaware City
# 2                 DE  Delaware City
# 3                NaN            NaN
# 4                 22        Beijing
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code  funded_at  raised_amount_usd
# 0                  B 2015-01-05         10000000.0
# 1                  A 2014-10-14                0.0
# 2                NaN 2014-03-01           700000.0
# 3                  B 2014-01-30          3406878.0
# 4                  A 2008-03-19          2000000.0

# %%
len(invests["company_name"].unique()), len(rounds["company_name"].unique())
# Out:
# (44577, 66102)

# %% [markdown]
# Since there are companies in `rounds` dataset that are not in `investments` dataset, <br>
# therefore we should keep `rounds` dataset for further analysis.

# %% [markdown]
# # Data Cleaning (Cont.)

# %% [markdown]
# ## Checking All Missing Values

# %%
def datasetsNulls(dfList, datasetNames, nullCol="nulls_", pad=""):
    """
    Use this when you want to display a column of column names,
    then a column of the null values, and repeat that for each dataset.
    Returns a dataframe
    """
    cols = []
    nulls = []
    maxArrayLen = 0
    for i, df in enumerate(dfList):
        cols.append(df.columns.tolist())
        nulls.append(df.isnull().sum().tolist())
        maxArrayLen = max(maxArrayLen, len(cols[i]))
    
    dictCsvs = {}
    for i, df in enumerate(dfList):
        cols[i] += [pad] * (maxArrayLen - len(cols[i])) #padding the lists to make them have equal lengths 
        nulls[i] += [None] *  (maxArrayLen - len(nulls[i]))
        dictCsvs[datasetNames[i]] = cols[i]
        dictCsvs[nullCol + str(i+1)] = nulls[i]
    
    return pd.DataFrame(dictCsvs)

# %%
dfAllNulls = datasetsNulls(dfAll, lstCsvNames)
dfAllNulls
# Out:
#               acquisitions  nulls_1              companies  nulls_2  \
# 0        company_permalink        0      company_permalink      0.0
# 1             company_name        1           company_name      1.0
# 2    company_category_list     4984           homepage_url   5058.0
# 3     company_country_code     4669  company_category_list   3148.0
# 4       company_state_code     4949      funding_total_usd      0.0
# 5           company_region     4911                 status      0.0
# 6             company_city     4911   company_country_code   6958.0
# 7       acquirer_permalink        1     company_state_code   8547.0
# 8            acquirer_name        1         company_region   8030.0
# 9   acquirer_category_list     2389           company_city   8028.0
# 10   acquirer_country_code     1171         funding_rounds      0.0
# 11     acquirer_state_code     1436             founded_at  15221.0
# 12         acquirer_region     1360       first_funding_at     24.0
# 13           acquirer_city     1360        last_funding_at      0.0
# 14             acquired_at       13                             NaN
# 15          acquired_month       15                             NaN
# 16            price_amount    13957                             NaN
# 17     price_currency_code        7                             NaN
#
#                 investments  nulls_3                   rounds  nulls_4
# 0         company_permalink        0        company_permalink      0.0
# 1              company_name        1             company_name      1.0
# 2     company_category_list     3632    company_category_list   3410.0
# 3      company_country_code    10521     company_country_code   8678.0
# 4        company_state_code    13431       company_state_code  10946.0
# 5            company_region    12485           company_region  10167.0
# 6              company_city    12483             company_city  10164.0
# 7        investor_permalink       12  funding_round_permalink      0.0
# 8             investor_name       12       funding_round_type      0.0
# 9     investor_country_code    30939       funding_round_code  83809.0
# 10      investor_state_code    44739                funded_at      0.0
# 11          investor_region    43217        raised_amount_usd  19990.0
# 12            investor_city    32164                               NaN
# 13  funding_round_permalink        0                               NaN
# 14       funding_round_type        0                               NaN
# 15       funding_round_code    87585                               NaN
# 16                funded_at        0                               NaN
# 17        raised_amount_usd    21619                               NaN

# %% [markdown]
# ### `dropna()` for columns with few missing values

# %% [markdown]
# Notice that there is one row that doesn't contain a company name, <br>
# so let's validate that it is the same company across all datasets, <br>
# so we can remove it:

# %%
datasetsCols(dfAll, lstCsvNames)
# Out:
#               acquisitions              companies              investments  \
# 0        company_permalink      company_permalink        company_permalink
# 1             company_name           company_name             company_name
# 2    company_category_list           homepage_url    company_category_list
# 3     company_country_code  company_category_list     company_country_code
# 4       company_state_code      funding_total_usd       company_state_code
# 5           company_region                 status           company_region
# 6             company_city   company_country_code             company_city
# 7       acquirer_permalink     company_state_code       investor_permalink
# 8            acquirer_name         company_region            investor_name
# 9   acquirer_category_list           company_city    investor_country_code
# 10   acquirer_country_code         funding_rounds      investor_state_code
# 11     acquirer_state_code             founded_at          investor_region
# 12         acquirer_region       first_funding_at            investor_city
# 13           acquirer_city        last_funding_at  funding_round_permalink
# 14             acquired_at                              funding_round_type
# 15          acquired_month                              funding_round_code
# 16            price_amount                                       funded_at
# 17     price_currency_code                               raised_amount_usd
#
#                      rounds
# 0         company_permalink
# 1              company_name
# 2     company_category_list
# 3      company_country_code
# 4        company_state_code
# 5            company_region
# 6              company_city
# 7   funding_round_permalink
# 8        funding_round_type
# 9        funding_round_code
# 10                funded_at
# 11        raised_amount_usd
# 12
# 13
# 14
# 15
# 16
# 17

# %%
#company_permalink of each row that doesn't have a company name:
for df in dfAll:
    print(df[df['company_name'].isnull()]['company_permalink'].values)
# Out:
# ['mendatio"']
# ['/organization/tell-it-in']
# ['/organization/tell-it-in']
# ['/organization/tell-it-in']

# %% [markdown]
# So apparently, the `acquisitions` dataset has a different permalink that has no company name, <br>
# So we could remove these two companies, as the total number of companies are big enough to get the insight that we want.

# %% [markdown]
# `dfAllNulls` dataframe also shows that there are missing values for `acquirer_name` and `investor_name` <br>
# which can't be imputed, so we'll also remove them.

# %% [markdown]
# Finally, we'll remove the missing values for columns that have less than 100 `NaN`, <br>
# as they're small in comparison to their respective datasets:

# %%
# This syntax won't work, as it turns out, df[0] is a copy of a dataframe (eg: a copy of acquisitions, so they don't share the same reference)
#for df in dfAll:
#    nulls = df.isnull().sum()
#    cols = nulls[(nulls <= 100) & (nulls != 0)].index.tolist()
#    df.dropna(subset=cols, inplace=True)
#dfAllNulls = datasetsNulls(dfAll, lstCsvNames)
#dfAllNulls
# Out:
#               acquisitions  nulls_1              companies  nulls_2  \
# 0        company_permalink        0      company_permalink      0.0
# 1             company_name        0           company_name      0.0
# 2    company_category_list     4977           homepage_url   5058.0
# 3     company_country_code     4661  company_category_list   3147.0
# 4       company_state_code     4940      funding_total_usd      0.0
# 5           company_region     4902                 status      0.0
# 6             company_city     4902   company_country_code   6956.0
# 7       acquirer_permalink        0     company_state_code   8545.0
# 8            acquirer_name        0         company_region   8028.0
# 9   acquirer_category_list     2387           company_city   8026.0
# 10   acquirer_country_code     1168         funding_rounds      0.0
# 11     acquirer_state_code     1432             founded_at  15218.0
# 12         acquirer_region     1356       first_funding_at      0.0
# 13           acquirer_city     1356        last_funding_at      0.0
# 14             acquired_at        0                             NaN
# 15          acquired_month        0                             NaN
# 16            price_amount    13941                             NaN
# 17     price_currency_code        0                             NaN
#
#                 investments  nulls_3                   rounds  nulls_4
# 0         company_permalink        0        company_permalink      0.0
# 1              company_name        0             company_name      0.0
# 2     company_category_list     3632    company_category_list   3410.0
# 3      company_country_code    10521     company_country_code   8678.0
# 4        company_state_code    13431       company_state_code  10946.0
# 5            company_region    12485           company_region  10167.0
# 6              company_city    12483             company_city  10164.0
# 7        investor_permalink        0  funding_round_permalink      0.0
# 8             investor_name        0       funding_round_type      0.0
# 9     investor_country_code    30927       funding_round_code  83808.0
# 10      investor_state_code    44727                funded_at      0.0
# 11          investor_region    43205        raised_amount_usd  19990.0
# 12            investor_city    32152                               NaN
# 13  funding_round_permalink        0                               NaN
# 14       funding_round_type        0                               NaN
# 15       funding_round_code    87576                               NaN
# 16                funded_at        0                               NaN
# 17        raised_amount_usd    21619                               NaN

# %%
nulls = acquis.isnull().sum()
cols = nulls[(nulls <= 100) & (nulls != 0)].index.tolist()
acquis.dropna(subset=cols, inplace=True)

nulls = companies.isnull().sum()
cols = nulls[(nulls <= 100) & (nulls != 0)].index.tolist()
companies.dropna(subset=cols, inplace=True)

nulls = invests.isnull().sum()
cols = nulls[(nulls <= 100) & (nulls != 0)].index.tolist()
invests.dropna(subset=cols, inplace=True)

nulls = rounds.isnull().sum()
cols = nulls[(nulls <= 100) & (nulls != 0)].index.tolist()
rounds.dropna(subset=cols, inplace=True)

# %%
dfAll = [acquis, companies, invests, rounds]
lstCsvNames = ["acquisitions", "companies", "investments", "rounds"]
dfAllNulls = datasetsNulls(dfAll, lstCsvNames)
dfAllNulls
# Out:
#               acquisitions  nulls_1               companies  nulls_2  \
# 0        company_permalink      0.0       company_permalink      0.0
# 1             company_name      0.0            company_name      0.0
# 2    company_category_list      0.0            homepage_url   5055.0
# 3     company_country_code      0.0   company_category_list      0.0
# 4       company_state_code      0.0       funding_total_usd      0.0
# 5             company_city      0.0                  status      0.0
# 6       acquirer_permalink      0.0    company_country_code      0.0
# 7            acquirer_name      0.0            company_city      0.0
# 8   acquirer_category_list      0.0          funding_rounds      0.0
# 9    acquirer_country_code      0.0              founded_at      0.0
# 10     acquirer_state_code      0.0        first_funding_at      0.0
# 11           acquirer_city      0.0         last_funding_at      0.0
# 12             acquired_at      0.0  time_before_first_fund      0.0
# 13          acquired_month      0.0                              NaN
# 14            price_amount  13941.0                              NaN
# 15     price_currency_code      0.0                              NaN
# 16                              NaN                              NaN
#
#                 investments  nulls_3                   rounds  nulls_4
# 0         company_permalink        0        company_permalink      0.0
# 1              company_name        0             company_name      0.0
# 2     company_category_list        0    company_category_list      0.0
# 3      company_country_code        0     company_country_code      0.0
# 4        company_state_code        0       company_state_code  10946.0
# 5              company_city        0             company_city  10164.0
# 6        investor_permalink        0  funding_round_permalink      0.0
# 7             investor_name        0       funding_round_type      0.0
# 8     investor_country_code        0       funding_round_code  83808.0
# 9       investor_state_code        0                funded_at      0.0
# 10            investor_city        0        raised_amount_usd      0.0
# 11  funding_round_permalink        0                               NaN
# 12       funding_round_type        0                               NaN
# 13       funding_round_code    87576                               NaN
# 14                funded_at        0                               NaN
# 15        raised_amount_usd        0                               NaN
# 16             total_raised    14384                               NaN

# %% [markdown]
# ## Converting & Imputing Dates

# %%
#Farah: plz impute (not drop) the columns' missing values related to dates in each dataset which are:
#founded_at.. and that's it :] 
# Suggestion: convert the dates of all the columns that have date values from "object" to datetime
#       Helpful link: https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#converting-to-timestamps
# Then, make the founded_at a couple of days before first_funding_at

#Sincerely No. -Farah :)

# %% [markdown]
# We are currently interested in 'founded_at', 'first_funding_at' and 'last_funding_at' columns. Before doing operations on dates, they need to be converted first from 'Object' to 'DateTime'.

# %%
companies['founded_at'] =pd.to_datetime(companies['founded_at'], errors = 'coerce')
companies['first_funding_at'] =pd.to_datetime(companies['first_funding_at'], errors = 'coerce')
companies['last_funding_at'] =pd.to_datetime(companies['last_funding_at'], errors = 'coerce')
companies.dtypes
# Out:
# company_permalink                object
# company_name                     object
# homepage_url                     object
# company_category_list            object
# funding_total_usd                object
# status                           object
# company_country_code             object
# company_state_code               object
# company_region                   object
# company_city                     object
# funding_rounds                    int64
# founded_at               datetime64[ns]
# first_funding_at         datetime64[ns]
# last_funding_at          datetime64[ns]
# dtype: object

# %% [markdown]
# After converting, we need to impute the missing values on the dates of when those companies where founded at. So, this will be done by first creating a new column that calculates how long it took to get the first funding. This will be done by subtracting the date of the founding from the date of the first funding. Note that we will find some values in negative which indicate that some companies took funding before establishing it.

# %%
companies['time_before_first_fund'] = companies['first_funding_at'] - companies['founded_at']
companies['time_before_first_fund']
# Out:
# 0             NaT
# 1       -187 days
# 2             NaT
# 3        443 days
# 4       1665 days
#            ...
# 66363         NaT
# 66364   -194 days
# 66365   1308 days
# 66366    365 days
# 66367         NaT
# Name: time_before_first_fund, Length: 66343, dtype: timedelta64[ns]

# %% [markdown]
# Now we need to calculate the mean of the time before the first funding and impute the missing values with this average. Notice that the average is 1370 days which is around 3.7 years which means there must be some outliers that messed up the average.

# %%
companies['time_before_first_fund'].mean()
# Out:
# Timedelta('1370 days 03:49:18.015610624')

# %% [markdown]
# Therefore, we will need to visualize those outliers and maybe if they are causing inaccuracy in the data, we can drop them.

# %%
plt.scatter(companies['first_funding_at'], companies['founded_at'], s = 20, alpha = 0.5)
plt.xlabel('first_funding_at')
plt.ylabel('founded_at')
# Out:
# Text(0, 0.5, 'founded_at')

# %% [markdown]
# We Noticed that there are some outliers than can be removed from the dataset so we will create a temporary dataframe that will contain the outliers so we can drop them later on. The first outliers that we want to deduct are the ones at the left of the center.

# %%
from datetime import datetime
tempdf = companies.copy()
tempdf = tempdf[(tempdf.first_funding_at <= datetime.strptime("01/01/1983", "%d/%m/%Y"))& (tempdf.founded_at <= datetime.strptime("01/01/2000", "%d/%m/%Y"))]
dropseries = tempdf.copy()
dropseries
# Out:
#                         company_permalink          company_name  \
# 744                /organization/abo-data              ABO Data
# 3728                  /organization/apple                 Apple
# 8786   /organization/buena-park-locksmith  Buena Park Locksmith
# 26908                  /organization/ikro                  Ikro
# 28378             /organization/intercomp             Intercomp
# 36251              /organization/mitrol-2                Mitrol
#
#                               homepage_url  \
# 744                      http://PLATONE.IO
# 3728                  http://www.apple.com
# 8786   http://www.BuenaParkLocksmithCA.com
# 26908              http://www.ikro.com.br/
# 28378                                  NaN
# 36251                                  NaN
#
#                                    company_category_list funding_total_usd  \
# 744                                  Enterprise Software           1000000
# 3728   Computers|Consumer Electronics|Electronics|Har...            250000
# 8786                                    Local Businesses                 -
# 26908            Automotive|Heavy Industry|Manufacturing            724000
# 28378                                                NaN            549000
# 36251                                                NaN           9000000
#
#           status company_country_code company_state_code company_region  \
# 744    operating                  USA                 TX     TX - Other
# 3728         ipo                  USA                 CA    SF Bay Area
# 8786   operating                  USA                 CA        Anaheim
# 26908     closed                  BRA                 23    BRA - Other
# 28378     closed                  NaN                NaN            NaN
# 36251     closed                  NaN                NaN            NaN
#
#       company_city  funding_rounds founded_at first_funding_at  \
# 744          Italy               1 1979-01-01       1979-01-01
# 3728     Cupertino               1 1976-04-01       1977-05-15
# 8786    Buena Park               1 1974-11-20       1973-04-15
# 26908       Canoas               1 1947-01-01       1982-06-01
# 28378          NaN               1 1968-01-01       1971-01-01
# 36251          NaN               1 1971-01-01       1980-01-01
#
#       last_funding_at time_before_first_fund
# 744        1979-01-01                 0 days
# 3728       1977-05-15               409 days
# 8786       1973-04-15              -584 days
# 26908      1982-06-01             12935 days
# 28378      1971-01-01              1096 days
# 36251      1980-01-01              3287 days

# %% [markdown]
# Plotting the outliers on a separate graph:

# %%
plt.scatter(tempdf['first_funding_at'], tempdf['founded_at'], s = 20)
plt.xlabel('first_funding_at')
plt.ylabel('founded_at')
# Out:
# Text(0, 0.5, 'founded_at')

# %% [markdown]
# Now we will determine the outliers that are the bottom of the center from the original graph.

# %%
tempdf = companies.copy()
tempdf = tempdf[(tempdf.first_funding_at < datetime.strptime("01/01/2005", "%d/%m/%Y"))& (tempdf.founded_at <= datetime.strptime("01/01/1900", "%d/%m/%Y"))]
tempdf
# Out:
#                                        company_permalink  \
# 4563   /organization/asia-pacific-marine-container-lines
# 4748                               /organization/athenix
# 8240                       /organization/boylan-bottling
# 12370                /organization/coleman-natural-foods
# 13513  /organization/counterpane-internet-security-in...
# 20690                      /organization/fkk-corporation
# 47744               /organization/remington-arms-company
# 49957               /organization/scottish-newcastle-plc
#
#                               company_name                     homepage_url  \
# 4563   Asia Pacific Marine Container Lines     http://AsiaPacificMarine.com
# 4748                               Athenix       http://www.athenixcorp.com
# 8240                       Boylan Bottling  https://www.boylanbottling.com/
# 12370                Coleman Natural Foods   http://www.colemannatural.com/
# 13513        Counterpane Internet Security       http://www.counterpane.com
# 20690                      FKK Corporation   http://www.fkk-corporation.com
# 47744               Remington Arms Company        http://www.remington.com/
# 49957             Scottish & Newcastle PLC                              NaN
#
#                                    company_category_list funding_total_usd  \
# 4563   Logistics Company|Shipping|Shipping Broker Ind...                 -
# 4748                                       Biotechnology          43500000
# 8240                                                 NaN                 -
# 12370                                        Hospitality           9000000
# 13513       Risk Management|Sales and Marketing|Security          20000000
# 20690                                Hardware + Software                 -
# 47744              Manufacturing|Outdoors|Sporting Goods          30000000
# 49957                                            Brewing           4200000
#
#           status company_country_code company_state_code company_region  \
# 4563      closed                  CAN                 BC      Vancouver
# 4748    acquired                  USA                 NC        Raleigh
# 8240      closed                  USA                 NY  New York City
# 12370  operating                  USA                 NC      Asheville
# 13513   acquired                  USA                 CA    SF Bay Area
# 20690  operating                  JPN                 22          Kyoto
# 47744  operating                  USA                 NC     Greensboro
# 49957  operating                  GBR                 U8      Edinburgh
#
#         company_city  funding_rounds founded_at first_funding_at  \
# 4563       Vancouver               1 1870-01-05       1998-09-01
# 4748         Raleigh               4 1863-01-01       2001-09-10
# 8240        New York               1 1891-01-01       2003-09-10
# 12370  Mountain Home               1 1875-01-01       2003-08-20
# 13513      Cupertino               1 1888-01-01       2003-01-14
# 20690      Kyoto-shi               1 1854-02-01       1995-01-01
# 47744        Madison               1 1816-01-01       2003-01-10
# 49957      Edinburgh               1 1749-01-01       2003-10-10
#
#       last_funding_at time_before_first_fund
# 4563       1998-09-01             46990 days
# 4748       2008-07-23             50656 days
# 8240       2003-09-10             41159 days
# 12370      2003-08-20             46982 days
# 13513      2003-01-14             42016 days
# 20690      1995-01-01             51468 days
# 47744      2003-01-10             68310 days
# 49957      2003-10-10             93053 days

# %% [markdown]
# Plotting the outliers on a separate graph:

# %%
plt.scatter(tempdf['first_funding_at'], tempdf['founded_at'], s = 20)
plt.xlabel('first_funding_at')
plt.ylabel('founded_at')
# Out:
# Text(0, 0.5, 'founded_at')

# %% [markdown]
# Now we will concatenate the newly discovered outliers to the ones from before

# %%
dropseries = pd.concat([dropseries, tempdf])
dropseries
# Out:
#                                        company_permalink  \
# 744                               /organization/abo-data
# 3728                                 /organization/apple
# 8786                  /organization/buena-park-locksmith
# 26908                                 /organization/ikro
# 28378                            /organization/intercomp
# 36251                             /organization/mitrol-2
# 4563   /organization/asia-pacific-marine-container-lines
# 4748                               /organization/athenix
# 8240                       /organization/boylan-bottling
# 12370                /organization/coleman-natural-foods
# 13513  /organization/counterpane-internet-security-in...
# 20690                      /organization/fkk-corporation
# 47744               /organization/remington-arms-company
# 49957               /organization/scottish-newcastle-plc
#
#                               company_name  \
# 744                               ABO Data
# 3728                                 Apple
# 8786                  Buena Park Locksmith
# 26908                                 Ikro
# 28378                            Intercomp
# 36251                               Mitrol
# 4563   Asia Pacific Marine Container Lines
# 4748                               Athenix
# 8240                       Boylan Bottling
# 12370                Coleman Natural Foods
# 13513        Counterpane Internet Security
# 20690                      FKK Corporation
# 47744               Remington Arms Company
# 49957             Scottish & Newcastle PLC
#
#                               homepage_url  \
# 744                      http://PLATONE.IO
# 3728                  http://www.apple.com
# 8786   http://www.BuenaParkLocksmithCA.com
# 26908              http://www.ikro.com.br/
# 28378                                  NaN
# 36251                                  NaN
# 4563          http://AsiaPacificMarine.com
# 4748            http://www.athenixcorp.com
# 8240       https://www.boylanbottling.com/
# 12370       http://www.colemannatural.com/
# 13513           http://www.counterpane.com
# 20690       http://www.fkk-corporation.com
# 47744            http://www.remington.com/
# 49957                                  NaN
#
#                                    company_category_list funding_total_usd  \
# 744                                  Enterprise Software           1000000
# 3728   Computers|Consumer Electronics|Electronics|Har...            250000
# 8786                                    Local Businesses                 -
# 26908            Automotive|Heavy Industry|Manufacturing            724000
# 28378                                                NaN            549000
# 36251                                                NaN           9000000
# 4563   Logistics Company|Shipping|Shipping Broker Ind...                 -
# 4748                                       Biotechnology          43500000
# 8240                                                 NaN                 -
# 12370                                        Hospitality           9000000
# 13513       Risk Management|Sales and Marketing|Security          20000000
# 20690                                Hardware + Software                 -
# 47744              Manufacturing|Outdoors|Sporting Goods          30000000
# 49957                                            Brewing           4200000
#
#           status company_country_code company_state_code company_region  \
# 744    operating                  USA                 TX     TX - Other
# 3728         ipo                  USA                 CA    SF Bay Area
# 8786   operating                  USA                 CA        Anaheim
# 26908     closed                  BRA                 23    BRA - Other
# 28378     closed                  NaN                NaN            NaN
# 36251     closed                  NaN                NaN            NaN
# 4563      closed                  CAN                 BC      Vancouver
# 4748    acquired                  USA                 NC        Raleigh
# 8240      closed                  USA                 NY  New York City
# 12370  operating                  USA                 NC      Asheville
# 13513   acquired                  USA                 CA    SF Bay Area
# 20690  operating                  JPN                 22          Kyoto
# 47744  operating                  USA                 NC     Greensboro
# 49957  operating                  GBR                 U8      Edinburgh
#
#         company_city  funding_rounds founded_at first_funding_at  \
# 744            Italy               1 1979-01-01       1979-01-01
# 3728       Cupertino               1 1976-04-01       1977-05-15
# 8786      Buena Park               1 1974-11-20       1973-04-15
# 26908         Canoas               1 1947-01-01       1982-06-01
# 28378            NaN               1 1968-01-01       1971-01-01
# 36251            NaN               1 1971-01-01       1980-01-01
# 4563       Vancouver               1 1870-01-05       1998-09-01
# 4748         Raleigh               4 1863-01-01       2001-09-10
# 8240        New York               1 1891-01-01       2003-09-10
# 12370  Mountain Home               1 1875-01-01       2003-08-20
# 13513      Cupertino               1 1888-01-01       2003-01-14
# 20690      Kyoto-shi               1 1854-02-01       1995-01-01
# 47744        Madison               1 1816-01-01       2003-01-10
# 49957      Edinburgh               1 1749-01-01       2003-10-10
#
#       last_funding_at time_before_first_fund
# 744        1979-01-01                 0 days
# 3728       1977-05-15               409 days
# 8786       1973-04-15              -584 days
# 26908      1982-06-01             12935 days
# 28378      1971-01-01              1096 days
# 36251      1980-01-01              3287 days
# 4563       1998-09-01             46990 days
# 4748       2008-07-23             50656 days
# 8240       2003-09-10             41159 days
# 12370      2003-08-20             46982 days
# 13513      2003-01-14             42016 days
# 20690      1995-01-01             51468 days
# 47744      2003-01-10             68310 days
# 49957      2003-10-10             93053 days

# %% [markdown]
# Finally, we will deduct the outliers that are the top right corner

# %%
tempdf = companies.copy()
tempdf = tempdf[(tempdf.first_funding_at > datetime.strptime("01/01/2010", "%d/%m/%Y"))& (tempdf.founded_at >= datetime.strptime("01/01/2030", "%d/%m/%Y"))]
tempdf
# Out:
#                 company_permalink  company_name             homepage_url  \
# 16681  /organization/dugoutfc-ltd  DugoutFC Ltd  http://www.dugoutfc.com
# 32736      /organization/livamp-2        LIVAMP    http://www.livamp.com
# 53396         /organization/soply         Soply       https://soply.com/
#
#                                 company_category_list funding_total_usd  \
# 16681                                  Fantasy Sports            100000
# 32736                       Entertainment|Music|Video            300000
# 53396  Creative Industries|Digital Media|Marketplaces            150000
#
#           status company_country_code company_state_code company_region  \
# 16681  operating                  NaN                NaN            NaN
# 32736     closed                  NaN                NaN            NaN
# 53396  operating                  GBR                 H9         London
#
#       company_city  funding_rounds founded_at first_funding_at  \
# 16681          NaN               1 2105-02-17       2015-01-01
# 32736          NaN               1 2041-09-21       2015-08-31
# 53396       London               1 2104-01-01       2013-07-01
#
#       last_funding_at time_before_first_fund
# 16681      2015-01-01            -32919 days
# 32736      2015-08-31             -9518 days
# 53396      2013-07-01            -33055 days

# %% [markdown]
# Visualizing the outliers:

# %%
plt.scatter(tempdf['first_funding_at'], tempdf['founded_at'], s = 20)
plt.xlabel('first_funding_at')
plt.ylabel('founded_at')
# Out:
# Text(0, 0.5, 'founded_at')

# %% [markdown]
# Concatinating the outliers on the rest:

# %%
dropseries = pd.concat([dropseries, tempdf])
dropseries
# Out:
#                                        company_permalink  \
# 744                               /organization/abo-data
# 3728                                 /organization/apple
# 8786                  /organization/buena-park-locksmith
# 26908                                 /organization/ikro
# 28378                            /organization/intercomp
# 36251                             /organization/mitrol-2
# 4563   /organization/asia-pacific-marine-container-lines
# 4748                               /organization/athenix
# 8240                       /organization/boylan-bottling
# 12370                /organization/coleman-natural-foods
# 13513  /organization/counterpane-internet-security-in...
# 20690                      /organization/fkk-corporation
# 47744               /organization/remington-arms-company
# 49957               /organization/scottish-newcastle-plc
# 16681                         /organization/dugoutfc-ltd
# 32736                             /organization/livamp-2
# 53396                                /organization/soply
#
#                               company_name  \
# 744                               ABO Data
# 3728                                 Apple
# 8786                  Buena Park Locksmith
# 26908                                 Ikro
# 28378                            Intercomp
# 36251                               Mitrol
# 4563   Asia Pacific Marine Container Lines
# 4748                               Athenix
# 8240                       Boylan Bottling
# 12370                Coleman Natural Foods
# 13513        Counterpane Internet Security
# 20690                      FKK Corporation
# 47744               Remington Arms Company
# 49957             Scottish & Newcastle PLC
# 16681                         DugoutFC Ltd
# 32736                               LIVAMP
# 53396                                Soply
#
#                               homepage_url  \
# 744                      http://PLATONE.IO
# 3728                  http://www.apple.com
# 8786   http://www.BuenaParkLocksmithCA.com
# 26908              http://www.ikro.com.br/
# 28378                                  NaN
# 36251                                  NaN
# 4563          http://AsiaPacificMarine.com
# 4748            http://www.athenixcorp.com
# 8240       https://www.boylanbottling.com/
# 12370       http://www.colemannatural.com/
# 13513           http://www.counterpane.com
# 20690       http://www.fkk-corporation.com
# 47744            http://www.remington.com/
# 49957                                  NaN
# 16681              http://www.dugoutfc.com
# 32736                http://www.livamp.com
# 53396                   https://soply.com/
#
#                                    company_category_list funding_total_usd  \
# 744                                  Enterprise Software           1000000
# 3728   Computers|Consumer Electronics|Electronics|Har...            250000
# 8786                                    Local Businesses                 -
# 26908            Automotive|Heavy Industry|Manufacturing            724000
# 28378                                                NaN            549000
# 36251                                                NaN           9000000
# 4563   Logistics Company|Shipping|Shipping Broker Ind...                 -
# 4748                                       Biotechnology          43500000
# 8240                                                 NaN                 -
# 12370                                        Hospitality           9000000
# 13513       Risk Management|Sales and Marketing|Security          20000000
# 20690                                Hardware + Software                 -
# 47744              Manufacturing|Outdoors|Sporting Goods          30000000
# 49957                                            Brewing           4200000
# 16681                                     Fantasy Sports            100000
# 32736                          Entertainment|Music|Video            300000
# 53396     Creative Industries|Digital Media|Marketplaces            150000
#
#           status company_country_code company_state_code company_region  \
# 744    operating                  USA                 TX     TX - Other
# 3728         ipo                  USA                 CA    SF Bay Area
# 8786   operating                  USA                 CA        Anaheim
# 26908     closed                  BRA                 23    BRA - Other
# 28378     closed                  NaN                NaN            NaN
# 36251     closed                  NaN                NaN            NaN
# 4563      closed                  CAN                 BC      Vancouver
# 4748    acquired                  USA                 NC        Raleigh
# 8240      closed                  USA                 NY  New York City
# 12370  operating                  USA                 NC      Asheville
# 13513   acquired                  USA                 CA    SF Bay Area
# 20690  operating                  JPN                 22          Kyoto
# 47744  operating                  USA                 NC     Greensboro
# 49957  operating                  GBR                 U8      Edinburgh
# 16681  operating                  NaN                NaN            NaN
# 32736     closed                  NaN                NaN            NaN
# 53396  operating                  GBR                 H9         London
#
#         company_city  funding_rounds founded_at first_funding_at  \
# 744            Italy               1 1979-01-01       1979-01-01
# 3728       Cupertino               1 1976-04-01       1977-05-15
# 8786      Buena Park               1 1974-11-20       1973-04-15
# 26908         Canoas               1 1947-01-01       1982-06-01
# 28378            NaN               1 1968-01-01       1971-01-01
# 36251            NaN               1 1971-01-01       1980-01-01
# 4563       Vancouver               1 1870-01-05       1998-09-01
# 4748         Raleigh               4 1863-01-01       2001-09-10
# 8240        New York               1 1891-01-01       2003-09-10
# 12370  Mountain Home               1 1875-01-01       2003-08-20
# 13513      Cupertino               1 1888-01-01       2003-01-14
# 20690      Kyoto-shi               1 1854-02-01       1995-01-01
# 47744        Madison               1 1816-01-01       2003-01-10
# 49957      Edinburgh               1 1749-01-01       2003-10-10
# 16681            NaN               1 2105-02-17       2015-01-01
# 32736            NaN               1 2041-09-21       2015-08-31
# 53396         London               1 2104-01-01       2013-07-01
#
#       last_funding_at time_before_first_fund
# 744        1979-01-01                 0 days
# 3728       1977-05-15               409 days
# 8786       1973-04-15              -584 days
# 26908      1982-06-01             12935 days
# 28378      1971-01-01              1096 days
# 36251      1980-01-01              3287 days
# 4563       1998-09-01             46990 days
# 4748       2008-07-23             50656 days
# 8240       2003-09-10             41159 days
# 12370      2003-08-20             46982 days
# 13513      2003-01-14             42016 days
# 20690      1995-01-01             51468 days
# 47744      2003-01-10             68310 days
# 49957      2003-10-10             93053 days
# 16681      2015-01-01            -32919 days
# 32736      2015-08-31             -9518 days
# 53396      2013-07-01            -33055 days

# %% [markdown]
# Now, we can drop all of the outliers that have been detected.

# %%
list = dropseries.index
companies = companies.drop(list)
#companies['time_before_first_fund'].sort_values(ascending=False)

# %% [markdown]
# Plotting the graph once more after cleaning:

# %%
plt.scatter(companies['first_funding_at'], companies['founded_at'], s = 20, alpha=0.5)
plt.xlabel('first_funding_at')
plt.ylabel('founded_at')
# Out:
# Text(0, 0.5, 'founded_at')

# %% [markdown]
# Now, we can calculate the mean. Notice that there were not much of a difference but deducting the outliers helped keeping the data realistic because some dates were 2090, 2100, etc. which is unrealistic.

# %%
companies['time_before_first_fund'].mean()
# Out:
# Timedelta('1363 days 03:13:16.759422320')

# %% [markdown]
# Filling the missing values with the new mean:

# %%
companies['time_before_first_fund'].fillna(companies['time_before_first_fund'].mean(), inplace = True)
companies['time_before_first_fund']
# Out:
# 0       1363 days 03:13:16.759422320
# 1                -187 days +00:00:00
# 2       1363 days 03:13:16.759422320
# 3                  443 days 00:00:00
# 4                 1665 days 00:00:00
#                     ...
# 66363   1363 days 03:13:16.759422320
# 66364            -194 days +00:00:00
# 66365             1308 days 00:00:00
# 66366              365 days 00:00:00
# 66367   1363 days 03:13:16.759422320
# Name: time_before_first_fund, Length: 66326, dtype: timedelta64[ns]

# %% [markdown]
# After calculating the mean and filling the nulls with it, now we can impute the missing dates in the 'founded_at' column by subtracting the time before first funding from the first funding date.

# %%
companies['founded_at'].fillna(companies['first_funding_at'] - companies['time_before_first_fund'], inplace = True)
companies['founded_at']
# Out:
# 0       2011-04-12 20:46:43.240577680
# 1       2014-09-04 00:00:00.000000000
# 2       2010-05-07 20:46:43.240577680
# 3       2007-01-01 00:00:00.000000000
# 4       2010-01-01 00:00:00.000000000
#                      ...
# 66363   2008-07-07 20:46:43.240577680
# 66364   2012-05-13 00:00:00.000000000
# 66365   2011-01-01 00:00:00.000000000
# 66366   2014-01-01 00:00:00.000000000
# 66367   2010-01-06 20:46:43.240577680
# Name: founded_at, Length: 66326, dtype: datetime64[ns]

# %% [markdown]
# Converting 'aquired_at' of the acquisitons dataset from Object to date:

# %%
acquis['acquired_at'] =pd.to_datetime(acquis['acquired_at'], errors = 'coerce')
acquis.dtypes
# Out:
# company_permalink                 object
# company_name                      object
# company_category_list             object
# company_country_code              object
# company_state_code                object
# company_region                    object
# company_city                      object
# acquirer_permalink                object
# acquirer_name                     object
# acquirer_category_list            object
# acquirer_country_code             object
# acquirer_state_code               object
# acquirer_region                   object
# acquirer_city                     object
# acquired_at               datetime64[ns]
# acquired_month                    object
# price_amount                     float64
# price_currency_code               object
# dtype: object

# %% [markdown]
# Converting 'funded_at' of the investments dataset from Object to date:

# %%
invests['funded_at'] =pd.to_datetime(invests['funded_at'], errors = 'coerce')
invests.dtypes
# Out:
# company_permalink                  object
# company_name                       object
# company_category_list              object
# company_country_code               object
# company_state_code                 object
# company_region                     object
# company_city                       object
# investor_permalink                 object
# investor_name                      object
# investor_country_code              object
# investor_state_code                object
# investor_region                    object
# investor_city                      object
# funding_round_permalink            object
# funding_round_type                 object
# funding_round_code                 object
# funded_at                  datetime64[ns]
# raised_amount_usd                 float64
# dtype: object

# %% [markdown]
# Converting 'funded_at' of the rounds dataset from Object to date:

# %%
rounds['funded_at'] =pd.to_datetime(rounds['funded_at'], errors = 'coerce')
rounds.dtypes
# Out:
# company_permalink                  object
# company_name                       object
# company_category_list              object
# company_country_code               object
# company_state_code                 object
# company_region                     object
# company_city                       object
# funding_round_permalink            object
# funding_round_type                 object
# funding_round_code                 object
# funded_at                  datetime64[ns]
# raised_amount_usd                 float64
# dtype: object

# %% [markdown]
# ## Imputing Categories

# %% [markdown]
# Regarding the category list in the five datasets, since we don't have any indicator on deducing the null values in this column, we will fill the nulls with "missing". With samples, it's provided that the same rows (companies) that their category is missing in one dataset, are the same rows in the others so even merging the datasets will not be helpful.

# %%
companies['company_category_list'].fillna('missing', inplace=True)
acquis['company_category_list'].fillna('missing', inplace=True)
acquis['acquirer_category_list'].fillna('missing', inplace=True)
invests['company_category_list'].fillna('missing', inplace=True)
rounds['company_category_list'].fillna('missing', inplace=True)

# %% [markdown]
# ## Imputing Raised Amount

# %% [markdown]
# There are alot of missing data in the raised amount column in the data set. One strategy that could be taken is calculating the mean of all of the funds of this certain company and impute its nulls with the average of total fund it has recieved before. First we calculate the mean of of the total funding of each company then add it in a new row, then compare each row if the raised amount column is null, then fill it with the average of the company otherwise leave it as it is.

# %%
total = invests.groupby(['company_name'])['raised_amount_usd'].transform(np.mean)
total = pd.DataFrame(total)
invests['total_raised'] = total
invests['raised_amount_usd'] = np.where((invests['raised_amount_usd'].isnull()), invests['total_raised'], invests['raised_amount_usd'])
invests['raised_amount_usd'].fillna(invests['raised_amount_usd'].mean(), inplace = True)
invests
# Out:
#                                         company_permalink  \
# 0                                   /organization/0-6-com
# 1                          /organization/004-technologies
# 2                        /organization/01games-technology
# 3                                    /organization/0xdata
# 4                                    /organization/0xdata
# ...                                                   ...
# 168642                          /organization/zzzzapp-com
# 168643                                /organization/Áeron
# 168644                                /organization/Áeron
# 168645                              /organization/Ôasys-2
# 168646  /organization/İnovatiff-reklam-ve-tanıtım-hizm...
#
#                                       company_name  \
# 0                                          0-6.com
# 1                                 004 Technologies
# 2                               01Games Technology
# 3                                           H2O.ai
# 4                                           H2O.ai
# ...                                            ...
# 168642                       Zzzzapp Wireless ltd.
# 168643                                       ÁERON
# 168644                                       ÁERON
# 168645                                       Ôasys
# 168646  İnovatiff Reklam ve Tanıtım Hizmetleri Tic
#
#                                     company_category_list  \
# 0                                             Curated Web
# 1                                                Software
# 2                                                   Games
# 3                                               Analytics
# 4                                               Analytics
# ...                                                   ...
# 168642        Advertising|Mobile|Web Development|Wireless
# 168643                                            missing
# 168644                                            missing
# 168645  Consumer Electronics|Internet of Things|Teleco...
# 168646                 Consumer Goods|E-Commerce|Internet
#
#        company_country_code company_state_code         company_region  \
# 0                       CHN                 22                Beijing
# 1                       USA                 IL  Springfield, Illinois
# 2                       HKG                NaN              Hong Kong
# 3                       USA                 CA            SF Bay Area
# 4                       USA                 CA            SF Bay Area
# ...                     ...                ...                    ...
# 168642                  HRV                 15                  Split
# 168643                  NaN                NaN                    NaN
# 168644                  NaN                NaN                    NaN
# 168645                  USA                 CA            SF Bay Area
# 168646                  NaN                NaN                    NaN
#
#          company_city                               investor_permalink  \
# 0             Beijing                /organization/dt-capital-partners
# 1           Champaign                  /organization/venturecapital-de
# 2           Hong Kong                /organization/cyberport-hong-kong
# 3       Mountain View                        /organization/capital-one
# 4       Mountain View             /organization/nexus-venture-partners
# ...               ...                                              ...
# 168642          Split                             /organization/eleven
# 168643            NaN                    /organization/day-one-capital
# 168644            NaN  /organization/sz-chenyi-capital-fund-management
# 168645  San Francisco                    /organization/startupbootcamp
# 168646            NaN                           /person/serkan-erdoğan
#
#                             investor_name investor_country_code  \
# 0                     DT Capital Partners                   CHN
# 1                   VCDE Venture Partners                   DEU
# 2                     Cyberport Hong Kong                   HKG
# 3                             Capital One                   USA
# 4                  Nexus Venture Partners                   USA
# ...                                   ...                   ...
# 168642                             Eleven                   BGR
# 168643    Day One Capital Fund Management                   HUN
# 168644  Széchenyi Capital Fund Management                   NaN
# 168645                    Startupbootcamp                   GBR
# 168646                     Serkan Erdoğan                   NaN
#
#        investor_state_code   investor_region investor_city  \
# 0                       23          Shanghai      Shanghai
# 1                        5         Frankfurt     Frankfurt
# 2                      NaN         Hong Kong     Hong Kong
# 3                       VA  Washington, D.C.        Mclean
# 4                       CA       SF Bay Area    Menlo Park
# ...                    ...               ...           ...
# 168642                  42             Sofia         Sofia
# 168643                   5          Budapest      Budapest
# 168644                 NaN               NaN           NaN
# 168645                  H9            London        London
# 168646                 NaN               NaN           NaN
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 1       /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830            venture
# 2       /funding-round/7d53696f2b4f607a2f2a8cbb83d01839        undisclosed
# 3       /funding-round/3bb2ee4a2d89251a10aaa735b1180e44            venture
# 4       /funding-round/383a9bd2c04f7038bb543ccef5ba3eae               seed
# ...                                                 ...                ...
# 168642  /funding-round/ff1aa06ed5da186c84f101549035d4ae               seed
# 168643  /funding-round/59f4dce44723b794f21ded3daed6e4fe            venture
# 168644  /funding-round/59f4dce44723b794f21ded3daed6e4fe            venture
# 168645  /funding-round/35f09d0794651719b02bbfd859ba9ff5               seed
# 168646  /funding-round/af942869878d2cd788ef5189b435ebc4              grant
#
#        funding_round_code  funded_at  raised_amount_usd  total_raised
# 0                       A 2008-03-19       2.000000e+06  2.000000e+06
# 1                     NaN 2014-07-24       1.493930e+07           NaN
# 2                     NaN 2014-07-01       4.125000e+04  4.125000e+04
# 3                       B 2015-11-09       2.000000e+07  1.010714e+07
# 4                     NaN 2013-05-22       3.000000e+06  1.010714e+07
# ...                   ...        ...                ...           ...
# 168642                NaN 2013-05-01       3.284200e+04  3.576800e+04
# 168643                  A 2014-08-01       1.493930e+07           NaN
# 168644                  A 2014-08-01       1.493930e+07           NaN
# 168645                NaN 2015-01-01       1.819200e+04  1.819200e+04
# 168646                NaN 2013-10-01       1.485100e+04  1.485100e+04
#
# [168634 rows x 19 columns]

# %%
#farah stop point here

# %% [markdown]
# ## Cleaning & Imputing Geographical Locations

# %% [markdown]
# ### Removing `company_state_code` and `company_region`

# %% [markdown]
# We don't need `company_state_code` in our analysis, <br>
# As country code and city are sufficient to know <br>
# an approximation of the geographical location of the company. <br>
# Therefore, let's remove it:

# %%
companies[['company_country_code', 'company_state_code', 'company_city']].head(10)
# Out:
#   company_country_code company_state_code   company_city
# 0                  IND                 16         Mumbai
# 1                  USA                 DE  Delaware City
# 2                  NaN                NaN            NaN
# 3                  CHN                 22        Beijing
# 4                  USA                 IL      Champaign
# 5                  HKG                NaN      Hong Kong
# 6                  CAN                 BC      Vancouver
# 7                  USA                 CA  Mountain View
# 8                  USA                 CA  San Francisco
# 9                  CHL                 12     Las Condes

# %%
companies.drop('company_state_code', axis=1, inplace=True)

# %% [markdown]
# `company_region` is also redundent, as it is usually the same as `company_city`.<br>
# Let's validate this:

# %%
# Note: same logic applies for the permalinks
acquis.dropna(subset=['acquirer_permalink', 'acquirer_name'], inplace=True)
invests.dropna(subset=['investor_permalink', 'investor_name'], inplace=True)

# %% [markdown]
# Also, we'll remove the missing values for columns that have less than 100 `NaN`, <br>
# as they're small in comparison to their respective datasets:

# %%
companies[companies.company_region == companies.company_city][['company_region', 'company_city']]
# Out:
#       company_region company_city
# 0             Mumbai       Mumbai
# 3            Beijing      Beijing
# 5          Hong Kong    Hong Kong
# 6          Vancouver    Vancouver
# 11           Orlando      Orlando
# ...              ...          ...
# 66354           Bath         Bath
# 66360      Milwaukee    Milwaukee
# 66362         London       London
# 66363        Beijing      Beijing
# 66364          Split        Split
#
# [25356 rows x 2 columns]

# %% [markdown]
# Let's see the mean of similarity between the strings using builtin library `difflib.SequenceMatcher`:

# %%
from difflib import SequenceMatcher
similarities = []
rgs = companies.company_region.values.tolist()
cts = companies.company_city.values.tolist()
for i in range(min(len(rgs), len(cts))):
    if not (rgs[i] != rgs[i] or cts[i] != cts[i]): # If either of the elements is NaN, then don't find the similarity
        similarities.append(SequenceMatcher(None, rgs[i], cts[i]).ratio()) # Gets the similarity between each two strings
avgSim = sum(similarities) / len(similarities)
avgSim
# Out:
# 0.6175397944380312

# %% [markdown]
# However, `SequenceMatcher` only finds the longest contiguous matching subsequence, <br>
# and all other characters will drastically decrease the similarity, which isn't very accurate, <br>
# Therefore, let's try to see how many times a string is a substring of another:

# %%
subsCount = 0
for i in range(min(len(rgs), len(cts))):
    if not (rgs[i] != rgs[i] or cts[i] != cts[i]):
        subsCount += (rgs[i] in cts[i] or cts[i] in rgs[i])
subsCount
# Out:
# 29878

# %% [markdown]
# So to summarize: almost half of the companies have the same data for `region` and `city` (25360) <br>
# There are around 5000 companies that have the same semantic meaning between the data <br>
# (e.g: 'New York City' is the same as 'NYC, New York City') <br>
# Therefore, `company_region` can be removed without losing any possible future insights:

# %%
companies.drop('company_region', axis=1, inplace=True)

acquis.drop('company_region', axis=1, inplace=True)
acquis.drop('acquirer_region', axis=1, inplace=True)

invests.drop('company_region', axis=1, inplace=True)
invests.drop('investor_region', axis=1, inplace=True)

rounds.drop('company_region', axis=1, inplace=True)

# %% [markdown]
# ### Imputing `company_country_code` and `company_city`

# %% [markdown]
# #### Failed attempt using `company_permalink`:
# 1. check the company's permalink
# 2. find HTML that contains the headquarters location (country and city)
# 3. scrape country and convert it to country code using `pycountry.countries`
# 4. scrape city and impute it in `company_city`

# %% [markdown]
# Step 1: appending "https://www.crunchbase.com" to each permalink <br>
# to be able to access the company's webpage on crunchbase. <br>
# However, since the new permalink will be much longer (thus slower for accessing as a dataset's primary index) <br>
# we'll create a function that appends the string as a prefix and that will be accessed throughout the notebook

# %% [markdown]
# Step 2: Finding location of country and city on the webpage:
# let's check company [004](https://www.crunchbase.com/organization/004)'s webpage for example: <Br>
# <img src="Phase 1/countryAndCityInCrunchbase.png" width=400 height=300 />

# %% [markdown]
# By inspecting the HTML, we notice 4 instances of the class <br>
# `component--field-formatter field-type-identifier-multi` (in a `span` element),<br>and the data that we want
# is always the first instance: <br>
# <img src="Phase 1/countryAndCityLocationInHTML.png" width=700 height=500 />

# %% [markdown]
# Step 3: scrape that info using `requests` and `bs4` libraries: <br>
# (Note, we're using `threading.Thread` here to increase performance by scraping in multithreads)

# %% [markdown]
# However, this is a deadend, as crunchbase is powered by [distill network](https://www.google.com/search?q=distil+network&sxsrf=APq-WBt2mubTHz1xGfmKgpzlWtHah5qAaA%3A1648578960023&ei=kFFDYsx646qVB_nKh7gK&ved=0ahUKEwjMgq-a--v2AhVjVeUKHXnlAacQ4dUDCA4&uact=5&oq=distil+network&gs_lcp=Cgdnd3Mtd2l6EAMyBggAEAcQHjIGCAAQBxAeMgYIABAHEB4yBggAEAcQHjIGCAAQBxAeMgYIABAHEB4yBggAEAcQHjIGCAAQBxAeMgYIABAHEB4yBggAEAcQHjoHCCMQsAMQJzoHCAAQRxCwA0oECEEYAEoECEYYAFCyCliyCmCLD2gBcAF4AIABowGIAaMBkgEDMC4xmAEAoAEByAEKwAEB&sclient=gws-wiz#:~:text=distil%20networks%20uses%20machine%20learning%20to%20identify%20and%20mitigate%20potential%20bad%20bots%2C%20fingerprinting%20them%20so%20that%20they%20can%20still%20be%20tracked%20if%20they%20reconnect%20from%20a%20different%20ip%20address) <br>
# So when we tried to scrap from it, the following html was always displayed: <br><br>
# <img src="Phase 1/crunchbaseAccessDenied.png">

# %% [markdown]
# #### Failed attempt using [linkedin](https://www.linkedin.com/in/ashrafharess/)

# %% [markdown]
# It failed because after a while, linkedin detects that you are a bot: <br><br>
# <img src='Phase 1/linkedinSecurityCheck.png' width=500 height=300>

# %% [markdown]
# However, the steps are displayed below to show how this was initially done using multithreads:

# %% [markdown]
# Step 1: Login into linkedin using `selenium.webdriver`:

# %%
from selenium import webdriver
import time
import warnings
warnings.filterwarnings('ignore') # to suppress warnings about internal code deprecations
options=webdriver.ChromeOptions()
options.add_argument('--incognito')
options.add_argument('--headless')
driver=webdriver.Chrome(options=options)
driver.get('https://www.linkedin.com/uas/login')

username = driver.find_element_by_id('username')
username.send_keys('xxfarah600xx@gmail.com')
password = driver.find_element_by_id('password')
password.send_keys('#0LinkedIn0#')
log_in_button = driver.find_element_by_class_name('from__button--floating')
log_in_button.click()

# %% [markdown]
# Step 2: Visualize the html of the data you need to scrape: <br><br>
# <img src='Phase 1/linkedinAboutLocations.png' width=800 height=500>

# %%
driver.get('https://www.linkedin.com/company/absolvent/about/')
time.sleep(3) # sleeping to render javascript code before parsing to BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
locCard = soup.find('div', 'org-location-card pv2')
locCard.text
# Out:
# '\n\n      Primary\n    \n \n     Warsaw,   PL\n  \n\n\n        Get directions\n      \n\n        Get directions to  Warsaw,   PL\n      \n\n\n\n\n'

# %%
import re
re.findall(r'Primary[\n\s]+(\w+)', locCard.text)
# Out:
# ['Warsaw']

# %% [markdown]
# Step 3: Visualize another part of the html in case step 3 doesn't work: <br><br>
# <img src='Phase 1/linkedinAboutHeadquarters.png' width=700 height=500>

# %%
driver.get('https://www.linkedin.com/company/association-for-computing-machinery/about/')
time.sleep(3) # sleeping to render javascript code before parsing to BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
dl = soup.find('div', 'mb6').find('dl')
dl
# Out:
# <dl class="overflow-hidden">
# <dt class="mb1 text-heading-small">
#           Website
#         </dt>
# <dd class="mb4 text-body-small t-black--light">
# <a class="link-without-visited-state ember-view" href="https://www.acm.org/" id="ember65" rel="noopener noreferrer" tabindex="0" target="_blank">
# <span class="link-without-visited-state" dir="ltr">
#               https://www.acm.org/
#             </span>
# </a>
# </dd>
# <dt class="mb1 text-heading-small">
#           Phone
#         </dt>
# <dd class="mb4 text-body-small t-black--light">
# <a class="link-without-visited-state ember-view" href="tel:+1 (212) 626-0500" id="ember66" rel="noopener noreferrer" tabindex="0" target="_blank">
# <span aria-hidden="true" class="link-without-visited-state" dir="ltr">
#               +1 (212) 626-0500
#             </span>
# <span class="visually-hidden">
#               Phone number is +1 (212) 626-0500
#             </span>
# </a>
# </dd>
# <dt class="mb1 text-heading-small">
#             Industry
#           </dt>
# <dd class="mb4 text-body-small t-black--light">
#             Book and Periodical Publishing
#           </dd>
# <dt class="mb1 text-heading-small">
#           Company size
#         </dt>
# <dd class="text-body-small t-black--light mb1">
#             51-200 employees
#         </dd>
# <dd class="text-body-small t-black--light mb4">
#             1,195 on LinkedIn
#             <span class="artdeco-hoverable-trigger artdeco-hoverable-trigger--content-placed-bottom ember-view" id="ember67" tabindex="-1">
# <button aria-controls="artdeco-hoverable-artdeco-gen-42" aria-describedby="artdeco-hoverable-artdeco-gen-42" aria-expanded="false" aria-label="More info" class="org-about-company-module__employees-count-tooltip-trigger artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view" id="ember68" type="button"> <li-icon aria-hidden="true" class="artdeco-button__icon" size="small" type="notify-pebble-icon"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M12 2H4a2 2 0 00-2 2v8a2 2 0 002 2h8a2 2 0 002-2V4a2 2 0 00-2-2zm-3 8v2H7.5A1.5 1.5 0 016 10.5a1.56 1.56 0 01.1-.5l1.08-3h2.13l-1.09 3zm0-3.75A1.25 1.25 0 1110.25 5 1.25 1.25 0 019 6.25z"></path>
# </svg></li-icon>
# <span class="artdeco-button__text">
#     Includes members with current employer listed as ACM, Association for Computing Machinery, including part-time roles.
# </span></button>
# <div class="ember-view" id="artdeco-gen-42"><div class="ember-view" id="ember70"></div></div>
# </span>
# </dd>
# <dt class="mb1 text-heading-small">
#             Headquarters
#           </dt>
# <dd class="mb4 text-body-small t-black--light">
#             New York, NY
#           </dd>
# <!-- -->
# <dt class="mb1 text-heading-small">
#           Founded
#         </dt>
# <dd class="mb4 text-body-small t-black--light">
#           1947
#         </dd>
# <dt class="mb1 text-heading-small">
#           Specialties
#         </dt>
# <dd class="mb4 text-body-small t-black--light" dir="ltr">
#           Computing
#         </dd>
# </dl>

# %%
dl = soup.find('div', 'mb6').find('dl')
nms = []
for tag in dl:
    txt = tag.text
    nms.append(txt)
nms
# Out:
# ['\n',
#  '\n          Website\n        ',
#  '\n',
#  '\n\n\n              https://www.acm.org/\n            \n\n',
#  '\n',
#  '\n          Phone\n        ',
#  '\n',
#  '\n\n\n              +1 (212) 626-0500\n            \n\n              Phone number is +1 (212) 626-0500\n            \n\n',
#  '\n',
#  '\n            Industry\n          ',
#  '\n',
#  '\n            Book and Periodical Publishing\n          ',
#  '\n',
#  '\n          Company size\n        ',
#  '\n',
#  '\n            51-200 employees\n        ',
#  '\n',
#  '\n            1,195 on LinkedIn\n            \n \n\n\n\n    Includes members with current employer listed as ACM, Association for Computing Machinery, including part-time roles.\n\n\n\n',
#  '\n',
#  '\n            Headquarters\n          ',
#  '\n',
#  '\n            New York, NY\n          ',
#  '\n',
#  '',
#  '\n',
#  '\n          Founded\n        ',
#  '\n',
#  '\n          1947\n        ',
#  '\n',
#  '\n          Specialties\n        ',
#  '\n',
#  '\n          Computing\n        ',
#  '\n']

# %%
# getting the values in key-value pairs, then we will extract the country from key "Headquarters"
dl = soup.find('div', 'mb6').find('dl')
keys = []
values = []
for tag in dl.find_all('dt'):
    txt = tag.text.strip()
    if (txt != ''):
        keys.append(txt)
for tag in dl.find_all('dd'):
    txt = tag.text.strip()
    if (txt != ''):
        values.append(txt)

# %%
keys, values
# Out:
# (['Website',
#   'Phone',
#   'Industry',
#   'Company size',
#   'Headquarters',
#   'Founded',
#   'Specialties'],
#  ['https://www.acm.org/',
#   '+1 (212) 626-0500\n            \n\n              Phone number is +1 (212) 626-0500',
#   'Book and Periodical Publishing',
#   '51-200 employees',
#   '1,195 on LinkedIn\n            \n \n\n\n\n    Includes members with current employer listed as ACM, Association for Computing Machinery, including part-time roles.',
#   'New York, NY',
#   '1947',
#   'Computing'])

# %%
values = [txt for txt in values if "Includes" not in txt] # a message which contains the word "Includes" sometime appears and is not needed, thus we don't include it
values
# Out:
# ['https://www.acm.org/',
#  '+1 (212) 626-0500\n            \n\n              Phone number is +1 (212) 626-0500',
#  'Book and Periodical Publishing',
#  '51-200 employees',
#  'New York, NY',
#  '1947',
#  'Computing']

# %%
# putting the key-value pairs in a dictionary
linkedinDict = dict(zip(keys, values))
linkedinDict
# Out:
# {'Website': 'https://www.acm.org/',
#  'Phone': '+1 (212) 626-0500\n            \n\n              Phone number is +1 (212) 626-0500',
#  'Industry': 'Book and Periodical Publishing',
#  'Company size': '51-200 employees',
#  'Headquarters': 'New York, NY',
#  'Founded': '1947',
#  'Specialties': 'Computing'}

# %%
linkedinDict["Headquarters"]
# Out:
# 'New York, NY'

# %% [markdown]
# Step 4: getting the country code of the companies and their corresponding indices and putting them in a list of tuples:

# %%
import threading # using multithreads to speed things up a little
lock = threading.Lock()
import pycountry
from geopy.geocoders import Nominatim # using this library to convert cities to countries
import time
import re

geolocator = Nominatim(user_agent="ashraf196280@bue.edu.eg")

idxToNan = []
def fetchCountry(idx, link):
    try:
        lock.acquire()
        driver.get(link) # same driver used from step 1
        time.sleep(2)
        soup = BeautifulSoup(driver.page_source, "html.parser")
        lock.release()
        dl = soup.find('div', 'mb6').find('dl')
        keys = []
        values = []
        for tag in dl.find_all('dt'):
            txt = tag.text.strip()
            if (txt != ''):
                keys.append(txt)
        for tag in dl.find_all('dd'):
            txt = tag.text.strip()
            if (txt != ''):
                values.append(txt)
        values = [txt for txt in values if "Includes" not in txt]
        linkedinDict = dict(zip(keys, values))
        if ('Headquarters' in linkedinDict):
            city = linkedinDict["Headquarters"]
            city = city.split(',')[0] # eg: "Cupertino, California" will be ["Cupertino", "California"], so "Cupertino" will be returned
        else:
            locCard = soup.find('div', 'org-location-card pv2')
            city = re.findall(r'Primary[\n\s]+(\w+)', locCard.text)[0]
        lock.acquire()
        location = geolocator.geocode(city, language="en")
        lock.release()
        if location is None:
            raise
    except:
        lock.acquire()
        idxToNan.append((idx, "missing")) # means that this website is not found on linkedin, so declare it as missing
        lock.release()
        return
    
    country = location.address.split(', ')[-1]
    try:
        alpha3Code = pycountry.countries.get(name=country).alpha_3
    except:
        alpha3Code = country[0:3].upper() #if not found in pycountry, assume that it is the first 3 letters of the country name
    lock.acquire()
    idxToNan.append((idx, alpha3Code))
    lock.release()

# %%
from threading import Thread
def imputeFromLinks(df, colToSuffixIntoURL, colToImpute, start, end, linkPrefix = ""):
    links = df[df[colToImpute].isnull()][[colToSuffixIntoURL]].squeeze()[start:end] # "squeeze()" converts df to series
    threads = []
    for tup in links.iteritems(): # tup[0] --> index, tup[1] --> url (i.e. link)
        th = Thread(target=fetchCountry, args=(tup[0], linkPrefix + tup[1].replace(" ", "") + '/about')) #making sure company name doesn't have spaces when suffixed into the url
        threads.append(th)
        th.start()
    for th in threads:
        th.join() # to wait until all multithreads finish to properly display the dataframe

# %%
# single threaded version (just in case multithreads gets blocked by linkedin)
from threading import Thread
def imputeFromLinksSingleThreads(df, colToSuffixIntoURL, colToImpute, linkPrefix = ""):
    links = df[df[colToImpute].isnull()][[colToSuffixIntoURL]].squeeze() # "squeeze()" converts df to series
    for tup in links.iteritems(): # tup[0] --> index, tup[1] --> url (i.e. link)
        fetchCountry(tup[0], linkPrefix + tup[1].replace(" ", "") + '/about') #making sure company name doesn't have spaces when suffixed into the url

# %%
links = companies[companies['company_country_code'].isnull()][['company_name']].squeeze()
len(links)
# Out:
# 6952

# %%
#imputeFromLinks(companies, "company_name", "company_country_code", "https://www.linkedin.com/company/", 0, 10)
# Out:
# Moscow

# %%
#idxToNan
# Out:
# [(21, 'missing'),
#  (35, 'missing'),
#  (39, 'RUS'),
#  (45, 'missing'),
#  (57, 'missing')]

# %%
# this was to save the output to a csv file in case the pc shut off after the above cell executed
#dfLinkedin = pd.DataFrame(idxToNan, columns=['index', 'company_country_code'])
#dfLinkedin.set_index('index')
#dfLinkedin.to_csv('Phase 1/countryCodesLinkedIn.csv', index=False)

# %% [markdown]
# #### Successful attempt using TLDs of `homepage_url`

# %% [markdown]
# Let's check the top level domain (TLD) of each link using regex and see if we can use that <br>
# to impute the country code:

# %%
# As you can see, there are only approximately 1500 rows that don't contain neither country_code nor homepage_url
hUrls = companies[companies['company_country_code'].isnull()][['homepage_url']].squeeze()
hUrls.dropna(inplace=True)
len(hUrls), len(companies[companies['company_country_code'].isnull()])
# Out:
# (5548, 6952)

# %%
hUrls.head(3)
# Out:
# 2         http://oneofthem.jp
# 21    http://www.1000chi.com/
# 35    http://beansaround.com/
# Name: homepage_url, dtype: object

# %%
hUrls.str.findall(r'(\.[^.]*)$').head(3) # use '\.([^.]*)$' if you don't want the '.', but we do, so leave it
# Out:
# 2       [.jp]
# 21    [.com/]
# 35    [.com/]
# Name: homepage_url, dtype: object

# %%
hUrls = hUrls.str.findall(r'(\.[^.]*)$').apply(lambda x : ''.join(x).split('/')[0]) # apply() will convert the list of strings to a string and remove '/' at the end of the string
hUrls
# Out:
# 2         .jp
# 21       .com
# 35       .com
# 39       .com
# 45       .com
#          ...
# 66317    .com
# 66325     .co
# 66333    .com
# 66365     .hu
# 66367    .com
# Name: homepage_url, Length: 5548, dtype: object

# %%
unwantedVals = hUrls.str.contains(pat='^$|com') # "^$" means empty string, "|" means "or"
hUrls = hUrls[~unwantedVals] # "~" is equivalent to "unwantedVals == False"
hUrls
# Out:
# 2           .jp
# 54          .br
# 79       .media
# 126         .hk
# 159         .me
#           ...
# 66220       .cz
# 66230       .my
# 66270      .php
# 66325       .co
# 66365       .hu
# Name: homepage_url, Length: 1541, dtype: object

# %% [markdown]
# Create a dictionary where key = TLD, value = country <br>
# e.g --> '.jp' : 'Japan'

# %%
#csv obtained from https://gist.github.com/derlin/421d2bb55018a1538271227ff6b1299d#file-country-codes-tlds-csv
tldsToCountries = pd.read_csv('Phase 1/country-codes-tlds.csv')
tldsToCountries.drop_duplicates(subset='tld', keep='first', inplace=True)
tldsToCountries['tld'] = tldsToCountries['tld'].apply(lambda x: x.replace(' ', ''))
tldsToCountries.to_csv(r'Phase 1/newCountryCodesTlds.csv', index = None, header=True)
tldsToCountries = tldsToCountries.set_index('tld').squeeze()
tldsToCountries = tldsToCountries.to_dict()
tldsToCountries['.jp']
# Out:
# 'Japan'

# %% [markdown]
# Use that dictionary to convert TLDs to their respective countries:

# %%
hCompanyLocs = hUrls.copy()
hCompanyLocs = hCompanyLocs.apply(lambda x : tldsToCountries[x] if (x in tldsToCountries) else 'none')
hCompanyLocs = hCompanyLocs[hCompanyLocs != 'none']
hCompanyLocs
# Out:
# 2                           Japan
# 54                         Brazil
# 126                     Hong Kong
# 159                    Montenegro
# 281                   Switzerland
#                    ...
# 66184              Réunion Island
# 66220    Czechia (Czech Republic)
# 66230                    Malaysia
# 66325                    Colombia
# 66365                     Hungary
# Name: homepage_url, Length: 1213, dtype: object

# %%
# 1213 countries could be imputed
len(hCompanyLocs)
# Out:
# 1213

# %% [markdown]
# Convert those countries to country codes:

# %%
import pycountry
def toAlphaCode3(country):
    countryInfo = pycountry.countries.get(name=country)
    if (countryInfo is None):
        return "none"
    return countryInfo.alpha_3

hCompanyLocs = hCompanyLocs.apply(lambda x : toAlphaCode3(x))
hCompanyLocs = hCompanyLocs[hCompanyLocs != 'none']
hCompanyLocs
# Out:
# 2        JPN
# 54       BRA
# 126      HKG
# 159      MNE
# 281      CHE
#         ...
# 65745    SVK
# 66120    POL
# 66230    MYS
# 66325    COL
# 66365    HUN
# Name: homepage_url, Length: 900, dtype: object

# %%
# only 900 countries have country codes present, so impute those only
# the following is just to illustrate the for loop in the next cell:
hCompanyLocs.index[0], hCompanyLocs.iloc[0]
# Out:
# (2, 'JPN')

# %% [markdown]
# impute into `country_codes` of `companies` dataset

# %%
for i in range(len(hCompanyLocs)):
    idx = hCompanyLocs.index[i]
    code = hCompanyLocs.iloc[i]
    companies.at[idx, 'company_country_code'] = code

# %% [markdown]
# ## Checking All `dtypes`

# %% [markdown]
# first we will convert the funding total in the companies dataset into float and then fill the nulls with zeros

# %%
companies['funding_total_usd'] = pd.to_numeric(companies['funding_total_usd'],errors = 'coerce')
companies['funding_total_usd'].fillna(0, inplace = True)
companies['funding_total_usd'] = companies['funding_total_usd'].astype(float, errors = 'raise')
companies.dtypes
# Out:
# company_permalink                  object
# company_name                       object
# homepage_url                       object
# company_category_list              object
# funding_total_usd                 float64
# status                             object
# company_country_code               object
# company_city                       object
# funding_rounds                      int64
# founded_at                 datetime64[ns]
# first_funding_at           datetime64[ns]
# last_funding_at            datetime64[ns]
# time_before_first_fund    timedelta64[ns]
# dtype: object

# %%
rounds['raised_amount_usd'] = pd.to_numeric(rounds['raised_amount_usd'],errors = 'coerce')
rounds['raised_amount_usd'].fillna(0, inplace = True)
rounds['raised_amount_usd'] = rounds['raised_amount_usd'].astype(float, errors = 'raise')
rounds.dtypes
# Out:
# company_permalink                  object
# company_name                       object
# company_category_list              object
# company_country_code               object
# company_state_code                 object
# company_city                       object
# funding_round_permalink            object
# funding_round_type                 object
# funding_round_code                 object
# funded_at                  datetime64[ns]
# raised_amount_usd                 float64
# dtype: object

# %%
def datasetsDtypes(dfList, datasetNames, dtypesCol="dtypes_", pad=""):
    cols = []
    nulls = []
    maxArrayLen = 0
    for i, df in enumerate(dfList):
        cols.append(df.columns.tolist())
        nulls.append(df.dtypes.tolist())
        maxArrayLen = max(maxArrayLen, len(cols[i]))
    
    dictCsvs = {}
    for i, df in enumerate(dfList):
        cols[i] += [pad] * (maxArrayLen - len(cols[i])) #padding the lists to make them have equal lengths 
        nulls[i] += [None] *  (maxArrayLen - len(nulls[i]))
        dictCsvs[datasetNames[i]] = cols[i]
        dictCsvs[dtypesCol + str(i+1)] = nulls[i]
    
    return pd.DataFrame(dictCsvs)

# %%
datasetsDtypes(dfAll, lstCsvNames)
# Out:
#               acquisitions        dtypes_1               companies  \
# 0        company_permalink          object       company_permalink
# 1             company_name          object            company_name
# 2    company_category_list          object            homepage_url
# 3     company_country_code          object   company_category_list
# 4       company_state_code          object       funding_total_usd
# 5             company_city          object                  status
# 6       acquirer_permalink          object    company_country_code
# 7            acquirer_name          object      company_state_code
# 8   acquirer_category_list          object          company_region
# 9    acquirer_country_code          object            company_city
# 10     acquirer_state_code          object          funding_rounds
# 11           acquirer_city          object              founded_at
# 12             acquired_at  datetime64[ns]        first_funding_at
# 13          acquired_month          object         last_funding_at
# 14            price_amount         float64  time_before_first_fund
# 15     price_currency_code          object
# 16                                    None
#
#            dtypes_2              investments        dtypes_3  \
# 0            object        company_permalink          object
# 1            object             company_name          object
# 2            object    company_category_list          object
# 3            object     company_country_code          object
# 4            object       company_state_code          object
# 5            object             company_city          object
# 6            object       investor_permalink          object
# 7            object            investor_name          object
# 8            object    investor_country_code          object
# 9            object      investor_state_code          object
# 10            int64            investor_city          object
# 11   datetime64[ns]  funding_round_permalink          object
# 12   datetime64[ns]       funding_round_type          object
# 13   datetime64[ns]       funding_round_code          object
# 14  timedelta64[ns]                funded_at  datetime64[ns]
# 15             None        raised_amount_usd         float64
# 16             None             total_raised         float64
#
#                      rounds        dtypes_4
# 0         company_permalink          object
# 1              company_name          object
# 2     company_category_list          object
# 3      company_country_code          object
# 4        company_state_code          object
# 5              company_city          object
# 6   funding_round_permalink          object
# 7        funding_round_type          object
# 8        funding_round_code          object
# 9                 funded_at  datetime64[ns]
# 10        raised_amount_usd         float64
# 11                                     None
# 12                                     None
# 13                                     None
# 14                                     None
# 15                                     None
# 16                                     None

# %% [markdown]
# ## Imputing Countries and country codes

# %% [markdown]
# After the failed attempt to scrape the country and then get the country code of each company we will impute the values with "missing" for now.

# %%
acquis['company_country_code']=acquis['company_country_code'].fillna("missing")
acquis['company_state_code']=acquis['company_state_code'].fillna("missing")
acquis['company_city']=acquis['company_city'].fillna("missing")

companies['company_country_code']=companies['company_country_code'].fillna("missing")
companies['company_city']=companies['company_city'].fillna("missing")

acquis['company_country_code']=acquis['company_country_code'].fillna("missing")
acquis['company_state_code']=acquis['company_state_code'].fillna("missing")
acquis['company_city']=acquis['company_city'].fillna("missing")
acquis['acquirer_country_code']=acquis['acquirer_country_code'].fillna("missing")
acquis['acquirer_state_code']=acquis['acquirer_state_code'].fillna("missing")
acquis['acquirer_city']=acquis['acquirer_city'].fillna("missing")

invests['company_country_code']=invests['company_country_code'].fillna("missing")
invests['company_state_code']=invests['company_state_code'].fillna("missing")
invests['company_city']=invests['company_city'].fillna("missing")
invests['investor_city']=invests['investor_city'].fillna("missing")
invests['investor_country_code']=invests['investor_country_code'].fillna("missing")
invests['investor_state_code']=invests['investor_state_code'].fillna("missing")


rounds['company_country_code']=rounds['company_country_code'].fillna("missing")

# %%
acquis[acquis.duplicated(keep = False) == True]
# Out:
#                      company_permalink       company_name  \
# 1856     /organization/backcountry-com    Backcountry.com
# 1857     /organization/backcountry-com    Backcountry.com
# 1932   /organization/bartlett-holdings  Bartlett Holdings
# 1933   /organization/bartlett-holdings  Bartlett Holdings
# 1934   /organization/bartlett-holdings  Bartlett Holdings
# ...                                ...                ...
# 17643        /organization/unveillance        Unveillance
# 17644        /organization/unveillance        Unveillance
# 17645        /organization/unveillance        Unveillance
# 18387         /organization/webmethods         webMethods
# 18388         /organization/webmethods         webMethods
#
#                          company_category_list company_country_code  \
# 1856                                E-Commerce                  USA
# 1857                                E-Commerce                  USA
# 1932                                   missing                  USA
# 1933                                   missing                  USA
# 1934                                   missing                  USA
# ...                                        ...                  ...
# 17643                               Technology                  USA
# 17644                               Technology                  USA
# 17645                               Technology                  USA
# 18387  B2B|Enterprise Software|Web Development              missing
# 18388  B2B|Enterprise Software|Web Development              missing
#
#       company_state_code      company_city  \
# 1856                  UT         Park City
# 1857                  UT         Park City
# 1932                  MA  Plymouth Meeting
# 1933                  MA  Plymouth Meeting
# 1934                  MA  Plymouth Meeting
# ...                  ...               ...
# 17643                 DE        Wilmington
# 17644                 DE        Wilmington
# 17645                 DE        Wilmington
# 18387            missing           missing
# 18388            missing           missing
#
#                         acquirer_permalink          acquirer_name  \
# 1856   /organization/tsg-consumer-partners  TSG Consumer Partners
# 1857   /organization/tsg-consumer-partners  TSG Consumer Partners
# 1932        /organization/harvest-partners       Harvest Partners
# 1933        /organization/harvest-partners       Harvest Partners
# 1934        /organization/harvest-partners       Harvest Partners
# ...                                    ...                    ...
# 17643               /organization/mandiant               Mandiant
# 17644               /organization/mandiant               Mandiant
# 17645               /organization/mandiant               Mandiant
# 18387            /organization/software-ag            Software AG
# 18388            /organization/software-ag            Software AG
#
#                                   acquirer_category_list  \
# 1856                                             missing
# 1857                                             missing
# 1932                                             missing
# 1933                                             missing
# 1934                                             missing
# ...                                                  ...
# 17643                                           Security
# 17644                                           Security
# 17645                                           Security
# 18387  Big Data|Enterprises|Enterprise Software|Software
# 18388  Big Data|Enterprises|Enterprise Software|Software
#
#       acquirer_country_code acquirer_state_code  acquirer_city acquired_at  \
# 1856                    USA                  CA  San Francisco  2015-07-01
# 1857                    USA                  CA  San Francisco  2015-07-01
# 1932                    USA                  NY       New York  2010-12-01
# 1933                    USA                  NY       New York  2010-12-01
# 1934                    USA                  NY       New York  2010-12-01
# ...                     ...                 ...            ...         ...
# 17643                   USA                  VA     Alexandria  2012-09-10
# 17644                   USA                  VA     Alexandria  2012-09-10
# 17645                   USA                  VA     Alexandria  2012-09-10
# 18387                   DEU                   5      Darmstadt  2007-04-01
# 18388                   DEU                   5      Darmstadt  2007-04-01
#
#       acquired_month  price_amount price_currency_code
# 1856         2015-07           NaN                 USD
# 1857         2015-07           NaN                 USD
# 1932         2010-12           NaN                 USD
# 1933         2010-12           NaN                 USD
# 1934         2010-12           NaN                 USD
# ...              ...           ...                 ...
# 17643        2012-09           NaN                 USD
# 17644        2012-09           NaN                 USD
# 17645        2012-09           NaN                 USD
# 18387        2007-04   500000000.0                 USD
# 18388        2007-04   500000000.0                 USD
#
# [71 rows x 16 columns]

# %%
acquis.drop_duplicates()
acquis
# Out:
#                                        company_permalink  \
# 0                                   /organization/003-ru
# 1                          /organization/0958572-b-c-ltd
# 2                     /organization/1-800-communications
# 3                           /organization/1-800-contacts
# 4      /organization/1-844-446-4460-pogo-customer-ser...
# ...                                                  ...
# 18963                          /organization/zynk-mobile
# 18964                               /organization/zyrion
# 18965                               /organization/zystor
# 18966                          /organization/zytex-group
# 18967                   /organization/’compass-solutions
#
#                                             company_name  \
# 0                                                 003.RU
# 1                                      0958572 B.C. Ltd.
# 2                                   1-800 Communications
# 3                                         1-800 Contacts
# 4      Games Support +1-800-311-5934 Pogo Games techn...
# ...                                                  ...
# 18963                                        Zynk Mobile
# 18964                                         Zyrion Inc
# 18965                                             Zystor
# 18966                                        Zytex group
# 18967                                N’compass Solutions
#
#                            company_category_list company_country_code  \
# 0      Consumer Electronics|Electronics|Internet                  RUS
# 1                                        missing              missing
# 2                                        missing                  USA
# 3                          Consumer Goods|Retail                  USA
# 4                                        missing              missing
# ...                                          ...                  ...
# 18963                                    missing              missing
# 18964                        Networking|Software                  USA
# 18965                              Biotechnology                  USA
# 18966                              Manufacturing                  IND
# 18967                     Information Technology                  USA
#
#       company_state_code company_city  \
# 0                     48       Moscow
# 1                missing      missing
# 2                     NY   Hicksville
# 3                     UT       Draper
# 4                missing      missing
# ...                  ...          ...
# 18963            missing      missing
# 18964                 CA    Sunnyvale
# 18965                 WI    Milwaukee
# 18966                 16       Mumbai
# 18967                 MN  Maple Grove
#
#                                       acquirer_permalink  \
# 0                             /organization/media-saturn
# 1      /organization/atlas-intellectual-property-mana...
# 2                           /organization/carsdirect-com
# 3                    /organization/thomas-h-lee-partners
# 4      /organization/pogo-customer-service-number-1-8...
# ...                                                  ...
# 18963                               /organization/zenvia
# 18964                               /organization/kaseya
# 18965              /organization/biomarin-pharmaceutical
# 18966                          /organization/brenntag-ag
# 18967                /organization/alphapoint-technology
#
#                                            acquirer_name  \
# 0                                           Media Saturn
# 1             ATLAS Intellectual Property Management Co.
# 2                                         CarsDirect.com
# 3                                 Thomas H. Lee Partners
# 4      Games Support +1-800-311-5934 Pogo Games techn...
# ...                                                  ...
# 18963                                             Zenvia
# 18964                                             Kaseya
# 18965                            BioMarin Pharmaceutical
# 18966                                        Brenntag AG
# 18967                              AlphaPoint Technology
#
#                                   acquirer_category_list  \
# 0          Enterprise Software|Media|Sales and Marketing
# 1              Finance|FinTech|Mobile|Telecommunications
# 2                                             E-Commerce
# 3      Business Development|Impact Investing|Investme...
# 4                                                missing
# ...                                                  ...
# 18963                                             Mobile
# 18964  Data Centers|Data Security|Flash Storage|Homel...
# 18965                                    Pharmaceuticals
# 18966                   Chemicals|Manufacturing|Services
# 18967  Data Center Infrastructure|Intellectual Asset ...
#
#       acquirer_country_code acquirer_state_code        acquirer_city  \
# 0                       ESP                  56            Barcelona
# 1                       USA                  WA              Seattle
# 2                       USA                  CA           El Segundo
# 3                       USA                  MA               Boston
# 4                       USA                  NY           Mamaroneck
# ...                     ...                 ...                  ...
# 18963                   BRA                  23         Porto Alegre
# 18964               missing             missing              missing
# 18965                   USA                  CA           San Rafael
# 18966                   DEU                   7  Mülheim An Der Ruhr
# 18967                   USA                  FL             Sarasota
#
#       acquired_at acquired_month  price_amount price_currency_code
# 0      2012-07-23        2012-07           NaN                 USD
# 1      2012-02-02        2012-02     9000000.0                 USD
# 2      2005-06-12        2005-06           NaN                 USD
# 3      2014-01-07        2014-01           NaN                 USD
# 4      2001-02-02        2001-02           NaN                 USD
# ...           ...            ...           ...                 ...
# 18963  2013-03-01        2013-03           NaN                 USD
# 18964  2013-06-25        2013-06           NaN                 USD
# 18965  2010-08-18        2010-08   115000000.0                 USD
# 18966  2013-09-25        2013-09    14000000.0                 USD
# 18967  2014-12-25        2014-12     4800000.0                 USD
#
# [18950 rows x 16 columns]

# %% [markdown]
# ## Checking Nulls

# %% [markdown]
# Now that we imputed all missing data, we will check and see that there are no more null values in any data set. Notice that the other nulls are in columns that are dropped already in the dataframes.

# %%
dfAll = [acquis, companies, invests, rounds]
lstCsvNames = ["acquisitions", "companies", "investments", "rounds"]
dfAllNulls = datasetsNulls(dfAll, lstCsvNames)
dfAllNulls
# Out:
#               acquisitions  nulls_1               companies  nulls_2  \
# 0        company_permalink      0.0       company_permalink      0.0
# 1             company_name      0.0            company_name      0.0
# 2    company_category_list      0.0            homepage_url   5055.0
# 3     company_country_code      0.0   company_category_list      0.0
# 4       company_state_code      0.0       funding_total_usd      0.0
# 5             company_city      0.0                  status      0.0
# 6       acquirer_permalink      0.0    company_country_code      0.0
# 7            acquirer_name      0.0            company_city      0.0
# 8   acquirer_category_list      0.0          funding_rounds      0.0
# 9    acquirer_country_code      0.0              founded_at      1.0
# 10     acquirer_state_code      0.0        first_funding_at      3.0
# 11           acquirer_city      0.0         last_funding_at      0.0
# 12             acquired_at      0.0  time_before_first_fund      0.0
# 13          acquired_month      0.0                              NaN
# 14            price_amount  13941.0                              NaN
# 15     price_currency_code      0.0                              NaN
# 16                              NaN                              NaN
#
#                 investments  nulls_3                   rounds  nulls_4
# 0         company_permalink        0        company_permalink      0.0
# 1              company_name        0             company_name      0.0
# 2     company_category_list        0    company_category_list      0.0
# 3      company_country_code        0     company_country_code      0.0
# 4        company_state_code        0       company_state_code  10946.0
# 5              company_city        0             company_city  10164.0
# 6        investor_permalink        0  funding_round_permalink      0.0
# 7             investor_name        0       funding_round_type      0.0
# 8     investor_country_code        0       funding_round_code  83808.0
# 9       investor_state_code        0                funded_at      0.0
# 10            investor_city        0        raised_amount_usd      0.0
# 11  funding_round_permalink        0                               NaN
# 12       funding_round_type        0                               NaN
# 13       funding_round_code    87576                               NaN
# 14                funded_at        0                               NaN
# 15        raised_amount_usd        0                               NaN
# 16             total_raised    14384                               NaN

# %% [markdown]
# # Answering the Questions

# %% [markdown]
# ## First Question (Ashraf)

# %% [markdown]
# 1.	Can the factors that affect a start-up’s growth be determined?
#     -	For this: We are initially interested in <br> `funding_total_usd`, `status`, and `funding_rounds`

# %% [markdown]
# This question can be measured with two approches:
# - Divide the companies into categories based on their status (either closed, operating or acquired) then look at the average of funding each category receives, then determine the correlation between the closed companies and their failure due to the low funds.
# - the second approch is finding how frequent a company receives funding regardless of how big or small this funding is. Funding frequency is important to consistently pump money into the company so it is a good indicator.

# %% [markdown]
# First, we will join the two datasets to answer our question which are companies and rounds

# %%
companies.sort_values(by=['company_name'], inplace=True)
rounds.sort_values(by=['company_name'],inplace=True)
comp_rounds = companies.join(rounds.set_index('company_name'), on='company_name',lsuffix='_left', rsuffix='_right')
comp_rounds
# Out:
#                  company_permalink_left            company_name  \
# 8387    /organization/bratpackstyle-llc    #BratPackStyle, LLC.
# 24857             /organization/hashoff                #HASHOFF
# 24857             /organization/hashoff                #HASHOFF
# 0                   /organization/-fame                   #fame
# 63213             /organization/waywire                #waywire
# ...                                 ...                     ...
# 31300  /organization/kutusu-video-ajans  İş kutusu video ajansı
# 18356                /organization/enso                 Еnso.fm
# 51461               /organization/shwrm                 ​Shwrüm
# 63626              /organization/wested                 ​WestEd
# 10964           /organization/chishenma           吃神马 ChiShenMa
#
#                        homepage_url  \
# 8387   http://www.bratpackstyle.com
# 24857        http://www.hashoff.com
# 24857        http://www.hashoff.com
# 0                http://livfame.com
# 63213        http://www.waywire.com
# ...                             ...
# 31300       http://www.iskutusu.com
# 18356                http://enso.fm
# 51461         http://www.shwrum.com
# 63626        http://www.wested.org/
# 10964             http://chishen.ma
#
#                               company_category_list_left  funding_total_usd  \
# 8387   Content Discovery|E-Commerce|Fashion|Lifestyle...       0.000000e+00
# 24857                Digital Media|Internet|Social Media       9.550000e+05
# 24857                Digital Media|Internet|Social Media       9.550000e+05
# 0                                                  Media       1.000000e+07
# 63213           Entertainment|News|Politics|Social Media       1.750000e+06
# ...                                                  ...                ...
# 31300      3D|Advertising|Online Video Advertising|Video       1.000000e+05
# 18356  Algorithms|Casual Games|Content Discovery|Edis...       2.783840e+04
# 51461   Design|Fashion|Internet|Mobile|Shopping|Software       5.000000e+04
# 63626                                         Nonprofits       3.000000e+06
# 10964                 Mobile|Restaurants|Specialty Foods       0.000000e+00
#
#           status company_country_code_left company_city_left  funding_rounds  \
# 8387      closed                       USA          New York               1
# 24857  operating                       USA            Denver               2
# 24857  operating                       USA            Denver               2
# 0      operating                       IND            Mumbai               1
# 63213   acquired                       USA          New York               1
# ...          ...                       ...               ...             ...
# 31300  operating                       TUR          Istanbul               1
# 18356  operating                       BGR             Sofia               1
# 51461  operating                       USA       Gainesville               1
# 63626  operating                       USA     San Francisco               1
# 10964  operating                       CHN          Shanghai               1
#
#                          founded_at  ...           company_permalink_right  \
# 8387  2015-04-19 00:00:00.000000000  ...   /organization/bratpackstyle-llc
# 24857 2014-04-01 00:00:00.000000000  ...             /organization/hashoff
# 24857 2014-04-01 00:00:00.000000000  ...             /organization/hashoff
# 0     2011-04-12 20:46:43.240577680  ...               /organization/-fame
# 63213 2012-06-01 00:00:00.000000000  ...             /organization/waywire
# ...                             ...  ...                               ...
# 31300 2013-01-01 00:00:00.000000000  ...  /organization/kutusu-video-ajans
# 18356 2015-06-29 00:00:00.000000000  ...                /organization/enso
# 51461 2013-01-01 00:00:00.000000000  ...               /organization/shwrm
# 63626 2010-10-27 20:46:43.240577680  ...              /organization/wested
# 10964 2014-01-01 00:00:00.000000000  ...           /organization/chishenma
#
#                              company_category_list_right  \
# 8387   Content Discovery|E-Commerce|Fashion|Lifestyle...
# 24857                Digital Media|Internet|Social Media
# 24857                Digital Media|Internet|Social Media
# 0                                                  Media
# 63213           Entertainment|News|Politics|Social Media
# ...                                                  ...
# 31300      3D|Advertising|Online Video Advertising|Video
# 18356  Algorithms|Casual Games|Content Discovery|Edis...
# 51461   Design|Fashion|Internet|Mobile|Shopping|Software
# 63626                                         Nonprofits
# 10964                 Mobile|Restaurants|Specialty Foods
#
#       company_country_code_right company_state_code company_city_right  \
# 8387                         USA                 NY           New York
# 24857                        USA                 CO             Denver
# 24857                        USA                 CO             Denver
# 0                            IND                 16             Mumbai
# 63213                        USA                 NY           New York
# ...                          ...                ...                ...
# 31300                        TUR                 34           Istanbul
# 18356                        BGR                 42              Sofia
# 51461                        USA                 FL        Gainesville
# 63626                        USA                 CA      San Francisco
# 10964                        CHN                 23           Shanghai
#
#                                funding_round_permalink funding_round_type  \
# 8387   /funding-round/7f52613bbda1edcaed3844d806d62757               seed
# 24857  /funding-round/669d6203c0374e6cf0e8d10f75ba0b8a     debt_financing
# 24857  /funding-round/889482c82e762d06c02a1dfa8fb41ccf     debt_financing
# 0      /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 63213  /funding-round/cc409188fa2b63482bd9008f682c2efa               seed
# ...                                                ...                ...
# 31300  /funding-round/86a2d1c65a4b520303a65eaaf7d44b63               seed
# 18356  /funding-round/53becfd9582cda62dcb2a6c9970810b3               seed
# 51461  /funding-round/cc9a173bdd48c97e5ceb22c10183c1f4               seed
# 63626  /funding-round/ebab19c45d43ad7ba54d6deb5c677518              grant
# 10964  /funding-round/aa4cde05f64453c60ca85a06a962f381               seed
#
#       funding_round_code  funded_at raised_amount_usd
# 8387                 NaN 2015-06-01               0.0
# 24857                NaN 2014-12-08          455000.0
# 24857                NaN 2015-08-11          500000.0
# 0                      B 2015-01-05        10000000.0
# 63213                NaN 2012-06-30         1750000.0
# ...                  ...        ...               ...
# 31300                NaN 2014-03-13          100000.0
# 18356                NaN 2015-07-01           27838.0
# 51461                NaN 2013-01-01           50000.0
# 63626                NaN 2014-07-22         3000000.0
# 10964                NaN 2014-02-28               0.0
#
# [115874 rows x 23 columns]

# %% [markdown]
# We will slice our new joined dataset into three categories based on the company's status:

# %%
operatingcomp_rounds = comp_rounds[comp_rounds['status'] == 'operating']
operatingcomp_rounds = operatingcomp_rounds[['company_name', 'funding_rounds', 'raised_amount_usd', 'funded_at']]
operatingcomp_rounds
# Out:
#                  company_name  funding_rounds  raised_amount_usd  funded_at
# 24857                #HASHOFF               2           455000.0 2014-12-08
# 24857                #HASHOFF               2           500000.0 2015-08-11
# 0                       #fame               1         10000000.0 2015-01-05
# 59910      &TV Communications               2          1000000.0 2010-06-04
# 59910      &TV Communications               2          3000000.0 2010-09-23
# ...                       ...             ...                ...        ...
# 31300  İş kutusu video ajansı               1           100000.0 2014-03-13
# 18356                 Еnso.fm               1            27838.0 2015-07-01
# 51461                 ​Shwrüm               1            50000.0 2013-01-01
# 63626                 ​WestEd               1          3000000.0 2014-07-22
# 10964           吃神马 ChiShenMa               1                0.0 2014-02-28
#
# [90890 rows x 4 columns]

# %%
acquiredcomp_rounds = comp_rounds[comp_rounds['status'] == 'acquired']
acquiredcomp_rounds = acquiredcomp_rounds[['company_name', 'funding_rounds', 'raised_amount_usd', 'funded_at']]
acquiredcomp_rounds
# Out:
#        company_name  funding_rounds  raised_amount_usd  funded_at
# 63213      #waywire               1          1750000.0 2012-06-30
# 47335         (RED)               1             2323.0 2000-03-05
# 54453     //Staq.io               1                0.0 2012-10-01
# 15     1 Mainstream               1          5000000.0 2015-03-17
# 20     1000 Markets               1           500000.0 2009-05-15
# ...             ...             ...                ...        ...
# 66277        zulily               4          6000000.0 2010-08-04
# 66277        zulily               4         85000000.0 2012-11-15
# 66309         zurvu               1          1200000.0 2014-03-20
# 66316        zuuka!               2                0.0 2011-01-24
# 66316        zuuka!               2                0.0 2012-06-11
#
# [11830 rows x 4 columns]

# %%
closedcomp_rounds = comp_rounds[comp_rounds['status'] == 'closed']
closedcomp_rounds = closedcomp_rounds[['company_name', 'funding_rounds', 'raised_amount_usd', 'funded_at']]
closedcomp_rounds
# Out:
#                company_name  funding_rounds  raised_amount_usd  funded_at
# 8387   #BratPackStyle, LLC.               1                0.0 2015-06-01
# 11998         .Club Domains               1          7000000.0 2013-05-31
# 21459         .FOX Networks               1          4912393.0 2007-01-16
# 12521           .comDominio               1                0.0 2004-02-12
# 34             10BestThings               1            50000.0 2009-04-01
# ...                     ...             ...                ...        ...
# 65152                yes.no               1          1000000.0 2015-05-01
# 65291                 yoone               1           197597.0 2010-11-03
# 65293                yoonew               2          2000000.0 2005-08-01
# 65293                yoonew               2          2000000.0 2007-01-01
# 66059     zipcodemailer.com               1            15000.0 2008-09-10
#
# [8820 rows x 4 columns]

# %% [markdown]
# Now we group the operating, acquired, and closed companies by their name and see how much total of fundings across the rounds each company earned. We will see that some of the closed companies did not receive any fundings and this has to be one of the highlighted reasons to their failure.

# %%
operatingtotal = pd.DataFrame(operatingcomp_rounds.groupby(['company_name'])['raised_amount_usd'].sum())
operatingtotal
# Out:
#                         raised_amount_usd
# company_name
# #HASHOFF                         955000.0
# #fame                          10000000.0
# &TV Communications              4000000.0
# 'Rock' Your Paper                 60385.0
# ( caravelo (                    1089811.0
# ...                                   ...
# İş kutusu video ajansı           100000.0
# Еnso.fm                           27838.0
# ​Shwrüm                           50000.0
# ​WestEd                         3000000.0
# 吃神马 ChiShenMa                         0.0
#
# [52832 rows x 1 columns]

# %%
acquiredtotal = pd.DataFrame(acquiredcomp_rounds.groupby(['company_name'])['raised_amount_usd'].sum())
acquiredtotal
# Out:
#               raised_amount_usd
# company_name
# #waywire              1750000.0
# (RED)                    2323.0
# //Staq.io                   0.0
# 1 Mainstream          5000000.0
# 1000 Markets           500000.0
# ...                         ...
# youcalc               3840000.0
# zoidu                   48600.0
# zulily              138600000.0
# zurvu                 1200000.0
# zuuka!                      0.0
#
# [5546 rows x 1 columns]

# %%
closedtotal = pd.DataFrame(closedcomp_rounds.groupby(['company_name'])['raised_amount_usd'].sum())
closedtotal
# Out:
#                       raised_amount_usd
# company_name
# #BratPackStyle, LLC.                0.0
# .Club Domains                 7000000.0
# .FOX Networks                 4912393.0
# .comDominio                         0.0
# 10BestThings                    50000.0
# ...                                 ...
# xkoto                        11035000.0
# yes.no                        1000000.0
# yoone                          197597.0
# yoonew                        4000000.0
# zipcodemailer.com               15000.0
#
# [6226 rows x 1 columns]

# %% [markdown]
#  Comparing the raised amount to the operating companies to the closed companies seem to be higher on average. Now let's calculate the average of the whole raised amount to see how much on average does a company need for operation.

# %%
d = {'status': ['operating', 'aquired', 'closed'], 'mean': [operatingtotal['raised_amount_usd'].mean(), acquiredtotal['raised_amount_usd'].mean(), closedtotal['raised_amount_usd'].mean()]}
statuses = pd.DataFrame(d)
statuses
# Out:
#       status          mean
# 0  operating  1.125185e+07
# 1    aquired  2.451532e+07
# 2     closed  8.636939e+06

# %% [markdown]
# We see now on the bar chart that the closed companies received the lowest amount of funding which can prove our intial hypothesis. The operating companies received more amount of funding compared to the closed companies while the acquired companies received much more which makes sense since the acquired companies mostly received those fundings either with debt until they got acquired so they recieved much more than either the closed or the operating.

# %%
plt.bar(statuses['status'], statuses['mean'])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# In Conclusion, not getting enough funding can critically affect the company's chance of success. This indicates that the companies must focus more on finding fundings and investments into their startups.

# %% [markdown]
# Regarding the second approach, we will look now at the closed companies that recieved more than one funding round:

# %%
closedcomp_rounds = closedcomp_rounds[closedcomp_rounds['funding_rounds'] > 1]

# %% [markdown]
# Now we will look at how frequent were the fundings for the  closed companies that received more than one round. We will ignore the negative signs and consider its absolute values as it might have one date came before the other or it might have been subtracted by 0 in case it received more than one funding on the same day. To solve the negatives problem we will perfom absolute function.

# %%
closedcomp_rounds = closedcomp_rounds.set_index('company_name').diff()
closedcomp_rounds = closedcomp_rounds.abs()
closedcomp_rounds = closedcomp_rounds.sort_values('funded_at')
closedcomp_rounds['funded_at'] = pd.to_numeric(closedcomp_rounds['funded_at'].dt.days, downcast='integer')
closedcomp_rounds[closedcomp_rounds['funded_at'] > 0]
# Out:
#                                  funding_rounds  raised_amount_usd  funded_at
# company_name
# Solvate                                     0.0                0.0        1.0
# Truckload USA                               0.0          4500000.0        1.0
# Zoe Majeste                                 0.0                0.0        2.0
# Nitinol Devices & Components                0.0                0.0        2.0
# Clarity Health Services                     1.0          6575000.0        3.0
# ...                                         ...                ...        ...
# Weemba                                      0.0        122600000.0     5003.0
# Campus Connectr                             0.0         49770000.0     5123.0
# YottaYotta                                  1.0         25000000.0     5525.0
# Open Environment Corporation                0.0        120408950.0     6210.0
# Cambridge Technology Group/KPMG             4.0         19500000.0     6695.0
#
# [3901 rows x 3 columns]

# %% [markdown]
# As seen below and in the ablove dataframe that the biggest gap between funding was (after 0) 5123 which seems to be a quite big gap on getting funding frequently in case of more than one round.

# %%
operatingcomp_rounds = operatingcomp_rounds[operatingcomp_rounds['funding_rounds'] > 1]

# %%
operatingcomp_rounds = operatingcomp_rounds.set_index('company_name').diff()
operatingcomp_rounds = operatingcomp_rounds.abs()
operatingcomp_rounds = operatingcomp_rounds.sort_values('funded_at')
operatingcomp_rounds['funded_at'] = pd.to_numeric(operatingcomp_rounds['funded_at'].dt.days, downcast='integer')
operatingcomp_rounds[operatingcomp_rounds['funded_at'] > 0]
# Out:
#                                 funding_rounds  raised_amount_usd  funded_at
# company_name
# Totango                                    1.0          3592500.0        1.0
# RevolutionCredit                           0.0            32475.0        1.0
# Eagle Genomics                             0.0           893998.0        1.0
# E-Health Records International             0.0                4.0        1.0
# ARTsys360                                  0.0            51202.0        1.0
# ...                                        ...                ...        ...
# Mtone Wireless                             4.0          3408086.0     6827.0
# SpamLion                                   0.0          2987500.0     6956.0
# Viewpoint Digital                          0.0         13000000.0     7037.0
# Advice Company                             0.0           475000.0     7289.0
# Viewpost                                   0.0         22470000.0     8580.0
#
# [55549 rows x 3 columns]

# %% [markdown]
# Seeing that the gap between frequent fundings either the operating companies or the closed ones, it seems either gaps are similar. so it may appear that the frequency of the funding is not as critical as for example the amount of the funing

# %% [markdown]
# In conclusion, frequent funding is can be considered but is not a critical factor in affecting the success of the company.

# %% [markdown]
# ## Second Question (Farah)

# %% [markdown]
# Regarding the Second Question:  <br>
# - 	Which regions (countries) are most probable to have the most failed startups?
#     -	For this: We are initially interested in <br> `country_code`, `status`, and `investor_name`

# %% [markdown]
# First we need to join the companies dataset with the investments dataset

# %%
companies.sort_values(by=['company_name'], inplace=True)
invests.sort_values(by=['company_name'],inplace=True)
comp_invests = companies.join(invests.set_index('company_name'), on='company_name',lsuffix='_left', rsuffix='_right')

# %%
comp_invests.T
# Out:
#                                                                          8387   \
# company_permalink_left                         /organization/bratpackstyle-llc
# company_name                                              #BratPackStyle, LLC.
# homepage_url                                      http://www.bratpackstyle.com
# company_category_list_left   Content Discovery|E-Commerce|Fashion|Lifestyle...
# funding_total_usd                                                          0.0
# status                                                                  closed
# company_country_code_left                                                  USA
# company_city_left                                                     New York
# funding_rounds                                                               1
# founded_at                                                 2015-04-19 00:00:00
# first_funding_at                                           2015-06-01 00:00:00
# last_funding_at                                            2015-06-01 00:00:00
# time_before_first_fund                                        43 days 00:00:00
# company_permalink_right                        /organization/bratpackstyle-llc
# company_category_list_right  Content Discovery|E-Commerce|Fashion|Lifestyle...
# company_country_code_right                                                 USA
# company_state_code                                                          NY
# company_city_right                                                    New York
# investor_permalink                                  /organization/nine-inc-llc
# investor_name                                                   Nine Inc. LLC.
# investor_country_code                                                  missing
# investor_state_code                                                    missing
# investor_city                                                          missing
# funding_round_permalink        /funding-round/7f52613bbda1edcaed3844d806d62757
# funding_round_type                                                        seed
# funding_round_code                                                         NaN
# funded_at                                                  2015-06-01 00:00:00
# raised_amount_usd                                              14939298.912426
# total_raised                                                               NaN
#
#                                                            24857  \
# company_permalink_left                     /organization/hashoff
# company_name                                            #HASHOFF
# homepage_url                              http://www.hashoff.com
# company_category_list_left   Digital Media|Internet|Social Media
# funding_total_usd                                       955000.0
# status                                                 operating
# company_country_code_left                                    USA
# company_city_left                                         Denver
# funding_rounds                                                 2
# founded_at                                   2014-04-01 00:00:00
# first_funding_at                             2014-12-08 00:00:00
# last_funding_at                              2015-08-11 00:00:00
# time_before_first_fund                         251 days 00:00:00
# company_permalink_right                                      NaN
# company_category_list_right                                  NaN
# company_country_code_right                                   NaN
# company_state_code                                           NaN
# company_city_right                                           NaN
# investor_permalink                                           NaN
# investor_name                                                NaN
# investor_country_code                                        NaN
# investor_state_code                                          NaN
# investor_city                                                NaN
# funding_round_permalink                                      NaN
# funding_round_type                                           NaN
# funding_round_code                                           NaN
# funded_at                                                    NaT
# raised_amount_usd                                            NaN
# total_raised                                                 NaN
#
#                                                      0      \
# company_permalink_left                 /organization/-fame
# company_name                                         #fame
# homepage_url                            http://livfame.com
# company_category_list_left                           Media
# funding_total_usd                               10000000.0
# status                                           operating
# company_country_code_left                              IND
# company_city_left                                   Mumbai
# funding_rounds                                           1
# founded_at                   2011-04-12 20:46:43.240577680
# first_funding_at                       2015-01-05 00:00:00
# last_funding_at                        2015-01-05 00:00:00
# time_before_first_fund        1363 days 03:13:16.759422320
# company_permalink_right                                NaN
# company_category_list_right                            NaN
# company_country_code_right                             NaN
# company_state_code                                     NaN
# company_city_right                                     NaN
# investor_permalink                                     NaN
# investor_name                                          NaN
# investor_country_code                                  NaN
# investor_state_code                                    NaN
# investor_city                                          NaN
# funding_round_permalink                                NaN
# funding_round_type                                     NaN
# funding_round_code                                     NaN
# funded_at                                              NaT
# raised_amount_usd                                      NaN
# total_raised                                           NaN
#
#                                                                        63213  \
# company_permalink_left                                 /organization/waywire
# company_name                                                        #waywire
# homepage_url                                          http://www.waywire.com
# company_category_list_left          Entertainment|News|Politics|Social Media
# funding_total_usd                                                  1750000.0
# status                                                              acquired
# company_country_code_left                                                USA
# company_city_left                                                   New York
# funding_rounds                                                             1
# founded_at                                               2012-06-01 00:00:00
# first_funding_at                                         2012-06-30 00:00:00
# last_funding_at                                          2012-06-30 00:00:00
# time_before_first_fund                                      29 days 00:00:00
# company_permalink_right                                /organization/waywire
# company_category_list_right         Entertainment|News|Politics|Social Media
# company_country_code_right                                               USA
# company_state_code                                                        NY
# company_city_right                                                  New York
# investor_permalink                                     /person/oprah-winfrey
# investor_name                                                  Oprah Winfrey
# investor_country_code                                                missing
# investor_state_code                                                  missing
# investor_city                                                        missing
# funding_round_permalink      /funding-round/cc409188fa2b63482bd9008f682c2efa
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2012-06-30 00:00:00
# raised_amount_usd                                                  1750000.0
# total_raised                                                       1750000.0
#
#                                                                        63213  \
# company_permalink_left                                 /organization/waywire
# company_name                                                        #waywire
# homepage_url                                          http://www.waywire.com
# company_category_list_left          Entertainment|News|Politics|Social Media
# funding_total_usd                                                  1750000.0
# status                                                              acquired
# company_country_code_left                                                USA
# company_city_left                                                   New York
# funding_rounds                                                             1
# founded_at                                               2012-06-01 00:00:00
# first_funding_at                                         2012-06-30 00:00:00
# last_funding_at                                          2012-06-30 00:00:00
# time_before_first_fund                                      29 days 00:00:00
# company_permalink_right                                /organization/waywire
# company_category_list_right         Entertainment|News|Politics|Social Media
# company_country_code_right                                               USA
# company_state_code                                                        NY
# company_city_right                                                  New York
# investor_permalink                        /organization/innovation-endeavors
# investor_name                                           Innovation Endeavors
# investor_country_code                                                    USA
# investor_state_code                                                       CA
# investor_city                                                      Palo Alto
# funding_round_permalink      /funding-round/cc409188fa2b63482bd9008f682c2efa
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2012-06-30 00:00:00
# raised_amount_usd                                                  1750000.0
# total_raised                                                       1750000.0
#
#                                                                        63213  \
# company_permalink_left                                 /organization/waywire
# company_name                                                        #waywire
# homepage_url                                          http://www.waywire.com
# company_category_list_left          Entertainment|News|Politics|Social Media
# funding_total_usd                                                  1750000.0
# status                                                              acquired
# company_country_code_left                                                USA
# company_city_left                                                   New York
# funding_rounds                                                             1
# founded_at                                               2012-06-01 00:00:00
# first_funding_at                                         2012-06-30 00:00:00
# last_funding_at                                          2012-06-30 00:00:00
# time_before_first_fund                                      29 days 00:00:00
# company_permalink_right                                /organization/waywire
# company_category_list_right         Entertainment|News|Politics|Social Media
# company_country_code_right                                               USA
# company_state_code                                                        NY
# company_city_right                                                  New York
# investor_permalink                         /organization/first-round-capital
# investor_name                                                    First Round
# investor_country_code                                                    USA
# investor_state_code                                                       CA
# investor_city                                                  San Francisco
# funding_round_permalink      /funding-round/cc409188fa2b63482bd9008f682c2efa
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2012-06-30 00:00:00
# raised_amount_usd                                                  1750000.0
# total_raised                                                       1750000.0
#
#                                                                        63213  \
# company_permalink_left                                 /organization/waywire
# company_name                                                        #waywire
# homepage_url                                          http://www.waywire.com
# company_category_list_left          Entertainment|News|Politics|Social Media
# funding_total_usd                                                  1750000.0
# status                                                              acquired
# company_country_code_left                                                USA
# company_city_left                                                   New York
# funding_rounds                                                             1
# founded_at                                               2012-06-01 00:00:00
# first_funding_at                                         2012-06-30 00:00:00
# last_funding_at                                          2012-06-30 00:00:00
# time_before_first_fund                                      29 days 00:00:00
# company_permalink_right                                /organization/waywire
# company_category_list_right         Entertainment|News|Politics|Social Media
# company_country_code_right                                               USA
# company_state_code                                                        NY
# company_city_right                                                  New York
# investor_permalink                                    /organization/afsquare
# investor_name                                                       AFSquare
# investor_country_code                                                    USA
# investor_state_code                                                       CA
# investor_city                                                    Culver City
# funding_round_permalink      /funding-round/cc409188fa2b63482bd9008f682c2efa
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2012-06-30 00:00:00
# raised_amount_usd                                                  1750000.0
# total_raised                                                       1750000.0
#
#                                                                        63213  \
# company_permalink_left                                 /organization/waywire
# company_name                                                        #waywire
# homepage_url                                          http://www.waywire.com
# company_category_list_left          Entertainment|News|Politics|Social Media
# funding_total_usd                                                  1750000.0
# status                                                              acquired
# company_country_code_left                                                USA
# company_city_left                                                   New York
# funding_rounds                                                             1
# founded_at                                               2012-06-01 00:00:00
# first_funding_at                                         2012-06-30 00:00:00
# last_funding_at                                          2012-06-30 00:00:00
# time_before_first_fund                                      29 days 00:00:00
# company_permalink_right                                /organization/waywire
# company_category_list_right         Entertainment|News|Politics|Social Media
# company_country_code_right                                               USA
# company_state_code                                                        NY
# company_city_right                                                  New York
# investor_permalink                                       /person/troy-carter
# investor_name                                                    Troy Carter
# investor_country_code                                                    USA
# investor_state_code                                                  missing
# investor_city                                                    Culver City
# funding_round_permalink      /funding-round/cc409188fa2b63482bd9008f682c2efa
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2012-06-30 00:00:00
# raised_amount_usd                                                  1750000.0
# total_raised                                                       1750000.0
#
#                                                                        63213  \
# company_permalink_left                                 /organization/waywire
# company_name                                                        #waywire
# homepage_url                                          http://www.waywire.com
# company_category_list_left          Entertainment|News|Politics|Social Media
# funding_total_usd                                                  1750000.0
# status                                                              acquired
# company_country_code_left                                                USA
# company_city_left                                                   New York
# funding_rounds                                                             1
# founded_at                                               2012-06-01 00:00:00
# first_funding_at                                         2012-06-30 00:00:00
# last_funding_at                                          2012-06-30 00:00:00
# time_before_first_fund                                      29 days 00:00:00
# company_permalink_right                                /organization/waywire
# company_category_list_right         Entertainment|News|Politics|Social Media
# company_country_code_right                                               USA
# company_state_code                                                        NY
# company_city_right                                                  New York
# investor_permalink                                       /person/jeff-weiner
# investor_name                                                    Jeff Weiner
# investor_country_code                                                    USA
# investor_state_code                                                  missing
# investor_city                                                  Mountain View
# funding_round_permalink      /funding-round/cc409188fa2b63482bd9008f682c2efa
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2012-06-30 00:00:00
# raised_amount_usd                                                  1750000.0
# total_raised                                                       1750000.0
#
#                                                        59910  ...  \
# company_permalink_left       /organization/tv-communications  ...
# company_name                              &TV Communications  ...
# homepage_url                           http://enjoyandtv.com  ...
# company_category_list_left                             Games  ...
# funding_total_usd                                  4000000.0  ...
# status                                             operating  ...
# company_country_code_left                                USA  ...
# company_city_left                                Los Angeles  ...
# funding_rounds                                             2  ...
# founded_at                     2006-09-09 20:46:43.240577680  ...
# first_funding_at                         2010-06-04 00:00:00  ...
# last_funding_at                          2010-09-23 00:00:00  ...
# time_before_first_fund          1363 days 03:13:16.759422320  ...
# company_permalink_right                                  NaN  ...
# company_category_list_right                              NaN  ...
# company_country_code_right                               NaN  ...
# company_state_code                                       NaN  ...
# company_city_right                                       NaN  ...
# investor_permalink                                       NaN  ...
# investor_name                                            NaN  ...
# investor_country_code                                    NaN  ...
# investor_state_code                                      NaN  ...
# investor_city                                            NaN  ...
# funding_round_permalink                                  NaN  ...
# funding_round_type                                       NaN  ...
# funding_round_code                                       NaN  ...
# funded_at                                                NaT  ...
# raised_amount_usd                                        NaN  ...
# total_raised                                             NaN  ...
#
#                                                                          66366  \
# company_permalink_left                                   /organization/Ôasys-2
# company_name                                                             Ôasys
# homepage_url                                              http://www.oasys.io/
# company_category_list_left   Consumer Electronics|Internet of Things|Teleco...
# funding_total_usd                                                      18192.0
# status                                                               operating
# company_country_code_left                                                  USA
# company_city_left                                                San Francisco
# funding_rounds                                                               1
# founded_at                                                 2014-01-01 00:00:00
# first_funding_at                                           2015-01-01 00:00:00
# last_funding_at                                            2015-01-01 00:00:00
# time_before_first_fund                                       365 days 00:00:00
# company_permalink_right                                  /organization/Ôasys-2
# company_category_list_right  Consumer Electronics|Internet of Things|Teleco...
# company_country_code_right                                                 USA
# company_state_code                                                          CA
# company_city_right                                               San Francisco
# investor_permalink                               /organization/startupbootcamp
# investor_name                                                  Startupbootcamp
# investor_country_code                                                      GBR
# investor_state_code                                                         H9
# investor_city                                                           London
# funding_round_permalink        /funding-round/35f09d0794651719b02bbfd859ba9ff5
# funding_round_type                                                        seed
# funding_round_code                                                         NaN
# funded_at                                                  2015-01-01 00:00:00
# raised_amount_usd                                                      18192.0
# total_raised                                                           18192.0
#
#                                                                        6454   \
# company_permalink_left                             /organization/berresearch
# company_name                                                    ÜberResearch
# homepage_url                                         http://uberresearch.com
# company_category_list_left                                       Curated Web
# funding_total_usd                                                        0.0
# status                                                             operating
# company_country_code_left                                                DEU
# company_city_left                                                    Cologne
# funding_rounds                                                             1
# founded_at                                               2013-01-01 00:00:00
# first_funding_at                                         2013-11-11 00:00:00
# last_funding_at                                          2013-11-11 00:00:00
# time_before_first_fund                                     314 days 00:00:00
# company_permalink_right                            /organization/berresearch
# company_category_list_right                                      Curated Web
# company_country_code_right                                               DEU
# company_state_code                                                         7
# company_city_right                                                   Cologne
# investor_permalink                             /organization/digital-science
# investor_name                                                Digital Science
# investor_country_code                                                    GBR
# investor_state_code                                                       H9
# investor_city                                                         London
# funding_round_permalink      /funding-round/79c551d8f3ef2035523910739d1bfbe9
# funding_round_type                                               undisclosed
# funding_round_code                                                       NaN
# funded_at                                                2013-11-11 00:00:00
# raised_amount_usd                                            14939298.912426
# total_raised                                                             NaN
#
#                                                                          66367  \
# company_permalink_left       /organization/İnovatiff-reklam-ve-tanıtım-hizm...
# company_name                        İnovatiff Reklam ve Tanıtım Hizmetleri Tic
# homepage_url                                              http://inovatiff.com
# company_category_list_left                  Consumer Goods|E-Commerce|Internet
# funding_total_usd                                                      14851.0
# status                                                               operating
# company_country_code_left                                              missing
# company_city_left                                                      missing
# funding_rounds                                                               1
# founded_at                                       2010-01-06 20:46:43.240577680
# first_funding_at                                           2013-10-01 00:00:00
# last_funding_at                                            2013-10-01 00:00:00
# time_before_first_fund                            1363 days 03:13:16.759422320
# company_permalink_right      /organization/İnovatiff-reklam-ve-tanıtım-hizm...
# company_category_list_right                 Consumer Goods|E-Commerce|Internet
# company_country_code_right                                             missing
# company_state_code                                                     missing
# company_city_right                                                     missing
# investor_permalink                                      /person/serkan-erdoğan
# investor_name                                                   Serkan Erdoğan
# investor_country_code                                                  missing
# investor_state_code                                                    missing
# investor_city                                                          missing
# funding_round_permalink        /funding-round/af942869878d2cd788ef5189b435ebc4
# funding_round_type                                                       grant
# funding_round_code                                                         NaN
# funded_at                                                  2013-10-01 00:00:00
# raised_amount_usd                                                      14851.0
# total_raised                                                           14851.0
#
#                                                                      31300  \
# company_permalink_left                    /organization/kutusu-video-ajans
# company_name                                        İş kutusu video ajansı
# homepage_url                                       http://www.iskutusu.com
# company_category_list_left   3D|Advertising|Online Video Advertising|Video
# funding_total_usd                                                 100000.0
# status                                                           operating
# company_country_code_left                                              TUR
# company_city_left                                                 Istanbul
# funding_rounds                                                           1
# founded_at                                             2013-01-01 00:00:00
# first_funding_at                                       2014-03-13 00:00:00
# last_funding_at                                        2014-03-13 00:00:00
# time_before_first_fund                                   436 days 00:00:00
# company_permalink_right                                                NaN
# company_category_list_right                                            NaN
# company_country_code_right                                             NaN
# company_state_code                                                     NaN
# company_city_right                                                     NaN
# investor_permalink                                                     NaN
# investor_name                                                          NaN
# investor_country_code                                                  NaN
# investor_state_code                                                    NaN
# investor_city                                                          NaN
# funding_round_permalink                                                NaN
# funding_round_type                                                     NaN
# funding_round_code                                                     NaN
# funded_at                                                              NaT
# raised_amount_usd                                                      NaN
# total_raised                                                           NaN
#
#                                                                          18356  \
# company_permalink_left                                      /organization/enso
# company_name                                                           Еnso.fm
# homepage_url                                                    http://enso.fm
# company_category_list_left   Algorithms|Casual Games|Content Discovery|Edis...
# funding_total_usd                                                  27838.40363
# status                                                               operating
# company_country_code_left                                                  BGR
# company_city_left                                                        Sofia
# funding_rounds                                                               1
# founded_at                                                 2015-06-29 00:00:00
# first_funding_at                                           2015-07-01 00:00:00
# last_funding_at                                            2015-07-01 00:00:00
# time_before_first_fund                                         2 days 00:00:00
# company_permalink_right                                     /organization/enso
# company_category_list_right  Algorithms|Casual Games|Content Discovery|Edis...
# company_country_code_right                                                 BGR
# company_state_code                                                          42
# company_city_right                                                       Sofia
# investor_permalink                                        /organization/eleven
# investor_name                                                           Eleven
# investor_country_code                                                      BGR
# investor_state_code                                                         42
# investor_city                                                            Sofia
# funding_round_permalink        /funding-round/53becfd9582cda62dcb2a6c9970810b3
# funding_round_type                                                        seed
# funding_round_code                                                         NaN
# funded_at                                                  2015-07-01 00:00:00
# raised_amount_usd                                                  27838.40363
# total_raised                                                       27838.40363
#
#                                                                          18356  \
# company_permalink_left                                      /organization/enso
# company_name                                                           Еnso.fm
# homepage_url                                                    http://enso.fm
# company_category_list_left   Algorithms|Casual Games|Content Discovery|Edis...
# funding_total_usd                                                  27838.40363
# status                                                               operating
# company_country_code_left                                                  BGR
# company_city_left                                                        Sofia
# funding_rounds                                                               1
# founded_at                                                 2015-06-29 00:00:00
# first_funding_at                                           2015-07-01 00:00:00
# last_funding_at                                            2015-07-01 00:00:00
# time_before_first_fund                                         2 days 00:00:00
# company_permalink_right                                     /organization/enso
# company_category_list_right  Algorithms|Casual Games|Content Discovery|Edis...
# company_country_code_right                                                 BGR
# company_state_code                                                          42
# company_city_right                                                       Sofia
# investor_permalink           /organization/axel-springer-plug-and-play-acce...
# investor_name                          Axel Springer Plug and Play Accelerator
# investor_country_code                                                      DEU
# investor_state_code                                                         16
# investor_city                                                           Berlin
# funding_round_permalink        /funding-round/53becfd9582cda62dcb2a6c9970810b3
# funding_round_type                                                        seed
# funding_round_code                                                         NaN
# funded_at                                                  2015-07-01 00:00:00
# raised_amount_usd                                                  27838.40363
# total_raised                                                       27838.40363
#
#                                                                         51461  \
# company_permalink_left                                    /organization/shwrm
# company_name                                                          ​Shwrüm
# homepage_url                                            http://www.shwrum.com
# company_category_list_left   Design|Fashion|Internet|Mobile|Shopping|Software
# funding_total_usd                                                     50000.0
# status                                                              operating
# company_country_code_left                                                 USA
# company_city_left                                                 Gainesville
# funding_rounds                                                              1
# founded_at                                                2013-01-01 00:00:00
# first_funding_at                                          2013-01-01 00:00:00
# last_funding_at                                           2013-01-01 00:00:00
# time_before_first_fund                                        0 days 00:00:00
# company_permalink_right                                                   NaN
# company_category_list_right                                               NaN
# company_country_code_right                                                NaN
# company_state_code                                                        NaN
# company_city_right                                                        NaN
# investor_permalink                                                        NaN
# investor_name                                                             NaN
# investor_country_code                                                     NaN
# investor_state_code                                                       NaN
# investor_city                                                             NaN
# funding_round_permalink                                                   NaN
# funding_round_type                                                        NaN
# funding_round_code                                                        NaN
# funded_at                                                                 NaT
# raised_amount_usd                                                         NaN
# total_raised                                                              NaN
#
#                                                      63626  \
# company_permalink_left                /organization/wested
# company_name                                       ​WestEd
# homepage_url                        http://www.wested.org/
# company_category_list_left                      Nonprofits
# funding_total_usd                                3000000.0
# status                                           operating
# company_country_code_left                              USA
# company_city_left                            San Francisco
# funding_rounds                                           1
# founded_at                   2010-10-27 20:46:43.240577680
# first_funding_at                       2014-07-22 00:00:00
# last_funding_at                        2014-07-22 00:00:00
# time_before_first_fund        1363 days 03:13:16.759422320
# company_permalink_right                                NaN
# company_category_list_right                            NaN
# company_country_code_right                             NaN
# company_state_code                                     NaN
# company_city_right                                     NaN
# investor_permalink                                     NaN
# investor_name                                          NaN
# investor_country_code                                  NaN
# investor_state_code                                    NaN
# investor_city                                          NaN
# funding_round_permalink                                NaN
# funding_round_type                                     NaN
# funding_round_code                                     NaN
# funded_at                                              NaT
# raised_amount_usd                                      NaN
# total_raised                                           NaN
#
#                                                                        10964  \
# company_permalink_left                               /organization/chishenma
# company_name                                                   吃神马 ChiShenMa
# homepage_url                                               http://chishen.ma
# company_category_list_left                Mobile|Restaurants|Specialty Foods
# funding_total_usd                                                        0.0
# status                                                             operating
# company_country_code_left                                                CHN
# company_city_left                                                   Shanghai
# funding_rounds                                                             1
# founded_at                                               2014-01-01 00:00:00
# first_funding_at                                         2014-02-28 00:00:00
# last_funding_at                                          2014-02-28 00:00:00
# time_before_first_fund                                      58 days 00:00:00
# company_permalink_right                              /organization/chishenma
# company_category_list_right               Mobile|Restaurants|Specialty Foods
# company_country_code_right                                               CHN
# company_state_code                                                        23
# company_city_right                                                  Shanghai
# investor_permalink                             /organization/chinaccelerator
# investor_name                                                Chinaccelerator
# investor_country_code                                                    CHN
# investor_state_code                                                       23
# investor_city                                                       Shanghai
# funding_round_permalink      /funding-round/aa4cde05f64453c60ca85a06a962f381
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2014-02-28 00:00:00
# raised_amount_usd                                            14939298.912426
# total_raised                                                             NaN
#
#                                                                        10964
# company_permalink_left                               /organization/chishenma
# company_name                                                   吃神马 ChiShenMa
# homepage_url                                               http://chishen.ma
# company_category_list_left                Mobile|Restaurants|Specialty Foods
# funding_total_usd                                                        0.0
# status                                                             operating
# company_country_code_left                                                CHN
# company_city_left                                                   Shanghai
# funding_rounds                                                             1
# founded_at                                               2014-01-01 00:00:00
# first_funding_at                                         2014-02-28 00:00:00
# last_funding_at                                          2014-02-28 00:00:00
# time_before_first_fund                                      58 days 00:00:00
# company_permalink_right                              /organization/chishenma
# company_category_list_right               Mobile|Restaurants|Specialty Foods
# company_country_code_right                                               CHN
# company_state_code                                                        23
# company_city_right                                                  Shanghai
# investor_permalink                                 /organization/sosventures
# investor_name                                                           SOSV
# investor_country_code                                                    USA
# investor_state_code                                                       NJ
# investor_city                                                      Princeton
# funding_round_permalink      /funding-round/aa4cde05f64453c60ca85a06a962f381
# funding_round_type                                                      seed
# funding_round_code                                                       NaN
# funded_at                                                2014-02-28 00:00:00
# raised_amount_usd                                            14939298.912426
# total_raised                                                             NaN
#
# [29 rows x 192146 columns]

# %% [markdown]
# Now, we will categorize the companies according to their status (oprating, closed, aquired)

# %%
closedcomp_invests = comp_invests[comp_invests['status'] == 'closed']
closedcomp_invests
# Out:
#                 company_permalink_left          company_name  \
# 8387   /organization/bratpackstyle-llc  #BratPackStyle, LLC.
# 11998       /organization/club-domains         .Club Domains
# 21459       /organization/fox-networks         .FOX Networks
# 12521         /organization/comdominio           .comDominio
# 34          /organization/10bestthings          10BestThings
# ...                                ...                   ...
# 64831              /organization/xkoto                 xkoto
# 65152             /organization/yes-no                yes.no
# 65291              /organization/yoone                 yoone
# 65293             /organization/yoonew                yoonew
# 66059  /organization/zipcodemailer-com     zipcodemailer.com
#
#                        homepage_url  \
# 8387   http://www.bratpackstyle.com
# 11998              http://nic.club/
# 21459         http://www.dotfox.com
# 12521  http://www.comdominio.com.br
# 34          http://10bestthings.com
# ...                             ...
# 64831          http://www.xkoto.com
# 65152                 http://yes.no
# 65291               http://yoone.de
# 65293         http://www.yoonew.com
# 66059  http://www.zipcodemailer.com
#
#                               company_category_list_left  funding_total_usd  \
# 8387   Content Discovery|E-Commerce|Fashion|Lifestyle...                0.0
# 11998                                           Software          7000000.0
# 21459                                        Advertising          4912393.0
# 12521                                           Internet                0.0
# 34                                           Curated Web            50000.0
# ...                                                  ...                ...
# 64831                                           Software         11035000.0
# 65152                           Q&A|Social Network Media          1000000.0
# 65291                                              Games           197597.0
# 65293                                        Curated Web          4000000.0
# 66059       Postal and Courier Services|Public Relations            15000.0
#
#        status company_country_code_left company_city_left  funding_rounds  \
# 8387   closed                       USA          New York               1
# 11998  closed                       USA      Oakland Park               1
# 21459  closed                   missing           missing               1
# 12521  closed                       BRA          Brazilia               1
# 34     closed                       USA         Cleveland               1
# ...       ...                       ...               ...             ...
# 64831  closed                       USA           Waltham               3
# 65152  closed                       ISR          Tel Aviv               1
# 65291  closed                       DEU         Bielefeld               1
# 65293  closed                       USA          New York               2
# 66059  closed                       USA            Peoria               1
#
#                          founded_at  ...          investor_name  \
# 8387  2015-04-19 00:00:00.000000000  ...         Nine Inc. LLC.
# 11998 2011-10-10 00:00:00.000000000  ...                    NaN
# 21459 2003-04-23 20:46:43.240577680  ...        Foresight Group
# 12521 2000-05-19 20:46:43.240577680  ...  Stratus Investimentos
# 34    2009-04-01 00:00:00.000000000  ...                    NaN
# ...                             ...  ...                    ...
# 64831 2005-01-01 00:00:00.000000000  ...     GrandBanks Capital
# 65152 2015-01-01 00:00:00.000000000  ...             Assaf Levy
# 65291 2010-11-03 00:00:00.000000000  ...                HackFwd
# 65293 2004-01-01 00:00:00.000000000  ...                    NaN
# 66059 2008-10-11 00:00:00.000000000  ...                    NaN
#
#       investor_country_code investor_state_code investor_city  \
# 8387                missing             missing       missing
# 11998                   NaN                 NaN           NaN
# 21459                   GBR                  H9        London
# 12521               missing             missing       missing
# 34                      NaN                 NaN           NaN
# ...                     ...                 ...           ...
# 64831                   USA                  MA     Wellesley
# 65152                   ISR             missing      Tel Aviv
# 65291                   DEU                   4       Hamburg
# 65293                   NaN                 NaN           NaN
# 66059                   NaN                 NaN           NaN
#
#                                funding_round_permalink funding_round_type  \
# 8387   /funding-round/7f52613bbda1edcaed3844d806d62757               seed
# 11998                                              NaN                NaN
# 21459  /funding-round/69a1536a6f4506538afd7aa7241ddbe1        undisclosed
# 12521  /funding-round/f39abc561eeeb14307837363e54d7e16            venture
# 34                                                 NaN                NaN
# ...                                                ...                ...
# 64831  /funding-round/b91008080714512f7c78656ed27238ab            venture
# 65152  /funding-round/e51932c2afebd10c5e8c08b94b57bcb7               seed
# 65291  /funding-round/9ee9e539e722753d4fb6b03e7800fb8a               seed
# 65293                                              NaN                NaN
# 66059                                              NaN                NaN
#
#       funding_round_code  funded_at raised_amount_usd total_raised
# 8387                 NaN 2015-06-01      1.493930e+07          NaN
# 11998                NaN        NaT               NaN          NaN
# 21459                NaN 2007-01-16      4.912393e+06    4912393.0
# 12521                NaN 2004-02-12      1.493930e+07          NaN
# 34                   NaN        NaT               NaN          NaN
# ...                  ...        ...               ...          ...
# 64831                  C 2009-01-26      3.000000e+06    4307000.0
# 65152                NaN 2015-05-01      1.000000e+06    1000000.0
# 65291                NaN 2010-11-03      1.975970e+05     197597.0
# 65293                NaN        NaT               NaN          NaN
# 66059                NaN        NaT               NaN          NaN
#
# [13557 rows x 29 columns]

# %% [markdown]
# We will group by the country to see the number of companies (of each status) in each country to gain insight if there's a massive difference between the number of operating companies and closed ones in a single country.

# %%
closedcomptotal = pd.DataFrame(closedcomp_invests.groupby(['company_country_code_left'])['company_name'].count())
closedcomptotal.drop('missing',inplace=True)
closedcomptotal.sort_values('company_name', ascending=False)
# Out:
#                            company_name
# company_country_code_left
# USA                                7956
# GBR                                 567
# CAN                                 370
# RUS                                 252
# FRA                                 199
# ...                                 ...
# PRI                                   1
# DOM                                   1
# GHA                                   1
# GTM                                   1
# LKA                                   1
#
# [95 rows x 1 columns]

# %% [markdown]
# Here's a heatmap that illustrates the previous dataframe. It shows us clearly that the US has the most closed companies while others have less.

# %%
sns.heatmap(closedcomptotal, vmin=1, vmax=7956);

# %% [markdown]
# Let's take a look on the number of investors in each country and see if it affects the number of closed companies.

# %%
investtotal = pd.DataFrame(closedcomp_invests.groupby(['investor_country_code'])['investor_name'].count())
investtotal.drop('missing',inplace=True)
investtotal.sort_values('investor_name', ascending=False)
# Out:
#                        investor_name
# investor_country_code
# USA                             6521
# GBR                              606
# CAN                              246
# DEU                              199
# FRA                              186
# ...                              ...
# PER                                1
# ISL                                1
# KEN                                1
# VEN                                1
# JEY                                1
#
# [71 rows x 1 columns]

# %% [markdown]
# Here we see that the US has most investors. Generally we can't determine if those number of investors are low or not untill we come up with the number of investors who invested in the operating companies then we can compare.

# %%
sns.heatmap(investtotal, vmin=1, vmax=6521)
# Out:
# <AxesSubplot:ylabel='investor_country_code'>

# %% [markdown]
# Now we categorize the operating companies

# %%
operatingcomp_invests = comp_invests[comp_invests['status'] == 'operating']
operatingcomp_invests
# Out:
#                 company_permalink_left        company_name  \
# 24857            /organization/hashoff            #HASHOFF
# 0                  /organization/-fame               #fame
# 59910  /organization/tv-communications  &TV Communications
# 48690    /organization/rock-your-paper   'Rock' Your Paper
# 48690    /organization/rock-your-paper   'Rock' Your Paper
# ...                                ...                 ...
# 18356               /organization/enso             Еnso.fm
# 51461              /organization/shwrm             ​Shwrüm
# 63626             /organization/wested             ​WestEd
# 10964          /organization/chishenma       吃神马 ChiShenMa
# 10964          /organization/chishenma       吃神马 ChiShenMa
#
#                        homepage_url  \
# 24857        http://www.hashoff.com
# 0                http://livfame.com
# 59910         http://enjoyandtv.com
# 48690  http://www.rockyourpaper.org
# 48690  http://www.rockyourpaper.org
# ...                             ...
# 18356                http://enso.fm
# 51461         http://www.shwrum.com
# 63626        http://www.wested.org/
# 10964             http://chishen.ma
# 10964             http://chishen.ma
#
#                               company_category_list_left  funding_total_usd  \
# 24857                Digital Media|Internet|Social Media       9.550000e+05
# 0                                                  Media       1.000000e+07
# 59910                                              Games       4.000000e+06
# 48690                               Education|Publishing       6.038500e+04
# 48690                               Education|Publishing       6.038500e+04
# ...                                                  ...                ...
# 18356  Algorithms|Casual Games|Content Discovery|Edis...       2.783840e+04
# 51461   Design|Fashion|Internet|Mobile|Shopping|Software       5.000000e+04
# 63626                                         Nonprofits       3.000000e+06
# 10964                 Mobile|Restaurants|Specialty Foods       0.000000e+00
# 10964                 Mobile|Restaurants|Specialty Foods       0.000000e+00
#
#           status company_country_code_left company_city_left  funding_rounds  \
# 24857  operating                       USA            Denver               2
# 0      operating                       IND            Mumbai               1
# 59910  operating                       USA       Los Angeles               2
# 48690  operating                       EST           Tallinn               2
# 48690  operating                       EST           Tallinn               2
# ...          ...                       ...               ...             ...
# 18356  operating                       BGR             Sofia               1
# 51461  operating                       USA       Gainesville               1
# 63626  operating                       USA     San Francisco               1
# 10964  operating                       CHN          Shanghai               1
# 10964  operating                       CHN          Shanghai               1
#
#                          founded_at  ...  \
# 24857 2014-04-01 00:00:00.000000000  ...
# 0     2011-04-12 20:46:43.240577680  ...
# 59910 2006-09-09 20:46:43.240577680  ...
# 48690 2012-10-26 00:00:00.000000000  ...
# 48690 2012-10-26 00:00:00.000000000  ...
# ...                             ...  ...
# 18356 2015-06-29 00:00:00.000000000  ...
# 51461 2013-01-01 00:00:00.000000000  ...
# 63626 2010-10-27 20:46:43.240577680  ...
# 10964 2014-01-01 00:00:00.000000000  ...
# 10964 2014-01-01 00:00:00.000000000  ...
#
#                                  investor_name investor_country_code  \
# 24857                                      NaN                   NaN
# 0                                          NaN                   NaN
# 59910                                      NaN                   NaN
# 48690                        Startup Wise Guys                   EST
# 48690                           Start-Up Chile                   CHL
# ...                                        ...                   ...
# 18356  Axel Springer Plug and Play Accelerator                   DEU
# 51461                                      NaN                   NaN
# 63626                                      NaN                   NaN
# 10964                          Chinaccelerator                   CHN
# 10964                                     SOSV                   USA
#
#       investor_state_code investor_city  \
# 24857                 NaN           NaN
# 0                     NaN           NaN
# 59910                 NaN           NaN
# 48690                   1       Tallinn
# 48690                  12      Santiago
# ...                   ...           ...
# 18356                  16        Berlin
# 51461                 NaN           NaN
# 63626                 NaN           NaN
# 10964                  23      Shanghai
# 10964                  NJ     Princeton
#
#                                funding_round_permalink funding_round_type  \
# 24857                                              NaN                NaN
# 0                                                  NaN                NaN
# 59910                                              NaN                NaN
# 48690  /funding-round/f28a7e530f9e4b29783d2c0aa4c68c62               seed
# 48690  /funding-round/f06b420775f7cb6c1541a9db526534bb               seed
# ...                                                ...                ...
# 18356  /funding-round/53becfd9582cda62dcb2a6c9970810b3               seed
# 51461                                              NaN                NaN
# 63626                                              NaN                NaN
# 10964  /funding-round/aa4cde05f64453c60ca85a06a962f381               seed
# 10964  /funding-round/aa4cde05f64453c60ca85a06a962f381               seed
#
#       funding_round_code  funded_at raised_amount_usd total_raised
# 24857                NaN        NaT               NaN          NaN
# 0                    NaN        NaT               NaN          NaN
# 59910                NaN        NaT               NaN          NaN
# 48690                NaN 2013-12-01      2.038500e+04  30192.50000
# 48690                NaN 2012-08-09      4.000000e+04  30192.50000
# ...                  ...        ...               ...          ...
# 18356                NaN 2015-07-01      2.783840e+04  27838.40363
# 51461                NaN        NaT               NaN          NaN
# 63626                NaN        NaT               NaN          NaN
# 10964                NaN 2014-02-28      1.493930e+07          NaN
# 10964                NaN 2014-02-28      1.493930e+07          NaN
#
# [144118 rows x 29 columns]

# %% [markdown]
# We will group by the country and see how many operating companies in each country.

# %%
operatingtotal = pd.DataFrame(operatingcomp_invests.groupby(['company_country_code_left'])['company_name'].count())
operatingtotal.drop('missing',inplace=True)
operatingtotal.sort_values('company_name', ascending=False)
# Out:
#                            company_name
# company_country_code_left
# USA                               92228
# GBR                                7846
# CAN                                3648
# IND                                3393
# CHN                                3325
# ...                                 ...
# SEN                                   1
# ROU                                   1
# QAT                                   1
# MSR                                   1
# AND                                   1
#
# [145 rows x 1 columns]

# %% [markdown]
# The heatmap yet again shows that the US has the most operating companies which seems noticable because it also had the most closed companies.

# %%
sns.heatmap(operatingtotal, vmin=1, vmax=92228)
# Out:
# <AxesSubplot:ylabel='company_country_code_left'>

# %% [markdown]
# As seen below, if we compare the number of investors that invested in operating companies around the world compared to who invested in closed companies we will find that the difference is huge and much more investors invested in those companies. This shows us that the lack of investors for the closed companies in their countries significantly affected the fate of the startup.

# %%
investtotal = pd.DataFrame(operatingcomp_invests.groupby(['investor_country_code'])['investor_name'].count())
investtotal.drop('missing',inplace=True)
investtotal.sort_values('investor_name', ascending=False)
# Out:
#                        investor_name
# investor_country_code
# USA                            67607
# GBR                             6018
# DEU                             2513
# FRA                             2355
# CHN                             2270
# ...                              ...
# TGO                                1
# TAN                                1
# MCO                                1
# MMR                                1
# BGD                                1
#
# [94 rows x 1 columns]

# %%
sns.heatmap(investtotal, vmin=1, vmax=67607)
# Out:
# <AxesSubplot:ylabel='investor_country_code'>

# %% [markdown]
# After looking in the closed and operating companies we see that we still can't determine if the country has more operting companies than the closed or not, so let's take one country and compare. For example, let's look at the USA since it has the highest number of operating companies, closed companies and investors.

# %%
df = comp_invests.loc[comp_invests['company_country_code_left'] == 'USA']
df = pd.DataFrame(df.groupby(['status'])['status'].count())
df
# Out:
#            status
# status
# acquired    22485
# closed       7956
# ipo          5302
# operating   92228

# %% [markdown]
# The dataframe above shows us how although the US has strong economics and massive amount of investor as seen earlier, it has a bulk of closed companies but compared to operting it's only 0.08 (7956/92228) of it. So, this reflects that due to the availability of investors and facilities it can be a great factor for companies to keep operating.

# %% [markdown]
# If we quickly look at another example and that is the country after the US which is The United Kingdom (GBR) it had 567 closed company with 606 investor in those closed companies and 7846 operating company with 6018 investor in those companies. Ofcourse, since the US is much bigger the number are biggr but we will look at the ratio between the closed and operating companies to find it 0.07. SIgnificantly it is closed to the US and we can consider that both countries have the same facilities and both show that the lack of investors can affect the companies.

# %% [markdown]
# ## Rest of Questions (Aisha)

# %% [markdown]
# Heads-up:
# 1) Here I didn't use the cleaned dataset version, as we can infer some insights from the null values
# 2)Some of the data could have been better if they were represented in charts but due to their data types it wasn't really possible and some of the others with favorable data types had labelling merging with one another making it impossible to read.

# %% [markdown]
# ### Question 3 : Analyzing Funding Rounds

# %% [markdown]
# We'll check the number of times funding is repeated overall irrespective of the differenece in company status and then we will see the company statuses.

# %% [markdown]
# #### Companies data set

# %%
import pandas as pd
df=pd.read_csv('companies.csv')
df.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list funding_total_usd  \
# 0                                              Media          10000000
# 1  Application Platforms|Real Time|Social Network...            700000
# 2                                  Apps|Games|Mobile           3406878
# 3                                        Curated Web           2000000
# 4                                           Software                 -
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN                    NaN            NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
#
#    funding_rounds  founded_at first_funding_at last_funding_at
# 0               1         NaN       2015-01-05      2015-01-05
# 1               2  2014-09-04       2014-03-01      2014-10-14
# 2               1         NaN       2014-01-30      2014-01-30
# 3               1  2007-01-01       2008-03-19      2008-03-19
# 4               1  2010-01-01       2014-07-24      2014-07-24

# %%
df.drop(['state_code', 'region'],axis=1,inplace=True)
df['first_funding_at']=df['first_funding_at'].fillna("not available")
df.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list funding_total_usd  \
# 0                                              Media          10000000
# 1  Application Platforms|Real Time|Social Network...            700000
# 2                                  Apps|Games|Mobile           3406878
# 3                                        Curated Web           2000000
# 4                                           Software                 -
#
#       status country_code           city  funding_rounds  founded_at  \
# 0  operating          IND         Mumbai               1         NaN
# 1  operating          USA  Delaware City               2  2014-09-04
# 2  operating          NaN            NaN               1         NaN
# 3  operating          CHN        Beijing               1  2007-01-01
# 4  operating          USA      Champaign               1  2010-01-01
#
#   first_funding_at last_funding_at
# 0       2015-01-05      2015-01-05
# 1       2014-03-01      2014-10-14
# 2       2014-01-30      2014-01-30
# 3       2008-03-19      2008-03-19
# 4       2014-07-24      2014-07-24

# %%
import matplotlib.pyplot as plt
df.status.hist()
plt.title('status difference')
# Out:
# Text(0.5, 1.0, 'status difference')

# %% [markdown]
# As the histogram above shows, we have more companies operating as compared to acquired ones which would imply that they received far more funding and produced more than those which were acquired.

# %% [markdown]
# #### IPO companies?

# %% [markdown]
# It's a situation in which one starts a business by soliciting capital from family, friends, and investors in exchange for a portion of the company. We go to an investor bank and inform them about the idea or product to raise money for this company. They will then introduce us to institutional investors / people who are interested in this idea or product, and they will sell some of the business's shares to assist in bringing the company to the public market. This helps raise a lot of money, sell shares at a reasonable price that suits the shareholder, raise more money through additional rounds of investment, and promote the brand because IPOs deliver a good credibility boost.
# The disadvantages include:
# When it comes to matters like openness, the SEC (Securities and Exchange Commission is the US federal agency in charge of regulating and managing financial markets) and exchanges have stringent criteria. As a result, public firms are required to reveal a great deal of business-related information, which may result in competitors obtaining access to material that is the company's trade secret.
# Less control as shareholders will now affect decision making.

# %% [markdown]
# We'll now separate companies in to 3 status categories; operating, acquired, and ipo. Then we'll compare the funding rounds based on these statuses.

# %%
operating=df.loc[df['status']=='operating']
acquired=df.loc[df['status']=='acquired']
ipo=df.loc[df['status']=='ipo']

# %% [markdown]
# #### 1-Operating companies

# %%
import matplotlib.pyplot as plt
operating.funding_rounds.value_counts().plot(kind="bar",alpha=0.5)
plt.title('Funding rounds')
plt.xlabel('funding')
plt.ylabel('funding frequency') 
plt.show()

# %% [markdown]
# The above curve can be matched to the values below and we can deduce that operating companies get more one time funding rounds that two.

# %%
operating['funding_rounds'].value_counts()
# Out:
# 1     34367
# 2      9871
# 3      4366
# 4      2066
# 5      1119
# 6       554
# 7       312
# 8       150
# 9        91
# 10       55
# 11       31
# 12       24
# 13       11
# 16        5
# 14        4
# 15        3
# 17        2
# 18        2
# 19        1
# Name: funding_rounds, dtype: int64

# %% [markdown]
# Now we will see how this differs from acquired companies.

# %% [markdown]
# #### 2-Acquired companies

# %%
#acquired companies

plt.title('funding rounds for aqcuired companies')
acquired.funding_rounds.value_counts().plot(kind="bar",alpha=0.5)
plt.title('Funding rounds')
plt.xlabel('funding')
plt.ylabel('funding frequency') 
plt.show()

# %% [markdown]
# This can be confirmed and further understood with the values below.

# %%
acquired['funding_rounds'].value_counts()

# %% [markdown]
# As we can see, both operating and acquired companies get more one time funding rounds than 2 with operating companies having by far the largest fundings. For IPO companies is illustrated below.

# %% [markdown]
# #### 3-IPO companies

# %%
#ipo companies
import matplotlib.pyplot as plt

plt.title('funding rounds for IPO companies')
ipo.funding_rounds.value_counts().plot(kind="bar",alpha=0.5)
plt.title('Funding rounds')
plt.xlabel('funding')
plt.ylabel('funding frequency') 
plt.show()

# %%
ipo['funding_rounds'].value_counts()
# Out:
# 1     646
# 2     277
# 3     192
# 4     137
# 5     100
# 6      72
# 7      39
# 8      36
# 9      18
# 10     10
# 11      9
# 13      4
# 12      3
# 15      2
# 16      1
# 14      1
# Name: funding_rounds, dtype: int64

# %% [markdown]
# We can conclude that operating companies exceed in founding rounds but all have higher one time fundings.

# %% [markdown]
# #### Investments data set part

# %%
d=pd.read_csv('investments.csv')
d.head()
# Out:
#                   company_permalink        company_name company_category_list  \
# 0             /organization/0-6-com             0-6.com           Curated Web
# 1    /organization/004-technologies    004 Technologies              Software
# 2  /organization/01games-technology  01Games Technology                 Games
# 3              /organization/0xdata              H2O.ai             Analytics
# 4              /organization/0xdata              H2O.ai             Analytics
#
#   company_country_code company_state_code         company_region  \
# 0                  CHN                 22                Beijing
# 1                  USA                 IL  Springfield, Illinois
# 2                  HKG                NaN              Hong Kong
# 3                  USA                 CA            SF Bay Area
# 4                  USA                 CA            SF Bay Area
#
#     company_city                    investor_permalink  \
# 0        Beijing     /organization/dt-capital-partners
# 1      Champaign       /organization/venturecapital-de
# 2      Hong Kong     /organization/cyberport-hong-kong
# 3  Mountain View             /organization/capital-one
# 4  Mountain View  /organization/nexus-venture-partners
#
#             investor_name investor_country_code investor_state_code  \
# 0     DT Capital Partners                   CHN                  23
# 1   VCDE Venture Partners                   DEU                   5
# 2     Cyberport Hong Kong                   HKG                 NaN
# 3             Capital One                   USA                  VA
# 4  Nexus Venture Partners                   USA                  CA
#
#     investor_region investor_city  \
# 0          Shanghai      Shanghai
# 1         Frankfurt     Frankfurt
# 2         Hong Kong     Hong Kong
# 3  Washington, D.C.        Mclean
# 4       SF Bay Area    Menlo Park
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 1  /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830            venture
# 2  /funding-round/7d53696f2b4f607a2f2a8cbb83d01839        undisclosed
# 3  /funding-round/3bb2ee4a2d89251a10aaa735b1180e44            venture
# 4  /funding-round/383a9bd2c04f7038bb543ccef5ba3eae               seed
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  A  2008-03-19          2000000.0
# 1                NaN  2014-07-24                NaN
# 2                NaN  2014-07-01            41250.0
# 3                  B  2015-11-09         20000000.0
# 4                NaN  2013-05-22          3000000.0

# %%
d.drop([ 'company_state_code','company_region','investor_state_code','investor_region'],axis=1,inplace=True)
d['raised_amount_usd']=d['raised_amount_usd'].fillna("not available")
d['funding_round_code']=d['funding_round_code'].fillna("not available")
d['company_country_code']=d['company_country_code'].fillna("not provided")
d['investor_country_code']=d['investor_country_code'].fillna("not provided")
d.head()
# Out:
#                   company_permalink        company_name company_category_list  \
# 0             /organization/0-6-com             0-6.com           Curated Web
# 1    /organization/004-technologies    004 Technologies              Software
# 2  /organization/01games-technology  01Games Technology                 Games
# 3              /organization/0xdata              H2O.ai             Analytics
# 4              /organization/0xdata              H2O.ai             Analytics
#
#   company_country_code   company_city                    investor_permalink  \
# 0                  CHN        Beijing     /organization/dt-capital-partners
# 1                  USA      Champaign       /organization/venturecapital-de
# 2                  HKG      Hong Kong     /organization/cyberport-hong-kong
# 3                  USA  Mountain View             /organization/capital-one
# 4                  USA  Mountain View  /organization/nexus-venture-partners
#
#             investor_name investor_country_code investor_city  \
# 0     DT Capital Partners                   CHN      Shanghai
# 1   VCDE Venture Partners                   DEU     Frankfurt
# 2     Cyberport Hong Kong                   HKG     Hong Kong
# 3             Capital One                   USA        Mclean
# 4  Nexus Venture Partners                   USA    Menlo Park
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 1  /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830            venture
# 2  /funding-round/7d53696f2b4f607a2f2a8cbb83d01839        undisclosed
# 3  /funding-round/3bb2ee4a2d89251a10aaa735b1180e44            venture
# 4  /funding-round/383a9bd2c04f7038bb543ccef5ba3eae               seed
#
#   funding_round_code   funded_at raised_amount_usd
# 0                  A  2008-03-19         2000000.0
# 1      not available  2014-07-24     not available
# 2      not available  2014-07-01           41250.0
# 3                  B  2015-11-09        20000000.0
# 4      not available  2013-05-22         3000000.0

# %%
d.drop_duplicates(subset=['company_country_code'])
d.drop_duplicates(subset=['investor_country_code'])
d.head()
# Out:
#                   company_permalink        company_name company_category_list  \
# 0             /organization/0-6-com             0-6.com           Curated Web
# 1    /organization/004-technologies    004 Technologies              Software
# 2  /organization/01games-technology  01Games Technology                 Games
# 3              /organization/0xdata              H2O.ai             Analytics
# 4              /organization/0xdata              H2O.ai             Analytics
#
#   company_country_code   company_city                    investor_permalink  \
# 0                  CHN        Beijing     /organization/dt-capital-partners
# 1                  USA      Champaign       /organization/venturecapital-de
# 2                  HKG      Hong Kong     /organization/cyberport-hong-kong
# 3                  USA  Mountain View             /organization/capital-one
# 4                  USA  Mountain View  /organization/nexus-venture-partners
#
#             investor_name investor_country_code investor_city  \
# 0     DT Capital Partners                   CHN      Shanghai
# 1   VCDE Venture Partners                   DEU     Frankfurt
# 2     Cyberport Hong Kong                   HKG     Hong Kong
# 3             Capital One                   USA        Mclean
# 4  Nexus Venture Partners                   USA    Menlo Park
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 1  /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830            venture
# 2  /funding-round/7d53696f2b4f607a2f2a8cbb83d01839        undisclosed
# 3  /funding-round/3bb2ee4a2d89251a10aaa735b1180e44            venture
# 4  /funding-round/383a9bd2c04f7038bb543ccef5ba3eae               seed
#
#   funding_round_code   funded_at raised_amount_usd
# 0                  A  2008-03-19         2000000.0
# 1      not available  2014-07-24     not available
# 2      not available  2014-07-01           41250.0
# 3                  B  2015-11-09        20000000.0
# 4      not available  2013-05-22         3000000.0

# %% [markdown]
# #### Question 4: How many investors do we have in different countries and which country dominates?

# %% [markdown]
# We will do this by checking the amount of times country codes repeat in the investor tables and the company country location names which could tell a little more about the country's financial and business status.

# %%
d.investor_country_code.value_counts()
# Out:
# USA             96341
# not provided    30939
# GBR              7616
# DEU              3256
# FRA              3007
#                 ...
# TTO                 1
# MAR                 1
# IRN                 1
# BAH                 1
# GIB                 1
# Name: investor_country_code, Length: 99, dtype: int64

# %%
d.company_country_code.value_counts()
# Out:
# USA             112283
# not provided     10521
# GBR               8579
# CAN               4009
# CHN               3778
#                  ...
# NPL                  1
# MDA                  1
# ALB                  1
# GGY                  1
# MCO                  1
# Name: company_country_code, Length: 126, dtype: int64

# %% [markdown]
# The above data shows that we have more investors in the USA and companies receiving investments as compared to other countries.
# We can deduce that this country has a better financial and business status as compared to the rest making it appear like pool of gain for investors.

# %% [markdown]
# #### Which investor dominates the market?

# %%
d['investor_name'].value_counts()
# Out:
# Sequoia Capital               1033
# Wayra                          936
# 500 Startups                   932
# New Enterprise Associates      902
# Intel Capital                  861
#                               ...
# Shazad Mohammed                  1
# Rick Gibson                      1
# Smurfit Family Investments       1
# Naren Nachiappan                 1
# Serkan Erdoğan                   1
# Name: investor_name, Length: 30189, dtype: int64

# %% [markdown]
# As we can see, Sequoia Capital dominates the market. Wayra and 500 Startups seem to be quit close in count from which we could deduce that they are competitors just like the rest of the companies in the list but the fact that their count have a 4 point gap could mean that they follow up on one another.

# %% [markdown]
# #### Question 5: Which company is most famous amongst investors?

# %%
d['company_name'].value_counts()
# Out:
# Uber                                          64
# DocuSign                                      61
# Fab                                           61
# Pinterest                                     60
# Mattermark                                    59
#                                               ..
# Kirondo                                        1
# Kiras Kiss                                     1
# Kipu Systems                                   1
# Kippt                                          1
# İnovatiff Reklam ve Tanıtım Hizmetleri Tic     1
# Name: company_name, Length: 44578, dtype: int64

# %% [markdown]
# The above data shows that the Uber company dominates the market with DocuSign and Fab having the same count which may infere that one is as trust worth as the other. The fact Uber is at the top of the list also tells us that this company has a lot of credibility in the eyes of investors.

# %% [markdown]
# #### Question 6: What about these company's specialization as compared to investment?Which category (field) attracts more funding?

# %% [markdown]
#  We will check the category list for both companies and investments dataframes.

# %%
#companies
df = df[df.category_list!= 'NaN']
df.category_list.value_counts()
# Out:
# Software                                                                       3995
# Biotechnology                                                                  3615
# E-Commerce                                                                     1332
# Mobile                                                                         1177
# Clean Technology                                                               1133
#                                                                                ...
# Consumer Internet|Marketplaces|Mobile|Mobile Payments|Transportation|Travel       1
# Apps|Mobile|Private Social Networking                                             1
# Cloud Computing|Enterprise Software|Infrastructure|PaaS|Social Media              1
# Content|SaaS|Social Media Marketing|Software                                      1
# Consumer Goods|E-Commerce|Internet                                                1
# Name: category_list, Length: 27296, dtype: int64

# %%
#investments
d = d[d.company_category_list!= 'NaN']
d.company_category_list.value_counts()

# %% [markdown]
# As we can see, although biotechnology is more ofinterest to investors, companies seem to have more interest in software which could be due to expensive and delicate nature of biotechnology.

# %% [markdown]
# #### Question 7: Are most of the investors also acquirers?

# %%
p=pd.read_csv("acquisitions.csv")
p.head()
# Out:
#                                    company_permalink  \
# 0                               /organization/003-ru
# 1                      /organization/0958572-b-c-ltd
# 2                 /organization/1-800-communications
# 3                       /organization/1-800-contacts
# 4  /organization/1-844-446-4460-pogo-customer-ser...
#
#                                         company_name  \
# 0                                             003.RU
# 1                                  0958572 B.C. Ltd.
# 2                               1-800 Communications
# 3                                     1-800 Contacts
# 4  Games Support +1-800-311-5934 Pogo Games techn...
#
#                        company_category_list company_country_code  \
# 0  Consumer Electronics|Electronics|Internet                  RUS
# 1                                        NaN                  NaN
# 2                                        NaN                  USA
# 3                      Consumer Goods|Retail                  USA
# 4                                        NaN                  NaN
#
#   company_state_code  company_region company_city  \
# 0                 48          Moscow       Moscow
# 1                NaN             NaN          NaN
# 2                 NY     Long Island   Hicksville
# 3                 UT  Salt Lake City       Draper
# 4                NaN             NaN          NaN
#
#                                   acquirer_permalink  \
# 0                         /organization/media-saturn
# 1  /organization/atlas-intellectual-property-mana...
# 2                       /organization/carsdirect-com
# 3                /organization/thomas-h-lee-partners
# 4  /organization/pogo-customer-service-number-1-8...
#
#                                        acquirer_name  \
# 0                                       Media Saturn
# 1         ATLAS Intellectual Property Management Co.
# 2                                     CarsDirect.com
# 3                             Thomas H. Lee Partners
# 4  Games Support +1-800-311-5934 Pogo Games techn...
#
#                               acquirer_category_list acquirer_country_code  \
# 0      Enterprise Software|Media|Sales and Marketing                   ESP
# 1          Finance|FinTech|Mobile|Telecommunications                   USA
# 2                                         E-Commerce                   USA
# 3  Business Development|Impact Investing|Investme...                   USA
# 4                                                NaN                   USA
#
#   acquirer_state_code acquirer_region acquirer_city acquired_at  \
# 0                  56       Barcelona     Barcelona  2012-07-23
# 1                  WA         Seattle       Seattle  2012-02-02
# 2                  CA     Los Angeles    El Segundo  2005-06-12
# 3                  MA          Boston        Boston  2014-01-07
# 4                  NY   New York City    Mamaroneck  2001-02-02
#
#   acquired_month  price_amount price_currency_code
# 0        2012-07           NaN                 USD
# 1        2012-02     9000000.0                 USD
# 2        2005-06           NaN                 USD
# 3        2014-01           NaN                 USD
# 4        2001-02           NaN                 USD

# %%
p.drop(['company_state_code', 'company_region','acquirer_state_code','acquirer_region'],axis=1,inplace=True)
p['company_category_list']=p['company_category_list'].fillna("not provided")
p['company_country_code']=p['company_country_code'].fillna("not provided")


p.head()
# Out:
#                                    company_permalink  \
# 0                               /organization/003-ru
# 1                      /organization/0958572-b-c-ltd
# 2                 /organization/1-800-communications
# 3                       /organization/1-800-contacts
# 4  /organization/1-844-446-4460-pogo-customer-ser...
#
#                                         company_name  \
# 0                                             003.RU
# 1                                  0958572 B.C. Ltd.
# 2                               1-800 Communications
# 3                                     1-800 Contacts
# 4  Games Support +1-800-311-5934 Pogo Games techn...
#
#                        company_category_list company_country_code  \
# 0  Consumer Electronics|Electronics|Internet                  RUS
# 1                               not provided         not provided
# 2                               not provided                  USA
# 3                      Consumer Goods|Retail                  USA
# 4                               not provided         not provided
#
#   company_city                                 acquirer_permalink  \
# 0       Moscow                         /organization/media-saturn
# 1          NaN  /organization/atlas-intellectual-property-mana...
# 2   Hicksville                       /organization/carsdirect-com
# 3       Draper                /organization/thomas-h-lee-partners
# 4          NaN  /organization/pogo-customer-service-number-1-8...
#
#                                        acquirer_name  \
# 0                                       Media Saturn
# 1         ATLAS Intellectual Property Management Co.
# 2                                     CarsDirect.com
# 3                             Thomas H. Lee Partners
# 4  Games Support +1-800-311-5934 Pogo Games techn...
#
#                               acquirer_category_list acquirer_country_code  \
# 0      Enterprise Software|Media|Sales and Marketing                   ESP
# 1          Finance|FinTech|Mobile|Telecommunications                   USA
# 2                                         E-Commerce                   USA
# 3  Business Development|Impact Investing|Investme...                   USA
# 4                                                NaN                   USA
#
#   acquirer_city acquired_at acquired_month  price_amount price_currency_code
# 0     Barcelona  2012-07-23        2012-07           NaN                 USD
# 1       Seattle  2012-02-02        2012-02     9000000.0                 USD
# 2    El Segundo  2005-06-12        2005-06           NaN                 USD
# 3        Boston  2014-01-07        2014-01           NaN                 USD
# 4    Mamaroneck  2001-02-02        2001-02           NaN                 USD

# %% [markdown]
# Now we'll count the frequency of appearance of acquirer names to determine which one of them is also an investor and compare it to the company names to figure out if the same companies are famous with investors too in this data set.

# %%
p.acquirer_name.value_counts()
# Out:
# Cisco                                    193
# Google                                   176
# Microsoft                                161
# IBM (International Business Machines)    138
# Yahoo!                                   118
#                                         ...
# Prime Active Capital                       1
# Wilcon                                     1
# Eco Green Auto Clean                       1
# Iotum                                      1
# 2000                                       1
# Name: acquirer_name, Length: 9475, dtype: int64

# %%
p.company_name.value_counts()
# Out:
# Unveil Technologies              6
# Ufree                            6
# California Apostille Services    5
# Travel Channel                   4
# Ziff Davis                       4
#                                 ..
# Focal Labs                       1
# Focus                            1
# Focus Group                      1
# Focus Systems                    1
# USA                              1
# Name: company_name, Length: 18503, dtype: int64

# %% [markdown]
# Shockingly, the first to top the list is Cisco unlike in the investor data set where Sequoia Capital tops the list. Also, it can be noticed that the companies which have had the most share acquisitions are Unveil Technologies and Ufree.

# %% [markdown]
# #### What can some of the null or missing values infer?

# %% [markdown]
# To do this we'll check the total missing values in the acquisitions data set.

# %%
p.isna().sum()
# Out:
# company_permalink             0
# company_name                  0
# company_category_list         0
# company_country_code          0
# company_city               4910
# acquirer_permalink            0
# acquirer_name                 0
# acquirer_category_list     2388
# acquirer_country_code      1170
# acquirer_city              1359
# acquired_at                  12
# acquired_month               14
# price_amount              13956
# price_currency_code           6
# dtype: int64

# %% [markdown]
# * The null values in the price_amount column may mean that the acquisition process have not being completed, was cancelled, or the files containing this information are not available.
#
# * Null in company_city may point out that either the location of the company is unexact or that the acquisition process was cancelled. The reverse may be true in case with the acquirer_city.
